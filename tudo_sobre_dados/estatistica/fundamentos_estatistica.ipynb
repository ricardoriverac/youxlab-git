# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics

# %% [markdown]
# # 1 medidas de posição

# %% [markdown]
# # Exemplo 1
#
# Vamos calcular a média de aluno na disciplina de matemática.
# #As notas do aluno foram: 7, 8, 6, 10.

# %%
nota = [7,8,6,10]
soma = sum(nota)
media = soma/len(nota)
print(f"a media do aluno e {media}")
# Out:
# a media do aluno e 7.75

# %% [markdown]
# # Exemplo 2
#
# Considere o índice de endividamento de um conjunto de empresas: 25%, 51%, 76%, 41%, 55%, 13%.

# %%
edividamento = [25,51,76,41,55,13]
def calcular_media(vetor):
    return sum(vetor)/len(vetor)
print(f"a media do edividamneto foi:{calcular_media(edividamento)}")
# Out:
# a media do edividamneto foi:43.5

# %% [markdown]
# # Exemplo 3
#
# Vamos supor que uma loja registrou o seguinte resultado quanto a venda de 4 produtos, em determinado dia:
# R$ 10, R$ 17, R$ 13, R$ 15.
# Calculemos a média.

# %%
vendas = [10, 17, 13, 15]
calcular_media(vendas)
# Out:
# 13.75

# %% [markdown]
# # Média aritmética ponderada
# Atribui pesos diferentes para cada elemento no conjunto de dados.

# %% [markdown]
# # Exemplo 4
#
# Considere um estudante que realizou o ENEM para tentar ingressar no curso de Ciência da Computação.
# O aluno obteve as seguintes notas (com os respectivos pesos de cada prova):
#
# Matemática e suas tecnologias: 718,91 (Peso 5);
#
# Ciências da natureza e suas tecnologias: 521,33 (Peso 2);

# %%
notas =  [ 718.91 , 521.33, 627.9, 610.12,930]
pesos =  [ 5, 2, 2, 4, 5]

# %%
np.average(notas,weights=pesos)
# Out:
# np.float64(721.305)

# %% [markdown]
# # Exemplo 5
#
#
# vamos calcular  a mediana da idade  de um conjunto de pessoas.Vamos considerar dois comjuntos

# %%
conjunto_A = [ 10,13,11,10,87]
conjunto_B = [ 23,31,17,18]

# %%
np.median(conjunto_A)
# Out:
# np.float64(11.0)

# %%
np.median(conjunto_B)
# Out:
# np.float64(20.5)

# %% [markdown]
# # Moda
# • Valor com maior frequência em um conjunto de dados.
# • Podemos ter as seguintes situações para um conjunto de dados: conjunto com uma única moda (unimodal), com duas modas (bimodal), várias modas (multimodal) ou nenhuma moda (amodal).

# %% [markdown]
# # Exemplo 6:
# Vamos calcular a moda para os conjuntos a seguir

# %%
a = [11, 2, 2, 9, 7]
b = [4, 4, 19]
c = [3, 3, 1, 9, 9]

# %%
statistics.mode(a)
# Out:
# 2

# %%
statistics.mode(b)
# Out:
# 4

# %%
statistics.multimode(c)
# Out:
# [3, 9]

# %% [markdown]
# # 2. Medidas de dispersão e associação
# • Objetivo: calcular o grau de dispersão de um conjunto de valores em torno da média.

# %% [markdown]
# # Amplitude
# • Diferença entre o maior e o menor valor de um conjunto de dados.

# %% [markdown]
# # Exemplo 7

# %%
B= [ 5,8,10,12,15]

# %%
np.var(B)
# Out:
# np.float64(11.6)
