# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
from os import path
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/trilha de dados igor/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *observação (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
# carregando o dataset corretamente
data = pd.read_csv('/content/drive/MyDrive/trilha de dados igor/GasPricesinBrazil_2004-2019.csv', sep=',')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                     0.012
# 1                      1.449                 0.399                     0.098
# 2                      1.760                 0.419                     0.070
# 3                      1.509                 0.432                     0.055
# 4                      1.400                 0.240                     0.066
# ...                      ...                   ...                       ...
# 103387                 3.690                 0.818                     0.018
# 103388                 3.789                 0.950                     0.038
# 103389                 3.499                 0.914                     0.065
# 103390                 3.490                 0.646                     0.076
# 103391                 3.699                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
# exibe as 10 primeiras linhas do dataframe
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
# 5                 0.426                     0.095                     0.957
# 6                 0.353                     0.150                     1.100
# 7                 0.515                     0.097                     1.116
# 8                 0.353                     0.101                     0.931
# 9                 0.277                     0.115                     0.947
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
# 5                       0.128                     0.5686
# 6                       0.068                     0.7332
# 7                       0.091                     0.9923
# 8                       0.072                     0.7577
# 9                       0.091                     0.5643
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
# 5                    1.35000                          0.134    5  2004
# 6                    1.29400                          0.062    5  2004
# 7                    1.36183                          0.082    5  2004
# 8                    1.29720                          0.077    5  2004
# 9                    1.35410                          0.096    5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     103392 non-null  int64
#  1   DATA INICIAL                   103392 non-null  object
#  2   DATA FINAL                     103392 non-null  object
#  3   REGIÃO                         103392 non-null  object
#  4   ESTADO                         103392 non-null  object
#  5   PRODUTO                        103392 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  7   UNIDADE DE MEDIDA              103392 non-null  object
#  8   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  9   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  12  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  13  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  19  MÊS                            103392 non-null  int64
#  20  ANO                            103392 non-null  int64
# dtypes: float64(11), int64(4), object(6)
# memory usage: 16.6+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.
#
# Além disso, note que alguns atributos/colunas, p. ex., 'PREÇO MÉDIO DISTRIBUIÇÃO', possui tipo de dado `object` ao invés de `float`. Esse `object`, no geral, representa strings. Isso parece estranho e suspeito. Veremos se isso é problemático mais pra frente.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (103392, 21)

# %%
print(f'O DataFrame possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atributos/variáveis.')
# Out:
# O DataFrame possui 103392 linhas/observações/registros e 21 colunas/atributos/variáveis.

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70.5, 15.2, 60.1],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O atributo `DataFrame.columns` retorna uma "lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(personagens_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df_renomeado = personagens_df.rename(columns={
    'nome': 'Nome Completo',  # renomeia a coluna de nome 'nome' para 'Nome Completo'
    'idade': 'Idade'
})

# %%
personagens_df_renomeado
# Out:
#     Nome Completo  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
personagens_df.rename(columns={'nome': 'Nome Completo','idade': 'Idade'}, inplace=True)

# %%
personagens_df
# Out:
#     Nome Completo  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as colunas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df.columns
# Out:
# Index(['Nome Completo', 'Idade', 'peso', 'eh jedi'], dtype='object')

# %%
personagens_df.columns = ['NOME', 'IDADE', 'PESO', 'EH_JEDI']

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  EH_JEDI
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  60.1    False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %%
# selecionando uma coluna inteira
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
# selecionando uma coluna inteira
# esta forma de acesso, só funciona para colunas com nomes sem espaços, acentos, etc (caracteres inválidos)
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
# selecionando a observação indexada no índice [1] do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5, 6.0, 9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5.5, 6.0, 9.5], index=['prova 1', 'prova 2', 'projeto'], name='Notas dos Luke Skywalker')
# Out:
# prova 1    5.5
# prova 2    6.0
# projeto    9.5
# Name: Notas dos Luke Skywalker, dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_view = data['PRODUTO']  # a series retornada refente à coluna, NÃO É UMA CÓPIA, mas sim, uma REFERÊNCIA/VIEW à coluna do dataframe
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 103387                 GNV
# 103388                 GNV
# 103389                 GNV
# 103390                 GNV
# 103391                 GNV
# Name: PRODUTO, Length: 103392, dtype: object

# %%
produto_copy_bkp = data['PRODUTO'].copy()  # retorna uma cópia da coluna 'PRODUTO'
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 103387                 GNV
# 103388                 GNV
# 103389                 GNV
# 103390                 GNV
# 103391                 GNV
# Name: PRODUTO, Length: 103392, dtype: object

# %%
data['PRODUTO'] = 'Combustível'  # atribuindo o valor constante 'Combustível' para linha do dataframe na coluna 'PRODUTO'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 103387                 GNV
# 103388                 GNV
# 103389                 GNV
# 103390                 GNV
# 103391                 GNV
# Name: PRODUTO, Length: 103392, dtype: object

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 103387                 GNV
# 103388                 GNV
# 103389                 GNV
# 103390                 GNV
# 103391                 GNV
# Name: PRODUTO, Length: 103392, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (103392, 21)

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 103392

# %%
# a quantidade de elementos da lista `novos_produtos` é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# 2               MATO GROSSO       Produto 2                           192
# 3        MATO GROSSO DO SUL       Produto 3                           162
# 4                   ALAGOAS       Produto 4                           103
# ...                     ...             ...                           ...
# 103387  RIO GRANDE DO NORTE  Produto 103387                             7
# 103388    RIO GRANDE DO SUL  Produto 103388                            23
# 103389       SANTA CATARINA  Produto 103389                            24
# 103390            SAO PAULO  Produto 103390                            52
# 103391              SERGIPE  Produto 103391                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                     0.012
# 1                      1.449                 0.399                     0.098
# 2                      1.760                 0.419                     0.070
# 3                      1.509                 0.432                     0.055
# 4                      1.400                 0.240                     0.066
# ...                      ...                   ...                       ...
# 103387                 3.690                 0.818                     0.018
# 103388                 3.789                 0.950                     0.038
# 103389                 3.499                 0.914                     0.065
# 103390                 3.490                 0.646                     0.076
# 103391                 3.699                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 21 columns]

# %%
print(produto_view)
print('\n')
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 103387                 GNV
# 103388                 GNV
# 103389                 GNV
# 103390                 GNV
# 103391                 GNV
# Name: PRODUTO, Length: 103392, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 103387                 GNV
# 103388                 GNV
# 103389                 GNV
# 103390                 GNV
# 103391                 GNV
# Name: PRODUTO, Length: 103392, dtype: object

# %%
# voltando para os produtos originais
data['PRODUTO'] = produto_copy_bkp  # produto_copy_bkp é uma Series

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                     0.012
# 1                      1.449                 0.399                     0.098
# 2                      1.760                 0.419                     0.070
# 3                      1.509                 0.432                     0.055
# 4                      1.400                 0.240                     0.066
# ...                      ...                   ...                       ...
# 103387                 3.690                 0.818                     0.018
# 103388                 3.789                 0.950                     0.038
# 103389                 3.499                 0.914                     0.065
# 103390                 3.490                 0.646                     0.076
# 103391                 3.699                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ ou uma constante a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# criando uma coluna a partir de um valor constante/default
# todas as linhas terão o mesmo valor para esta nova coluna
data['coluna sem nocao'] = 'DEFAULT'
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 103387                 0.818                     0.018
# 103388                 0.950                     0.038
# 103389                 0.914                     0.065
# 103390                 0.646                     0.076
# 103391                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 103387                          0.000    6  2019           DEFAULT
# 103388                          0.164    6  2019           DEFAULT
# 103389                          0.000    6  2019           DEFAULT
# 103390                          0.070    6  2019           DEFAULT
# 103391                          0.000    6  2019           DEFAULT
#
# [103392 rows x 22 columns]

# %%
data['coluna a partir de lista'] = range(data.shape[0])

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                     0.970
# 3                          0.055                     0.830
# 4                          0.066                     0.941
# ...                          ...                       ...
# 103387                     0.018                     2.756
# 103388                     0.038                     2.451
# 103389                     0.065                     1.998
# 103390                     0.076                     2.374
# 103391                     0.001                     2.518
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.110                     0.4201
# 1                            0.088                     0.5013
# 2                            0.095                     0.5614
# 3                            0.119                     0.5991
# 4                            0.077                     0.7441
# ...                            ...                        ...
# 103387                       0.000                     2.7560
# 103388                       0.402                     1.9842
# 103389                       0.000                     1.9981
# 103390                       0.165                     2.0179
# 103391                       0.000                     2.5175
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                         0.96660                          0.133    5  2004
# 1                         1.05000                          0.115    5  2004
# 2                         1.16100                          0.098    5  2004
# 3                         1.22242                          0.143    5  2004
# 4                         1.03170                          0.082    5  2004
# ...                           ...                            ...  ...   ...
# 103387                    2.75600                          0.000    6  2019
# 103388                    2.86610                          0.164    6  2019
# 103389                    1.99810                          0.000    6  2019
# 103390                    2.50930                          0.070    6  2019
# 103391                    2.51750                          0.000    6  2019
#
#         coluna sem nocao  coluna a partir de lista
# 0                DEFAULT                         0
# 1                DEFAULT                         1
# 2                DEFAULT                         2
# 3                DEFAULT                         3
# 4                DEFAULT                         4
# ...                  ...                       ...
# 103387           DEFAULT                    103387
# 103388           DEFAULT                    103388
# 103389           DEFAULT                    103389
# 103390           DEFAULT                    103390
# 103391           DEFAULT                    103391
#
# [103392 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
# não funciona pq a quantidade de elementos da lista (a serem atribuídos a nova coluna) é diferente
# da quantidade de linhas do dataframe
#data['nao funciona'] = [1, 2, 3]

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.110
# 1                     0.763                       0.088
# 2                     0.970                       0.095
# 3                     0.830                       0.119
# 4                     0.941                       0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.96660
# 1                     0.5013                    1.05000
# 2                     0.5614                    1.16100
# 3                     0.5991                    1.22242
# 4                     0.7441                    1.03170
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                          0.133    5  2004           DEFAULT
# 1                          0.115    5  2004           DEFAULT
# 2                          0.098    5  2004           DEFAULT
# 3                          0.143    5  2004           DEFAULT
# 4                          0.082    5  2004           DEFAULT
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 103387                          0.000    6  2019           DEFAULT
# 103388                          0.164    6  2019           DEFAULT
# 103389                          0.000    6  2019           DEFAULT
# 103390                          0.070    6  2019           DEFAULT
# 103391                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 103387                    103387                         21.444
# 103388                    103388                         20.406
# 103389                    103389                         17.472
# 103390                    103390                         18.120
# 103391                    103391                         22.182
#
# [103392 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço em real foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 103387                          0.000    6  2019           DEFAULT
# 103388                          0.164    6  2019           DEFAULT
# 103389                          0.000    6  2019           DEFAULT
# 103390                          0.070    6  2019           DEFAULT
# 103391                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 103387                    103387                         21.444
# 103388                    103388                         20.406
# 103389                    103389                         17.472
# 103390                    103390                         18.120
# 103391                    103391                         22.182
#
# [103392 rows x 24 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=103392, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais observações (Indexação)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                     0.970
# 3                1.262                  0.070  ...                     0.830
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0           DEFAULT                         0                          7.728
# 1           DEFAULT                         1                          6.972
# 2           DEFAULT                         2                          8.334
# 3           DEFAULT                         3                          7.572
# 4           DEFAULT                         4                          7.086
#
# [5 rows x 24 columns]

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma observação/linha:**

# %%
# selecionando a linha 1 => observação de índice [1] do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplas observações/linhas:**

# %%
# selecionando as linhas de índice de 0 a 5 (incluso)
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                     0.970
# 3                1.262                  0.070  ...                     0.830
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
# 5                       0.128                     0.5686
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
# 5                    1.35000                          0.134    5  2004
#
#    coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0           DEFAULT                         0                          7.728
# 1           DEFAULT                         1                          6.972
# 2           DEFAULT                         2                          8.334
# 3           DEFAULT                         3                          7.572
# 4           DEFAULT                         4                          7.086
# 5           DEFAULT                         5                          8.298
#
# [6 rows x 24 columns]

# %%
# selecionando as linhas de índice de 10 a 15 (incluso)
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                1.573                  0.134  ...                     1.079
# 11                1.276                  0.116  ...                     0.944
# 12                1.301                  0.109  ...                     0.980
# 13                1.805                  0.134  ...                     1.116
# 14                1.785                  0.035  ...                     1.373
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                     0.8857
# 11                       0.078                     0.7119
# 12                       0.052                     0.8267
# 13                       0.171                     0.7670
# 14                       0.167                     0.8339
# 15                       0.068                     0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 10                     1.2499                          0.072    5  2004
# 11                     1.1386                          0.083    5  2004
# 12                     1.1059                          0.053    5  2004
# 13                     1.2992                          0.153    5  2004
# 14                     1.4912                          0.122    5  2004
# 15                     1.2109                          0.060    5  2004
#
#     coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 10           DEFAULT                        10                          9.438
# 11           DEFAULT                        11                          7.656
# 12           DEFAULT                        12                          7.806
# 13           DEFAULT                        13                         10.830
# 14           DEFAULT                        14                         10.710
# 15           DEFAULT                        15                          9.468
#
# [6 rows x 24 columns]

# %%
# selecionando as linhas/observações de índice 1, 5, 10, 15
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                     0.5013
# 5                        0.128                     0.5686
# 10                       0.078                     0.8857
# 15                       0.068                     0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1                      1.0500                          0.115    5  2004
# 5                      1.3500                          0.134    5  2004
# 10                     1.2499                          0.072    5  2004
# 15                     1.2109                          0.060    5  2004
#
#     coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1            DEFAULT                         1                          6.972
# 5            DEFAULT                         5                          8.298
# 10           DEFAULT                        10                          9.438
# 15           DEFAULT                        15                          9.468
#
# [4 rows x 24 columns]

# %%
# selecionando as linhas/observações de índices 5, 1, 15, 10
data.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# 15                1.578                  0.123  ...                     1.137
# 10                1.573                  0.134  ...                     1.079
#
#     DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                     0.5686
# 1                        0.088                     0.5013
# 15                       0.068                     0.9515
# 10                       0.078                     0.8857
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 5                      1.3500                          0.134    5  2004
# 1                      1.0500                          0.115    5  2004
# 15                     1.2109                          0.060    5  2004
# 10                     1.2499                          0.072    5  2004
#
#     coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 5            DEFAULT                         5                          8.298
# 1            DEFAULT                         1                          6.972
# 15           DEFAULT                        15                          9.468
# 10           DEFAULT                        10                          9.438
#
# [4 rows x 24 columns]

# %%
# retornar o valor da linha de índice 1, coluna 4 ('ESTADO')
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
# e assim por diante

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna a linha de índice 0 (implícito)  ==> usando o iloc
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# retorna o valor da linha de índice 0 (implícito) e coluna de índice 1 (implícito)  ==> usando o iloc
pesquisa_de_satisfacao.iloc[0, 1]
# Out:
# np.int64(131)

# %%
# retorna a linha cujo o rótulo do índice é 'XboxOne'
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# NÃO FUNCIONA ===> iloc tentando acessar índices com rótulos
#pesquisa_de_satisfacao.iloc['XboxOne']

# %%
# NÃO FUNCIONA ===> loc tentando acessar índices rotulados com números
#pesquisa_de_satisfacao.loc[0]

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna o valor da linha 'Playstation4', coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# np.int64(2)

# %%
# selecionando as linhas de índices rotulados 'XboxOne', 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# #### OBSERVAÇÃO
# **Índices Númericos**, por default, possuem **rótulos que correspondem aos seus valores númericos.**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                     0.970
# 3                1.262                  0.070  ...                     0.830
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0           DEFAULT                         0                          7.728
# 1           DEFAULT                         1                          6.972
# 2           DEFAULT                         2                          8.334
# 3           DEFAULT                         3                          7.572
# 4           DEFAULT                         4                          7.086
#
# [5 rows x 24 columns]

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                     0.970
# 3                1.262                  0.070  ...                     0.830
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0           DEFAULT                         0                          7.728
# 1           DEFAULT                         1                          6.972
# 2           DEFAULT                         2                          8.334
# 3           DEFAULT                         3                          7.572
# 4           DEFAULT                         4                          7.086
#
# [5 rows x 24 columns]

# %%
# retornando a coluna/atributo 'ESTADO'
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
# a forma de acesso de colunas por .NOME_DA_COLUNA só funciona se
# NOME_DA_COLUNA não possuir caracteres inválidos (espaços, acentos, cedilha, ...)
### não funciona
# data.DATA INICIAL

# %%
# para colunas cujos rótulos possuem caracteres inválidos,
# apenas a seleção via string é válida
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 103387    2019-06-23
# 103388    2019-06-23
# 103389    2019-06-23
# 103390    2019-06-23
# 103391    2019-06-23
# Name: DATA INICIAL, Length: 103392, dtype: object

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %%
# selecionando múltiplas colunas: 'PRODUTO', 'ESTADO', 'REGIÃO'
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 103387               GNV  RIO GRANDE DO NORTE      NORDESTE
# 103388               GNV    RIO GRANDE DO SUL           SUL
# 103389               GNV       SANTA CATARINA           SUL
# 103390               GNV            SAO PAULO       SUDESTE
# 103391               GNV              SERGIPE      NORDESTE
#
# [103392 rows x 3 columns]

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                     0.970
# 3                1.262                  0.070  ...                     0.830
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0           DEFAULT                         0                          7.728
# 1           DEFAULT                         1                          6.972
# 2           DEFAULT                         2                          8.334
# 3           DEFAULT                         3                          7.572
# 4           DEFAULT                         4                          7.086
#
# [5 rows x 24 columns]

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
# deleta/remove in-place (no próprio dataframe) a coluna de rótulo 'Unnamed: 0'
#del data['Unnamed: 0']

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 103387                          0.000    6  2019           DEFAULT
# 103388                          0.164    6  2019           DEFAULT
# 103389                          0.000    6  2019           DEFAULT
# 103390                          0.070    6  2019           DEFAULT
# 103391                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 103387                    103387                         21.444
# 103388                    103388                         20.406
# 103389                    103389                         17.472
# 103390                    103390                         18.120
# 103391                    103391                         22.182
#
# [103392 rows x 24 columns]

# %% [markdown]
# <br>
#
# Vamos agora remover as colunas fictícias criadas nos vídeos.
# <br/>

# %%
del data['coluna sem nocao']
del data['coluna a partir de lista']
del data['PREÇO MÉDIO REVENDA (dólares)']

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
#data.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
#data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %%
# Mostra todos os estados cujos os preços dos combustíveis foram aferidos
# Mais tecnicamente, mostra os valores únicos presentes para o atributo/coluna 'ESTADO'.
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (observações) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
# faz uma comparação elemento a elemento da series, retornando uma Series de booleans
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103387    False
# 103388    False
# 103389    False
# 103390     True
# 103391    False
# Name: ESTADO, Length: 103392, dtype: bool

# %%
# salvando essa Series de booleans em uma variável
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103387    False
# 103388    False
# 103389    False
# 103390     True
# 103391    False
# Name: ESTADO, Length: 103392, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (103392,)

# %%
data.shape
# Out:
# (103392, 21)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 103296       ÓLEO DIESEL                           863              R$/l
# 103323   ÓLEO DIESEL S10                          1277              R$/l
# 103350    GASOLINA COMUM                          1644              R$/l
# 103377               GLP                          1017           R$/13Kg
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 23                    0.768                  0.085  ...                 1.150
# 50                    0.766                  0.083  ...                 1.150
# 77                    0.823                  0.071  ...                 1.199
# 104                   0.887                  0.075  ...                 1.359
# 131                   0.894                  0.071  ...                 1.199
# ...                     ...                    ...  ...                   ...
# 103296                3.448                  0.156  ...                 4.220
# 103323                3.574                  0.169  ...                 4.320
# 103350                4.142                  0.183  ...                 4.999
# 103377               66.893                  6.100  ...                89.900
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                     0.111
# 50                     0.190                     0.108
# 77                     0.209                     0.086
# 104                    0.216                     0.085
# 131                    0.205                     0.079
# ...                      ...                       ...
# 103296                 0.401                     0.045
# 103323                 0.451                     0.047
# 103350                 0.429                     0.044
# 103377                17.679                     0.091
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.570                       0.056
# 50                         0.576                       0.050
# 77                         0.614                       0.063
# 104                        0.671                       0.075
# 131                        0.689                       0.072
# ...                          ...                         ...
# 103296                     3.047                       0.097
# 103323                     3.123                       0.111
# 103350                     3.713                       0.097
# 103377                    49.214                       5.071
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.42710                     1.4123
# 50                        0.43204                     0.9724
# 77                        0.34951                     1.4120
# 104                       0.33980                     1.0669
# 131                       0.47797                     1.0669
# ...                           ...                        ...
# 103296                    2.85990                     3.3481
# 103323                    2.88500                     3.4910
# 103350                    3.52000                     4.0892
# 103377                   40.19000                    72.0000
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                              0.098    5  2004
# 50                              0.087    5  2004
# 77                              0.103    5  2004
# 104                             0.112    5  2004
# 131                             0.104    6  2004
# ...                               ...  ...   ...
# 103296                          0.032    6  2019
# 103323                          0.036    6  2019
# 103350                          0.026    6  2019
# 103377                          0.103    6  2019
# 103390                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 103296       ÓLEO DIESEL                           863              R$/l
# 103323   ÓLEO DIESEL S10                          1277              R$/l
# 103350    GASOLINA COMUM                          1644              R$/l
# 103377               GLP                          1017           R$/13Kg
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 23                    0.768                  0.085  ...                 1.150
# 50                    0.766                  0.083  ...                 1.150
# 77                    0.823                  0.071  ...                 1.199
# 104                   0.887                  0.075  ...                 1.359
# 131                   0.894                  0.071  ...                 1.199
# ...                     ...                    ...  ...                   ...
# 103296                3.448                  0.156  ...                 4.220
# 103323                3.574                  0.169  ...                 4.320
# 103350                4.142                  0.183  ...                 4.999
# 103377               66.893                  6.100  ...                89.900
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                     0.111
# 50                     0.190                     0.108
# 77                     0.209                     0.086
# 104                    0.216                     0.085
# 131                    0.205                     0.079
# ...                      ...                       ...
# 103296                 0.401                     0.045
# 103323                 0.451                     0.047
# 103350                 0.429                     0.044
# 103377                17.679                     0.091
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.570                       0.056
# 50                         0.576                       0.050
# 77                         0.614                       0.063
# 104                        0.671                       0.075
# 131                        0.689                       0.072
# ...                          ...                         ...
# 103296                     3.047                       0.097
# 103323                     3.123                       0.111
# 103350                     3.713                       0.097
# 103377                    49.214                       5.071
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.42710                     1.4123
# 50                        0.43204                     0.9724
# 77                        0.34951                     1.4120
# 104                       0.33980                     1.0669
# 131                       0.47797                     1.0669
# ...                           ...                        ...
# 103296                    2.85990                     3.3481
# 103323                    2.88500                     3.4910
# 103350                    3.52000                     4.0892
# 103377                   40.19000                    72.0000
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                              0.098    5  2004
# 50                              0.087    5  2004
# 77                              0.103    5  2004
# 104                             0.112    5  2004
# 131                             0.104    6  2004
# ...                               ...  ...   ...
# 103296                          0.032    6  2019
# 103323                          0.036    6  2019
# 103350                          0.026    6  2019
# 103377                          0.103    6  2019
# 103390                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %%
data.query('ESTADO == "SAO PAULO"')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 103296       ÓLEO DIESEL                           863              R$/l
# 103323   ÓLEO DIESEL S10                          1277              R$/l
# 103350    GASOLINA COMUM                          1644              R$/l
# 103377               GLP                          1017           R$/13Kg
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 23                    0.768                  0.085  ...                 1.150
# 50                    0.766                  0.083  ...                 1.150
# 77                    0.823                  0.071  ...                 1.199
# 104                   0.887                  0.075  ...                 1.359
# 131                   0.894                  0.071  ...                 1.199
# ...                     ...                    ...  ...                   ...
# 103296                3.448                  0.156  ...                 4.220
# 103323                3.574                  0.169  ...                 4.320
# 103350                4.142                  0.183  ...                 4.999
# 103377               66.893                  6.100  ...                89.900
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                     0.111
# 50                     0.190                     0.108
# 77                     0.209                     0.086
# 104                    0.216                     0.085
# 131                    0.205                     0.079
# ...                      ...                       ...
# 103296                 0.401                     0.045
# 103323                 0.451                     0.047
# 103350                 0.429                     0.044
# 103377                17.679                     0.091
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.570                       0.056
# 50                         0.576                       0.050
# 77                         0.614                       0.063
# 104                        0.671                       0.075
# 131                        0.689                       0.072
# ...                          ...                         ...
# 103296                     3.047                       0.097
# 103323                     3.123                       0.111
# 103350                     3.713                       0.097
# 103377                    49.214                       5.071
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.42710                     1.4123
# 50                        0.43204                     0.9724
# 77                        0.34951                     1.4120
# 104                       0.33980                     1.0669
# 131                       0.47797                     1.0669
# ...                           ...                        ...
# 103296                    2.85990                     3.3481
# 103323                    2.88500                     3.4910
# 103350                    3.52000                     4.0892
# 103377                   40.19000                    72.0000
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                              0.098    5  2004
# 50                              0.087    5  2004
# 77                              0.103    5  2004
# 104                             0.112    5  2004
# 131                             0.104    6  2004
# ...                               ...  ...   ...
# 103296                          0.032    6  2019
# 103323                          0.036    6  2019
# 103350                          0.026    6  2019
# 103377                          0.103    6  2019
# 103390                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análises feitas para os postos de São Paulo (neste caso).

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')

# %%
postos_sp
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 103296       ÓLEO DIESEL                           863              R$/l
# 103323   ÓLEO DIESEL S10                          1277              R$/l
# 103350    GASOLINA COMUM                          1644              R$/l
# 103377               GLP                          1017           R$/13Kg
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 23                    0.768                  0.085  ...                 1.150
# 50                    0.766                  0.083  ...                 1.150
# 77                    0.823                  0.071  ...                 1.199
# 104                   0.887                  0.075  ...                 1.359
# 131                   0.894                  0.071  ...                 1.199
# ...                     ...                    ...  ...                   ...
# 103296                3.448                  0.156  ...                 4.220
# 103323                3.574                  0.169  ...                 4.320
# 103350                4.142                  0.183  ...                 4.999
# 103377               66.893                  6.100  ...                89.900
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                     0.111
# 50                     0.190                     0.108
# 77                     0.209                     0.086
# 104                    0.216                     0.085
# 131                    0.205                     0.079
# ...                      ...                       ...
# 103296                 0.401                     0.045
# 103323                 0.451                     0.047
# 103350                 0.429                     0.044
# 103377                17.679                     0.091
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.570                       0.056
# 50                         0.576                       0.050
# 77                         0.614                       0.063
# 104                        0.671                       0.075
# 131                        0.689                       0.072
# ...                          ...                         ...
# 103296                     3.047                       0.097
# 103323                     3.123                       0.111
# 103350                     3.713                       0.097
# 103377                    49.214                       5.071
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.42710                     1.4123
# 50                        0.43204                     0.9724
# 77                        0.34951                     1.4120
# 104                       0.33980                     1.0669
# 131                       0.47797                     1.0669
# ...                           ...                        ...
# 103296                    2.85990                     3.3481
# 103323                    2.88500                     3.4910
# 103350                    3.52000                     4.0892
# 103377                   40.19000                    72.0000
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                              0.098    5  2004
# 50                              0.087    5  2004
# 77                              0.103    5  2004
# 104                             0.112    5  2004
# 131                             0.104    6  2004
# ...                               ...  ...   ...
# 103296                          0.032    6  2019
# 103323                          0.036    6  2019
# 103350                          0.026    6  2019
# 103377                          0.103    6  2019
# 103390                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4261, 21)

# %%
postos_sp
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 103296       ÓLEO DIESEL                           863              R$/l
# 103323   ÓLEO DIESEL S10                          1277              R$/l
# 103350    GASOLINA COMUM                          1644              R$/l
# 103377               GLP                          1017           R$/13Kg
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 23                    0.768                  0.085  ...                 1.150
# 50                    0.766                  0.083  ...                 1.150
# 77                    0.823                  0.071  ...                 1.199
# 104                   0.887                  0.075  ...                 1.359
# 131                   0.894                  0.071  ...                 1.199
# ...                     ...                    ...  ...                   ...
# 103296                3.448                  0.156  ...                 4.220
# 103323                3.574                  0.169  ...                 4.320
# 103350                4.142                  0.183  ...                 4.999
# 103377               66.893                  6.100  ...                89.900
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                     0.111
# 50                     0.190                     0.108
# 77                     0.209                     0.086
# 104                    0.216                     0.085
# 131                    0.205                     0.079
# ...                      ...                       ...
# 103296                 0.401                     0.045
# 103323                 0.451                     0.047
# 103350                 0.429                     0.044
# 103377                17.679                     0.091
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.570                       0.056
# 50                         0.576                       0.050
# 77                         0.614                       0.063
# 104                        0.671                       0.075
# 131                        0.689                       0.072
# ...                          ...                         ...
# 103296                     3.047                       0.097
# 103323                     3.123                       0.111
# 103350                     3.713                       0.097
# 103377                    49.214                       5.071
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.42710                     1.4123
# 50                        0.43204                     0.9724
# 77                        0.34951                     1.4120
# 104                       0.33980                     1.0669
# 131                       0.47797                     1.0669
# ...                           ...                        ...
# 103296                    2.85990                     3.3481
# 103323                    2.88500                     3.4910
# 103350                    3.52000                     4.0892
# 103377                   40.19000                    72.0000
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                              0.098    5  2004
# 50                              0.087    5  2004
# 77                              0.103    5  2004
# 104                             0.112    5  2004
# 131                             0.104    6  2004
# ...                               ...  ...   ...
# 103296                          0.032    6  2019
# 103323                          0.036    6  2019
# 103350                          0.026    6  2019
# 103377                          0.103    6  2019
# 103390                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %% [markdown]
# #### Resetando os índices

# %% [markdown]
# Note que os _índices das linhas/registros_ após a _filtragem_ **continuam sendo os mesmos** do DataFrame original. <br/>
# Em muitas situações, manter esta informação será importante.
#
# Mas, se você quiser **_resetar os índices_** do data frame filtrado, fazendo com que os registros começem com _índice 0 até num_linhas-1_, use o método `.reset_index`.

# %%
postos_sp.reset_index()
# Out:
#        index  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0         23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1         50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2         77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3        104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4        131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...      ...         ...          ...         ...      ...        ...
# 4256  103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4257  103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4258  103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259  103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260  103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4256       ÓLEO DIESEL                           863              R$/l
# 4257   ÓLEO DIESEL S10                          1277              R$/l
# 4258    GASOLINA COMUM                          1644              R$/l
# 4259               GLP                          1017           R$/13Kg
# 4260               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                   0.768  ...                 1.150                 0.198
# 1                   0.766  ...                 1.150                 0.190
# 2                   0.823  ...                 1.199                 0.209
# 3                   0.887  ...                 1.359                 0.216
# 4                   0.894  ...                 1.199                 0.205
# ...                   ...  ...                   ...                   ...
# 4256                3.448  ...                 4.220                 0.401
# 4257                3.574  ...                 4.320                 0.451
# 4258                4.142  ...                 4.999                 0.429
# 4259               66.893  ...                89.900                17.679
# 4260                3.020  ...                 3.490                 0.646
#
#       COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                        0.111                     0.570
# 1                        0.108                     0.576
# 2                        0.086                     0.614
# 3                        0.085                     0.671
# 4                        0.079                     0.689
# ...                        ...                       ...
# 4256                     0.045                     3.047
# 4257                     0.047                     3.123
# 4258                     0.044                     3.713
# 4259                     0.091                    49.214
# 4260                     0.076                     2.374
#
#       DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.42710
# 1                          0.050                    0.43204
# 2                          0.063                    0.34951
# 3                          0.075                    0.33980
# 4                          0.072                    0.47797
# ...                          ...                        ...
# 4256                       0.097                    2.85990
# 4257                       0.111                    2.88500
# 4258                       0.097                    3.52000
# 4259                       5.071                   40.19000
# 4260                       0.165                    2.01790
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                        1.4123                          0.098    5  2004
# 1                        0.9724                          0.087    5  2004
# 2                        1.4120                          0.103    5  2004
# 3                        1.0669                          0.112    5  2004
# 4                        1.0669                          0.104    6  2004
# ...                         ...                            ...  ...   ...
# 4256                     3.3481                          0.032    6  2019
# 4257                     3.4910                          0.036    6  2019
# 4258                     4.0892                          0.026    6  2019
# 4259                    72.0000                          0.103    6  2019
# 4260                     2.5093                          0.070    6  2019
#
# [4261 rows x 22 columns]

# %%
postos_sp.reset_index(drop=True)
# Out:
#       Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0             23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1             50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2             77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...          ...          ...         ...      ...        ...
# 4256      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4257      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4258      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4256       ÓLEO DIESEL                           863              R$/l
# 4257   ÓLEO DIESEL S10                          1277              R$/l
# 4258    GASOLINA COMUM                          1644              R$/l
# 4259               GLP                          1017           R$/13Kg
# 4260               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   0.768                  0.085  ...                 1.150
# 1                   0.766                  0.083  ...                 1.150
# 2                   0.823                  0.071  ...                 1.199
# 3                   0.887                  0.075  ...                 1.359
# 4                   0.894                  0.071  ...                 1.199
# ...                   ...                    ...  ...                   ...
# 4256                3.448                  0.156  ...                 4.220
# 4257                3.574                  0.169  ...                 4.320
# 4258                4.142                  0.183  ...                 4.999
# 4259               66.893                  6.100  ...                89.900
# 4260                3.020                  0.229  ...                 3.490
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                    0.198                     0.111
# 1                    0.190                     0.108
# 2                    0.209                     0.086
# 3                    0.216                     0.085
# 4                    0.205                     0.079
# ...                    ...                       ...
# 4256                 0.401                     0.045
# 4257                 0.451                     0.047
# 4258                 0.429                     0.044
# 4259                17.679                     0.091
# 4260                 0.646                     0.076
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                        0.570                       0.056
# 1                        0.576                       0.050
# 2                        0.614                       0.063
# 3                        0.671                       0.075
# 4                        0.689                       0.072
# ...                        ...                         ...
# 4256                     3.047                       0.097
# 4257                     3.123                       0.111
# 4258                     3.713                       0.097
# 4259                    49.214                       5.071
# 4260                     2.374                       0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                       0.42710                     1.4123
# 1                       0.43204                     0.9724
# 2                       0.34951                     1.4120
# 3                       0.33980                     1.0669
# 4                       0.47797                     1.0669
# ...                         ...                        ...
# 4256                    2.85990                     3.3481
# 4257                    2.88500                     3.4910
# 4258                    3.52000                     4.0892
# 4259                   40.19000                    72.0000
# 4260                    2.01790                     2.5093
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                             0.098    5  2004
# 1                             0.087    5  2004
# 2                             0.103    5  2004
# 3                             0.112    5  2004
# 4                             0.104    6  2004
# ...                             ...  ...   ...
# 4256                          0.032    6  2019
# 4257                          0.036    6  2019
# 4258                          0.026    6  2019
# 4259                          0.103    6  2019
# 4260                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %%
# ainda não foi alterado, precisamos usar o atributo/parâmetro inplace=True
postos_sp
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23              23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50              50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77              77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 103296      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103323      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 103296       ÓLEO DIESEL                           863              R$/l
# 103323   ÓLEO DIESEL S10                          1277              R$/l
# 103350    GASOLINA COMUM                          1644              R$/l
# 103377               GLP                          1017           R$/13Kg
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 23                    0.768                  0.085  ...                 1.150
# 50                    0.766                  0.083  ...                 1.150
# 77                    0.823                  0.071  ...                 1.199
# 104                   0.887                  0.075  ...                 1.359
# 131                   0.894                  0.071  ...                 1.199
# ...                     ...                    ...  ...                   ...
# 103296                3.448                  0.156  ...                 4.220
# 103323                3.574                  0.169  ...                 4.320
# 103350                4.142                  0.183  ...                 4.999
# 103377               66.893                  6.100  ...                89.900
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                     0.198                     0.111
# 50                     0.190                     0.108
# 77                     0.209                     0.086
# 104                    0.216                     0.085
# 131                    0.205                     0.079
# ...                      ...                       ...
# 103296                 0.401                     0.045
# 103323                 0.451                     0.047
# 103350                 0.429                     0.044
# 103377                17.679                     0.091
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.570                       0.056
# 50                         0.576                       0.050
# 77                         0.614                       0.063
# 104                        0.671                       0.075
# 131                        0.689                       0.072
# ...                          ...                         ...
# 103296                     3.047                       0.097
# 103323                     3.123                       0.111
# 103350                     3.713                       0.097
# 103377                    49.214                       5.071
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.42710                     1.4123
# 50                        0.43204                     0.9724
# 77                        0.34951                     1.4120
# 104                       0.33980                     1.0669
# 131                       0.47797                     1.0669
# ...                           ...                        ...
# 103296                    2.85990                     3.3481
# 103323                    2.88500                     3.4910
# 103350                    3.52000                     4.0892
# 103377                   40.19000                    72.0000
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                              0.098    5  2004
# 50                              0.087    5  2004
# 77                              0.103    5  2004
# 104                             0.112    5  2004
# 131                             0.104    6  2004
# ...                               ...  ...   ...
# 103296                          0.032    6  2019
# 103323                          0.036    6  2019
# 103350                          0.026    6  2019
# 103377                          0.103    6  2019
# 103390                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %%
postos_sp.reset_index(drop=True, inplace=True)

# %%
postos_sp
# Out:
#       Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0             23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1             50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2             77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...          ...          ...         ...      ...        ...
# 4256      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4257      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4258      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4256       ÓLEO DIESEL                           863              R$/l
# 4257   ÓLEO DIESEL S10                          1277              R$/l
# 4258    GASOLINA COMUM                          1644              R$/l
# 4259               GLP                          1017           R$/13Kg
# 4260               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   0.768                  0.085  ...                 1.150
# 1                   0.766                  0.083  ...                 1.150
# 2                   0.823                  0.071  ...                 1.199
# 3                   0.887                  0.075  ...                 1.359
# 4                   0.894                  0.071  ...                 1.199
# ...                   ...                    ...  ...                   ...
# 4256                3.448                  0.156  ...                 4.220
# 4257                3.574                  0.169  ...                 4.320
# 4258                4.142                  0.183  ...                 4.999
# 4259               66.893                  6.100  ...                89.900
# 4260                3.020                  0.229  ...                 3.490
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                    0.198                     0.111
# 1                    0.190                     0.108
# 2                    0.209                     0.086
# 3                    0.216                     0.085
# 4                    0.205                     0.079
# ...                    ...                       ...
# 4256                 0.401                     0.045
# 4257                 0.451                     0.047
# 4258                 0.429                     0.044
# 4259                17.679                     0.091
# 4260                 0.646                     0.076
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                        0.570                       0.056
# 1                        0.576                       0.050
# 2                        0.614                       0.063
# 3                        0.671                       0.075
# 4                        0.689                       0.072
# ...                        ...                         ...
# 4256                     3.047                       0.097
# 4257                     3.123                       0.111
# 4258                     3.713                       0.097
# 4259                    49.214                       5.071
# 4260                     2.374                       0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                       0.42710                     1.4123
# 1                       0.43204                     0.9724
# 2                       0.34951                     1.4120
# 3                       0.33980                     1.0669
# 4                       0.47797                     1.0669
# ...                         ...                        ...
# 4256                    2.85990                     3.3481
# 4257                    2.88500                     3.4910
# 4258                    3.52000                     4.0892
# 4259                   40.19000                    72.0000
# 4260                    2.01790                     2.5093
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                             0.098    5  2004
# 1                             0.087    5  2004
# 2                             0.103    5  2004
# 3                             0.112    5  2004
# 4                             0.104    6  2004
# ...                             ...  ...   ...
# 4256                          0.032    6  2019
# 4257                          0.036    6  2019
# 4258                          0.026    6  2019
# 4259                          0.103    6  2019
# 4260                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %%
# ALTERNATIVA MUITO COMUM
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)

# %%
postos_sp
# Out:
#       Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0             23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1             50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2             77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...          ...          ...         ...      ...        ...
# 4256      103296   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4257      103323   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4258      103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259      103377   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260      103390   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4256       ÓLEO DIESEL                           863              R$/l
# 4257   ÓLEO DIESEL S10                          1277              R$/l
# 4258    GASOLINA COMUM                          1644              R$/l
# 4259               GLP                          1017           R$/13Kg
# 4260               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   0.768                  0.085  ...                 1.150
# 1                   0.766                  0.083  ...                 1.150
# 2                   0.823                  0.071  ...                 1.199
# 3                   0.887                  0.075  ...                 1.359
# 4                   0.894                  0.071  ...                 1.199
# ...                   ...                    ...  ...                   ...
# 4256                3.448                  0.156  ...                 4.220
# 4257                3.574                  0.169  ...                 4.320
# 4258                4.142                  0.183  ...                 4.999
# 4259               66.893                  6.100  ...                89.900
# 4260                3.020                  0.229  ...                 3.490
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                    0.198                     0.111
# 1                    0.190                     0.108
# 2                    0.209                     0.086
# 3                    0.216                     0.085
# 4                    0.205                     0.079
# ...                    ...                       ...
# 4256                 0.401                     0.045
# 4257                 0.451                     0.047
# 4258                 0.429                     0.044
# 4259                17.679                     0.091
# 4260                 0.646                     0.076
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                        0.570                       0.056
# 1                        0.576                       0.050
# 2                        0.614                       0.063
# 3                        0.671                       0.075
# 4                        0.689                       0.072
# ...                        ...                         ...
# 4256                     3.047                       0.097
# 4257                     3.123                       0.111
# 4258                     3.713                       0.097
# 4259                    49.214                       5.071
# 4260                     2.374                       0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                       0.42710                     1.4123
# 1                       0.43204                     0.9724
# 2                       0.34951                     1.4120
# 3                       0.33980                     1.0669
# 4                       0.47797                     1.0669
# ...                         ...                        ...
# 4256                    2.85990                     3.3481
# 4257                    2.88500                     3.4910
# 4258                    3.52000                     4.0892
# 4259                   40.19000                    72.0000
# 4260                    2.01790                     2.5093
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                             0.098    5  2004
# 1                             0.087    5  2004
# 2                             0.103    5  2004
# 3                             0.112    5  2004
# 4                             0.104    6  2004
# ...                             ...  ...   ...
# 4256                          0.032    6  2019
# 4257                          0.036    6  2019
# 4258                          0.026    6  2019
# 4259                          0.103    6  2019
# 4260                          0.070    6  2019
#
# [4261 rows x 21 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103387    False
# 103388    False
# 103389    False
# 103390    False
# 103391    False
# Name: ESTADO, Length: 103392, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103387     True
# 103388     True
# 103389     True
# 103390     True
# 103391     True
# Name: PREÇO MÉDIO REVENDA, Length: 103392, dtype: bool

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103387    False
# 103388    False
# 103389    False
# 103390    False
# 103391    False
# Length: 103392, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/observações do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro **E** o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 2497          2497   2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO
# 2524          2524   2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO
# 2551          2551   2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO
# 2578          2578   2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO
# 2605          2605   2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103290      103290   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103317      103317   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103344      103344   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103371      103371   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103386      103386   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 2497    ETANOL HIDRATADO                           881              R$/l
# 2524    ETANOL HIDRATADO                           889              R$/l
# 2551    ETANOL HIDRATADO                           902              R$/l
# 2578    ETANOL HIDRATADO                           898              R$/l
# 2605    ETANOL HIDRATADO                           890              R$/l
# ...                  ...                           ...               ...
# 103290       ÓLEO DIESEL                           212              R$/l
# 103317   ÓLEO DIESEL S10                           335              R$/l
# 103344    GASOLINA COMUM                           422              R$/l
# 103371               GLP                           221           R$/13Kg
# 103386               GNV                           124             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 2497                  2.028                  0.148  ...                 2.550
# 2524                  2.125                  0.149  ...                 2.550
# 2551                  2.163                  0.138  ...                 2.599
# 2578                  2.166                  0.146  ...                 2.568
# 2605                  2.172                  0.143  ...                 2.550
# ...                     ...                    ...  ...                   ...
# 103290                3.569                  0.166  ...                 4.059
# 103317                3.697                  0.187  ...                 4.389
# 103344                4.928                  0.165  ...                 5.859
# 103371               65.010                  5.812  ...                79.000
# 103386                3.111                  0.260  ...                 3.799
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2497                   0.222                     0.073
# 2524                   0.286                     0.070
# 2551                   0.268                     0.064
# 2578                   0.231                     0.067
# 2605                   0.209                     0.066
# ...                      ...                       ...
# 103290                 0.467                     0.047
# 103317                 0.500                     0.051
# 103344                 0.538                     0.033
# 103371                17.475                     0.089
# 103386                 0.707                     0.084
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2497                       1.806                       0.110
# 2524                       1.839                       0.117
# 2551                       1.895                       0.134
# 2578                       1.935                       0.140
# 2605                       1.963                       0.133
# ...                          ...                         ...
# 103290                     3.102                       0.119
# 103317                     3.197                       0.127
# 103344                     4.390                       0.097
# 103371                    47.535                       3.934
# 103386                     2.404                       0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2497                       1.3100                     2.1358
# 2524                       1.4380                     2.2801
# 2551                       1.4300                     2.3454
# 2578                       1.4380                     2.2925
# 2605                       1.4380                     2.2513
# ...                           ...                        ...
# 103290                     2.8860                     3.5162
# 103317                     2.9772                     3.5388
# 103344                     4.2000                     4.6180
# 103371                    39.0000                    58.2000
# 103386                     2.1260                     2.7909
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 2497                            0.061    2  2006
# 2524                            0.064    3  2006
# 2551                            0.071    3  2006
# 2578                            0.072    3  2006
# 2605                            0.068    3  2006
# ...                               ...  ...   ...
# 103290                          0.038    6  2019
# 103317                          0.040    6  2019
# 103344                          0.022    6  2019
# 103371                          0.083    6  2019
# 103386                          0.072    6  2019
#
# [3053 rows x 21 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
data.query('ESTADO == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 22              22   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 23              23   2004-05-09  2004-05-15  SUDESTE       SAO PAULO
# 49              49   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 50              50   2004-05-16  2004-05-22  SUDESTE       SAO PAULO
# 76              76   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103350      103350   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
# 103371      103371   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
# 103386      103386   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 22      ETANOL HIDRATADO                           952              R$/l
# 23      ETANOL HIDRATADO                          4047              R$/l
# 49      ETANOL HIDRATADO                           948              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 76      ETANOL HIDRATADO                           973              R$/l
# ...                  ...                           ...               ...
# 103350    GASOLINA COMUM                          1644              R$/l
# 103371               GLP                           221           R$/13Kg
# 103377               GLP                          1017           R$/13Kg
# 103386               GNV                           124             R$/m3
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 22                    1.098                  0.154  ...                 1.890
# 23                    0.768                  0.085  ...                 1.150
# 49                    1.092                  0.157  ...                 1.499
# 50                    0.766                  0.083  ...                 1.150
# 76                    1.103                  0.140  ...                 1.589
# ...                     ...                    ...  ...                   ...
# 103350                4.142                  0.183  ...                 4.999
# 103371               65.010                  5.812  ...                79.000
# 103377               66.893                  6.100  ...                89.900
# 103386                3.111                  0.260  ...                 3.799
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                     0.140
# 23                     0.198                     0.111
# 49                     0.284                     0.144
# 50                     0.190                     0.108
# 76                     0.281                     0.127
# ...                      ...                       ...
# 103350                 0.429                     0.044
# 103371                17.475                     0.089
# 103377                17.679                     0.091
# 103386                 0.707                     0.084
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                       0.173
# 23                         0.570                       0.056
# 49                         0.808                       0.175
# 50                         0.576                       0.050
# 76                         0.822                       0.166
# ...                          ...                         ...
# 103350                     3.713                       0.097
# 103371                    47.535                       3.934
# 103377                    49.214                       5.071
# 103386                     2.404                       0.174
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                        0.32600                     1.2630
# 23                        0.42710                     1.4123
# 49                        0.32570                     1.2921
# 50                        0.43204                     0.9724
# 76                        0.38909                     1.1859
# ...                           ...                        ...
# 103350                    3.52000                     4.0892
# 103371                   39.00000                    58.2000
# 103377                   40.19000                    72.0000
# 103386                    2.12600                     2.7909
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 22                              0.220    5  2004
# 23                              0.098    5  2004
# 49                              0.217    5  2004
# 50                              0.087    5  2004
# 76                              0.202    5  2004
# ...                               ...  ...   ...
# 103350                          0.026    6  2019
# 103371                          0.083    6  2019
# 103377                          0.103    6  2019
# 103386                          0.072    6  2019
# 103390                          0.070    6  2019
#
# [8523 rows x 21 columns]

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (observação a observação) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (observação a observação) do DataFrame, quais são os registros cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, se tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 22              22   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 49              49   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 76              76   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# 103            103   2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO
# 130            130   2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103290      103290   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103317      103317   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103344      103344   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103371      103371   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103386      103386   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 22      ETANOL HIDRATADO                           952              R$/l
# 49      ETANOL HIDRATADO                           948              R$/l
# 76      ETANOL HIDRATADO                           973              R$/l
# 103     ETANOL HIDRATADO                           955              R$/l
# 130     ETANOL HIDRATADO                           966              R$/l
# ...                  ...                           ...               ...
# 103290       ÓLEO DIESEL                           212              R$/l
# 103317   ÓLEO DIESEL S10                           335              R$/l
# 103344    GASOLINA COMUM                           422              R$/l
# 103371               GLP                           221           R$/13Kg
# 103386               GNV                           124             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 22                    1.098                  0.154  ...                 1.890
# 49                    1.092                  0.157  ...                 1.499
# 76                    1.103                  0.140  ...                 1.589
# 103                   1.149                  0.156  ...                 1.599
# 130                   1.165                  0.154  ...                 1.599
# ...                     ...                    ...  ...                   ...
# 103290                3.569                  0.166  ...                 4.059
# 103317                3.697                  0.187  ...                 4.389
# 103344                4.928                  0.165  ...                 5.859
# 103371               65.010                  5.812  ...                79.000
# 103386                3.111                  0.260  ...                 3.799
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                     0.140
# 49                     0.284                     0.144
# 76                     0.281                     0.127
# 103                    0.300                     0.136
# 130                    0.254                     0.132
# ...                      ...                       ...
# 103290                 0.467                     0.047
# 103317                 0.500                     0.051
# 103344                 0.538                     0.033
# 103371                17.475                     0.089
# 103386                 0.707                     0.084
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                       0.173
# 49                         0.808                       0.175
# 76                         0.822                       0.166
# 103                        0.849                       0.188
# 130                        0.911                       0.198
# ...                          ...                         ...
# 103290                     3.102                       0.119
# 103317                     3.197                       0.127
# 103344                     4.390                       0.097
# 103371                    47.535                       3.934
# 103386                     2.404                       0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                        0.32600                     1.2630
# 49                        0.32570                     1.2921
# 76                        0.38909                     1.1859
# 103                       0.34530                     1.3667
# 130                       0.40000                     1.3667
# ...                           ...                        ...
# 103290                    2.88600                     3.5162
# 103317                    2.97720                     3.5388
# 103344                    4.20000                     4.6180
# 103371                   39.00000                    58.2000
# 103386                    2.12600                     2.7909
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 22                              0.220    5  2004
# 49                              0.217    5  2004
# 76                              0.202    5  2004
# 103                             0.221    5  2004
# 130                             0.217    6  2004
# ...                               ...  ...   ...
# 103290                          0.038    6  2019
# 103317                          0.040    6  2019
# 103344                          0.022    6  2019
# 103371                          0.083    6  2019
# 103386                          0.072    6  2019
#
# [4262 rows x 21 columns]

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 103290     True
# 103317     True
# 103344     True
# 103371     True
# 103386     True
# Name: PREÇO MÉDIO REVENDA, Length: 4262, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 2497          2497   2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO
# 2524          2524   2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO
# 2551          2551   2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO
# 2578          2578   2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO
# 2605          2605   2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103290      103290   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103317      103317   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103344      103344   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103371      103371   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103386      103386   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 2497    ETANOL HIDRATADO                           881              R$/l
# 2524    ETANOL HIDRATADO                           889              R$/l
# 2551    ETANOL HIDRATADO                           902              R$/l
# 2578    ETANOL HIDRATADO                           898              R$/l
# 2605    ETANOL HIDRATADO                           890              R$/l
# ...                  ...                           ...               ...
# 103290       ÓLEO DIESEL                           212              R$/l
# 103317   ÓLEO DIESEL S10                           335              R$/l
# 103344    GASOLINA COMUM                           422              R$/l
# 103371               GLP                           221           R$/13Kg
# 103386               GNV                           124             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 2497                  2.028                  0.148  ...                 2.550
# 2524                  2.125                  0.149  ...                 2.550
# 2551                  2.163                  0.138  ...                 2.599
# 2578                  2.166                  0.146  ...                 2.568
# 2605                  2.172                  0.143  ...                 2.550
# ...                     ...                    ...  ...                   ...
# 103290                3.569                  0.166  ...                 4.059
# 103317                3.697                  0.187  ...                 4.389
# 103344                4.928                  0.165  ...                 5.859
# 103371               65.010                  5.812  ...                79.000
# 103386                3.111                  0.260  ...                 3.799
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2497                   0.222                     0.073
# 2524                   0.286                     0.070
# 2551                   0.268                     0.064
# 2578                   0.231                     0.067
# 2605                   0.209                     0.066
# ...                      ...                       ...
# 103290                 0.467                     0.047
# 103317                 0.500                     0.051
# 103344                 0.538                     0.033
# 103371                17.475                     0.089
# 103386                 0.707                     0.084
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2497                       1.806                       0.110
# 2524                       1.839                       0.117
# 2551                       1.895                       0.134
# 2578                       1.935                       0.140
# 2605                       1.963                       0.133
# ...                          ...                         ...
# 103290                     3.102                       0.119
# 103317                     3.197                       0.127
# 103344                     4.390                       0.097
# 103371                    47.535                       3.934
# 103386                     2.404                       0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2497                       1.3100                     2.1358
# 2524                       1.4380                     2.2801
# 2551                       1.4300                     2.3454
# 2578                       1.4380                     2.2925
# 2605                       1.4380                     2.2513
# ...                           ...                        ...
# 103290                     2.8860                     3.5162
# 103317                     2.9772                     3.5388
# 103344                     4.2000                     4.6180
# 103371                    39.0000                    58.2000
# 103386                     2.1260                     2.7909
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 2497                            0.061    2  2006
# 2524                            0.064    3  2006
# 2551                            0.071    3  2006
# 2578                            0.072    3  2006
# 2605                            0.068    3  2006
# ...                               ...  ...   ...
# 103290                          0.038    6  2019
# 103317                          0.040    6  2019
# 103344                          0.022    6  2019
# 103371                          0.083    6  2019
# 103386                          0.072    6  2019
#
# [3053 rows x 21 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)

selecao_final = selecao_1 & selecao_2 & selecao_3

# %%
selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103387    False
# 103388    False
# 103389    False
# 103390    False
# 103391    False
# Length: 103392, dtype: bool

# %%
data_filtrado = data[selecao_final]
data_filtrado
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 12002        12002   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 12029        12029   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 12056        12056   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# 12083        12083   2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO
# 12110        12110   2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103058      103058   2019-06-09  2019-06-15  SUDESTE       SAO PAULO
# 103198      103198   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO
# 103204      103204   2019-06-16  2019-06-22  SUDESTE       SAO PAULO
# 103344      103344   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12002   GASOLINA COMUM                          1071              R$/l
# 12029   GASOLINA COMUM                          1055              R$/l
# 12056   GASOLINA COMUM                          1091              R$/l
# 12083   GASOLINA COMUM                          1055              R$/l
# 12110   GASOLINA COMUM                          1091              R$/l
# ...                ...                           ...               ...
# 103058  GASOLINA COMUM                          1643              R$/l
# 103198  GASOLINA COMUM                           418              R$/l
# 103204  GASOLINA COMUM                          1635              R$/l
# 103344  GASOLINA COMUM                           422              R$/l
# 103350  GASOLINA COMUM                          1644              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 12002                 2.045                  0.109  ...                 2.599
# 12029                 2.040                  0.113  ...                 2.599
# 12056                 2.042                  0.108  ...                 2.599
# 12083                 2.053                  0.111  ...                 2.599
# 12110                 2.063                  0.107  ...                 2.599
# ...                     ...                    ...  ...                   ...
# 103058                4.210                  0.177  ...                 4.992
# 103198                4.927                  0.160  ...                 5.859
# 103204                4.168                  0.177  ...                 5.199
# 103344                4.928                  0.165  ...                 5.859
# 103350                4.142                  0.183  ...                 4.999
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12002                  0.254                     0.053
# 12029                  0.252                     0.055
# 12056                  0.252                     0.053
# 12083                  0.251                     0.054
# 12110                  0.247                     0.052
# ...                      ...                       ...
# 103058                 0.425                     0.042
# 103198                 0.544                     0.032
# 103204                 0.443                     0.042
# 103344                 0.538                     0.033
# 103350                 0.429                     0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12002                      1.791                       0.047
# 12029                      1.788                       0.049
# 12056                      1.790                       0.046
# 12083                      1.802                       0.055
# 12110                      1.816                       0.054
# ...                          ...                         ...
# 103058                     3.785                       0.096
# 103198                     4.383                       0.100
# 103204                     3.725                       0.096
# 103344                     4.390                       0.097
# 103350                     3.713                       0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12002                     1.63630                    1.95940
# 12029                     1.59430                    1.99651
# 12056                     1.63596                    2.21370
# 12083                     1.64000                    2.21425
# 12110                     1.64000                    2.32425
# ...                           ...                        ...
# 103058                    3.52000                    4.10070
# 103198                    4.19720                    4.62390
# 103204                    3.50200                    4.08920
# 103344                    4.20000                    4.61800
# 103350                    3.52000                    4.08920
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 12002                           0.026    5  2004
# 12029                           0.027    5  2004
# 12056                           0.026    5  2004
# 12083                           0.031    5  2004
# 12110                           0.030    6  2004
# ...                               ...  ...   ...
# 103058                          0.025    6  2019
# 103198                          0.023    6  2019
# 103204                          0.026    6  2019
# 103344                          0.022    6  2019
# 103350                          0.026    6  2019
#
# [1564 rows x 21 columns]

# %%
print(data_filtrado['ESTADO'].unique())
print(data_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao_1]

# apenas registros de postos dos estados de SP e RJ
postos_sp_rj
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 22              22   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 23              23   2004-05-09  2004-05-15  SUDESTE       SAO PAULO
# 49              49   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 50              50   2004-05-16  2004-05-22  SUDESTE       SAO PAULO
# 76              76   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103350      103350   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
# 103371      103371   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103377      103377   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
# 103386      103386   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103390      103390   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 22      ETANOL HIDRATADO                           952              R$/l
# 23      ETANOL HIDRATADO                          4047              R$/l
# 49      ETANOL HIDRATADO                           948              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 76      ETANOL HIDRATADO                           973              R$/l
# ...                  ...                           ...               ...
# 103350    GASOLINA COMUM                          1644              R$/l
# 103371               GLP                           221           R$/13Kg
# 103377               GLP                          1017           R$/13Kg
# 103386               GNV                           124             R$/m3
# 103390               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 22                    1.098                  0.154  ...                 1.890
# 23                    0.768                  0.085  ...                 1.150
# 49                    1.092                  0.157  ...                 1.499
# 50                    0.766                  0.083  ...                 1.150
# 76                    1.103                  0.140  ...                 1.589
# ...                     ...                    ...  ...                   ...
# 103350                4.142                  0.183  ...                 4.999
# 103371               65.010                  5.812  ...                79.000
# 103377               66.893                  6.100  ...                89.900
# 103386                3.111                  0.260  ...                 3.799
# 103390                3.020                  0.229  ...                 3.490
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                     0.140
# 23                     0.198                     0.111
# 49                     0.284                     0.144
# 50                     0.190                     0.108
# 76                     0.281                     0.127
# ...                      ...                       ...
# 103350                 0.429                     0.044
# 103371                17.475                     0.089
# 103377                17.679                     0.091
# 103386                 0.707                     0.084
# 103390                 0.646                     0.076
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                       0.173
# 23                         0.570                       0.056
# 49                         0.808                       0.175
# 50                         0.576                       0.050
# 76                         0.822                       0.166
# ...                          ...                         ...
# 103350                     3.713                       0.097
# 103371                    47.535                       3.934
# 103377                    49.214                       5.071
# 103386                     2.404                       0.174
# 103390                     2.374                       0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                        0.32600                     1.2630
# 23                        0.42710                     1.4123
# 49                        0.32570                     1.2921
# 50                        0.43204                     0.9724
# 76                        0.38909                     1.1859
# ...                           ...                        ...
# 103350                    3.52000                     4.0892
# 103371                   39.00000                    58.2000
# 103377                   40.19000                    72.0000
# 103386                    2.12600                     2.7909
# 103390                    2.01790                     2.5093
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 22                              0.220    5  2004
# 23                              0.098    5  2004
# 49                              0.217    5  2004
# 50                              0.087    5  2004
# 76                              0.202    5  2004
# ...                               ...  ...   ...
# 103350                          0.026    6  2019
# 103371                          0.083    6  2019
# 103377                          0.103    6  2019
# 103386                          0.072    6  2019
# 103390                          0.070    6  2019
#
# [8523 rows x 21 columns]

# %%
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]

# apenas registros de postos dos estados de SP e RJ cujo produto é GASOLINA COMUM
postos_sp_rj_gasolina
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 12002        12002   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 12003        12003   2004-05-09  2004-05-15  SUDESTE       SAO PAULO
# 12029        12029   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 12030        12030   2004-05-16  2004-05-22  SUDESTE       SAO PAULO
# 12056        12056   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103058      103058   2019-06-09  2019-06-15  SUDESTE       SAO PAULO
# 103198      103198   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO
# 103204      103204   2019-06-16  2019-06-22  SUDESTE       SAO PAULO
# 103344      103344   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12002   GASOLINA COMUM                          1071              R$/l
# 12003   GASOLINA COMUM                          4107              R$/l
# 12029   GASOLINA COMUM                          1055              R$/l
# 12030   GASOLINA COMUM                          4133              R$/l
# 12056   GASOLINA COMUM                          1091              R$/l
# ...                ...                           ...               ...
# 103058  GASOLINA COMUM                          1643              R$/l
# 103198  GASOLINA COMUM                           418              R$/l
# 103204  GASOLINA COMUM                          1635              R$/l
# 103344  GASOLINA COMUM                           422              R$/l
# 103350  GASOLINA COMUM                          1644              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 12002                 2.045                  0.109  ...                 2.599
# 12003                 1.891                  0.101  ...                 2.399
# 12029                 2.040                  0.113  ...                 2.599
# 12030                 1.888                  0.101  ...                 2.220
# 12056                 2.042                  0.108  ...                 2.599
# ...                     ...                    ...  ...                   ...
# 103058                4.210                  0.177  ...                 4.992
# 103198                4.927                  0.160  ...                 5.859
# 103204                4.168                  0.177  ...                 5.199
# 103344                4.928                  0.165  ...                 5.859
# 103350                4.142                  0.183  ...                 4.999
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12002                  0.254                     0.053
# 12003                  0.235                     0.053
# 12029                  0.252                     0.055
# 12030                  0.233                     0.053
# 12056                  0.252                     0.053
# ...                      ...                       ...
# 103058                 0.425                     0.042
# 103198                 0.544                     0.032
# 103204                 0.443                     0.042
# 103344                 0.538                     0.033
# 103350                 0.429                     0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12002                      1.791                       0.047
# 12003                      1.656                       0.064
# 12029                      1.788                       0.049
# 12030                      1.655                       0.063
# 12056                      1.790                       0.046
# ...                          ...                         ...
# 103058                     3.785                       0.096
# 103198                     4.383                       0.100
# 103204                     3.725                       0.096
# 103344                     4.390                       0.097
# 103350                     3.713                       0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12002                     1.63630                    1.95940
# 12003                     1.38000                    1.94400
# 12029                     1.59430                    1.99651
# 12030                     1.38000                    1.93190
# 12056                     1.63596                    2.21370
# ...                           ...                        ...
# 103058                    3.52000                    4.10070
# 103198                    4.19720                    4.62390
# 103204                    3.50200                    4.08920
# 103344                    4.20000                    4.61800
# 103350                    3.52000                    4.08920
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 12002                           0.026    5  2004
# 12003                           0.039    5  2004
# 12029                           0.027    5  2004
# 12030                           0.038    5  2004
# 12056                           0.026    5  2004
# ...                               ...  ...   ...
# 103058                          0.025    6  2019
# 103198                          0.023    6  2019
# 103204                          0.026    6  2019
# 103344                          0.022    6  2019
# 103350                          0.026    6  2019
#
# [1570 rows x 21 columns]

# %%
selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)

postos_sp_rj_gasolina_preco_maior_que_2 = postos_sp_rj_gasolina[selecao_3]
postos_sp_rj_gasolina_preco_maior_que_2
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 12002        12002   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 12029        12029   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 12056        12056   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# 12083        12083   2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO
# 12110        12110   2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 103058      103058   2019-06-09  2019-06-15  SUDESTE       SAO PAULO
# 103198      103198   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO
# 103204      103204   2019-06-16  2019-06-22  SUDESTE       SAO PAULO
# 103344      103344   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 103350      103350   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12002   GASOLINA COMUM                          1071              R$/l
# 12029   GASOLINA COMUM                          1055              R$/l
# 12056   GASOLINA COMUM                          1091              R$/l
# 12083   GASOLINA COMUM                          1055              R$/l
# 12110   GASOLINA COMUM                          1091              R$/l
# ...                ...                           ...               ...
# 103058  GASOLINA COMUM                          1643              R$/l
# 103198  GASOLINA COMUM                           418              R$/l
# 103204  GASOLINA COMUM                          1635              R$/l
# 103344  GASOLINA COMUM                           422              R$/l
# 103350  GASOLINA COMUM                          1644              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 12002                 2.045                  0.109  ...                 2.599
# 12029                 2.040                  0.113  ...                 2.599
# 12056                 2.042                  0.108  ...                 2.599
# 12083                 2.053                  0.111  ...                 2.599
# 12110                 2.063                  0.107  ...                 2.599
# ...                     ...                    ...  ...                   ...
# 103058                4.210                  0.177  ...                 4.992
# 103198                4.927                  0.160  ...                 5.859
# 103204                4.168                  0.177  ...                 5.199
# 103344                4.928                  0.165  ...                 5.859
# 103350                4.142                  0.183  ...                 4.999
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12002                  0.254                     0.053
# 12029                  0.252                     0.055
# 12056                  0.252                     0.053
# 12083                  0.251                     0.054
# 12110                  0.247                     0.052
# ...                      ...                       ...
# 103058                 0.425                     0.042
# 103198                 0.544                     0.032
# 103204                 0.443                     0.042
# 103344                 0.538                     0.033
# 103350                 0.429                     0.044
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12002                      1.791                       0.047
# 12029                      1.788                       0.049
# 12056                      1.790                       0.046
# 12083                      1.802                       0.055
# 12110                      1.816                       0.054
# ...                          ...                         ...
# 103058                     3.785                       0.096
# 103198                     4.383                       0.100
# 103204                     3.725                       0.096
# 103344                     4.390                       0.097
# 103350                     3.713                       0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12002                     1.63630                    1.95940
# 12029                     1.59430                    1.99651
# 12056                     1.63596                    2.21370
# 12083                     1.64000                    2.21425
# 12110                     1.64000                    2.32425
# ...                           ...                        ...
# 103058                    3.52000                    4.10070
# 103198                    4.19720                    4.62390
# 103204                    3.50200                    4.08920
# 103344                    4.20000                    4.61800
# 103350                    3.52000                    4.08920
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 12002                           0.026    5  2004
# 12029                           0.027    5  2004
# 12056                           0.026    5  2004
# 12083                           0.031    5  2004
# 12110                           0.030    6  2004
# ...                               ...  ...   ...
# 103058                          0.025    6  2019
# 103198                          0.023    6  2019
# 103204                          0.026    6  2019
# 103344                          0.022    6  2019
# 103350                          0.026    6  2019
#
# [1564 rows x 21 columns]

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data['ANO'] == 2008) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
data[selecao]
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5088         5088   2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5089         5089   2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5090         5090   2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5091         5091   2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5092         5092   2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...           ...          ...         ...           ...                  ...
# 54771       54771   2012-12-30  2013-01-05       SUDESTE       RIO DE JANEIRO
# 54772       54772   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 54773       54773   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 54774       54774   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 54775       54775   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5088   ETANOL HIDRATADO                            80              R$/l
# 5089   ETANOL HIDRATADO                           255              R$/l
# 5090   ETANOL HIDRATADO                           142              R$/l
# 5091   ETANOL HIDRATADO                           133              R$/l
# 5092   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 54771               GNV                           184             R$/m3
# 54772               GNV                            17             R$/m3
# 54773               GNV                            34             R$/m3
# 54774               GNV                            82             R$/m3
# 54775               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 5088                 1.806                  0.082  ...                 1.950
# 5089                 1.616                  0.100  ...                 1.899
# 5090                 1.581                  0.095  ...                 1.850
# 5091                 1.831                  0.046  ...                 1.910
# 5092                 1.699                  0.098  ...                 1.999
# ...                    ...                    ...  ...                   ...
# 54771                1.666                  0.148  ...                 2.090
# 54772                1.891                  0.015  ...                 1.900
# 54773                1.980                  0.040  ...                 2.140
# 54774                1.598                  0.199  ...                 2.599
# 54775                1.847                  0.033  ...                 1.899
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 5088                  0.290                     0.045
# 5089                  0.293                     0.062
# 5090                  0.278                     0.060
# 5091                  0.382                     0.025
# 5092                  0.199                     0.058
# ...                     ...                       ...
# 54771                 0.345                     0.089
# 54772                 0.466                     0.008
# 54773                 0.566                     0.020
# 54774                 0.397                     0.125
# 54775                 0.504                     0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5088                      1.516                       0.061
# 5089                      1.323                       0.050
# 5090                      1.303                       0.073
# 5091                      1.449                       0.044
# 5092                      1.500                       0.062
# ...                         ...                         ...
# 54771                     1.321                       0.118
# 54772                     1.425                       0.098
# 54773                     1.414                       0.028
# 54774                     1.201                       0.182
# 54775                     1.343                       0.178
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5088                      1.3892                     1.6157
# 5089                      1.2242                     1.6173
# 5090                      1.1400                     1.4500
# 5091                      1.3247                     1.5514
# 5092                      1.3900                     1.7689
# ...                          ...                        ...
# 54771                     1.0964                     1.5028
# 54772                     1.2657                     1.4789
# 54773                     1.3997                     1.4608
# 54774                     0.8354                     1.5350
# 54775                     1.1253                     1.5430
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 5088                           0.040    1  2008
# 5089                           0.038    1  2008
# 5090                           0.056    1  2008
# 5091                           0.030    1  2008
# 5092                           0.041    1  2008
# ...                              ...  ...   ...
# 54771                          0.089   12  2012
# 54772                          0.069   12  2012
# 54773                          0.020   12  2012
# 54774                          0.152   12  2012
# 54775                          0.133   12  2012
#
# [19056 rows x 21 columns]

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
selecao = data['ANO'].isin(lista_de_anos)  # retorna uma Series de booleanos
data[selecao]
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5088         5088   2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5089         5089   2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5090         5090   2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5091         5091   2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5092         5092   2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...           ...          ...         ...           ...                  ...
# 54771       54771   2012-12-30  2013-01-05       SUDESTE       RIO DE JANEIRO
# 54772       54772   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 54773       54773   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 54774       54774   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 54775       54775   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5088   ETANOL HIDRATADO                            80              R$/l
# 5089   ETANOL HIDRATADO                           255              R$/l
# 5090   ETANOL HIDRATADO                           142              R$/l
# 5091   ETANOL HIDRATADO                           133              R$/l
# 5092   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 54771               GNV                           184             R$/m3
# 54772               GNV                            17             R$/m3
# 54773               GNV                            34             R$/m3
# 54774               GNV                            82             R$/m3
# 54775               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 5088                 1.806                  0.082  ...                 1.950
# 5089                 1.616                  0.100  ...                 1.899
# 5090                 1.581                  0.095  ...                 1.850
# 5091                 1.831                  0.046  ...                 1.910
# 5092                 1.699                  0.098  ...                 1.999
# ...                    ...                    ...  ...                   ...
# 54771                1.666                  0.148  ...                 2.090
# 54772                1.891                  0.015  ...                 1.900
# 54773                1.980                  0.040  ...                 2.140
# 54774                1.598                  0.199  ...                 2.599
# 54775                1.847                  0.033  ...                 1.899
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 5088                  0.290                     0.045
# 5089                  0.293                     0.062
# 5090                  0.278                     0.060
# 5091                  0.382                     0.025
# 5092                  0.199                     0.058
# ...                     ...                       ...
# 54771                 0.345                     0.089
# 54772                 0.466                     0.008
# 54773                 0.566                     0.020
# 54774                 0.397                     0.125
# 54775                 0.504                     0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5088                      1.516                       0.061
# 5089                      1.323                       0.050
# 5090                      1.303                       0.073
# 5091                      1.449                       0.044
# 5092                      1.500                       0.062
# ...                         ...                         ...
# 54771                     1.321                       0.118
# 54772                     1.425                       0.098
# 54773                     1.414                       0.028
# 54774                     1.201                       0.182
# 54775                     1.343                       0.178
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5088                      1.3892                     1.6157
# 5089                      1.2242                     1.6173
# 5090                      1.1400                     1.4500
# 5091                      1.3247                     1.5514
# 5092                      1.3900                     1.7689
# ...                          ...                        ...
# 54771                     1.0964                     1.5028
# 54772                     1.2657                     1.4789
# 54773                     1.3997                     1.4608
# 54774                     0.8354                     1.5350
# 54775                     1.1253                     1.5430
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 5088                           0.040    1  2008
# 5089                           0.038    1  2008
# 5090                           0.056    1  2008
# 5091                           0.030    1  2008
# 5092                           0.041    1  2008
# ...                              ...  ...   ...
# 54771                          0.089   12  2012
# 54772                          0.069   12  2012
# 54773                          0.020   12  2012
# 54774                          0.152   12  2012
# 54775                          0.133   12  2012
#
# [19056 rows x 21 columns]

# %% [markdown]
# **ALTERNATIVA 3**

# %%
lista_de_anos
# Out:
# [2008, 2010, 2012]

# %%
data.query('ANO in @lista_de_anos')
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5088         5088   2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5089         5089   2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5090         5090   2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5091         5091   2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5092         5092   2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...           ...          ...         ...           ...                  ...
# 54771       54771   2012-12-30  2013-01-05       SUDESTE       RIO DE JANEIRO
# 54772       54772   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 54773       54773   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 54774       54774   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 54775       54775   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5088   ETANOL HIDRATADO                            80              R$/l
# 5089   ETANOL HIDRATADO                           255              R$/l
# 5090   ETANOL HIDRATADO                           142              R$/l
# 5091   ETANOL HIDRATADO                           133              R$/l
# 5092   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 54771               GNV                           184             R$/m3
# 54772               GNV                            17             R$/m3
# 54773               GNV                            34             R$/m3
# 54774               GNV                            82             R$/m3
# 54775               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 5088                 1.806                  0.082  ...                 1.950
# 5089                 1.616                  0.100  ...                 1.899
# 5090                 1.581                  0.095  ...                 1.850
# 5091                 1.831                  0.046  ...                 1.910
# 5092                 1.699                  0.098  ...                 1.999
# ...                    ...                    ...  ...                   ...
# 54771                1.666                  0.148  ...                 2.090
# 54772                1.891                  0.015  ...                 1.900
# 54773                1.980                  0.040  ...                 2.140
# 54774                1.598                  0.199  ...                 2.599
# 54775                1.847                  0.033  ...                 1.899
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 5088                  0.290                     0.045
# 5089                  0.293                     0.062
# 5090                  0.278                     0.060
# 5091                  0.382                     0.025
# 5092                  0.199                     0.058
# ...                     ...                       ...
# 54771                 0.345                     0.089
# 54772                 0.466                     0.008
# 54773                 0.566                     0.020
# 54774                 0.397                     0.125
# 54775                 0.504                     0.018
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5088                      1.516                       0.061
# 5089                      1.323                       0.050
# 5090                      1.303                       0.073
# 5091                      1.449                       0.044
# 5092                      1.500                       0.062
# ...                         ...                         ...
# 54771                     1.321                       0.118
# 54772                     1.425                       0.098
# 54773                     1.414                       0.028
# 54774                     1.201                       0.182
# 54775                     1.343                       0.178
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5088                      1.3892                     1.6157
# 5089                      1.2242                     1.6173
# 5090                      1.1400                     1.4500
# 5091                      1.3247                     1.5514
# 5092                      1.3900                     1.7689
# ...                          ...                        ...
# 54771                     1.0964                     1.5028
# 54772                     1.2657                     1.4789
# 54773                     1.3997                     1.4608
# 54774                     0.8354                     1.5350
# 54775                     1.1253                     1.5430
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 5088                           0.040    1  2008
# 5089                           0.038    1  2008
# 5090                           0.056    1  2008
# 5091                           0.030    1  2008
# 5092                           0.041    1  2008
# ...                              ...  ...   ...
# 54771                          0.089   12  2012
# 54772                          0.069   12  2012
# 54773                          0.020   12  2012
# 54774                          0.152   12  2012
# 54775                          0.133   12  2012
#
# [19056 rows x 21 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
# 5                 0.426                     0.095                     0.957
# 6                 0.353                     0.150                     1.100
# 7                 0.515                     0.097                     1.116
# 8                 0.353                     0.101                     0.931
# 9                 0.277                     0.115                     0.947
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
# 5                       0.128                     0.5686
# 6                       0.068                     0.7332
# 7                       0.091                     0.9923
# 8                       0.072                     0.7577
# 9                       0.091                     0.5643
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
# 5                    1.35000                          0.134    5  2004
# 6                    1.29400                          0.062    5  2004
# 7                    1.36183                          0.082    5  2004
# 8                    1.29720                          0.077    5  2004
# 9                    1.35410                          0.096    5  2004
#
# [10 rows x 21 columns]

# %%
for index, row in data.head(10).iterrows():
    print(f'indice {index} ==> {row["ESTADO"]}')
# Out:
# indice 0 ==> DISTRITO FEDERAL
# indice 1 ==> GOIAS
# indice 2 ==> MATO GROSSO
# indice 3 ==> MATO GROSSO DO SUL
# indice 4 ==> ALAGOAS
# indice 5 ==> BAHIA
# indice 6 ==> CEARA
# indice 7 ==> MARANHAO
# indice 8 ==> PARAIBA
# indice 9 ==> PERNAMBUCO

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388      103388   2019-06-23  2019-06-29           SUL
# 103389      103389   2019-06-23  2019-06-29           SUL
# 103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 103387             R$/m3                3.574                  0.065  ...
# 103388             R$/m3                3.401                  0.129  ...
# 103389             R$/m3                2.912                  0.190  ...
# 103390             R$/m3                3.020                  0.229  ...
# 103391             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                     0.012
# 1                      1.449                 0.399                     0.098
# 2                      1.760                 0.419                     0.070
# 3                      1.509                 0.432                     0.055
# 4                      1.400                 0.240                     0.066
# ...                      ...                   ...                       ...
# 103387                 3.690                 0.818                     0.018
# 103388                 3.789                 0.950                     0.038
# 103389                 3.499                 0.914                     0.065
# 103390                 3.490                 0.646                     0.076
# 103391                 3.699                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 21 columns]

# %% [markdown]
# ### 2.1 Tratando observações com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     103392 non-null  int64
#  1   DATA INICIAL                   103392 non-null  object
#  2   DATA FINAL                     103392 non-null  object
#  3   REGIÃO                         103392 non-null  object
#  4   ESTADO                         103392 non-null  object
#  5   PRODUTO                        103392 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  7   UNIDADE DE MEDIDA              103392 non-null  object
#  8   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  9   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  12  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  13  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  19  MÊS                            103392 non-null  int64
#  20  ANO                            103392 non-null  int64
# dtypes: float64(11), int64(4), object(6)
# memory usage: 16.6+ MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null / nan** para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente alguns registros têm uma string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ser o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do dataset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     103392 non-null  int64
#  1   DATA INICIAL                   103392 non-null  datetime64[ns]
#  2   DATA FINAL                     103392 non-null  datetime64[ns]
#  3   REGIÃO                         103392 non-null  object
#  4   ESTADO                         103392 non-null  object
#  5   PRODUTO                        103392 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  7   UNIDADE DE MEDIDA              103392 non-null  object
#  8   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  9   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  12  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  13  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  19  MÊS                            103392 non-null  int64
#  20  ANO                            103392 non-null  int64
# dtypes: datetime64[ns](2), float64(11), int64(4), object(4)
# memory usage: 16.6+ MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
# convertendo atributos/colunas para 'numeric'
for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    # converte a coluna (de valores string) para um tipo numérico
    # Em caso de erro na conversão (p. ex., uma string que não representa um número), um valor vazio (null / nan) será
    # atribuído no lugar
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     103392 non-null  int64
#  1   DATA INICIAL                   103392 non-null  datetime64[ns]
#  2   DATA FINAL                     103392 non-null  datetime64[ns]
#  3   REGIÃO                         103392 non-null  object
#  4   ESTADO                         103392 non-null  object
#  5   PRODUTO                        103392 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  7   UNIDADE DE MEDIDA              103392 non-null  object
#  8   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  9   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  12  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  13  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  19  MÊS                            103392 non-null  int64
#  20  ANO                            103392 non-null  int64
# dtypes: datetime64[ns](2), float64(11), int64(4), object(4)
# memory usage: 16.6+ MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Nos dados originais, quais eram os valores do PREÇO MÉDIO DISTRIBUIÇÃO dos registros que agora possuem valores NaN
data[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
# Retorna uma cópia do data fram `data_pre` com todos os valores NaN de todas as colunas agora preenchidos com 0.
# Para alterar o próprio data frame, use o argumento `inplace=True`.
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#         Unnamed: 0 DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0                0   2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1                1   2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2                2   2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3                3   2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4                4   2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...            ...          ...        ...           ...                  ...
# 103387      103387   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388      103388   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 103389      103389   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 103390      103390   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 103391      103391   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103387               GNV                             7             R$/m3
# 103388               GNV                            23             R$/m3
# 103389               GNV                            24             R$/m3
# 103390               GNV                            52             R$/m3
# 103391               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                     1.288                  0.016  ...                 1.350
# 1                     1.162                  0.114  ...                 1.449
# 2                     1.389                  0.097  ...                 1.760
# 3                     1.262                  0.070  ...                 1.509
# 4                     1.181                  0.078  ...                 1.400
# ...                     ...                    ...  ...                   ...
# 103387                3.574                  0.065  ...                 3.690
# 103388                3.401                  0.129  ...                 3.789
# 103389                2.912                  0.190  ...                 3.499
# 103390                3.020                  0.229  ...                 3.490
# 103391                3.697                  0.005  ...                 3.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 103387                 0.818                     0.018
# 103388                 0.950                     0.038
# 103389                 0.914                     0.065
# 103390                 0.646                     0.076
# 103391                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 21 columns]

# %%
data_pre_fill[mask]  # valores que antes eram NaN, agora são 0
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %%
# retorna uma cópia do data frame `data_pre` com todos os valores NaN das colunas:
# 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO' e 'PREÇO MÁXIMO DISTRIBUIÇÃO', respectivamente, com os valores: 10, 20, 30, 'vazio'.
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})

# %%
data_pre_fill[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
# remove, no próprio dataframe, todas as linhas/registros com valores NaN (vazios) em quaisquer colunas/atributos.
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     103392 non-null  int64
#  1   DATA INICIAL                   103392 non-null  datetime64[ns]
#  2   DATA FINAL                     103392 non-null  datetime64[ns]
#  3   REGIÃO                         103392 non-null  object
#  4   ESTADO                         103392 non-null  object
#  5   PRODUTO                        103392 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  7   UNIDADE DE MEDIDA              103392 non-null  object
#  8   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  9   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  12  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  13  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  19  MÊS                            103392 non-null  int64
#  20  ANO                            103392 non-null  int64
# dtypes: datetime64[ns](2), float64(11), int64(4), object(4)
# memory usage: 16.6+ MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('/content/drive/MyDrive/trilha de dados igor/GasPricesinBrazil_2004-2019-prepocessando_final.csv')

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %%
data_final = pd.read_csv('/content/drive/MyDrive/trilha de dados igor/GasPricesinBrazil_2004-2019-prepocessando_final.csv')

# %%
data_final
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 103387        103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388        103388      103388   2019-06-23  2019-06-29           SUL
# 103389        103389      103389   2019-06-23  2019-06-29           SUL
# 103390        103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391        103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 103387             R$/m3                3.574  ...                 3.690
# 103388             R$/m3                3.401  ...                 3.789
# 103389             R$/m3                2.912  ...                 3.499
# 103390             R$/m3                3.020  ...                 3.490
# 103391             R$/m3                3.697  ...                 3.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 103387                 0.818                     0.018
# 103388                 0.950                     0.038
# 103389                 0.914                     0.065
# 103390                 0.646                     0.076
# 103391                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 22 columns]

# %% [markdown]
# O Pandas fornecem algumas funções/métodos que computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final.describe()
# Out:
#         Unnamed: 0.1     Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  103392.000000  103392.000000                 103392.000000
# mean    51695.500000   51695.500000                    240.511935
# std     29846.843853   29846.843853                    408.039174
# min         0.000000       0.000000                      1.000000
# 25%     25847.750000   25847.750000                     47.000000
# 50%     51695.500000   51695.500000                    108.000000
# 75%     77543.250000   77543.250000                    251.000000
# max    103391.000000  103391.000000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        103392.000000          103392.000000         103392.000000
# mean             10.784472               0.652589              9.334931
# std              17.685852               1.346422             15.024383
# min               0.766000               0.000000              0.590000
# 25%               2.073000               0.073000              1.900000
# 50%               2.723000               0.115000              2.509000
# 75%               3.745000               0.190000              3.490000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000         103392.000000             103392.000000
# mean              12.458686              2.225151                  0.045749
# std               20.801190              4.375085                  0.024488
# min                0.999000              0.001000                  0.000000
# 25%                2.330000              0.282000                  0.030000
# 50%                3.000000              0.383000                  0.042000
# 75%                4.150000              0.560000                  0.058000
# max              120.000000             36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()
stats
# Out:
#         Unnamed: 0.1     Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  103392.000000  103392.000000                 103392.000000
# mean    51695.500000   51695.500000                    240.511935
# std     29846.843853   29846.843853                    408.039174
# min         0.000000       0.000000                      1.000000
# 25%     25847.750000   25847.750000                     47.000000
# 50%     51695.500000   51695.500000                    108.000000
# 75%     77543.250000   77543.250000                    251.000000
# max    103391.000000  103391.000000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        103392.000000          103392.000000         103392.000000
# mean             10.784472               0.652589              9.334931
# std              17.685852               1.346422             15.024383
# min               0.766000               0.000000              0.590000
# 25%               2.073000               0.073000              1.900000
# 50%               2.723000               0.115000              2.509000
# 75%               3.745000               0.190000              3.490000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000         103392.000000             103392.000000
# mean              12.458686              2.225151                  0.045749
# std               20.801190              4.375085                  0.024488
# min                0.999000              0.001000                  0.000000
# 25%                2.330000              0.282000                  0.030000
# 50%                3.000000              0.383000                  0.042000
# 75%                4.150000              0.560000                  0.058000
# max              120.000000             36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000

# %%
stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
# ALTERNATIVA MAIS EFICIENTE
# apenas computa as estatísticas descritivas para 3 atributos
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#         Unnamed: 0.1     Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  103392.000000  103392.000000                 103392.000000
# mean    51695.500000   51695.500000                    240.511935
# std     29846.843853   29846.843853                    408.039174
# min         0.000000       0.000000                      1.000000
# 25%     25847.750000   25847.750000                     47.000000
# 50%     51695.500000   51695.500000                    108.000000
# 75%     77543.250000   77543.250000                    251.000000
# max    103391.000000  103391.000000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        103392.000000          103392.000000         103392.000000
# mean             10.784472               0.652589              9.334931
# std              17.685852               1.346422             15.024383
# min               0.766000               0.000000              0.590000
# 25%               2.073000               0.073000              1.900000
# 50%               2.723000               0.115000              2.509000
# 75%               3.745000               0.190000              3.490000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000         103392.000000             103392.000000
# mean              12.458686              2.225151                  0.045749
# std               20.801190              4.375085                  0.024488
# min                0.999000              0.001000                  0.000000
# 25%                2.330000              0.282000                  0.030000
# 50%                3.000000              0.383000                  0.042000
# 75%                4.150000              0.560000                  0.058000
# max              120.000000             36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       Unnamed: 0.1  Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# min            0.0         0.0                      1.000000
# max       103391.0    103391.0                   4167.000000
# mean       51695.5     51695.5                    240.511935
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# min              0.766000               0.000000              0.590000
# max             99.357000              10.748000             90.000000
# mean            10.784472               0.652589              9.334931
#
#       PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.999000              0.001000                  0.000000
# max             120.000000             36.847000                  0.262000
# mean             12.458686              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# mean                  8.559322                    0.559441
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# min                    0.325700                   0.599200
# max                   83.000000                  94.500000
# mean                   7.414814                   9.805621
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS          ANO
# min                         0.00000   1.000000  2004.000000
# max                         0.78000  12.000000  2019.000000
# mean                        0.04664   6.485067  2011.737001

# %%
stats.loc[['min', 'max', 'mean'], 'PREÇO MÉDIO REVENDA']
# Out:
# min      0.766000
# max     99.357000
# mean    10.784472
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 15.02

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts()  # retorna em ordem decrescente, a quantidade de registros/linhas para cada estado
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame()  # converte uma Series para um DataFrame
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(series):
    return series.sum()  # retorna a soma de todos os valores de uma series

# %%
# aplica a função soma para cada linha do dataframe
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
# aplica a função soma para cada coluna do dataframe
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100            111            37.0
# Linha 2   2   20   200            222            74.0
# Linha 3   3   30   300            333           111.0
# Linha 4   4   40   400            444           148.0
# Linha 5  10  100  1000           1110           370.0

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
# plica a lambda function abaixo para cada elemento da coluna
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100            111            37.0    200
# Linha 2   2   20   200            222            74.0    400
# Linha 3   3   30   300            333           111.0    600
# Linha 4   4   40   400            444           148.0    800
# Linha 5  10  100  1000           1110           370.0   2000

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2  A * 2
# Linha 1   1   10   100            111            37.0    200      2
# Linha 2   2   20   200            222            74.0    400      4
# Linha 3   3   30   300            333           111.0    600      6
# Linha 4   4   40   400            444           148.0    800      8
# Linha 5  10  100  1000           1110           370.0   2000     20

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
# retorna um novo dataframe com todos os elementos ao quadrado.
# poderíamos usar uma função ao invés de uma lambda function
df.applymap(lambda x: x ** 2)
# Out:
# /tmp/ipython-input-3314123372.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x ** 2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
# retorna uma nova Series com todos os nomes com letras maiuscúlas.
# poderíamos usar uma função ao invés de uma lambda function
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %%
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
# O Pandas já fornece uma série de métodos para manipulação de strings.
# Assim, poderíamos usar o código abaixo para obter o mesmo resultado.
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 22 columns]

# %% [markdown]
# `groupby`: Usado para criar **grupos de elementos** (e.x., baseado nos valores de um atributo (categórico)). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
# agrupa as linhas da tablea de acordo com suas respectivas regiões
grupos = data_final.groupby('REGIÃO')
grupos

# %%
# retorna os grupos obtidos pelo groupby
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
# retorna os índices das linhas/observações de cada grupo
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383]),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391]),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379]),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390]),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389])}

# %%
# retorna um dataframe apenas com as observações do grupo 'CENTRO OESTE'
grupos.get_group('CENTRO OESTE')
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 27                27          27   2004-05-16  2004-05-22  CENTRO OESTE
# ...              ...         ...          ...         ...           ...
# 103359        103359      103359   2019-06-23  2019-06-29  CENTRO OESTE
# 103361        103361      103361   2019-06-23  2019-06-29  CENTRO OESTE
# 103363        103363      103363   2019-06-23  2019-06-29  CENTRO OESTE
# 103364        103364      103364   2019-06-23  2019-06-29  CENTRO OESTE
# 103383        103383      103383   2019-06-23  2019-06-29  CENTRO OESTE
#
#                     ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0         DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                    GOIAS  ETANOL HIDRATADO                           387
# 2              MATO GROSSO  ETANOL HIDRATADO                           192
# 3       MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 27        DISTRITO FEDERAL  ETANOL HIDRATADO                           144
# ...                    ...               ...                           ...
# 103359    DISTRITO FEDERAL               GLP                            42
# 103361               GOIAS               GLP                           209
# 103363         MATO GROSSO               GLP                            95
# 103364  MATO GROSSO DO SUL               GLP                           115
# 103383  MATO GROSSO DO SUL               GNV                             2
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 27                  R$/l                1.271  ...                 1.300
# ...                  ...                  ...  ...                   ...
# 103359           R$/13Kg               73.452  ...                95.000
# 103361           R$/13Kg               71.968  ...                85.000
# 103363           R$/13Kg               96.691  ...               115.000
# 103364           R$/13Kg               72.297  ...                99.000
# 103383             R$/m3                2.934  ...                 2.968
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 27                     0.448                     0.031
# ...                      ...                       ...
# 103359                21.509                     0.066
# 103361                15.044                     0.075
# 103363                19.789                     0.071
# 103364                16.707                     0.111
# 103383                 0.901                     0.017
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 27                         0.823                       0.111
# ...                          ...                         ...
# 103359                    51.943                       7.877
# 103361                    56.924                       4.285
# 103363                    76.902                       8.846
# 103364                    55.590                       5.109
# 103383                     2.033                       0.259
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 27                         0.4094                    1.19310
# ...                           ...                        ...
# 103359                    44.0000                   62.82000
# 103361                    45.5700                   61.60000
# 103363                    61.1500                   90.00000
# 103364                    47.0000                   72.00000
# 103383                     1.8500                    2.21610
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 27                              0.135    5  2004
# ...                               ...  ...   ...
# 103359                          0.152    6  2019
# 103361                          0.075    6  2019
# 103363                          0.115    6  2019
# 103364                          0.092    6  2019
# 103383                          0.127    6  2019
#
# [14545 rows x 22 columns]

# %%
# descreva para nós algumas estatística descritivas para as observações de cada grupo
grupos.describe()
# Out:
#              Unnamed: 0.1                                              \
#                     count          mean           std   min       25%
# REGIÃO
# CENTRO OESTE      14545.0  51513.529735  30249.703441   0.0  24534.00
# NORDESTE          35788.0  51747.311557  29649.153398   4.0  26722.25
# NORTE             24000.0  51449.594583  30579.271162  13.0  23413.75
# SUDESTE           16744.0  52004.892021  29224.691293  20.0  28121.75
# SUL               12315.0  51818.422899  29327.733219  24.0  27584.50
#
#                                          Unnamed: 0                ...   MÊS  \
#                   50%      75%       max      count          mean  ...   75%
# REGIÃO                                                             ...
# CENTRO OESTE  52057.0  77898.0  103383.0    14545.0  51513.529735  ...   9.0
# NORDESTE      50956.5  77535.5  103391.0    35788.0  51747.311557  ...  10.0
# NORTE         53045.5  77942.5  103379.0    24000.0  51449.594583  ...   9.0
# SUDESTE       51161.5  77054.5  103390.0    16744.0  52004.892021  ...   9.0
# SUL           51002.0  76994.5  103389.0    12315.0  51818.422899  ...   9.0
#
#                         ANO                                                 \
#                max    count         mean       std     min     25%     50%
# REGIÃO
# CENTRO OESTE  12.0  14545.0  2011.773599  4.409036  2004.0  2008.0  2012.0
# NORDESTE      12.0  35788.0  2011.704454  4.418046  2004.0  2008.0  2012.0
# NORTE         12.0  24000.0  2011.812083  4.410914  2004.0  2008.0  2012.0
# SUDESTE       12.0  16744.0  2011.707895  4.395436  2004.0  2008.0  2012.0
# SUL           12.0  12315.0  2011.681608  4.408312  2004.0  2008.0  2012.0
#
#
#                  75%     max
# REGIÃO
# CENTRO OESTE  2016.0  2019.0
# NORDESTE      2016.0  2019.0
# NORTE         2016.0  2019.0
# SUDESTE       2016.0  2019.0
# SUL           2015.0  2019.0
#
# [5 rows x 128 columns]

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1316802999.py in <cell line: 0>()
# ----> 1 grupos.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
grupos.min()
# Out:
#               Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL  \
# REGIÃO
# CENTRO OESTE             0           0   2004-05-09  2004-05-15
# NORDESTE                 4           4   2004-05-09  2004-05-15
# NORTE                   13          13   2004-05-09  2004-05-15
# SUDESTE                 20          20   2004-05-09  2004-05-15
# SUL                     24          24   2004-05-09  2004-05-15
#
#                         ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE               ALAGOAS  ETANOL HIDRATADO
# NORTE                     ACRE  ETANOL HIDRATADO
# SUDESTE         ESPIRITO SANTO  ETANOL HIDRATADO
# SUL                     PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                1.097                    0.0  ...
# NORDESTE                    0.975                    0.0  ...
# NORTE                       1.226                    0.0  ...
# SUDESTE                     0.766                    0.0  ...
# SUL                         0.922                    0.0  ...
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                 1.099                 0.031
# NORDESTE                     0.999                 0.039
# NORTE                        1.300                 0.022
# SUDESTE                      1.099                 0.001
# SUL                          1.199                 0.025
#
#               COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                       0.0                     0.737
# NORDESTE                           0.0                     0.586
# NORTE                              0.0                     0.674
# SUDESTE                            0.0                     0.506
# SUL                                0.0                     0.667
#
#               DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                         0.0                    0.38790
# NORDESTE                             0.0                    0.36320
# NORTE                                0.0                    0.51022
# SUDESTE                              0.0                    0.32570
# SUL                                  0.0                    0.43000
#
#               PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS  \
# REGIÃO
# CENTRO OESTE                     0.8359                            0.0    1
# NORDESTE                         0.5992                            0.0    1
# NORTE                            0.9612                            0.0    1
# SUDESTE                          0.7822                            0.0    1
# SUL                              0.7044                            0.0    1
#
#                ANO
# REGIÃO
# CENTRO OESTE  2004
# NORDESTE      2004
# NORTE         2004
# SUDESTE       2004
# SUL           2004
#
# [5 rows x 21 columns]

# %%
data_final.groupby('REGIÃO').min()
# Out:
#               Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL  \
# REGIÃO
# CENTRO OESTE             0           0   2004-05-09  2004-05-15
# NORDESTE                 4           4   2004-05-09  2004-05-15
# NORTE                   13          13   2004-05-09  2004-05-15
# SUDESTE                 20          20   2004-05-09  2004-05-15
# SUL                     24          24   2004-05-09  2004-05-15
#
#                         ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE               ALAGOAS  ETANOL HIDRATADO
# NORTE                     ACRE  ETANOL HIDRATADO
# SUDESTE         ESPIRITO SANTO  ETANOL HIDRATADO
# SUL                     PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                1.097                    0.0  ...
# NORDESTE                    0.975                    0.0  ...
# NORTE                       1.226                    0.0  ...
# SUDESTE                     0.766                    0.0  ...
# SUL                         0.922                    0.0  ...
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                 1.099                 0.031
# NORDESTE                     0.999                 0.039
# NORTE                        1.300                 0.022
# SUDESTE                      1.099                 0.001
# SUL                          1.199                 0.025
#
#               COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                       0.0                     0.737
# NORDESTE                           0.0                     0.586
# NORTE                              0.0                     0.674
# SUDESTE                            0.0                     0.506
# SUL                                0.0                     0.667
#
#               DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                         0.0                    0.38790
# NORDESTE                             0.0                    0.36320
# NORTE                                0.0                    0.51022
# SUDESTE                              0.0                    0.32570
# SUL                                  0.0                    0.43000
#
#               PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS  \
# REGIÃO
# CENTRO OESTE                     0.8359                            0.0    1
# NORDESTE                         0.5992                            0.0    1
# NORTE                            0.9612                            0.0    1
# SUDESTE                          0.7822                            0.0    1
# SUL                              0.7044                            0.0    1
#
#                ANO
# REGIÃO
# CENTRO OESTE  2004
# NORDESTE      2004
# NORTE         2004
# SUDESTE       2004
# SUL           2004
#
# [5 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                     0.825
# 1                 0.399                     0.098                     0.763
# 2                 0.419                     0.070                     0.970
# 3                 0.432                     0.055                     0.830
# 4                 0.240                     0.066                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
# [5 rows x 22 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Qual é o preço médio de cada do Produto (Combustível) para cada Região?

# %%
# Agrupa os registros do dataframe primeiramente por suas regiões.
# Então, agrupa os registros de cada região (grupo) de acordo com seus produtos.
grupos = data_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [11980, 11981, 11982, 11983, 12007, 12008, 12009, 12010, 12034, 12035, 12036, 12037, 12061, 12062, 12063, 12064, 12088, 12089, 12090, 12091, 12115, 12116, 12117, 12118, 12142, 12143, 12144, 12145, 12169, 12170, 12171, 12172, 12196, 12197, 12198, 12199, 12223, 12224, 12225, 12226, 12250, 12251, 12252, 12253, 12277, 12278, 12279, 12280, 12304, 12305, 12306, 12307, 12331, 12332, 12333, 12334, 12358, 12359, 12360, 12361, 12385, 12386, 12387, 12388, 12412, 12413, 12414, 12415, 12439, 12440, 12441, 12442, 12466, 12467, 12468, 12469, 12493, 12494, 12495, 12496, 12520, 12521, 12522, 12523, 12547, 12548, 12549, 12550, 12574, 12575, 12576, 12577, 12601, 12602, 12603, 12604, 12628, 12629, 12630, 12631, ...], ('CENTRO OESTE', 'GLP'): [24019, 24020, 24021, 24022, 24046, 24047, 24048, 24049, 24073, 24074, 24075, 24076, 24100, 24101, 24102, 24103, 24127, 24128, 24129, 24130, 24154, 24155, 24156, 24157, 24181, 24182, 24183, 24184, 24208, 24209, 24210, 24211, 24235, 24236, 24237, 24238, 24262, 24263, 24264, 24265, 24289, 24290, 24291, 24292, 24316, 24317, 24318, 24319, 24343, 24344, 24345, 24346, 24370, 24371, 24372, 24373, 24397, 24398, 24399, 24400, 24424, 24425, 24426, 24427, 24451, 24452, 24453, 24454, 24478, 24479, 24480, 24481, 24505, 24506, 24507, 24508, 24532, 24533, 24534, 24535, 24558, 24559, 24560, 24561, 24585, 24586, 24587, 24588, 24612, 24613, 24614, 24615, 24639, 24640, 24641, 24642, 24666, 24667, 24668, 24669, ...], ('CENTRO OESTE', 'GNV'): [35892, 35907, 35922, 35937, 35952, 35967, 35982, 35997, 36012, 36027, 36042, 36057, 36072, 36087, 36102, 36117, 36132, 36147, 36162, 36177, 36192, 36207, 36222, 36237, 36252, 36267, 36283, 36298, 36313, 36329, 36345, 36360, 36375, 36390, 36405, 36420, 36436, 36451, 36466, 36481, 36495, 36510, 36525, 36541, 36557, 36572, 36588, 36604, 36620, 36635, 36650, 36665, 36680, 36695, 36710, 36725, 36740, 36755, 36770, 36785, 36800, 36815, 36830, 36845, 36860, 36875, 36890, 36918, 36932, 36948, 36962, 36991, 37006, 37021, 37037, 37053, 37068, 37084, 37100, 37116, 37132, 37148, 37164, 37180, 37196, 37212, 37228, 37244, 37259, 37275, 37291, 37307, 37323, 37339, 37355, 37371, 37387, 37403, 37419, 37435, ...], ('CENTRO OESTE', 'ÓLEO DIESEL'): [42612, 42613, 42614, 42615, 42639, 42640, 42641, 42642, 42666, 42667, 42668, 42669, 42693, 42694, 42695, 42696, 42720, 42721, 42722, 42723, 42747, 42748, 42749, 42750, 42774, 42775, 42776, 42777, 42801, 42802, 42803, 42804, 42828, 42829, 42830, 42831, 42855, 42856, 42857, 42858, 42882, 42883, 42884, 42885, 42909, 42910, 42911, 42912, 42936, 42937, 42938, 42939, 42963, 42964, 42965, 42966, 42990, 42991, 42992, 42993, 43017, 43018, 43019, 43020, 43044, 43045, 43046, 43047, 43071, 43072, 43073, 43074, 43098, 43099, 43100, 43101, 43125, 43126, 43127, 43128, 43152, 43153, 43154, 43155, 43179, 43180, 43181, 43182, 43206, 43207, 43208, 43209, 43233, 43234, 43235, 43236, 43260, 43261, 43262, 43263, ...], ('CENTRO OESTE', 'ÓLEO DIESEL S10'): [54834, 54835, 54973, 54975, 54976, 55117, 55119, 55120, 55260, 55262, 55264, 55265, 55405, 55407, 55408, 55549, 55551, 55552, 55692, 55694, 55695, 55835, 55837, 55838, 55981, 55983, 55984, 56128, 56130, 56131, 56276, 56278, 56279, 56421, 56423, 56424, 56566, 56568, 56569, 56711, 56713, 56714, 56854, 56856, 56858, 56859, 57002, 57004, 57006, 57007, 57148, 57150, 57152, 57153, 57293, 57295, 57297, 57298, 57440, 57442, 57444, 57445, 57586, 57588, 57590, 57591, 57732, 57734, 57736, 57737, ...

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1316802999.py in <cell line: 0>()
# ----> 1 grupos.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135670
#               GASOLINA COMUM       3.077476
#               GLP                 48.176747
#               GNV                  1.856312
#               ÓLEO DIESEL          2.481286
#               ÓLEO DIESEL S10      3.294752
# NORDESTE      ETANOL HIDRATADO     2.320266
#               GASOLINA COMUM       3.001887
#               GLP                 41.966090
#               GNV                  1.881722
#               ÓLEO DIESEL          2.346950
#               ÓLEO DIESEL S10      3.041966
# NORTE         ETANOL HIDRATADO     2.511624
#               GASOLINA COMUM       3.149501
#               GLP                 47.065572
#               GNV                  2.084399
#               ÓLEO DIESEL          2.571048
#               ÓLEO DIESEL S10      3.316231
# SUDESTE       ETANOL HIDRATADO     2.163621
#               GASOLINA COMUM       3.000565
#               GLP                 42.081544
#               GNV                  1.716074
#               ÓLEO DIESEL          2.339699
#               ÓLEO DIESEL S10      3.056194
# SUL           ETANOL HIDRATADO     2.268156
#               GASOLINA COMUM       2.972569
#               GLP                 43.490318
#               GNV                  1.865612
#               ÓLEO DIESEL          2.332293
#               ÓLEO DIESEL S10      2.981775
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
#              ÓLEO DIESEL S10   3032.0   3.041966   0.441550   2.130   2.60000
# NORTE        ETANOL HIDRATADO  5177.0   2.511624   0.646781   1.226   2.03300
#              GASOLINA COMUM    5464.0   3.149501   0.641249   1.995   2.70475
#              GLP               5327.0  47.065572  14.553748  28.086  36.32950
#              GNV                243.0   2.084399   0.622229   1.399   1.39900
#              ÓLEO DIESEL       5465.0   2.571048   0.650994   1.450   2.08600
#              ÓLEO DIESEL S10   2324.0   3.316231   0.529044   2.193   2.88300
# SUDESTE      ETANOL HIDRATADO  3137.0   2.163621   0.651486   0.766   1.69200
#              GASOLINA COMUM    3140.0   3.000565   0.698573   1.888   2.50200
#              GLP               3137.0  42.081544  11.524738  28.026  33.63600
#              GNV               2841.0   1.716074   0.462098   0.996   1.42400
#              ÓLEO DIESEL       3140.0   2.339699   0.588641   1.356   1.87600
#              ÓLEO DIESEL S10   1349.0   3.056194   0.418396   2.180   2.65000
# SUL          ETANOL HIDRATADO  2353.0   2.268156   0.702877   0.922   1.72100
#              GASOLINA COMUM    2354.0   2.972569   0.623557   1.961   2.54300
#              GLP               2343.0  43.490318  11.640755  29.440  34.79250
#              GNV               1899.0   1.865612   0.490703   1.168   1.49900
#              ÓLEO DIESEL       2354.0   2.332293   0.527845   1.374   1.95100
#              ÓLEO DIESEL S10   1012.0   2.981775   0.365470   2.151   2.66300
#
#                                    50%       75%     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   2.0005   2.47900   3.598
#              GASOLINA COMUM     2.8565   3.45975   4.963
#              GLP               42.8385  55.90425  99.357
#              GNV                1.7490   2.16800   3.239
#              ÓLEO DIESEL        2.2465   3.01900   4.162
#              ÓLEO DIESEL S10    3.3540   3.61900   4.200
# NORDESTE     ETANOL HIDRATADO   2.1860   2.67000   3.927
#              GASOLINA COMUM     2.7410   3.42450   4.951
#              GLP               36.8550  48.35100  79.630
#              GNV                1.8005   2.01125   3.811
#              ÓLEO DIESEL        2.0820   2.86700   4.010
#              ÓLEO DIESEL S10    3.0865   3.33800   4.027
# NORTE        ETANOL HIDRATADO   2.3390   2.89600   4.102
#              GASOLINA COMUM     2.9330   3.58475   5.362
#              GLP               42.3110  54.07500  87.270
#              GNV                2.0600   2.65000   3.240
#              ÓLEO DIESEL        2.3390   3.08200   4.774
#              ÓLEO DIESEL S10    3.3155   3.65300   4.878
# SUDESTE      ETANOL HIDRATADO   2.0430   2.56700   4.115
#              GASOLINA COMUM     2.7930   3.45150   5.119
#              GLP               38.2800  49.25900  79.192
#              GNV                1.6630   1.90400   3.399
#              ÓLEO DIESEL        2.0825   2.82500   3.994
#              ÓLEO DIESEL S10    3.0910   3.38600   4.080
# SUL          ETANOL HIDRATADO   2.1130   2.60100   4.287
#              GASOLINA COMUM     2.7315   3.34225   4.953
#              GLP               39.9760  48.73350  72.088
#              GNV                1.7020   2.15950   3.476
#              ÓLEO DIESEL        2.0900   2.78450   3.800
#              ÓLEO DIESEL S10    2.9910   3.25200   3.815

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])  # ignora o NaN
# Out:
# /tmp/ipython-input-4019042758.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum, min])  # ignora o NaN
# /tmp/ipython-input-4019042758.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum, min])  # ignora o NaN
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
# Computa o menor e maior valor do 'PREÇO MÉDIO REVENDA' para cada região (grupo)
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
# /tmp/ipython-input-2265528623.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# /tmp/ipython-input-2265528623.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.

# %%
data_final
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 103387        103387      103387   2019-06-23  2019-06-29      NORDESTE
# 103388        103388      103388   2019-06-23  2019-06-29           SUL
# 103389        103389      103389   2019-06-23  2019-06-29           SUL
# 103390        103390      103390   2019-06-23  2019-06-29       SUDESTE
# 103391        103391      103391   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103387  RIO GRANDE DO NORTE               GNV                             7
# 103388    RIO GRANDE DO SUL               GNV                            23
# 103389       SANTA CATARINA               GNV                            24
# 103390            SAO PAULO               GNV                            52
# 103391              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 103387             R$/m3                3.574  ...                 3.690
# 103388             R$/m3                3.401  ...                 3.789
# 103389             R$/m3                2.912  ...                 3.499
# 103390             R$/m3                3.020  ...                 3.490
# 103391             R$/m3                3.697  ...                 3.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                      0.240                     0.066
# ...                      ...                       ...
# 103387                 0.818                     0.018
# 103388                 0.950                     0.038
# 103389                 0.914                     0.065
# 103390                 0.646                     0.076
# 103391                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 103387                          0.000    6  2019
# 103388                          0.164    6  2019
# 103389                          0.000    6  2019
# 103390                          0.070    6  2019
# 103391                          0.000    6  2019
#
# [103392 rows x 22 columns]

# %% [markdown]
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_final.query('ANO != 2019')
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                 0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                 1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                 2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                 3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                 4           4   2004-05-09  2004-05-15      NORDESTE
# ...             ...         ...          ...         ...           ...
# 99734         99734       99734   2018-12-30  2019-01-05       SUDESTE
# 99735         99735       99735   2018-12-30  2019-01-05      NORDESTE
# 99736         99736       99736   2018-12-30  2019-01-05           SUL
# 99737         99737       99737   2018-12-30  2019-01-05           SUL
# 99738         99738       99738   2018-12-30  2019-01-05       SUDESTE
#
#                     ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0         DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                    GOIAS  ETANOL HIDRATADO                           387
# 2              MATO GROSSO  ETANOL HIDRATADO                           192
# 3       MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                  ALAGOAS  ETANOL HIDRATADO                           103
# ...                    ...               ...                           ...
# 99734       RIO DE JANEIRO               GNV                           122
# 99735  RIO GRANDE DO NORTE               GNV                            10
# 99736    RIO GRANDE DO SUL               GNV                            16
# 99737       SANTA CATARINA               GNV                            15
# 99738            SAO PAULO               GNV                            41
#
#       UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                  R$/l                1.288  ...                 1.350
# 1                  R$/l                1.162  ...                 1.449
# 2                  R$/l                1.389  ...                 1.760
# 3                  R$/l                1.262  ...                 1.509
# 4                  R$/l                1.181  ...                 1.400
# ...                 ...                  ...  ...                   ...
# 99734             R$/m3                3.080  ...                 3.999
# 99735             R$/m3                3.465  ...                 3.590
# 99736             R$/m3                3.402  ...                 3.499
# 99737             R$/m3                2.944  ...                 3.199
# 99738             R$/m3                2.353  ...                 3.429
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                     0.240                     0.066
# ...                     ...                       ...
# 99734                 0.699                     0.085
# 99735                 0.759                     0.017
# 99736                 1.296                     0.030
# 99737                 0.670                     0.042
# 99738                 0.467                     0.192
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 99734                          0.068   12  2018
# 99735                          0.000   12  2018
# 99736                          0.118   12  2018
# 99737                          0.124   12  2018
# 99738                          0.133   12  2018
#
# [99739 rows x 22 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas.

# %%
df = data_final.query('ANO != 2019')

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                 0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                 1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                 2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                 3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                 4           4   2004-05-09  2004-05-15      NORDESTE
# ...             ...         ...          ...         ...           ...
# 99734         99734       99734   2018-12-30  2019-01-05       SUDESTE
# 99735         99735       99735   2018-12-30  2019-01-05      NORDESTE
# 99736         99736       99736   2018-12-30  2019-01-05           SUL
# 99737         99737       99737   2018-12-30  2019-01-05           SUL
# 99738         99738       99738   2018-12-30  2019-01-05       SUDESTE
#
#                     ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0         DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                    GOIAS  ETANOL HIDRATADO                           387
# 2              MATO GROSSO  ETANOL HIDRATADO                           192
# 3       MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                  ALAGOAS  ETANOL HIDRATADO                           103
# ...                    ...               ...                           ...
# 99734       RIO DE JANEIRO               GNV                           122
# 99735  RIO GRANDE DO NORTE               GNV                            10
# 99736    RIO GRANDE DO SUL               GNV                            16
# 99737       SANTA CATARINA               GNV                            15
# 99738            SAO PAULO               GNV                            41
#
#       UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                  R$/l                1.288  ...                 1.350
# 1                  R$/l                1.162  ...                 1.449
# 2                  R$/l                1.389  ...                 1.760
# 3                  R$/l                1.262  ...                 1.509
# 4                  R$/l                1.181  ...                 1.400
# ...                 ...                  ...  ...                   ...
# 99734             R$/m3                3.080  ...                 3.999
# 99735             R$/m3                3.465  ...                 3.590
# 99736             R$/m3                3.402  ...                 3.499
# 99737             R$/m3                2.944  ...                 3.199
# 99738             R$/m3                2.353  ...                 3.429
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                     0.463                     0.012
# 1                     0.399                     0.098
# 2                     0.419                     0.070
# 3                     0.432                     0.055
# 4                     0.240                     0.066
# ...                     ...                       ...
# 99734                 0.699                     0.085
# 99735                 0.759                     0.017
# 99736                 1.296                     0.030
# 99737                 0.670                     0.042
# 99738                 0.467                     0.192
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 99734                          0.068   12  2018
# 99735                          0.000   12  2018
# 99736                          0.118   12  2018
# 99737                          0.124   12  2018
# 99738                          0.133   12  2018
#
# [99739 rows x 22 columns]

# %% [markdown]
# ### 7.1 Qual a quantidade de registros de cada produto em cada região?

# %%
grupos = df.groupby('PRODUTO')
grupos

# %%
grupos['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6821
#                  NORTE          5021
#                  SUDESTE        3039
#                  CENTRO OESTE   3022
#                  SUL            2278
# GASOLINA COMUM   NORDESTE       6838
#                  NORTE          5289
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# GLP              NORDESTE       6185
#                  NORTE          5152
#                  SUDESTE        3037
#                  CENTRO OESTE   2998
#                  SUL            2268
# GNV              NORDESTE       5030
#                  SUDESTE        2772
#                  SUL            1847
#                  CENTRO OESTE    825
#                  NORTE           233
# ÓLEO DIESEL      NORDESTE       6836
#                  NORTE          5290
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# ÓLEO DIESEL S10  NORDESTE       2807
#                  NORTE          2149
#                  SUDESTE        1249
#                  CENTRO OESTE   1110
#                  SUL             937

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolina_sp_2018 = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_sp_2018.head()
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92319         92319       92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92465         92465       92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92610         92610       92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# 92755         92755       92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO
# 92901         92901       92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92319  GASOLINA COMUM                          1641              R$/l
# 92465  GASOLINA COMUM                          1648              R$/l
# 92610  GASOLINA COMUM                          1648              R$/l
# 92755  GASOLINA COMUM                          1644              R$/l
# 92901  GASOLINA COMUM                          1646              R$/l
#
#        PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 92319                3.988  ...                 4.599                 0.411
# 92465                4.002  ...                 4.499                 0.412
# 92610                4.006  ...                 4.899                 0.410
# 92755                4.019  ...                 4.699                 0.423
# 92901                4.004  ...                 4.597                 0.416
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92319                     0.039                     3.577
# 92465                     0.039                     3.590
# 92610                     0.040                     3.596
# 92755                     0.039                     3.596
# 92901                     0.039                     3.588
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92319                       0.104                      2.990
# 92465                       0.102                      2.990
# 92610                       0.102                      2.990
# 92755                       0.107                      2.924
# 92901                       0.102                      2.990
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 92319                     3.9510                          0.029    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92610                     3.9014                          0.028    1  2018
# 92755                     3.9537                          0.030    1  2018
# 92901                     3.9537                          0.028    2  2018
#
# [5 rows x 22 columns]

# %%
gasolina_sp_2018.shape
# Out:
# (52, 22)

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
gasolina_sp_2018.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count     52.000000     52.000000                     52.000000
# mean   96011.153846  96011.153846                   1610.211538
# std     2189.712340   2189.712340                    213.627432
# min    92319.000000  92319.000000                    102.000000
# 25%    94178.750000  94178.750000                   1639.000000
# 50%    95995.500000  95995.500000                   1642.000000
# 75%    97856.250000  97856.250000                   1644.000000
# max    99698.000000  99698.000000                   1649.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count            52.000000              52.000000             52.000000
# mean              4.202769               0.175500              3.671500
# std               0.180672               0.017955              0.163808
# min               3.970000               0.150000              3.369000
# 25%               4.008000               0.159750              3.499000
# 50%               4.202000               0.173000              3.679000
# 75%               4.336250               0.189000              3.784000
# max               4.512000               0.216000              3.969000
#
#        PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count             52.000000             52.000000                 52.000000
# mean               4.975750              0.442481                  0.041750
# std                0.211198              0.063271                  0.003965
# min                4.499000              0.366000                  0.034000
# 25%                4.899000              0.404500                  0.039000
# 50%                4.999000              0.421500                  0.040000
# 75%                5.099000              0.470250                  0.044000
# max                5.299000              0.640000                  0.051000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count                 52.000000                   52.000000
# mean                   3.760288                    0.109654
# std                    0.163664                    0.010712
# min                    3.563000                    0.087000
# 25%                    3.620250                    0.102000
# 50%                    3.756500                    0.108000
# 75%                    3.862250                    0.116250
# max                    4.085000                    0.144000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count                   52.00000                  52.000000
# mean                     3.31295                   4.139454
# std                      0.26684                   0.195897
# min                      2.92400                   3.887500
# 25%                      2.99000                   3.965775
# 50%                      3.35000                   4.095500
# 75%                      3.53250                   4.259000
# max                      3.76000                   4.551000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS     ANO
# count                      52.000000  52.000000    52.0
# mean                        0.029096   6.615385  2018.0
# std                         0.002460   3.470627     0.0
# min                         0.023000   1.000000  2018.0
# 25%                         0.028000   4.000000  2018.0
# 50%                         0.029000   7.000000  2018.0
# 75%                         0.030000   9.250000  2018.0
# max                         0.037000  12.000000  2018.0

# %%
gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238         92238       92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319         92319       92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384         92384       92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465         92465       92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529         92529       92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...             ...         ...          ...         ...      ...        ...
# 99410         99410       99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472         99472       99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553         99553       99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617         99617       99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698         99698       99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# 92319    GASOLINA COMUM                          1641              R$/l
# 92384  ETANOL HIDRATADO                          1661              R$/l
# 92465    GASOLINA COMUM                          1648              R$/l
# 92529  ETANOL HIDRATADO                          1662              R$/l
# ...                 ...                           ...               ...
# 99410    GASOLINA COMUM                          1637              R$/l
# 99472  ETANOL HIDRATADO                          1662              R$/l
# 99553    GASOLINA COMUM                          1641              R$/l
# 99617  ETANOL HIDRATADO                          1661              R$/l
# 99698    GASOLINA COMUM                          1643              R$/l
#
#        PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 92238                2.833  ...                 3.399                 0.338
# 92319                3.988  ...                 4.599                 0.411
# 92384                2.868  ...                 3.399                 0.331
# 92465                4.002  ...                 4.499                 0.412
# 92529                2.874  ...                 3.399                 0.324
# ...                    ...  ...                   ...                   ...
# 99410                4.129  ...                 5.099                 0.490
# 99472                2.644  ...                 3.699                 0.305
# 99553                4.129  ...                 4.999                 0.484
# 99617                2.643  ...                 3.699                 0.303
# 99698                4.113  ...                 4.999                 0.503
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92238                     0.049                     2.495
# 92319                     0.039                     3.577
# 92384                     0.047                     2.537
# 92465                     0.039                     3.590
# 92529                     0.047                     2.550
# ...                         ...                       ...
# 99410                     0.049                     3.639
# 99472                     0.062                     2.339
# 99553                     0.049                     3.645
# 99617                     0.061                     2.340
# 99698                     0.049                     3.610
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92238                       0.092                     2.1842
# 92319                       0.104                     2.9900
# 92384                       0.087                     2.2600
# 92465                       0.102                     2.9900
# 92529                       0.095                     1.6900
# ...                           ...                        ...
# 99410                       0.110                     3.3500
# 99472                       0.094                     2.0067
# 99553                       0.107                     3.3500
# 99617                       0.097                     1.9072
# 99698                       0.100                     3.3500
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 92238                     2.8833                          0.037    1  2018
# 92319                     3.9510                          0.029    1  2018
# 92384                     2.8471                          0.034    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92529                     2.9722                          0.037    1  2018
# ...                          ...                            ...  ...   ...
# 99410                     3.9892                          0.030   12  2018
# 99472                     2.7443                          0.040   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99617                     2.7957                          0.041   12  2018
# 99698                     3.9585                          0.028   12  2018
#
# [104 rows x 22 columns]

# %%
lista_de_estados = ["GASOLINA COMUM", "ETANOL HIDRATADO"]
df.query('PRODUTO in @lista_de_estados and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238         92238       92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319         92319       92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384         92384       92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465         92465       92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529         92529       92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...             ...         ...          ...         ...      ...        ...
# 99410         99410       99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472         99472       99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553         99553       99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617         99617       99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698         99698       99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# 92319    GASOLINA COMUM                          1641              R$/l
# 92384  ETANOL HIDRATADO                          1661              R$/l
# 92465    GASOLINA COMUM                          1648              R$/l
# 92529  ETANOL HIDRATADO                          1662              R$/l
# ...                 ...                           ...               ...
# 99410    GASOLINA COMUM                          1637              R$/l
# 99472  ETANOL HIDRATADO                          1662              R$/l
# 99553    GASOLINA COMUM                          1641              R$/l
# 99617  ETANOL HIDRATADO                          1661              R$/l
# 99698    GASOLINA COMUM                          1643              R$/l
#
#        PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 92238                2.833  ...                 3.399                 0.338
# 92319                3.988  ...                 4.599                 0.411
# 92384                2.868  ...                 3.399                 0.331
# 92465                4.002  ...                 4.499                 0.412
# 92529                2.874  ...                 3.399                 0.324
# ...                    ...  ...                   ...                   ...
# 99410                4.129  ...                 5.099                 0.490
# 99472                2.644  ...                 3.699                 0.305
# 99553                4.129  ...                 4.999                 0.484
# 99617                2.643  ...                 3.699                 0.303
# 99698                4.113  ...                 4.999                 0.503
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92238                     0.049                     2.495
# 92319                     0.039                     3.577
# 92384                     0.047                     2.537
# 92465                     0.039                     3.590
# 92529                     0.047                     2.550
# ...                         ...                       ...
# 99410                     0.049                     3.639
# 99472                     0.062                     2.339
# 99553                     0.049                     3.645
# 99617                     0.061                     2.340
# 99698                     0.049                     3.610
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92238                       0.092                     2.1842
# 92319                       0.104                     2.9900
# 92384                       0.087                     2.2600
# 92465                       0.102                     2.9900
# 92529                       0.095                     1.6900
# ...                           ...                        ...
# 99410                       0.110                     3.3500
# 99472                       0.094                     2.0067
# 99553                       0.107                     3.3500
# 99617                       0.097                     1.9072
# 99698                       0.100                     3.3500
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 92238                     2.8833                          0.037    1  2018
# 92319                     3.9510                          0.029    1  2018
# 92384                     2.8471                          0.034    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92529                     2.9722                          0.037    1  2018
# ...                          ...                            ...  ...   ...
# 99410                     3.9892                          0.030   12  2018
# 99472                     2.7443                          0.040   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99617                     2.7957                          0.041   12  2018
# 99698                     3.9585                          0.028   12  2018
#
# [104 rows x 22 columns]

# %%
gasolina_etanol_sp_2018 = df.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_etanol_sp_2018
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238         92238       92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319         92319       92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384         92384       92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465         92465       92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529         92529       92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...             ...         ...          ...         ...      ...        ...
# 99410         99410       99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472         99472       99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553         99553       99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617         99617       99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698         99698       99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# 92319    GASOLINA COMUM                          1641              R$/l
# 92384  ETANOL HIDRATADO                          1661              R$/l
# 92465    GASOLINA COMUM                          1648              R$/l
# 92529  ETANOL HIDRATADO                          1662              R$/l
# ...                 ...                           ...               ...
# 99410    GASOLINA COMUM                          1637              R$/l
# 99472  ETANOL HIDRATADO                          1662              R$/l
# 99553    GASOLINA COMUM                          1641              R$/l
# 99617  ETANOL HIDRATADO                          1661              R$/l
# 99698    GASOLINA COMUM                          1643              R$/l
#
#        PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 92238                2.833  ...                 3.399                 0.338
# 92319                3.988  ...                 4.599                 0.411
# 92384                2.868  ...                 3.399                 0.331
# 92465                4.002  ...                 4.499                 0.412
# 92529                2.874  ...                 3.399                 0.324
# ...                    ...  ...                   ...                   ...
# 99410                4.129  ...                 5.099                 0.490
# 99472                2.644  ...                 3.699                 0.305
# 99553                4.129  ...                 4.999                 0.484
# 99617                2.643  ...                 3.699                 0.303
# 99698                4.113  ...                 4.999                 0.503
#
#        COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 92238                     0.049                     2.495
# 92319                     0.039                     3.577
# 92384                     0.047                     2.537
# 92465                     0.039                     3.590
# 92529                     0.047                     2.550
# ...                         ...                       ...
# 99410                     0.049                     3.639
# 99472                     0.062                     2.339
# 99553                     0.049                     3.645
# 99617                     0.061                     2.340
# 99698                     0.049                     3.610
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92238                       0.092                     2.1842
# 92319                       0.104                     2.9900
# 92384                       0.087                     2.2600
# 92465                       0.102                     2.9900
# 92529                       0.095                     1.6900
# ...                           ...                        ...
# 99410                       0.110                     3.3500
# 99472                       0.094                     2.0067
# 99553                       0.107                     3.3500
# 99617                       0.097                     1.9072
# 99698                       0.100                     3.3500
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 92238                     2.8833                          0.037    1  2018
# 92319                     3.9510                          0.029    1  2018
# 92384                     2.8471                          0.034    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92529                     2.9722                          0.037    1  2018
# ...                          ...                            ...  ...   ...
# 99410                     3.9892                          0.030   12  2018
# 99472                     2.7443                          0.040   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99617                     2.7957                          0.041   12  2018
# 99698                     3.9585                          0.028   12  2018
#
# [104 rows x 22 columns]

# %%
# considerando os preços do etanol e da gasolina juntos, teremos essas estatística descritivas
gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
