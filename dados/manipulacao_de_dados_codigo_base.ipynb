# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv('./sample_data/GasPricesinBrazil_2004-2019 (2).csv', sep=';')

# %%
# !ls ./sample_data/
# Out:
#  anscombe.json			        mnist_test.csv
#  california_housing_test.csv	        mnist_train_small.csv
#  california_housing_train.csv	        README.md
# 'GasPricesinBrazil_2004-2019 (2).csv'

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
# mostrando as 10 primeiras linhas da dataframe
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (106823, 21)

# %%
print(f'O dataset possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atributos/variaveis.')
# Out:
# O dataset possui 106823 linhas/observações/registros e 21 colunas/atributos/variaveis.

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame ({
    'nome': ['Luke Skywalker, Yoda, Palpatine'],
    'idade': ['16, 1000, 70'],
    'peso': ['70.5, 15.2, 60.1'],
    'eh jedi': ['True, True, False']

})

# %%
personagens_df
# Out:
#                               nome         idade              peso  \
# 0  Luke Skywalker, Yoda, Palpatine  16, 1000, 70  70.5, 15.2, 60.1
#
#              eh jedi
# 0  True, True, False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     1 non-null      object
#  1   idade    1 non-null      object
#  2   peso     1 non-null      object
#  3   eh jedi  1 non-null      object
# dtypes: object(4)
# memory usage: 164.0+ bytes

# %%
personagens_df.columns
# Out:
# Index(['NOME', 'IDADE', 'PESO', 'EH_JEDI'], dtype='object')

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
type(personagens_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df
# Out:
#                               nome         idade              peso  \
# 0  Luke Skywalker, Yoda, Palpatine  16, 1000, 70  70.5, 15.2, 60.1
#
#              eh jedi
# 0  True, True, False

# %%
personagens_df_renomeado = personagens_df.rename(columns={
    'nome': 'Nome Completo',
    'idade': 'Idade',

})

# %%
personagens_df_renomeado
# Out:
#                      Nome Completo         Idade              peso  \
# 0  Luke Skywalker, Yoda, Palpatine  16, 1000, 70  70.5, 15.2, 60.1
#
#              eh jedi
# 0  True, True, False

# %%
personagens_df
# Out:
#                               nome         idade              peso  \
# 0  Luke Skywalker, Yoda, Palpatine  16, 1000, 70  70.5, 15.2, 60.1
#
#              eh jedi
# 0  True, True, False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
personagens_df.rename(columns={'nome': 'Nome Completo','idade': 'Idade'}, inplace=True)

# %%
personagens_df
# Out:
#                      Nome Completo         Idade              peso  \
# 0  Luke Skywalker, Yoda, Palpatine  16, 1000, 70  70.5, 15.2, 60.1
#
#              eh jedi
# 0  True, True, False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df.columns = ['NOME','IDADE','PESO', 'EH_JEDI']

# %%
personagens_df
# Out:
#                               NOME         IDADE              PESO  \
# 0  Luke Skywalker, Yoda, Palpatine  16, 1000, 70  70.5, 15.2, 60.1
#
#              EH_JEDI
# 0  True, True, False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
# selecionando uma coluna inteira
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# só funciona se não tiver espaços ou caracteres
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
pd.Series([5.5, 6.0, 9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5, 6.0, 9.5], index = ['prova 1', 'prova 2', 'projeto'], name ='Notas do Luke Skywalker' )
# Out:
# prova 1    5.5
# prova 2    6.0
# projeto    9.5
# Name: Notas do Luke Skywalker, dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_view = data['PRODUTO'] # não é uma cópia
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp = data['PRODUTO'].copy() # Retorna uma cópia da coluna "produto"
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = 'Combustivel'
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustivel                           127              R$/l
# 1  Combustivel                           387              R$/l
# 2  Combustivel                           192              R$/l
# 3  Combustivel                           162              R$/l
# 4  Combustivel                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Combustivel {i}' for i in range(nrows) ]
len(novos_produtos)
# Out:
# 106823

# %%
# a quantidade de elementos na lista "novos_produtos" é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO             PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Combustivel 0                           127
# 1                     GOIAS       Combustivel 1                           387
# 2               MATO GROSSO       Combustivel 2                           192
# 3        MATO GROSSO DO SUL       Combustivel 3                           162
# 4                   ALAGOAS       Combustivel 4                           103
# ...                     ...                 ...                           ...
# 106818  RIO GRANDE DO NORTE  Combustivel 106818                             7
# 106819    RIO GRANDE DO SUL  Combustivel 106819                            23
# 106820       SANTA CATARINA  Combustivel 106820                            24
# 106821            SAO PAULO  Combustivel 106821                            52
# 106822              SERGIPE  Combustivel 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
print(produto_view)
print('\n')
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# voltando para o produto original
data['PRODUTO'] = produto_copy_bkp # produto_copy_bkp é uma Series

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# criando uma coluna a partir do valor constante/default
# todas as linhas terão o mesmo valor para esta nova coluna
data ['coluna sem nocao'] = 'DEFAULT'
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  coluna sem nocao
# 0                              0.133   5  2004           DEFAULT
# 1                              0.115   5  2004           DEFAULT
# 2                              0.098   5  2004           DEFAULT
# 3                              0.143   5  2004           DEFAULT
# 4                              0.082   5  2004           DEFAULT
# ...                              ...  ..   ...               ...
# 106818                             0   6  2019           DEFAULT
# 106819                         0.164   6  2019           DEFAULT
# 106820                             0   6  2019           DEFAULT
# 106821                          0.07   6  2019           DEFAULT
# 106822                             0   6  2019           DEFAULT
#
# [106823 rows x 22 columns]

# %%
data['coluna a partir de lista'] = range(data.shape[0])

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        coluna sem nocao  coluna a partir de lista
# 0               DEFAULT                         0
# 1               DEFAULT                         1
# 2               DEFAULT                         2
# 3               DEFAULT                         3
# 4               DEFAULT                         4
# ...                 ...                       ...
# 106818          DEFAULT                    106818
# 106819          DEFAULT                    106819
# 106820          DEFAULT                    106820
# 106821          DEFAULT                    106821
# 106822          DEFAULT                    106822
#
# [106823 rows x 23 columns]

# %%
# Para atribuir o mesmo valor a todas as linhas, atribua um escalar (valor único)
data['nova_coluna_valor_unico'] = '1, 2, 3'

# Para atribuir valores diferentes, a lista deve ter o mesmo número de elementos que o DataFrame
# Por exemplo, se você quisesse atribuir os números 1, 2, 3 e NaN para o resto (exemplo hipotético):
# import numpy as np
# valores = ['1', '2', '3'] + [np.nan] * (data.shape[0] - 3)
# data['nova_coluna_lista'] = valores

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
#
# [5 rows x 24 columns]

# %%
data['PREÇO MÉDIA REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] *6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                             0.11                     0.4201
# 1                            0.088                     0.5013
# 2                            0.095                     0.5614
# 3                            0.119                     0.5991
# 4                            0.077                     0.7441
# ...                            ...                        ...
# 106818                           0                      2.756
# 106819                       0.402                     1.9842
# 106820                           0                     1.9981
# 106821                       0.165                     2.0179
# 106822                           0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                          0.133   5  2004
# 1                           1.05                          0.115   5  2004
# 2                          1.161                          0.098   5  2004
# 3                        1.22242                          0.143   5  2004
# 4                         1.0317                          0.082   5  2004
# ...                          ...                            ...  ..   ...
# 106818                     2.756                              0   6  2019
# 106819                    2.8661                          0.164   6  2019
# 106820                    1.9981                              0   6  2019
# 106821                    2.5093                           0.07   6  2019
# 106822                    2.5175                              0   6  2019
#
#        coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0               DEFAULT                        0                 1, 2, 3
# 1               DEFAULT                        1                 1, 2, 3
# 2               DEFAULT                        2                 1, 2, 3
# 3               DEFAULT                        3                 1, 2, 3
# 4               DEFAULT                        4                 1, 2, 3
# ...                 ...                      ...                     ...
# 106818          DEFAULT                   106818                 1, 2, 3
# 106819          DEFAULT                   106819                 1, 2, 3
# 106820          DEFAULT                   106820                 1, 2, 3
# 106821          DEFAULT                   106821                 1, 2, 3
# 106822          DEFAULT                   106822                 1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 25 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                             0.11                     0.4201
# 1                            0.088                     0.5013
# 2                            0.095                     0.5614
# 3                            0.119                     0.5991
# 4                            0.077                     0.7441
# ...                            ...                        ...
# 106818                           0                      2.756
# 106819                       0.402                     1.9842
# 106820                           0                     1.9981
# 106821                       0.165                     2.0179
# 106822                           0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                          0.133   5  2004
# 1                           1.05                          0.115   5  2004
# 2                          1.161                          0.098   5  2004
# 3                        1.22242                          0.143   5  2004
# 4                         1.0317                          0.082   5  2004
# ...                          ...                            ...  ..   ...
# 106818                     2.756                              0   6  2019
# 106819                    2.8661                          0.164   6  2019
# 106820                    1.9981                              0   6  2019
# 106821                    2.5093                           0.07   6  2019
# 106822                    2.5175                              0   6  2019
#
#        coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0               DEFAULT                        0                 1, 2, 3
# 1               DEFAULT                        1                 1, 2, 3
# 2               DEFAULT                        2                 1, 2, 3
# 3               DEFAULT                        3                 1, 2, 3
# 4               DEFAULT                        4                 1, 2, 3
# ...                 ...                      ...                     ...
# 106818          DEFAULT                   106818                 1, 2, 3
# 106819          DEFAULT                   106819                 1, 2, 3
# 106820          DEFAULT                   106820                 1, 2, 3
# 106821          DEFAULT                   106821                 1, 2, 3
# 106822          DEFAULT                   106822                 1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 25 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                1.288                  0.016  ...
# 1                1.162                  0.114  ...
# 2                1.389                  0.097  ...
# 3                1.262                  0.070  ...
# 4                1.181                  0.078  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                          0.133   5  2004
# 1                      1.05                          0.115   5  2004
# 2                     1.161                          0.098   5  2004
# 3                   1.22242                          0.143   5  2004
# 4                    1.0317                          0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0          DEFAULT                        0                 1, 2, 3
# 1          DEFAULT                        1                 1, 2, 3
# 2          DEFAULT                        2                 1, 2, 3
# 3          DEFAULT                        3                 1, 2, 3
# 4          DEFAULT                        4                 1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 25 columns]

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
# selecionando a linha 1
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# nova_coluna_valor_unico                   1, 2, 3
# PREÇO MÉDIA REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
# selecionando linhas de 0 a 5
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                1.288                  0.016  ...
# 1                1.162                  0.114  ...
# 2                1.389                  0.097  ...
# 3                1.262                  0.070  ...
# 4                1.181                  0.078  ...
# 5                1.383                  0.132  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
# 5                       0.128                     0.5686
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                          0.133   5  2004
# 1                      1.05                          0.115   5  2004
# 2                     1.161                          0.098   5  2004
# 3                   1.22242                          0.143   5  2004
# 4                    1.0317                          0.082   5  2004
# 5                      1.35                          0.134   5  2004
#
#   coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0          DEFAULT                        0                 1, 2, 3
# 1          DEFAULT                        1                 1, 2, 3
# 2          DEFAULT                        2                 1, 2, 3
# 3          DEFAULT                        3                 1, 2, 3
# 4          DEFAULT                        4                 1, 2, 3
# 5          DEFAULT                        5                 1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
# 5                          8.298
#
# [6 rows x 25 columns]

# %%
# selecionando linhas de 10 a 15
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 10                1.573                  0.134  ...
# 11                1.276                  0.116  ...
# 12                1.301                  0.109  ...
# 13                1.805                  0.134  ...
# 14                1.785                  0.035  ...
# 15                1.578                  0.123  ...
#
#     DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                     0.8857
# 11                       0.078                     0.7119
# 12                       0.052                     0.8267
# 13                       0.171                      0.767
# 14                       0.167                     0.8339
# 15                       0.068                     0.9515
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 10                    1.2499                          0.072   5  2004
# 11                    1.1386                          0.083   5  2004
# 12                    1.1059                          0.053   5  2004
# 13                    1.2992                          0.153   5  2004
# 14                    1.4912                          0.122   5  2004
# 15                    1.2109                           0.06   5  2004
#
#    coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 10          DEFAULT                       10                 1, 2, 3
# 11          DEFAULT                       11                 1, 2, 3
# 12          DEFAULT                       12                 1, 2, 3
# 13          DEFAULT                       13                 1, 2, 3
# 14          DEFAULT                       14                 1, 2, 3
# 15          DEFAULT                       15                 1, 2, 3
#
#     PREÇO MÉDIA REVENDA (dólares)
# 10                          9.438
# 11                          7.656
# 12                          7.806
# 13                         10.830
# 14                         10.710
# 15                          9.468
#
# [6 rows x 25 columns]

# %%
# selecionando as linhas de indice 1, 5, 10, 15
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 1                 1.162                  0.114  ...
# 5                 1.383                  0.132  ...
# 10                1.573                  0.134  ...
# 15                1.578                  0.123  ...
#
#     DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                     0.5013
# 5                        0.128                     0.5686
# 10                       0.078                     0.8857
# 15                       0.068                     0.9515
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                       1.05                          0.115   5  2004
# 5                       1.35                          0.134   5  2004
# 10                    1.2499                          0.072   5  2004
# 15                    1.2109                           0.06   5  2004
#
#    coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 1           DEFAULT                        1                 1, 2, 3
# 5           DEFAULT                        5                 1, 2, 3
# 10          DEFAULT                       10                 1, 2, 3
# 15          DEFAULT                       15                 1, 2, 3
#
#     PREÇO MÉDIA REVENDA (dólares)
# 1                           6.972
# 5                           8.298
# 10                          9.438
# 15                          9.468
#
# [4 rows x 25 columns]

# %%
# selecionando as linahas do indices 5, 1, 15, 10
data.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 5                 1.383                  0.132  ...
# 1                 1.162                  0.114  ...
# 15                1.578                  0.123  ...
# 10                1.573                  0.134  ...
#
#     DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                     0.5686
# 1                        0.088                     0.5013
# 15                       0.068                     0.9515
# 10                       0.078                     0.8857
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                       1.35                          0.134   5  2004
# 1                       1.05                          0.115   5  2004
# 15                    1.2109                           0.06   5  2004
# 10                    1.2499                          0.072   5  2004
#
#    coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 5           DEFAULT                        5                 1, 2, 3
# 1           DEFAULT                        1                 1, 2, 3
# 15          DEFAULT                       15                 1, 2, 3
# 10          DEFAULT                       10                 1, 2, 3
#
#     PREÇO MÉDIA REVENDA (dólares)
# 5                           8.298
# 1                           6.972
# 15                          9.468
# 10                          9.438
#
# [4 rows x 25 columns]

# %%
# retornar o valor da linha de indice 1, coluna 4 ('ESTADO')
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# retorna o valor do indice 0
pesquisa_de_satisfacao.iloc[0, 1]
# Out:
# np.int64(131)

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# NÃO FUNCIONA
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna o valor da linha  'Playstation'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# np.int64(2)

# %%
# selecionando as linhas dos indices 'XboxOne', 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
# retorna todas as linhas e apenas colunas com rotulos 'bom' e 'pessimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# OBSERVAÇÃO

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                1.288                  0.016  ...
# 1                1.162                  0.114  ...
# 2                1.389                  0.097  ...
# 3                1.262                  0.070  ...
# 4                1.181                  0.078  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                          0.133   5  2004
# 1                      1.05                          0.115   5  2004
# 2                     1.161                          0.098   5  2004
# 3                   1.22242                          0.143   5  2004
# 4                    1.0317                          0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0          DEFAULT                        0                 1, 2, 3
# 1          DEFAULT                        1                 1, 2, 3
# 2          DEFAULT                        2                 1, 2, 3
# 3          DEFAULT                        3                 1, 2, 3
# 4          DEFAULT                        4                 1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 25 columns]

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# nova_coluna_valor_unico                   1, 2, 3
# PREÇO MÉDIA REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# nova_coluna_valor_unico                   1, 2, 3
# PREÇO MÉDIA REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                1.288                  0.016  ...
# 1                1.162                  0.114  ...
# 2                1.389                  0.097  ...
# 3                1.262                  0.070  ...
# 4                1.181                  0.078  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                          0.133   5  2004
# 1                      1.05                          0.115   5  2004
# 2                     1.161                          0.098   5  2004
# 3                   1.22242                          0.143   5  2004
# 4                    1.0317                          0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0          DEFAULT                        0                 1, 2, 3
# 1          DEFAULT                        1                 1, 2, 3
# 2          DEFAULT                        2                 1, 2, 3
# 3          DEFAULT                        3                 1, 2, 3
# 4          DEFAULT                        4                 1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 25 columns]

# %%
# retornando a coluna 'estado'
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# usando . só funciona sem  caracteres
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
# selecionando varias colunas
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                1.288                  0.016  ...
# 1                1.162                  0.114  ...
# 2                1.389                  0.097  ...
# 3                1.262                  0.070  ...
# 4                1.181                  0.078  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                          0.133   5  2004
# 1                      1.05                          0.115   5  2004
# 2                     1.161                          0.098   5  2004
# 3                   1.22242                          0.143   5  2004
# 4                    1.0317                          0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista nova_coluna_valor_unico  \
# 0          DEFAULT                        0                 1, 2, 3
# 1          DEFAULT                        1                 1, 2, 3
# 2          DEFAULT                        2                 1, 2, 3
# 3          DEFAULT                        3                 1, 2, 3
# 4          DEFAULT                        4                 1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 25 columns]

# %%
# deleta no próprio dataframe a coluna de rótulo
del data['Unnamed: 0']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                             0.11                    0.4201
# 1                            0.088                    0.5013
# 2                            0.095                    0.5614
# 3                            0.119                    0.5991
# 4                            0.077                    0.7441
# ...                            ...                       ...
# 106818                           0                     2.756
# 106819                       0.402                    1.9842
# 106820                           0                    1.9981
# 106821                       0.165                    2.0179
# 106822                           0                    2.5175
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                          0.9666                         0.133   5  2004
# 1                            1.05                         0.115   5  2004
# 2                           1.161                         0.098   5  2004
# 3                         1.22242                         0.143   5  2004
# 4                          1.0317                         0.082   5  2004
# ...                           ...                           ...  ..   ...
# 106818                      2.756                             0   6  2019
# 106819                     2.8661                         0.164   6  2019
# 106820                     1.9981                             0   6  2019
# 106821                     2.5093                          0.07   6  2019
# 106822                     2.5175                             0   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0               DEFAULT                        0                  1, 2, 3
# 1               DEFAULT                        1                  1, 2, 3
# 2               DEFAULT                        2                  1, 2, 3
# 3               DEFAULT                        3                  1, 2, 3
# 4               DEFAULT                        4                  1, 2, 3
# ...                 ...                      ...                      ...
# 106818          DEFAULT                   106818                  1, 2, 3
# 106819          DEFAULT                   106819                  1, 2, 3
# 106820          DEFAULT                   106820                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
# 106822          DEFAULT                   106822                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 24 columns]

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./sample_data/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %%
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 24)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                         1.4123                         0.098   5  2004
# 50                         0.9724                         0.087   5  2004
# 77                          1.412                         0.103   5  2004
# 104                        1.0669                         0.112   5  2004
# 131                        1.0669                         0.104   6  2004
# ...                           ...                           ...  ..   ...
# 106724                     3.3481                         0.032   6  2019
# 106751                      3.491                         0.036   6  2019
# 106778                     4.0892                         0.026   6  2019
# 106805                         72                         0.103   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23              DEFAULT                       23                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 77              DEFAULT                       77                  1, 2, 3
# 104             DEFAULT                      104                  1, 2, 3
# 131             DEFAULT                      131                  1, 2, 3
# ...                 ...                      ...                      ...
# 106724          DEFAULT                   106724                  1, 2, 3
# 106751          DEFAULT                   106751                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 23                              4.608
# 50                              4.596
# 77                              4.938
# 104                             5.322
# 131                             5.364
# ...                               ...
# 106724                         20.688
# 106751                         21.444
# 106778                         24.852
# 106805                        401.358
# 106821                         18.120
#
# [4263 rows x 24 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                         1.4123                         0.098   5  2004
# 50                         0.9724                         0.087   5  2004
# 77                          1.412                         0.103   5  2004
# 104                        1.0669                         0.112   5  2004
# 131                        1.0669                         0.104   6  2004
# ...                           ...                           ...  ..   ...
# 106724                     3.3481                         0.032   6  2019
# 106751                      3.491                         0.036   6  2019
# 106778                     4.0892                         0.026   6  2019
# 106805                         72                         0.103   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23              DEFAULT                       23                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 77              DEFAULT                       77                  1, 2, 3
# 104             DEFAULT                      104                  1, 2, 3
# 131             DEFAULT                      131                  1, 2, 3
# ...                 ...                      ...                      ...
# 106724          DEFAULT                   106724                  1, 2, 3
# 106751          DEFAULT                   106751                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 23                              4.608
# 50                              4.596
# 77                              4.938
# 104                             5.322
# 131                             5.364
# ...                               ...
# 106724                         20.688
# 106751                         21.444
# 106778                         24.852
# 106805                        401.358
# 106821                         18.120
#
# [4263 rows x 24 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %%
data.query('ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                         1.4123                         0.098   5  2004
# 50                         0.9724                         0.087   5  2004
# 77                          1.412                         0.103   5  2004
# 104                        1.0669                         0.112   5  2004
# 131                        1.0669                         0.104   6  2004
# ...                           ...                           ...  ..   ...
# 106724                     3.3481                         0.032   6  2019
# 106751                      3.491                         0.036   6  2019
# 106778                     4.0892                         0.026   6  2019
# 106805                         72                         0.103   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23              DEFAULT                       23                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 77              DEFAULT                       77                  1, 2, 3
# 104             DEFAULT                      104                  1, 2, 3
# 131             DEFAULT                      131                  1, 2, 3
# ...                 ...                      ...                      ...
# 106724          DEFAULT                   106724                  1, 2, 3
# 106751          DEFAULT                   106751                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 23                              4.608
# 50                              4.596
# 77                              4.938
# 104                             5.322
# 131                             5.364
# ...                               ...
# 106724                         20.688
# 106751                         21.444
# 106778                         24.852
# 106805                        401.358
# 106821                         18.120
#
# [4263 rows x 24 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de São Paulo.

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                         1.4123                         0.098   5  2004
# 50                         0.9724                         0.087   5  2004
# 77                          1.412                         0.103   5  2004
# 104                        1.0669                         0.112   5  2004
# 131                        1.0669                         0.104   6  2004
# ...                           ...                           ...  ..   ...
# 106724                     3.3481                         0.032   6  2019
# 106751                      3.491                         0.036   6  2019
# 106778                     4.0892                         0.026   6  2019
# 106805                         72                         0.103   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23              DEFAULT                       23                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 77              DEFAULT                       77                  1, 2, 3
# 104             DEFAULT                      104                  1, 2, 3
# 131             DEFAULT                      131                  1, 2, 3
# ...                 ...                      ...                      ...
# 106724          DEFAULT                   106724                  1, 2, 3
# 106751          DEFAULT                   106751                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 23                              4.608
# 50                              4.596
# 77                              4.938
# 104                             5.322
# 131                             5.364
# ...                               ...
# 106724                         20.688
# 106751                         21.444
# 106778                         24.852
# 106805                        401.358
# 106821                         18.120
#
# [4263 rows x 24 columns]

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 24)

# %%
postos_sp.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                   0.085                 0.590  ...
# 50                   0.083                 0.590  ...
# 77                   0.071                 0.620  ...
# 104                  0.075                 0.639  ...
# 131                  0.071                 0.669  ...
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                        0.056                    0.4271
# 50                         0.05                   0.43204
# 77                        0.063                   0.34951
# 104                       0.075                    0.3398
# 131                       0.072                   0.47797
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                      1.4123                         0.098   5  2004
# 50                      0.9724                         0.087   5  2004
# 77                       1.412                         0.103   5  2004
# 104                     1.0669                         0.112   5  2004
# 131                     1.0669                         0.104   6  2004
#
#     coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23           DEFAULT                       23                  1, 2, 3
# 50           DEFAULT                       50                  1, 2, 3
# 77           DEFAULT                       77                  1, 2, 3
# 104          DEFAULT                      104                  1, 2, 3
# 131          DEFAULT                      131                  1, 2, 3
#
#      PREÇO MÉDIA REVENDA (dólares)
# 23                           4.608
# 50                           4.596
# 77                           4.938
# 104                          5.322
# 131                          5.364
#
# [5 rows x 24 columns]

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                         1.4123                         0.098   5  2004
# 50                         0.9724                         0.087   5  2004
# 77                          1.412                         0.103   5  2004
# 104                        1.0669                         0.112   5  2004
# 131                        1.0669                         0.104   6  2004
# ...                           ...                           ...  ..   ...
# 106724                     3.3481                         0.032   6  2019
# 106751                      3.491                         0.036   6  2019
# 106778                     4.0892                         0.026   6  2019
# 106805                         72                         0.103   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23              DEFAULT                       23                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 77              DEFAULT                       77                  1, 2, 3
# 104             DEFAULT                      104                  1, 2, 3
# 131             DEFAULT                      131                  1, 2, 3
# ...                 ...                      ...                      ...
# 106724          DEFAULT                   106724                  1, 2, 3
# 106751          DEFAULT                   106751                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 23                              4.608
# 50                              4.596
# 77                              4.938
# 104                             5.322
# 131                             5.364
# ...                               ...
# 106724                         20.688
# 106751                         21.444
# 106778                         24.852
# 106805                        401.358
# 106821                         18.120
#
# [4263 rows x 24 columns]

# %% [markdown]
# resetando indices

# %%
postos_sp.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0         23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1         50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2         77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3        104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4        131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...      ...          ...         ...      ...        ...               ...
# 4258  106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259  106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260  106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261  106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262  106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  ...  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.085  ...                       0.056
# 1                     0.083  ...                        0.05
# 2                     0.071  ...                       0.063
# 3                     0.075  ...                       0.075
# 4                     0.071  ...                       0.072
# ...                     ...  ...                         ...
# 4258                  0.156  ...                       0.097
# 4259                  0.169  ...                       0.111
# 4260                  0.183  ...                       0.097
# 4261                  6.100  ...                       5.071
# 4262                  0.229  ...                       0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                        0.4271                    1.4123
# 1                       0.43204                    0.9724
# 2                       0.34951                     1.412
# 3                        0.3398                    1.0669
# 4                       0.47797                    1.0669
# ...                         ...                       ...
# 4258                     2.8599                    3.3481
# 4259                      2.885                     3.491
# 4260                       3.52                    4.0892
# 4261                      40.19                        72
# 4262                     2.0179                    2.5093
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                             0.098   5  2004          DEFAULT
# 1                             0.087   5  2004          DEFAULT
# 2                             0.103   5  2004          DEFAULT
# 3                             0.112   5  2004          DEFAULT
# 4                             0.104   6  2004          DEFAULT
# ...                             ...  ..   ...              ...
# 4258                          0.032   6  2019          DEFAULT
# 4259                          0.036   6  2019          DEFAULT
# 4260                          0.026   6  2019          DEFAULT
# 4261                          0.103   6  2019          DEFAULT
# 4262                           0.07   6  2019          DEFAULT
#
#      coluna a partir de lista nova_coluna_valor_unico  \
# 0                          23                 1, 2, 3
# 1                          50                 1, 2, 3
# 2                          77                 1, 2, 3
# 3                         104                 1, 2, 3
# 4                         131                 1, 2, 3
# ...                       ...                     ...
# 4258                   106724                 1, 2, 3
# 4259                   106751                 1, 2, 3
# 4260                   106778                 1, 2, 3
# 4261                   106805                 1, 2, 3
# 4262                   106821                 1, 2, 3
#
#       PREÇO MÉDIA REVENDA (dólares)
# 0                             4.608
# 1                             4.596
# 2                             4.938
# 3                             5.322
# 4                             5.364
# ...                             ...
# 4258                         20.688
# 4259                         21.444
# 4260                         24.852
# 4261                        401.358
# 4262                         18.120
#
# [4263 rows x 25 columns]

# %%
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.4271
# 1                           0.05                   0.43204
# 2                          0.063                   0.34951
# 3                          0.075                    0.3398
# 4                          0.072                   0.47797
# ...                          ...                       ...
# 4258                       0.097                    2.8599
# 4259                       0.111                     2.885
# 4260                       0.097                      3.52
# 4261                       5.071                     40.19
# 4262                       0.165                    2.0179
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                        1.4123                         0.098   5  2004
# 1                        0.9724                         0.087   5  2004
# 2                         1.412                         0.103   5  2004
# 3                        1.0669                         0.112   5  2004
# 4                        1.0669                         0.104   6  2004
# ...                         ...                           ...  ..   ...
# 4258                     3.3481                         0.032   6  2019
# 4259                      3.491                         0.036   6  2019
# 4260                     4.0892                         0.026   6  2019
# 4261                         72                         0.103   6  2019
# 4262                     2.5093                          0.07   6  2019
#
#      coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0             DEFAULT                       23                  1, 2, 3
# 1             DEFAULT                       50                  1, 2, 3
# 2             DEFAULT                       77                  1, 2, 3
# 3             DEFAULT                      104                  1, 2, 3
# 4             DEFAULT                      131                  1, 2, 3
# ...               ...                      ...                      ...
# 4258          DEFAULT                   106724                  1, 2, 3
# 4259          DEFAULT                   106751                  1, 2, 3
# 4260          DEFAULT                   106778                  1, 2, 3
# 4261          DEFAULT                   106805                  1, 2, 3
# 4262          DEFAULT                   106821                  1, 2, 3
#
#       PREÇO MÉDIA REVENDA (dólares)
# 0                             4.608
# 1                             4.596
# 2                             4.938
# 3                             5.322
# 4                             5.364
# ...                             ...
# 4258                         20.688
# 4259                         21.444
# 4260                         24.852
# 4261                        401.358
# 4262                         18.120
#
# [4263 rows x 24 columns]

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 23                         1.4123                         0.098   5  2004
# 50                         0.9724                         0.087   5  2004
# 77                          1.412                         0.103   5  2004
# 104                        1.0669                         0.112   5  2004
# 131                        1.0669                         0.104   6  2004
# ...                           ...                           ...  ..   ...
# 106724                     3.3481                         0.032   6  2019
# 106751                      3.491                         0.036   6  2019
# 106778                     4.0892                         0.026   6  2019
# 106805                         72                         0.103   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 23              DEFAULT                       23                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 77              DEFAULT                       77                  1, 2, 3
# 104             DEFAULT                      104                  1, 2, 3
# 131             DEFAULT                      131                  1, 2, 3
# ...                 ...                      ...                      ...
# 106724          DEFAULT                   106724                  1, 2, 3
# 106751          DEFAULT                   106751                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 23                              4.608
# 50                              4.596
# 77                              4.938
# 104                             5.322
# 131                             5.364
# ...                               ...
# 106724                         20.688
# 106751                         21.444
# 106778                         24.852
# 106805                        401.358
# 106821                         18.120
#
# [4263 rows x 24 columns]

# %%
postos_sp.reset_index(drop=True, inplace=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.4271
# 1                           0.05                   0.43204
# 2                          0.063                   0.34951
# 3                          0.075                    0.3398
# 4                          0.072                   0.47797
# ...                          ...                       ...
# 4258                       0.097                    2.8599
# 4259                       0.111                     2.885
# 4260                       0.097                      3.52
# 4261                       5.071                     40.19
# 4262                       0.165                    2.0179
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                        1.4123                         0.098   5  2004
# 1                        0.9724                         0.087   5  2004
# 2                         1.412                         0.103   5  2004
# 3                        1.0669                         0.112   5  2004
# 4                        1.0669                         0.104   6  2004
# ...                         ...                           ...  ..   ...
# 4258                     3.3481                         0.032   6  2019
# 4259                      3.491                         0.036   6  2019
# 4260                     4.0892                         0.026   6  2019
# 4261                         72                         0.103   6  2019
# 4262                     2.5093                          0.07   6  2019
#
#      coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0             DEFAULT                       23                  1, 2, 3
# 1             DEFAULT                       50                  1, 2, 3
# 2             DEFAULT                       77                  1, 2, 3
# 3             DEFAULT                      104                  1, 2, 3
# 4             DEFAULT                      131                  1, 2, 3
# ...               ...                      ...                      ...
# 4258          DEFAULT                   106724                  1, 2, 3
# 4259          DEFAULT                   106751                  1, 2, 3
# 4260          DEFAULT                   106778                  1, 2, 3
# 4261          DEFAULT                   106805                  1, 2, 3
# 4262          DEFAULT                   106821                  1, 2, 3
#
#       PREÇO MÉDIA REVENDA (dólares)
# 0                             4.608
# 1                             4.596
# 2                             4.938
# 3                             5.322
# 4                             5.364
# ...                             ...
# 4258                         20.688
# 4259                         21.444
# 4260                         24.852
# 4261                        401.358
# 4262                         18.120
#
# [4263 rows x 24 columns]

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.4271
# 1                           0.05                   0.43204
# 2                          0.063                   0.34951
# 3                          0.075                    0.3398
# 4                          0.072                   0.47797
# ...                          ...                       ...
# 4258                       0.097                    2.8599
# 4259                       0.111                     2.885
# 4260                       0.097                      3.52
# 4261                       5.071                     40.19
# 4262                       0.165                    2.0179
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                        1.4123                         0.098   5  2004
# 1                        0.9724                         0.087   5  2004
# 2                         1.412                         0.103   5  2004
# 3                        1.0669                         0.112   5  2004
# 4                        1.0669                         0.104   6  2004
# ...                         ...                           ...  ..   ...
# 4258                     3.3481                         0.032   6  2019
# 4259                      3.491                         0.036   6  2019
# 4260                     4.0892                         0.026   6  2019
# 4261                         72                         0.103   6  2019
# 4262                     2.5093                          0.07   6  2019
#
#      coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0             DEFAULT                       23                  1, 2, 3
# 1             DEFAULT                       50                  1, 2, 3
# 2             DEFAULT                       77                  1, 2, 3
# 3             DEFAULT                      104                  1, 2, 3
# 4             DEFAULT                      131                  1, 2, 3
# ...               ...                      ...                      ...
# 4258          DEFAULT                   106724                  1, 2, 3
# 4259          DEFAULT                   106751                  1, 2, 3
# 4260          DEFAULT                   106778                  1, 2, 3
# 4261          DEFAULT                   106805                  1, 2, 3
# 4262          DEFAULT                   106821                  1, 2, 3
#
#       PREÇO MÉDIA REVENDA (dólares)
# 0                             4.608
# 1                             4.596
# 2                             4.938
# 3                             5.322
# 4                             5.364
# ...                             ...
# 4258                         20.688
# 4259                         21.444
# 4260                         24.852
# 4261                        401.358
# 4262                         18.120
#
# [4263 rows x 24 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 2501                    0.148                 1.589  ...
# 2528                    0.149                 1.779  ...
# 2555                    0.138                 1.799  ...
# 2582                    0.146                 1.760  ...
# 2609                    0.143                 1.789  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 2501                          0.11                      1.31
# 2528                         0.117                     1.438
# 2555                         0.134                      1.43
# 2582                          0.14                     1.438
# 2609                         0.133                     1.438
# ...                            ...                       ...
# 106718                       0.119                     2.886
# 106745                       0.127                    2.9772
# 106772                       0.097                       4.2
# 106799                       3.934                        39
# 106817                       0.174                     2.126
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 2501                       2.1358                         0.061   2  2006
# 2528                       2.2801                         0.064   3  2006
# 2555                       2.3454                         0.071   3  2006
# 2582                       2.2925                         0.072   3  2006
# 2609                       2.2513                         0.068   3  2006
# ...                           ...                           ...  ..   ...
# 106718                     3.5162                         0.038   6  2019
# 106745                     3.5388                          0.04   6  2019
# 106772                      4.618                         0.022   6  2019
# 106799                       58.2                         0.083   6  2019
# 106817                     2.7909                         0.072   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 2501            DEFAULT                     2501                  1, 2, 3
# 2528            DEFAULT                     2528                  1, 2, 3
# 2555            DEFAULT                     2555                  1, 2, 3
# 2582            DEFAULT                     2582                  1, 2, 3
# 2609            DEFAULT                     2609                  1, 2, 3
# ...                 ...                      ...                      ...
# 106718          DEFAULT                   106718                  1, 2, 3
# 106745          DEFAULT                   106745                  1, 2, 3
# 106772          DEFAULT                   106772                  1, 2, 3
# 106799          DEFAULT                   106799                  1, 2, 3
# 106817          DEFAULT                   106817                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 2501                           12.168
# 2528                           12.750
# 2555                           12.978
# 2582                           12.996
# 2609                           13.032
# ...                               ...
# 106718                         21.414
# 106745                         22.182
# 106772                         29.568
# 106799                        390.060
# 106817                         18.666
#
# [3054 rows x 24 columns]

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 49                               948              R$/l                1.092
# 76                               973              R$/l                1.103
# 103                              955              R$/l                1.149
# 130                              966              R$/l                1.165
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 49                      0.157                 0.740  ...
# 76                      0.140                 0.770  ...
# 103                     0.156                 0.799  ...
# 130                     0.154                 0.830  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 22                           0.173                     0.326
# 49                           0.175                    0.3257
# 76                           0.166                   0.38909
# 103                          0.188                    0.3453
# 130                          0.198                       0.4
# ...                            ...                       ...
# 106718                       0.119                     2.886
# 106745                       0.127                    2.9772
# 106772                       0.097                       4.2
# 106799                       3.934                        39
# 106817                       0.174                     2.126
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 22                          1.263                          0.22   5  2004
# 49                         1.2921                         0.217   5  2004
# 76                         1.1859                         0.202   5  2004
# 103                        1.3667                         0.221   5  2004
# 130                        1.3667                         0.217   6  2004
# ...                           ...                           ...  ..   ...
# 106718                     3.5162                         0.038   6  2019
# 106745                     3.5388                          0.04   6  2019
# 106772                      4.618                         0.022   6  2019
# 106799                       58.2                         0.083   6  2019
# 106817                     2.7909                         0.072   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 22              DEFAULT                       22                  1, 2, 3
# 49              DEFAULT                       49                  1, 2, 3
# 76              DEFAULT                       76                  1, 2, 3
# 103             DEFAULT                      103                  1, 2, 3
# 130             DEFAULT                      130                  1, 2, 3
# ...                 ...                      ...                      ...
# 106718          DEFAULT                   106718                  1, 2, 3
# 106745          DEFAULT                   106745                  1, 2, 3
# 106772          DEFAULT                   106772                  1, 2, 3
# 106799          DEFAULT                   106799                  1, 2, 3
# 106817          DEFAULT                   106817                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 22                              6.588
# 49                              6.552
# 76                              6.618
# 103                             6.894
# 130                             6.990
# ...                               ...
# 106718                         21.414
# 106745                         22.182
# 106772                         29.568
# 106799                        390.060
# 106817                         18.666
#
# [4263 rows x 24 columns]

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2.0
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 2501                    0.148                 1.589  ...
# 2528                    0.149                 1.779  ...
# 2555                    0.138                 1.799  ...
# 2582                    0.146                 1.760  ...
# 2609                    0.143                 1.789  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 2501                          0.11                      1.31
# 2528                         0.117                     1.438
# 2555                         0.134                      1.43
# 2582                          0.14                     1.438
# 2609                         0.133                     1.438
# ...                            ...                       ...
# 106718                       0.119                     2.886
# 106745                       0.127                    2.9772
# 106772                       0.097                       4.2
# 106799                       3.934                        39
# 106817                       0.174                     2.126
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 2501                       2.1358                         0.061   2  2006
# 2528                       2.2801                         0.064   3  2006
# 2555                       2.3454                         0.071   3  2006
# 2582                       2.2925                         0.072   3  2006
# 2609                       2.2513                         0.068   3  2006
# ...                           ...                           ...  ..   ...
# 106718                     3.5162                         0.038   6  2019
# 106745                     3.5388                          0.04   6  2019
# 106772                      4.618                         0.022   6  2019
# 106799                       58.2                         0.083   6  2019
# 106817                     2.7909                         0.072   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 2501            DEFAULT                     2501                  1, 2, 3
# 2528            DEFAULT                     2528                  1, 2, 3
# 2555            DEFAULT                     2555                  1, 2, 3
# 2582            DEFAULT                     2582                  1, 2, 3
# 2609            DEFAULT                     2609                  1, 2, 3
# ...                 ...                      ...                      ...
# 106718          DEFAULT                   106718                  1, 2, 3
# 106745          DEFAULT                   106745                  1, 2, 3
# 106772          DEFAULT                   106772                  1, 2, 3
# 106799          DEFAULT                   106799                  1, 2, 3
# 106817          DEFAULT                   106817                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 2501                           12.168
# 2528                           12.750
# 2555                           12.978
# 2582                           12.996
# 2609                           13.032
# ...                               ...
# 106718                         21.414
# 106745                         22.182
# 106772                         29.568
# 106799                        390.060
# 106817                         18.666
#
# [3054 rows x 24 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)

selecao_final = selecao_1 & selecao_2 & selecao_3

# %%
data_filtrado = data[selecao_final]
data_filtrado
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12086                        0.047                    1.6363
# 12113                        0.049                    1.5943
# 12140                        0.046                   1.63596
# 12167                        0.055                      1.64
# 12194                        0.054                      1.64
# ...                            ...                       ...
# 106479                       0.096                      3.52
# 106623                         0.1                    4.1972
# 106629                       0.096                     3.502
# 106772                       0.097                       4.2
# 106778                       0.097                      3.52
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 12086                      1.9594                         0.026   5  2004
# 12113                     1.99651                         0.027   5  2004
# 12140                      2.2137                         0.026   5  2004
# 12167                     2.21425                         0.031   5  2004
# 12194                     2.32425                          0.03   6  2004
# ...                           ...                           ...  ..   ...
# 106479                     4.1007                         0.025   6  2019
# 106623                     4.6239                         0.023   6  2019
# 106629                     4.0892                         0.026   6  2019
# 106772                      4.618                         0.022   6  2019
# 106778                     4.0892                         0.026   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 12086           DEFAULT                    12086                  1, 2, 3
# 12113           DEFAULT                    12113                  1, 2, 3
# 12140           DEFAULT                    12140                  1, 2, 3
# 12167           DEFAULT                    12167                  1, 2, 3
# 12194           DEFAULT                    12194                  1, 2, 3
# ...                 ...                      ...                      ...
# 106479          DEFAULT                   106479                  1, 2, 3
# 106623          DEFAULT                   106623                  1, 2, 3
# 106629          DEFAULT                   106629                  1, 2, 3
# 106772          DEFAULT                   106772                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 12086                          12.270
# 12113                          12.240
# 12140                          12.252
# 12167                          12.318
# 12194                          12.378
# ...                               ...
# 106479                         25.260
# 106623                         29.562
# 106629                         25.008
# 106772                         29.568
# 106778                         24.852
#
# [1564 rows x 24 columns]

# %%
print(data_filtrado['ESTADO'].unique())
print(data_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao_1]

postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 23                              4047              R$/l                0.768
# 49                               948              R$/l                1.092
# 50                              4066              R$/l                0.766
# 76                               973              R$/l                1.103
# ...                              ...               ...                  ...
# 106778                          1644              R$/l                4.142
# 106799                           221           R$/13Kg               65.010
# 106805                          1017           R$/13Kg               66.893
# 106817                           124             R$/m3                3.111
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 23                      0.085                 0.590  ...
# 49                      0.157                 0.740  ...
# 50                      0.083                 0.590  ...
# 76                      0.140                 0.770  ...
# ...                       ...                   ...  ...
# 106778                  0.183                 3.769  ...
# 106799                  5.812                50.000  ...
# 106805                  6.100                50.000  ...
# 106817                  0.260                 2.799  ...
# 106821                  0.229                 2.699  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 22                           0.173                     0.326
# 23                           0.056                    0.4271
# 49                           0.175                    0.3257
# 50                            0.05                   0.43204
# 76                           0.166                   0.38909
# ...                            ...                       ...
# 106778                       0.097                      3.52
# 106799                       3.934                        39
# 106805                       5.071                     40.19
# 106817                       0.174                     2.126
# 106821                       0.165                    2.0179
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 22                          1.263                          0.22   5  2004
# 23                         1.4123                         0.098   5  2004
# 49                         1.2921                         0.217   5  2004
# 50                         0.9724                         0.087   5  2004
# 76                         1.1859                         0.202   5  2004
# ...                           ...                           ...  ..   ...
# 106778                     4.0892                         0.026   6  2019
# 106799                       58.2                         0.083   6  2019
# 106805                         72                         0.103   6  2019
# 106817                     2.7909                         0.072   6  2019
# 106821                     2.5093                          0.07   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 22              DEFAULT                       22                  1, 2, 3
# 23              DEFAULT                       23                  1, 2, 3
# 49              DEFAULT                       49                  1, 2, 3
# 50              DEFAULT                       50                  1, 2, 3
# 76              DEFAULT                       76                  1, 2, 3
# ...                 ...                      ...                      ...
# 106778          DEFAULT                   106778                  1, 2, 3
# 106799          DEFAULT                   106799                  1, 2, 3
# 106805          DEFAULT                   106805                  1, 2, 3
# 106817          DEFAULT                   106817                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 22                              6.588
# 23                              4.608
# 49                              6.552
# 50                              4.596
# 76                              6.618
# ...                               ...
# 106778                         24.852
# 106799                        390.060
# 106805                        401.358
# 106817                         18.666
# 106821                         18.120
#
# [8526 rows x 24 columns]

# %%
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]

postos_sp_rj_gasolina
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12087                           4107              R$/l                1.891
# 12113                           1055              R$/l                2.040
# 12114                           4133              R$/l                1.888
# 12140                           1091              R$/l                2.042
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12087                   0.101                 1.570  ...
# 12113                   0.113                 1.700  ...
# 12114                   0.101                 1.540  ...
# 12140                   0.108                 1.700  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12086                        0.047                    1.6363
# 12087                        0.064                      1.38
# 12113                        0.049                    1.5943
# 12114                        0.063                      1.38
# 12140                        0.046                   1.63596
# ...                            ...                       ...
# 106479                       0.096                      3.52
# 106623                         0.1                    4.1972
# 106629                       0.096                     3.502
# 106772                       0.097                       4.2
# 106778                       0.097                      3.52
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 12086                      1.9594                         0.026   5  2004
# 12087                       1.944                         0.039   5  2004
# 12113                     1.99651                         0.027   5  2004
# 12114                      1.9319                         0.038   5  2004
# 12140                      2.2137                         0.026   5  2004
# ...                           ...                           ...  ..   ...
# 106479                     4.1007                         0.025   6  2019
# 106623                     4.6239                         0.023   6  2019
# 106629                     4.0892                         0.026   6  2019
# 106772                      4.618                         0.022   6  2019
# 106778                     4.0892                         0.026   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 12086           DEFAULT                    12086                  1, 2, 3
# 12087           DEFAULT                    12087                  1, 2, 3
# 12113           DEFAULT                    12113                  1, 2, 3
# 12114           DEFAULT                    12114                  1, 2, 3
# 12140           DEFAULT                    12140                  1, 2, 3
# ...                 ...                      ...                      ...
# 106479          DEFAULT                   106479                  1, 2, 3
# 106623          DEFAULT                   106623                  1, 2, 3
# 106629          DEFAULT                   106629                  1, 2, 3
# 106772          DEFAULT                   106772                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 12086                          12.270
# 12087                          11.346
# 12113                          12.240
# 12114                          11.328
# 12140                          12.252
# ...                               ...
# 106479                         25.260
# 106623                         29.562
# 106629                         25.008
# 106772                         29.568
# 106778                         24.852
#
# [1570 rows x 24 columns]

# %%
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)
postos_sp_rj_gasolina_preco_maior_2 = postos_sp_rj_gasolina[selecao_3]
postos_sp_rj_gasolina_preco_maior_2
# Out:
# /tmp/ipython-input-385443829.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   postos_sp_rj_gasolina_preco_maior_2 = postos_sp_rj_gasolina[selecao_3]
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12086                        0.047                    1.6363
# 12113                        0.049                    1.5943
# 12140                        0.046                   1.63596
# 12167                        0.055                      1.64
# 12194                        0.054                      1.64
# ...                            ...                       ...
# 106479                       0.096                      3.52
# 106623                         0.1                    4.1972
# 106629                       0.096                     3.502
# 106772                       0.097                       4.2
# 106778                       0.097                      3.52
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 12086                      1.9594                         0.026   5  2004
# 12113                     1.99651                         0.027   5  2004
# 12140                      2.2137                         0.026   5  2004
# 12167                     2.21425                         0.031   5  2004
# 12194                     2.32425                          0.03   6  2004
# ...                           ...                           ...  ..   ...
# 106479                     4.1007                         0.025   6  2019
# 106623                     4.6239                         0.023   6  2019
# 106629                     4.0892                         0.026   6  2019
# 106772                      4.618                         0.022   6  2019
# 106778                     4.0892                         0.026   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 12086           DEFAULT                    12086                  1, 2, 3
# 12113           DEFAULT                    12113                  1, 2, 3
# 12140           DEFAULT                    12140                  1, 2, 3
# 12167           DEFAULT                    12167                  1, 2, 3
# 12194           DEFAULT                    12194                  1, 2, 3
# ...                 ...                      ...                      ...
# 106479          DEFAULT                   106479                  1, 2, 3
# 106623          DEFAULT                   106623                  1, 2, 3
# 106629          DEFAULT                   106629                  1, 2, 3
# 106772          DEFAULT                   106772                  1, 2, 3
# 106778          DEFAULT                   106778                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 12086                          12.270
# 12113                          12.240
# 12140                          12.252
# 12167                          12.318
# 12194                          12.378
# ...                               ...
# 106479                         25.260
# 106623                         29.562
# 106629                         25.008
# 106772                         29.568
# 106778                         24.852
#
# [1564 rows x 24 columns]

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data['ANO'] == 2008) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5098                        0.061                    1.3892
# 5099                         0.05                    1.2242
# 5100                        0.073                      1.14
# 5101                        0.044                    1.3247
# 5102                        0.062                      1.39
# ...                           ...                       ...
# 55754                       0.098                    1.2657
# 55755                       0.028                    1.3997
# 55756                           -                         -
# 55757                       0.182                    0.8354
# 55758                       0.178                    1.1253
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5098                      1.6157                          0.04   1  2008
# 5099                      1.6173                         0.038   1  2008
# 5100                        1.45                         0.056   1  2008
# 5101                      1.5514                          0.03   1  2008
# 5102                      1.7689                         0.041   1  2008
# ...                          ...                           ...  ..   ...
# 55754                     1.4789                         0.069  12  2012
# 55755                     1.4608                          0.02  12  2012
# 55756                          -                             -  12  2012
# 55757                      1.535                         0.152  12  2012
# 55758                      1.543                         0.133  12  2012
#
#       coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 5098           DEFAULT                     5098                  1, 2, 3
# 5099           DEFAULT                     5099                  1, 2, 3
# 5100           DEFAULT                     5100                  1, 2, 3
# 5101           DEFAULT                     5101                  1, 2, 3
# 5102           DEFAULT                     5102                  1, 2, 3
# ...                ...                      ...                      ...
# 55754          DEFAULT                    55754                  1, 2, 3
# 55755          DEFAULT                    55755                  1, 2, 3
# 55756          DEFAULT                    55756                  1, 2, 3
# 55757          DEFAULT                    55757                  1, 2, 3
# 55758          DEFAULT                    55758                  1, 2, 3
#
#        PREÇO MÉDIA REVENDA (dólares)
# 5098                          10.836
# 5099                           9.696
# 5100                           9.486
# 5101                          10.986
# 5102                          10.194
# ...                              ...
# 55754                         11.346
# 55755                         11.880
# 55756                         12.018
# 55757                          9.588
# 55758                         11.082
#
# [19576 rows x 24 columns]

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
selecao = data['ANO'].isin(lista_de_anos)
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5098                        0.061                    1.3892
# 5099                         0.05                    1.2242
# 5100                        0.073                      1.14
# 5101                        0.044                    1.3247
# 5102                        0.062                      1.39
# ...                           ...                       ...
# 55754                       0.098                    1.2657
# 55755                       0.028                    1.3997
# 55756                           -                         -
# 55757                       0.182                    0.8354
# 55758                       0.178                    1.1253
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5098                      1.6157                          0.04   1  2008
# 5099                      1.6173                         0.038   1  2008
# 5100                        1.45                         0.056   1  2008
# 5101                      1.5514                          0.03   1  2008
# 5102                      1.7689                         0.041   1  2008
# ...                          ...                           ...  ..   ...
# 55754                     1.4789                         0.069  12  2012
# 55755                     1.4608                          0.02  12  2012
# 55756                          -                             -  12  2012
# 55757                      1.535                         0.152  12  2012
# 55758                      1.543                         0.133  12  2012
#
#       coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 5098           DEFAULT                     5098                  1, 2, 3
# 5099           DEFAULT                     5099                  1, 2, 3
# 5100           DEFAULT                     5100                  1, 2, 3
# 5101           DEFAULT                     5101                  1, 2, 3
# 5102           DEFAULT                     5102                  1, 2, 3
# ...                ...                      ...                      ...
# 55754          DEFAULT                    55754                  1, 2, 3
# 55755          DEFAULT                    55755                  1, 2, 3
# 55756          DEFAULT                    55756                  1, 2, 3
# 55757          DEFAULT                    55757                  1, 2, 3
# 55758          DEFAULT                    55758                  1, 2, 3
#
#        PREÇO MÉDIA REVENDA (dólares)
# 5098                          10.836
# 5099                           9.696
# 5100                           9.486
# 5101                          10.986
# 5102                          10.194
# ...                              ...
# 55754                         11.346
# 55755                         11.880
# 55756                         12.018
# 55757                          9.588
# 55758                         11.082
#
# [19576 rows x 24 columns]

# %% [markdown]
# ALTERNATIVA 3

# %%
lista_de_anos
# Out:
# [2008, 2010, 2012]

# %%
data.query('ANO in @lista_de_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5098                        0.061                    1.3892
# 5099                         0.05                    1.2242
# 5100                        0.073                      1.14
# 5101                        0.044                    1.3247
# 5102                        0.062                      1.39
# ...                           ...                       ...
# 55754                       0.098                    1.2657
# 55755                       0.028                    1.3997
# 55756                           -                         -
# 55757                       0.182                    0.8354
# 55758                       0.178                    1.1253
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5098                      1.6157                          0.04   1  2008
# 5099                      1.6173                         0.038   1  2008
# 5100                        1.45                         0.056   1  2008
# 5101                      1.5514                          0.03   1  2008
# 5102                      1.7689                         0.041   1  2008
# ...                          ...                           ...  ..   ...
# 55754                     1.4789                         0.069  12  2012
# 55755                     1.4608                          0.02  12  2012
# 55756                          -                             -  12  2012
# 55757                      1.535                         0.152  12  2012
# 55758                      1.543                         0.133  12  2012
#
#       coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 5098           DEFAULT                     5098                  1, 2, 3
# 5099           DEFAULT                     5099                  1, 2, 3
# 5100           DEFAULT                     5100                  1, 2, 3
# 5101           DEFAULT                     5101                  1, 2, 3
# 5102           DEFAULT                     5102                  1, 2, 3
# ...                ...                      ...                      ...
# 55754          DEFAULT                    55754                  1, 2, 3
# 55755          DEFAULT                    55755                  1, 2, 3
# 55756          DEFAULT                    55756                  1, 2, 3
# 55757          DEFAULT                    55757                  1, 2, 3
# 55758          DEFAULT                    55758                  1, 2, 3
#
#        PREÇO MÉDIA REVENDA (dólares)
# 5098                          10.836
# 5099                           9.696
# 5100                           9.486
# 5101                          10.986
# 5102                          10.194
# ...                              ...
# 55754                         11.346
# 55755                         11.880
# 55756                         12.018
# 55757                          9.588
# 55758                         11.082
#
# [19576 rows x 24 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
data.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                 1.190  ...
# 1                1.162                  0.114                 0.890  ...
# 2                1.389                  0.097                 1.180  ...
# 3                1.262                  0.070                 1.090  ...
# 4                1.181                  0.078                 1.050  ...
# 5                1.383                  0.132                 0.999  ...
# 6                1.453                  0.218                 1.030  ...
# 7                1.631                  0.158                 1.350  ...
# 8                1.284                  0.130                 1.100  ...
# 9                1.224                  0.141                 0.989  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
# 6                       0.068                    0.7332
# 7                       0.091                    0.9923
# 8                       0.072                    0.7577
# 9                       0.091                    0.5643
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
# 6                      1.294                         0.062   5  2004
# 7                    1.36183                         0.082   5  2004
# 8                     1.2972                         0.077   5  2004
# 9                     1.3541                         0.096   5  2004
#
#   coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0          DEFAULT                        0                  1, 2, 3
# 1          DEFAULT                        1                  1, 2, 3
# 2          DEFAULT                        2                  1, 2, 3
# 3          DEFAULT                        3                  1, 2, 3
# 4          DEFAULT                        4                  1, 2, 3
# 5          DEFAULT                        5                  1, 2, 3
# 6          DEFAULT                        6                  1, 2, 3
# 7          DEFAULT                        7                  1, 2, 3
# 8          DEFAULT                        8                  1, 2, 3
# 9          DEFAULT                        9                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
# 5                          8.298
# 6                          8.718
# 7                          9.786
# 8                          7.704
# 9                          7.344
#
# [10 rows x 24 columns]

# %%
for index, row in data.head(10).iterrows():
    print(f"indice {index} ==> {row['ESTADO']}")
# Out:
# indice 0 ==> DISTRITO FEDERAL
# indice 1 ==> GOIAS
# indice 2 ==> MATO GROSSO
# indice 3 ==> MATO GROSSO DO SUL
# indice 4 ==> ALAGOAS
# indice 5 ==> BAHIA
# indice 6 ==> CEARA
# indice 7 ==> MARANHAO
# indice 8 ==> PARAIBA
# indice 9 ==> PERNAMBUCO

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                             0.11                    0.4201
# 1                            0.088                    0.5013
# 2                            0.095                    0.5614
# 3                            0.119                    0.5991
# 4                            0.077                    0.7441
# ...                            ...                       ...
# 106818                           0                     2.756
# 106819                       0.402                    1.9842
# 106820                           0                    1.9981
# 106821                       0.165                    2.0179
# 106822                           0                    2.5175
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                          0.9666                         0.133   5  2004
# 1                            1.05                         0.115   5  2004
# 2                           1.161                         0.098   5  2004
# 3                         1.22242                         0.143   5  2004
# 4                          1.0317                         0.082   5  2004
# ...                           ...                           ...  ..   ...
# 106818                      2.756                             0   6  2019
# 106819                     2.8661                         0.164   6  2019
# 106820                     1.9981                             0   6  2019
# 106821                     2.5093                          0.07   6  2019
# 106822                     2.5175                             0   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 0               DEFAULT                        0                  1, 2, 3
# 1               DEFAULT                        1                  1, 2, 3
# 2               DEFAULT                        2                  1, 2, 3
# 3               DEFAULT                        3                  1, 2, 3
# 4               DEFAULT                        4                  1, 2, 3
# ...                 ...                      ...                      ...
# 106818          DEFAULT                   106818                  1, 2, 3
# 106819          DEFAULT                   106819                  1, 2, 3
# 106820          DEFAULT                   106820                  1, 2, 3
# 106821          DEFAULT                   106821                  1, 2, 3
# 106822          DEFAULT                   106822                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 24 columns]

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  coluna sem nocao               106823 non-null  object
#  21  coluna a partir de lista       106823 non-null  int64
#  22  nova_coluna_valor_unico        106823 non-null  object
#  23  PREÇO MÉDIA REVENDA (dólares)  106823 non-null  float64
# dtypes: float64(6), int64(4), object(14)
# memory usage: 19.6+ MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  coluna sem nocao               106823 non-null  object
#  21  coluna a partir de lista       106823 non-null  int64
#  22  nova_coluna_valor_unico        106823 non-null  object
#  23  PREÇO MÉDIA REVENDA (dólares)  106823 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(12)
# memory usage: 19.6+ MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
for atributo in['MARGEM MÉDIA REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO','DESVIO PADRÃO DISTRIBUIÇÃO','PREÇO MÍNIMO DISTRIBUIÇÃO','PREÇO MÁXIMO DISTRIBUIÇÃO','COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1903                           NaN                        NaN
# 1958                           NaN                        NaN
# 2012                           NaN                        NaN
# 2497                           NaN                        NaN
# 3199                           NaN                        NaN
# ...                            ...                        ...
# 106664                         NaN                        NaN
# 106666                         NaN                        NaN
# 106811                         NaN                        NaN
# 106813                         NaN                        NaN
# 106815                         NaN                        NaN
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1903                          NaN                            NaN    9  2005
# 1958                          NaN                            NaN   10  2005
# 2012                          NaN                            NaN   10  2005
# 2497                          NaN                            NaN    2  2006
# 3199                          NaN                            NaN    8  2006
# ...                           ...                            ...  ...   ...
# 106664                        NaN                            NaN    6  2019
# 106666                        NaN                            NaN    6  2019
# 106811                        NaN                            NaN    6  2019
# 106813                        NaN                            NaN    6  2019
# 106815                        NaN                            NaN    6  2019
#
#         coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 1903             DEFAULT                      1903                  1, 2, 3
# 1958             DEFAULT                      1958                  1, 2, 3
# 2012             DEFAULT                      2012                  1, 2, 3
# 2497             DEFAULT                      2497                  1, 2, 3
# 3199             DEFAULT                      3199                  1, 2, 3
# ...                  ...                       ...                      ...
# 106664           DEFAULT                    106664                  1, 2, 3
# 106666           DEFAULT                    106666                  1, 2, 3
# 106811           DEFAULT                    106811                  1, 2, 3
# 106813           DEFAULT                    106813                  1, 2, 3
# 106815           DEFAULT                    106815                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 1903                           10.164
# 1958                           12.000
# 2012                           13.662
# 2497                           13.092
# 3199                           13.710
# ...                               ...
# 106664                         20.670
# 106666                         18.792
# 106811                         19.794
# 106813                         21.288
# 106815                         19.740
#
# [3400 rows x 24 columns]

# %%
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1903                             -                         -
# 1958                             -                         -
# 2012                             -                         -
# 2497                             -                         -
# 3199                             -                         -
# ...                            ...                       ...
# 106664                           -                         -
# 106666                           -                         -
# 106811                           -                         -
# 106813                           -                         -
# 106815                           -                         -
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1903                            -                             -   9  2005
# 1958                            -                             -  10  2005
# 2012                            -                             -  10  2005
# 2497                            -                             -   2  2006
# 3199                            -                             -   8  2006
# ...                           ...                           ...  ..   ...
# 106664                          -                             -   6  2019
# 106666                          -                             -   6  2019
# 106811                          -                             -   6  2019
# 106813                          -                             -   6  2019
# 106815                          -                             -   6  2019
#
#        coluna sem nocao coluna a partir de lista  nova_coluna_valor_unico  \
# 1903            DEFAULT                     1903                  1, 2, 3
# 1958            DEFAULT                     1958                  1, 2, 3
# 2012            DEFAULT                     2012                  1, 2, 3
# 2497            DEFAULT                     2497                  1, 2, 3
# 3199            DEFAULT                     3199                  1, 2, 3
# ...                 ...                      ...                      ...
# 106664          DEFAULT                   106664                  1, 2, 3
# 106666          DEFAULT                   106666                  1, 2, 3
# 106811          DEFAULT                   106811                  1, 2, 3
# 106813          DEFAULT                   106813                  1, 2, 3
# 106815          DEFAULT                   106815                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 1903                           10.164
# 1958                           12.000
# 2012                           13.662
# 2497                           13.092
# 3199                           13.710
# ...                               ...
# 106664                         20.670
# 106666                         18.792
# 106811                         19.794
# 106813                         21.288
# 106815                         19.740
#
# [3400 rows x 24 columns]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.110                     0.4201
# 1                            0.088                     0.5013
# 2                            0.095                     0.5614
# 3                            0.119                     0.5991
# 4                            0.077                     0.7441
# ...                            ...                        ...
# 106818                       0.000                     2.7560
# 106819                       0.402                     1.9842
# 106820                       0.000                     1.9981
# 106821                       0.165                     2.0179
# 106822                       0.000                     2.5175
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                         0.96660                          0.133    5  2004
# 1                         1.05000                          0.115    5  2004
# 2                         1.16100                          0.098    5  2004
# 3                         1.22242                          0.143    5  2004
# 4                         1.03170                          0.082    5  2004
# ...                           ...                            ...  ...   ...
# 106818                    2.75600                          0.000    6  2019
# 106819                    2.86610                          0.164    6  2019
# 106820                    1.99810                          0.000    6  2019
# 106821                    2.50930                          0.070    6  2019
# 106822                    2.51750                          0.000    6  2019
#
#         coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 0                DEFAULT                         0                  1, 2, 3
# 1                DEFAULT                         1                  1, 2, 3
# 2                DEFAULT                         2                  1, 2, 3
# 3                DEFAULT                         3                  1, 2, 3
# 4                DEFAULT                         4                  1, 2, 3
# ...                  ...                       ...                      ...
# 106818           DEFAULT                    106818                  1, 2, 3
# 106819           DEFAULT                    106819                  1, 2, 3
# 106820           DEFAULT                    106820                  1, 2, 3
# 106821           DEFAULT                    106821                  1, 2, 3
# 106822           DEFAULT                    106822                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 24 columns]

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1903                           0.0                        0.0
# 1958                           0.0                        0.0
# 2012                           0.0                        0.0
# 2497                           0.0                        0.0
# 3199                           0.0                        0.0
# ...                            ...                        ...
# 106664                         0.0                        0.0
# 106666                         0.0                        0.0
# 106811                         0.0                        0.0
# 106813                         0.0                        0.0
# 106815                         0.0                        0.0
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1903                          0.0                            0.0    9  2005
# 1958                          0.0                            0.0   10  2005
# 2012                          0.0                            0.0   10  2005
# 2497                          0.0                            0.0    2  2006
# 3199                          0.0                            0.0    8  2006
# ...                           ...                            ...  ...   ...
# 106664                        0.0                            0.0    6  2019
# 106666                        0.0                            0.0    6  2019
# 106811                        0.0                            0.0    6  2019
# 106813                        0.0                            0.0    6  2019
# 106815                        0.0                            0.0    6  2019
#
#         coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 1903             DEFAULT                      1903                  1, 2, 3
# 1958             DEFAULT                      1958                  1, 2, 3
# 2012             DEFAULT                      2012                  1, 2, 3
# 2497             DEFAULT                      2497                  1, 2, 3
# 3199             DEFAULT                      3199                  1, 2, 3
# ...                  ...                       ...                      ...
# 106664           DEFAULT                    106664                  1, 2, 3
# 106666           DEFAULT                    106666                  1, 2, 3
# 106811           DEFAULT                    106811                  1, 2, 3
# 106813           DEFAULT                    106813                  1, 2, 3
# 106815           DEFAULT                    106815                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 1903                           10.164
# 1958                           12.000
# 2012                           13.662
# 2497                           13.092
# 3199                           13.710
# ...                               ...
# 106664                         20.670
# 106666                         18.792
# 106811                         19.794
# 106813                         21.288
# 106815                         19.740
#
# [3400 rows x 24 columns]

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1903                           NaN                        NaN
# 1958                           NaN                        NaN
# 2012                           NaN                        NaN
# 2497                           NaN                        NaN
# 3199                           NaN                        NaN
# ...                            ...                        ...
# 106664                         NaN                        NaN
# 106666                         NaN                        NaN
# 106811                         NaN                        NaN
# 106813                         NaN                        NaN
# 106815                         NaN                        NaN
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1903                          NaN                            NaN    9  2005
# 1958                          NaN                            NaN   10  2005
# 2012                          NaN                            NaN   10  2005
# 2497                          NaN                            NaN    2  2006
# 3199                          NaN                            NaN    8  2006
# ...                           ...                            ...  ...   ...
# 106664                        NaN                            NaN    6  2019
# 106666                        NaN                            NaN    6  2019
# 106811                        NaN                            NaN    6  2019
# 106813                        NaN                            NaN    6  2019
# 106815                        NaN                            NaN    6  2019
#
#         coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 1903             DEFAULT                      1903                  1, 2, 3
# 1958             DEFAULT                      1958                  1, 2, 3
# 2012             DEFAULT                      2012                  1, 2, 3
# 2497             DEFAULT                      2497                  1, 2, 3
# 3199             DEFAULT                      3199                  1, 2, 3
# ...                  ...                       ...                      ...
# 106664           DEFAULT                    106664                  1, 2, 3
# 106666           DEFAULT                    106666                  1, 2, 3
# 106811           DEFAULT                    106811                  1, 2, 3
# 106813           DEFAULT                    106813                  1, 2, 3
# 106815           DEFAULT                    106815                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 1903                           10.164
# 1958                           12.000
# 2012                           13.662
# 2497                           13.092
# 3199                           13.710
# ...                               ...
# 106664                         20.670
# 106666                         18.792
# 106811                         19.794
# 106813                         21.288
# 106815                         19.740
#
# [3400 rows x 24 columns]

# %%
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO':10,
    'DESVIO PADRÃO DISTRIBUIÇÃO':20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO':30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO':'vazio'

})

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1903                          20.0                       30.0
# 1958                          20.0                       30.0
# 2012                          20.0                       30.0
# 2497                          20.0                       30.0
# 3199                          20.0                       30.0
# ...                            ...                        ...
# 106664                        20.0                       30.0
# 106666                        20.0                       30.0
# 106811                        20.0                       30.0
# 106813                        20.0                       30.0
# 106815                        20.0                       30.0
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 1903                        vazio                            NaN    9  2005
# 1958                        vazio                            NaN   10  2005
# 2012                        vazio                            NaN   10  2005
# 2497                        vazio                            NaN    2  2006
# 3199                        vazio                            NaN    8  2006
# ...                           ...                            ...  ...   ...
# 106664                      vazio                            NaN    6  2019
# 106666                      vazio                            NaN    6  2019
# 106811                      vazio                            NaN    6  2019
# 106813                      vazio                            NaN    6  2019
# 106815                      vazio                            NaN    6  2019
#
#        coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 1903            DEFAULT                      1903                  1, 2, 3
# 1958            DEFAULT                      1958                  1, 2, 3
# 2012            DEFAULT                      2012                  1, 2, 3
# 2497            DEFAULT                      2497                  1, 2, 3
# 3199            DEFAULT                      3199                  1, 2, 3
# ...                 ...                       ...                      ...
# 106664          DEFAULT                    106664                  1, 2, 3
# 106666          DEFAULT                    106666                  1, 2, 3
# 106811          DEFAULT                    106811                  1, 2, 3
# 106813          DEFAULT                    106813                  1, 2, 3
# 106815          DEFAULT                    106815                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 1903                           10.164
# 1958                           12.000
# 2012                           13.662
# 2497                           13.092
# 3199                           13.710
# ...                               ...
# 106664                         20.670
# 106666                         18.792
# 106811                         19.794
# 106813                         21.288
# 106815                         19.740
#
# [3400 rows x 24 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  18  MÊS                            103392 non-null  int64
#  19  ANO                            103392 non-null  int64
#  20  coluna sem nocao               103392 non-null  object
#  21  coluna a partir de lista       103392 non-null  int64
#  22  nova_coluna_valor_unico        103392 non-null  object
#  23  PREÇO MÉDIA REVENDA (dólares)  103392 non-null  float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(6)
# memory usage: 19.7+ MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('./sample_data/GasPricesinBrazil_2004-2019_preprocessado_final.csv', index=False)

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv('./sample_data/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
data_final.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        coluna a partir de lista  PREÇO MÉDIA REVENDA (dólares)
# count             103392.000000                  103392.000000
# mean               52973.958682                      64.706834
# std                30968.261500                     106.115110
# min                    0.000000                       4.596000
# 25%                25964.750000                      12.438000
# 50%                52661.500000                      16.338000
# 75%                79918.250000                      22.470000
# max               106822.000000                     596.142000

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()[['PREÇO MÉDIO REVENDA']]
# Out:
#        PREÇO MÉDIO REVENDA
# count        103392.000000
# mean             10.784472
# std              17.685852
# min               0.766000
# 25%               2.073000
# 50%               2.723000
# 75%               3.745000
# max              99.357000

# %%
stats = data_final.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        coluna a partir de lista  PREÇO MÉDIA REVENDA (dólares)
# count             103392.000000                  103392.000000
# mean               52973.958682                      64.706834
# std                30968.261500                     106.115110
# min                    0.000000                       4.596000
# 25%                25964.750000                      12.438000
# 50%                52661.500000                      16.338000
# 75%                79918.250000                      22.470000
# max               106822.000000                     596.142000

# %%
stats[['PREÇO MÉDIO REVENDA','PREÇO MÁXIMO REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
stats[['PREÇO MÉDIO REVENDA','PREÇO MÁXIMO REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count             8.000000              8.000000                  8.000000
# mean          12941.141790          12944.467360              12938.155376
# std           36547.680764          36546.343970              36548.882996
# min               0.766000              0.999000                  0.506000
# 25%               2.560500              2.832500                  2.200000
# 50%               7.264736              8.304343                  5.933161
# 75%              38.103639             45.600893                 30.987014
# max          103392.000000         103392.000000             103392.000000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        coluna a partir de lista  PREÇO MÉDIA REVENDA (dólares)
# count             103392.000000                  103392.000000
# mean               52973.958682                      64.706834
# std                30968.261500                     106.115110
# min                    0.000000                       4.596000
# 25%                25964.750000                      12.438000
# 50%                52661.500000                      16.338000
# 75%                79918.250000                      22.470000
# max               106822.000000                     596.142000

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000             0.766000
# max                    4167.000000            99.357000
# mean                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# mean                  8.559322                    0.559441
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# min                    0.325700                   0.599200
# max                   83.000000                  94.500000
# mean                   7.414814                   9.805621
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS          ANO  \
# min                         0.00000   1.000000  2004.000000
# max                         0.78000  12.000000  2019.000000
# mean                        0.04664   6.485067  2011.737001
#
#       coluna a partir de lista  PREÇO MÉDIA REVENDA (dólares)
# min                   0.000000                       4.596000
# max              106822.000000                     596.142000
# mean              52973.958682                      64.706834

# %%
stats.loc[['min', 'max', 'mean'], 'PREÇO MÉDIO REVENDA']
# Out:
# min      0.766000
# max     99.357000
# mean    10.784472
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 0           DEFAULT                         0                  1, 2, 3
# 1           DEFAULT                         1                  1, 2, 3
# 2           DEFAULT                         2                  1, 2, 3
# 3           DEFAULT                         3                  1, 2, 3
# 4           DEFAULT                         4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços minimos de revendas é {mean:.2} +- {std:.2}')
# Out:
# A média dos preços minimos de revendas é 9.3 +- 1.5e+01

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts()
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame()
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(linha):
    return linha.sum()

# %%
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MÉDIA(A, B, C'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MÉDIA(A, B, C
# Linha 1   1   10   100            111           37.0
# Linha 2   2   20   200            222           74.0
# Linha 3   3   30   300            333          111.0
# Linha 4   4   40   400            444          148.0
# Linha 5  10  100  1000           1110          370.0

# %%
df['C * 2'] = df['C'].apply(lambda x: x*2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MÉDIA(A, B, C  C * 2
# Linha 1   1   10   100            111           37.0    200
# Linha 2   2   20   200            222           74.0    400
# Linha 3   3   30   300            333          111.0    600
# Linha 4   4   40   400            444          148.0    800
# Linha 5  10  100  1000           1110          370.0   2000

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA(A, B, C)  MÉDIA(A, B, C  C * 2  A * 2
# Linha 1   1   10   100            111           37.0    200      2
# Linha 2   2   20   200            222           74.0    400      4
# Linha 3   3   30   300            333          111.0    600      6
# Linha 4   4   40   400            444          148.0    800      8
# Linha 5  10  100  1000           1110          370.0   2000     20

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df.applymap(lambda x: x**2)
# Out:
# /tmp/ipython-input-1911323247.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x**2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pero'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3     Pero
# dtype: object

# %%
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3     PERO
# dtype: object

# %%
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3     Pero
# dtype: object

# %%
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3     PERO
# dtype: object

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 0           DEFAULT                         0                  1, 2, 3
# 1           DEFAULT                         1                  1, 2, 3
# 2           DEFAULT                         2                  1, 2, 3
# 3           DEFAULT                         3                  1, 2, 3
# 4           DEFAULT                         4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383]),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391]),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379]),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390]),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389])}

# %%
grupos.get_group('CENTRO OESTE')
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27       2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...             ...         ...           ...                 ...
# 103359   2019-06-23  2019-06-29  CENTRO OESTE    DISTRITO FEDERAL
# 103361   2019-06-23  2019-06-29  CENTRO OESTE               GOIAS
# 103363   2019-06-23  2019-06-29  CENTRO OESTE         MATO GROSSO
# 103364   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
# 103383   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 27      ETANOL HIDRATADO                           144              R$/l
# ...                  ...                           ...               ...
# 103359               GLP                            42           R$/13Kg
# 103361               GLP                           209           R$/13Kg
# 103363               GLP                            95           R$/13Kg
# 103364               GLP                           115           R$/13Kg
# 103383               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 27                    1.271                  0.039                 1.060  ...
# ...                     ...                    ...                   ...  ...
# 103359               73.452                  4.875                65.000  ...
# 103361               71.968                  5.381                53.000  ...
# 103363               96.691                  6.835                73.000  ...
# 103364               72.297                  8.054                59.990  ...
# 103383                2.934                  0.049                 2.899  ...
#
#         DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.110                     0.4201
# 1                            0.088                     0.5013
# 2                            0.095                     0.5614
# 3                            0.119                     0.5991
# 27                           0.111                     0.4094
# ...                            ...                        ...
# 103359                       7.877                    44.0000
# 103361                       4.285                    45.5700
# 103363                       8.846                    61.1500
# 103364                       5.109                    47.0000
# 103383                       0.259                     1.8500
#
#         PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                         0.96660                          0.133    5  2004
# 1                         1.05000                          0.115    5  2004
# 2                         1.16100                          0.098    5  2004
# 3                         1.22242                          0.143    5  2004
# 27                        1.19310                          0.135    5  2004
# ...                           ...                            ...  ...   ...
# 103359                   62.82000                          0.152    6  2019
# 103361                   61.60000                          0.075    6  2019
# 103363                   90.00000                          0.115    6  2019
# 103364                   72.00000                          0.092    6  2019
# 103383                    2.21610                          0.127    6  2019
#
#         coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 0                DEFAULT                         0                  1, 2, 3
# 1                DEFAULT                         1                  1, 2, 3
# 2                DEFAULT                         2                  1, 2, 3
# 3                DEFAULT                         3                  1, 2, 3
# 27               DEFAULT                        27                  1, 2, 3
# ...                  ...                       ...                      ...
# 103359           DEFAULT                    106787                  1, 2, 3
# 103361           DEFAULT                    106789                  1, 2, 3
# 103363           DEFAULT                    106791                  1, 2, 3
# 103364           DEFAULT                    106792                  1, 2, 3
# 103383           DEFAULT                    106812                  1, 2, 3
#
#         PREÇO MÉDIA REVENDA (dólares)
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 27                              7.626
# ...                               ...
# 103359                        440.712
# 103361                        431.808
# 103363                        580.146
# 103364                        433.782
# 103383                         17.604
#
# [14545 rows x 24 columns]

# %%
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      14545.0  144.898453  105.699340  1.0   80.0
# NORDESTE                          35788.0  124.721834  113.110808  1.0   41.0
# NORTE                             24000.0   67.835958   52.961342  1.0   31.0
# SUDESTE                           16744.0  726.068024  787.588935  1.0  168.0
# SUL                               12315.0  366.266423  233.276285  1.0  188.0
#
#                                    PREÇO MÉDIO REVENDA             ...  \
#                 50%    75%     max               count       mean  ...
# REGIÃO                                                             ...
# CENTRO OESTE  128.0  192.0   766.0             14545.0  12.299706  ...
# NORDESTE       95.0  169.0   625.0             35788.0   9.558746  ...
# NORTE          53.0   95.0   383.0             24000.0  12.633086  ...
# SUDESTE       412.0  996.0  4167.0             16744.0   9.828218  ...
# SUL           368.0  563.0  1416.0             12315.0  10.254388  ...
#
#              coluna a partir de lista           PREÇO MÉDIA REVENDA (dólares)  \
#                                   75%       max                         count
# REGIÃO
# CENTRO OESTE                  80299.0  106812.0                       14545.0
# NORDESTE                      79910.5  106822.0                       35788.0
# NORTE                         80343.5  106807.0                       24000.0
# SUDESTE                       79401.5  106821.0                       16744.0
# SUL                           79332.5  106820.0                       12315.0
#
#
#                    mean         std    min     25%     50%     75%      max
# REGIÃO
# CENTRO OESTE  73.798239  119.704635  6.582  12.684  16.866  23.166  596.142
# NORDESTE      57.352477   95.933090  5.850  11.886  15.744  21.480  477.780
# NORTE         75.798516  117.827109  7.356  14.292  17.982  25.386  523.620
# SUDESTE       58.969309   97.709682  4.596  11.262  15.321  21.435  475.152
# SUL           61.526326  101.423263  5.532  11.940  15.582  21.318  432.528
#
# [5 rows x 128 columns]

# %%
grupos.mean(numeric_only=True)
# Out:
#               NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# REGIÃO
# CENTRO OESTE                    144.898453            12.299706
# NORDESTE                        124.721834             9.558746
# NORTE                            67.835958            12.633086
# SUDESTE                         726.068024             9.828218
# SUL                             366.266423            10.254388
#
#               DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# REGIÃO
# CENTRO OESTE               0.695078             10.610077
# NORDESTE                   0.552230              8.375173
# NORTE                      0.718957             11.410176
# SUDESTE                    0.678608              7.966396
# SUL                        0.729338              8.434376
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE             13.993156              2.438077
# NORDESTE                 10.788018              2.069198
# NORTE                    14.448137              2.221746
# SUDESTE                  11.894671              2.335709
# SUL                      12.391134              2.283191
#
#               COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  0.042077                  9.861629
# NORDESTE                      0.041247                  7.489549
# NORTE                         0.047480                 10.411340
# SUDESTE                       0.055126                  7.492509
# SUL                           0.047045                  7.971197
#
#               DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                    0.692259                   8.511186
# NORDESTE                        0.514093                   6.563284
# NORTE                           0.442566                   9.505328
# SUDESTE                         0.585445                   6.000720
# SUL                             0.726774                   6.443075
#
#               PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  11.130478                       0.039288
# NORDESTE                       8.461956                       0.047887
# NORTE                         11.314534                       0.034485
# SUDESTE                        9.330476                       0.060778
# SUL                            9.851008                       0.056162
#
#                    MÊS          ANO  coluna a partir de lista  \
# REGIÃO
# CENTRO OESTE  6.483396  2011.773599              52794.848127
# NORDESTE      6.487845  2011.704454              53022.749022
# NORTE         6.488458  2011.812083              52735.865958
# SUDESTE       6.481844  2011.707895              53281.350334
# SUL           6.476736  2011.681608              53089.777913
#
#               PREÇO MÉDIA REVENDA (dólares)
# REGIÃO
# CENTRO OESTE                      73.798239
# NORDESTE                          57.352477
# NORTE                             75.798516
# SUDESTE                           58.969309
# SUL                               61.526326

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.110                     0.4201
# 1                       0.088                     0.5013
# 2                       0.095                     0.5614
# 3                       0.119                     0.5991
# 4                       0.077                     0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 0                    0.96660                          0.133    5  2004
# 1                    1.05000                          0.115    5  2004
# 2                    1.16100                          0.098    5  2004
# 3                    1.22242                          0.143    5  2004
# 4                    1.03170                          0.082    5  2004
#
#    coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 0           DEFAULT                         0                  1, 2, 3
# 1           DEFAULT                         1                  1, 2, 3
# 2           DEFAULT                         2                  1, 2, 3
# 3           DEFAULT                         3                  1, 2, 3
# 4           DEFAULT                         4                  1, 2, 3
#
#    PREÇO MÉDIA REVENDA (dólares)
# 0                          7.728
# 1                          6.972
# 2                          8.334
# 3                          7.572
# 4                          7.086
#
# [5 rows x 24 columns]

# %%
data_final.groupby(['REGIÃO', 'PRODUTO']).mean(numeric_only=True)
# Out:
#                                NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    155.514414
#              GASOLINA COMUM                      155.447352
#              GLP                                 202.113944
#              GNV                                   3.759150
#              ÓLEO DIESEL                         131.940332
#              ÓLEO DIESEL S10                      76.054545
# NORDESTE     ETANOL HIDRATADO                    154.143770
#              GASOLINA COMUM                      174.051678
#              GLP                                 127.294072
#              GNV                                  17.498068
#              ÓLEO DIESEL                         135.536185
#              ÓLEO DIESEL S10                      93.857190
# NORTE        ETANOL HIDRATADO                     47.731312
#              GASOLINA COMUM                       77.837665
#              GLP                                  91.767224
#              GNV                                   1.378601
#              ÓLEO DIESEL                          68.135956
#              ÓLEO DIESEL S10                      40.495267
# SUDESTE      ETANOL HIDRATADO                   1038.720115
#              GASOLINA COMUM                     1051.909236
#              GLP                                 757.155881
#              GNV                                  81.839493
#              ÓLEO DIESEL                         771.300955
#              ÓLEO DIESEL S10                     419.743514
# SUL          ETANOL HIDRATADO                    454.889928
#              GASOLINA COMUM                      495.972387
#              GLP                                 487.431498
#              GNV                                  21.242759
#              ÓLEO DIESEL                         364.170348
#              ÓLEO DIESEL S10                     230.283597
#
#                                PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO             2.135670               0.111992
#              GASOLINA COMUM               3.077476               0.104105
#              GLP                         48.176747               2.911219
#              GNV                          1.856312               0.032635
#              ÓLEO DIESEL                  2.481286               0.081540
#              ÓLEO DIESEL S10              3.294752               0.108976
# NORDESTE     ETANOL HIDRATADO             2.320266               0.115449
#              GASOLINA COMUM               3.001887               0.108104
#              GLP                         41.966090               2.667713
#              GNV                          1.881722               0.061486
#              ÓLEO DIESEL                  2.346950               0.069301
#              ÓLEO DIESEL S10              3.041966               0.091881
# NORTE        ETANOL HIDRATADO             2.511624               0.123097
#              GASOLINA COMUM               3.149501               0.140339
#              GLP                         47.065572               2.811086
#              GNV                          2.084399               0.007749
#              ÓLEO DIESEL                  2.571048               0.105590
#              ÓLEO DIESEL S10              3.316231               0.127927
# SUDESTE      ETANOL HIDRATADO             2.163621               0.134447
#              GASOLINA COMUM               3.000565               0.122024
#              GLP                         42.081544               3.117192
#              GNV                          1.716074               0.130730
#              ÓLEO DIESEL                  2.339699               0.082670
#              ÓLEO DIESEL S10              3.056194               0.109765
# SUL          ETANOL HIDRATADO             2.268156               0.123595
#              GASOLINA COMUM               2.972569               0.117779
#              GLP                         43.490318               3.408160
#              GNV                          1.865612               0.065362
#              ÓLEO DIESEL                  2.332293               0.081869
#              ÓLEO DIESEL S10              2.981775               0.110249
#
#                                PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO              1.926522              2.433303
#              GASOLINA COMUM                2.866732              3.338657
#              GLP                          40.936969             55.244748
#              GNV                           1.824489              1.885087
#              ÓLEO DIESEL                   2.310497              2.686205
#              ÓLEO DIESEL S10               3.070625              3.559399
# NORDESTE     ETANOL HIDRATADO              2.099488              2.654045
#              GASOLINA COMUM                2.780405              3.277436
#              GLP                          36.142140             47.701105
#              GNV                           1.820660              2.038715
#              ÓLEO DIESEL                   2.203687              2.534809
#              ÓLEO DIESEL S10               2.851121              3.304049
# NORTE        ETANOL HIDRATADO              2.331752              2.849155
#              GASOLINA COMUM                2.956946              3.540174
#              GLP                          42.185523             54.103233
#              GNV                           2.079103              2.091321
#              ÓLEO DIESEL                   2.400341              2.831189
#              ÓLEO DIESEL S10               3.128494              3.645934
# SUDESTE      ETANOL HIDRATADO              1.810669              2.629952
#              GASOLINA COMUM                2.698406              3.463277
#              GLP                          33.297570             51.319812
#              GNV                           1.548030              2.123404
#              ÓLEO DIESEL                   2.118881              2.659866
#              ÓLEO DIESEL S10               2.765417              3.457892
# SUL          ETANOL HIDRATADO              1.947168              2.672393
#              GASOLINA COMUM                2.677828              3.340463
#              GLP                          34.939095             53.352339
#              GNV                           1.779690              2.046901
#              ÓLEO DIESEL                   2.124973              2.611223
#              ÓLEO DIESEL S10               2.707439              3.366409
#
#                                MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO              0.334742                  0.055679
#              GASOLINA COMUM                0.413081                  0.033634
#              GLP                          10.144382                  0.057783
#              GNV                           0.467869                  0.016150
#              ÓLEO DIESEL                   0.269293                  0.032117
#              ÓLEO DIESEL S10               0.375726                  0.032577
# NORDESTE     ETANOL HIDRATADO              0.300006                  0.052053
#              GASOLINA COMUM                0.400337                  0.036357
#              GLP                           9.951840                  0.060451
#              GNV                           0.517594                  0.032138
#              ÓLEO DIESEL                   0.233981                  0.029401
#              ÓLEO DIESEL S10               0.326030                  0.030066
# NORTE        ETANOL HIDRATADO              0.362131                  0.050314
#              GASOLINA COMUM                0.454351                  0.045172
#              GLP                           8.660637                  0.059383
#              GNV                           0.371848                  0.003025
#              ÓLEO DIESEL                   0.323795                  0.041224
#              ÓLEO DIESEL S10               0.417151                  0.038669
# SUDESTE      ETANOL HIDRATADO              0.300850                  0.064111
#              GASOLINA COMUM                0.361858                  0.041105
#              GLP                          10.952603                  0.070829
#              GNV                           0.478567                  0.075199
#              ÓLEO DIESEL                   0.261930                  0.034798
#              ÓLEO DIESEL S10               0.362285                  0.035397
# SUL          ETANOL HIDRATADO              0.316748                  0.055945
#              GASOLINA COMUM                0.371459                  0.039308
#              GLP                          10.484570                  0.075147
#              GNV                           0.478205                  0.032599
#              ÓLEO DIESEL                   0.276743                  0.034138
#              ÓLEO DIESEL S10               0.368439                  0.036409
#
#                                PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                  1.800927
#              GASOLINA COMUM                    2.664395
#              GLP                              38.032365
#              GNV                               1.388443
#              ÓLEO DIESEL                       2.211993
#              ÓLEO DIESEL S10                   2.919026
# NORDESTE     ETANOL HIDRATADO                  2.020260
#              GASOLINA COMUM                    2.601550
#              GLP                              32.014250
#              GNV                               1.364128
#              ÓLEO DIESEL                       2.112969
#              ÓLEO DIESEL S10                   2.715936
# NORTE        ETANOL HIDRATADO                  2.149494
#              GASOLINA COMUM                    2.695151
#              GLP                              38.404935
#              GNV                               1.712551
#              ÓLEO DIESEL                       2.247253
#              ÓLEO DIESEL S10                   2.899079
# SUDESTE      ETANOL HIDRATADO                  1.862771
#              GASOLINA COMUM                    2.638708
#              GLP                              31.128941
#              GNV                               1.237507
#              ÓLEO DIESEL                       2.077769
#              ÓLEO DIESEL S10                   2.693909
# SUL          ETANOL HIDRATADO                  1.951408
#              GASOLINA COMUM                    2.601110
#              GLP                              33.005748
#              GNV                               1.387408
#              ÓLEO DIESEL                       2.055550
#              ÓLEO DIESEL S10                   2.613336
#
#                                DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    0.082278
#              GASOLINA COMUM                      0.057165
#              GLP                                 3.024617
#              GNV                                 0.020891
#              ÓLEO DIESEL                         0.049874
#              ÓLEO DIESEL S10                     0.073233
# NORDESTE     ETANOL HIDRATADO                    0.090895
#              GASOLINA COMUM                      0.056139
#              GLP                                 2.527986
#              GNV                                 0.119690
#              ÓLEO DIESEL                         0.048033
#              ÓLEO DIESEL S10                     0.065408
# NORTE        ETANOL HIDRATADO                    0.094058
#              GASOLINA COMUM                      0.067774
#              GLP                                 1.734085
#              GNV                                 0.012959
#              ÓLEO DIESEL                         0.060785
#              ÓLEO DIESEL S10                     0.082405
# SUDESTE      ETANOL HIDRATADO                    0.107642
#              GASOLINA COMUM                      0.066199
#              GLP                                 2.741245
#              GNV                                 0.136902
#              ÓLEO DIESEL                         0.051781
#              ÓLEO DIESEL S10                     0.078823
# SUL          ETANOL HIDRATADO                    0.112108
#              GASOLINA COMUM                      0.064611
#              GLP                                 3.461267
#              GNV                                 0.113510
#              ÓLEO DIESEL                         0.053771
#              ÓLEO DIESEL S10                     0.081475
#
#                                PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                   1.629448
#              GASOLINA COMUM                     2.553451
#              GLP                               32.142998
#              GNV                                1.370323
#              ÓLEO DIESEL                        2.106889
#              ÓLEO DIESEL S10                    2.779236
# NORDESTE     ETANOL HIDRATADO                   1.799990
#              GASOLINA COMUM                     2.487578
#              GLP                               27.493395
#              GNV                                1.215388
#              ÓLEO DIESEL                        2.017312
#              ÓLEO DIESEL S10                    2.594516
# NORTE        ETANOL HIDRATADO                   1.983308
#              GASOLINA COMUM                     2.582237
#              GLP                               34.773738
#              GNV                                1.704218
#              ÓLEO DIESEL                        2.135717
#              ÓLEO DIESEL S10                    2.764806
# SUDESTE      ETANOL HIDRATADO                   1.540547
#              GASOLINA COMUM                     2.438181
#              GLP                               24.089119
#              GNV                                1.054692
#              ÓLEO DIESEL                        1.931599
#              ÓLEO DIESEL S10                    2.489478
# SUL          ETANOL HIDRATADO                   1.634512
#              GASOLINA COMUM                     2.432431
#              GLP                               25.791680
#              GNV                                1.233294
#              ÓLEO DIESEL                        1.926497
#              ÓLEO DIESEL S10                    2.438362
#
#                                PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                   2.009326
#              GASOLINA COMUM                     2.824949
#              GLP                               43.451689
#              GNV                                1.407466
#              ÓLEO DIESEL                        2.323683
#              ÓLEO DIESEL S10                    3.040020
# NORDESTE     ETANOL HIDRATADO                   2.229782
#              GASOLINA COMUM                     2.764345
#              GLP                               36.713845
#              GNV                                1.522437
#              ÓLEO DIESEL                        2.223088
#              ÓLEO DIESEL S10                    2.865362
# NORTE        ETANOL HIDRATADO                   2.320192
#              GASOLINA COMUM                     2.851914
#              GLP                               41.960261
#              GNV                                1.724462
#              ÓLEO DIESEL                        2.366200
#              ÓLEO DIESEL S10                    3.047200
# SUDESTE      ETANOL HIDRATADO                   2.179384
#              GASOLINA COMUM                     2.882938
#              GLP                               39.873958
#              GNV                                1.487619
#              ÓLEO DIESEL                        2.256056
#              ÓLEO DIESEL S10                    2.924680
# SUL          ETANOL HIDRATADO                   2.240606
#              GASOLINA COMUM                     2.826101
#              GLP                               42.029554
#              GNV                                1.512227
#              ÓLEO DIESEL                        2.207007
#              ÓLEO DIESEL S10                    2.814347
#
#                                COEF DE VARIAÇÃO DISTRIBUIÇÃO       MÊS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                       0.049851  6.507047
#              GASOLINA COMUM                         0.021549  6.507658
#              GLP                                    0.076607  6.490962
#              GNV                                    0.014126  6.408501
#              ÓLEO DIESEL                            0.021995  6.507658
#              ÓLEO DIESEL S10                        0.024829  6.329752
# NORDESTE     ETANOL HIDRATADO                       0.046830  6.505819
#              GASOLINA COMUM                         0.021565  6.501062
#              GLP                                    0.076961  6.517317
#              GNV                                    0.098374  6.490340
#              ÓLEO DIESEL                            0.022107  6.501062
#              ÓLEO DIESEL S10                        0.024048  6.317942
# NORTE        ETANOL HIDRATADO                       0.046450  6.511686
#              GASOLINA COMUM                         0.025225  6.500183
#              GLP                                    0.044272  6.502722
#              GNV                                    0.006025  6.485597
#              ÓLEO DIESEL                            0.026873  6.498079
#              ÓLEO DIESEL S10                        0.028042  6.354131
# SUDESTE      ETANOL HIDRATADO                       0.060287  6.501434
#              GASOLINA COMUM                         0.024951  6.500637
#              GLP                                    0.087555  6.498566
#              GNV                                    0.127156  6.478001
#              ÓLEO DIESEL                            0.023954  6.500637
#              ÓLEO DIESEL S10                        0.028969  6.318013
# SUL          ETANOL HIDRATADO                       0.062075  6.501912
#              GASOLINA COMUM                         0.024564  6.501274
#              GLP                                    0.102631  6.516005
#              GNV                                    0.082502  6.420748
#              ÓLEO DIESEL                            0.025223  6.501274
#              ÓLEO DIESEL S10                        0.030871  6.318182
#
#                                        ANO  coluna a partir de lista  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  2011.434017              38483.494234
#              GASOLINA COMUM    2011.430759              45307.328334
#              GLP               2011.428341              52223.154616
#              GNV               2010.829988              53688.927981
#              ÓLEO DIESEL       2011.430759              63205.485322
#              ÓLEO DIESEL S10   2015.970248              82987.259504
# NORDESTE     ETANOL HIDRATADO  2011.421516              38298.875958
#              GASOLINA COMUM    2011.431262              45299.113408
#              GLP               2011.185335              50884.853978
#              GNV               2011.103168              55782.423493
#              ÓLEO DIESEL       2011.430676              63204.997592
#              ÓLEO DIESEL S10   2015.759894              81327.308047
# NORTE        ETANOL HIDRATADO  2011.228511              36600.115704
#              GASOLINA COMUM    2011.438141              45396.695095
#              GLP               2011.399850              52110.264877
#              GNV               2012.016461              62756.650206
#              ÓLEO DIESEL       2011.441537              63266.472095
#              ÓLEO DIESEL S10   2015.786145              81558.487522
# SUDESTE      ETANOL HIDRATADO  2011.426522              38356.866752
#              GASOLINA COMUM    2011.433121              45323.124841
#              GLP               2011.435448              52224.677718
#              GNV               2011.001760              55403.984512
#              ÓLEO DIESEL       2011.433121              63227.152866
#              ÓLEO DIESEL S10   2015.762046              81347.689400
# SUL          ETANOL HIDRATADO  2011.427539              38369.645984
#              GASOLINA COMUM    2011.430331              45304.342821
#              GLP               2011.409731              52059.060179
#              GNV               2010.783570              54663.799895
#              ÓLEO DIESEL       2011.430331              63215.999575
#              ÓLEO DIESEL S10   2015.755929              81303.377470
#
#                                PREÇO MÉDIA REVENDA (dólares)
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                      12.814019
#              GASOLINA COMUM                        18.464858
#              GLP                                  289.060480
#              GNV                                   11.137870
#              ÓLEO DIESEL                           14.887717
#              ÓLEO DIESEL S10                       19.768512
# NORDESTE     ETANOL HIDRATADO                      13.921593
#              GASOLINA COMUM                        18.011325
#              GLP                                  251.796538
#              GNV                                   11.290334
#              ÓLEO DIESEL                           14.081699
#              ÓLEO DIESEL S10                       18.251796
# NORTE        ETANOL HIDRATADO                      15.069745
#              GASOLINA COMUM                        18.897009
#              GLP                                  282.393433
#              GNV                                   12.506395
#              ÓLEO DIESEL                           15.426290
#              ÓLEO DIESEL S10                       19.897384
# SUDESTE      ETANOL HIDRATADO                      12.981724
#              GASOLINA COMUM                        18.003392
#              GLP                                  252.489267
#              GNV                                   10.296444
#              ÓLEO DIESEL                           14.038192
#              ÓLEO DIESEL S10                       18.337165
# SUL          ETANOL HIDRATADO                      13.608933
#              GASOLINA COMUM                        17.835413
#              GLP                                  260.941908
#              GNV                                   11.193675
#              ÓLEO DIESEL                           13.993759
#              ÓLEO DIESEL S10                       17.890648

# %%
grupos.mean(numeric_only=True)
# Out:
#               NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# REGIÃO
# CENTRO OESTE                    144.898453            12.299706
# NORDESTE                        124.721834             9.558746
# NORTE                            67.835958            12.633086
# SUDESTE                         726.068024             9.828218
# SUL                             366.266423            10.254388
#
#               DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# REGIÃO
# CENTRO OESTE               0.695078             10.610077
# NORDESTE                   0.552230              8.375173
# NORTE                      0.718957             11.410176
# SUDESTE                    0.678608              7.966396
# SUL                        0.729338              8.434376
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE             13.993156              2.438077
# NORDESTE                 10.788018              2.069198
# NORTE                    14.448137              2.221746
# SUDESTE                  11.894671              2.335709
# SUL                      12.391134              2.283191
#
#               COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  0.042077                  9.861629
# NORDESTE                      0.041247                  7.489549
# NORTE                         0.047480                 10.411340
# SUDESTE                       0.055126                  7.492509
# SUL                           0.047045                  7.971197
#
#               DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                    0.692259                   8.511186
# NORDESTE                        0.514093                   6.563284
# NORTE                           0.442566                   9.505328
# SUDESTE                         0.585445                   6.000720
# SUL                             0.726774                   6.443075
#
#               PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                  11.130478                       0.039288
# NORDESTE                       8.461956                       0.047887
# NORTE                         11.314534                       0.034485
# SUDESTE                        9.330476                       0.060778
# SUL                            9.851008                       0.056162
#
#                    MÊS          ANO  coluna a partir de lista  \
# REGIÃO
# CENTRO OESTE  6.483396  2011.773599              52794.848127
# NORDESTE      6.487845  2011.704454              53022.749022
# NORTE         6.488458  2011.812083              52735.865958
# SUDESTE       6.481844  2011.707895              53281.350334
# SUL           6.476736  2011.681608              53089.777913
#
#               PREÇO MÉDIA REVENDA (dólares)
# REGIÃO
# CENTRO OESTE                      73.798239
# NORDESTE                          57.352477
# NORTE                             75.798516
# SUDESTE                           58.969309
# SUL                               61.526326

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO
# CENTRO OESTE    12.299706
# NORDESTE         9.558746
# NORTE           12.633086
# SUDESTE          9.828218
# SUL             10.254388
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                 count       mean        std    min    25%     50%     75%  \
# REGIÃO
# CENTRO OESTE  14545.0  12.299706  19.950773  1.097  2.114  2.8110  3.8610
# NORDESTE      35788.0   9.558746  15.988848  0.975  1.981  2.6240  3.5800
# NORTE         24000.0  12.633086  19.637852  1.226  2.382  2.9970  4.2310
# SUDESTE       16744.0   9.828218  16.284947  0.766  1.877  2.5535  3.5725
# SUL           12315.0  10.254388  16.903877  0.922  1.990  2.5970  3.5530
#
#                  max
# REGIÃO
# CENTRO OESTE  99.357
# NORDESTE      79.630
# NORTE         87.270
# SUDESTE       79.192
# SUL           72.088

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None,None,None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg(['sum', 'min'])
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([ 'min', 'max'])
# Out:
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_exercicios = data_final.query('ANO != 2019')

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %%
data_exercicios.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
postos_por_regiao_produto = data_exercicios.groupby(['REGIÃO', 'PRODUTO'])['NÚMERO DE POSTOS PESQUISADOS'].sum()
total_postos_por_regiao = data_exercicios.groupby('REGIÃO')['NÚMERO DE POSTOS PESQUISADOS'].sum()

proporcao_postos = postos_por_regiao_produto.div(total_postos_por_regiao, level='REGIÃO').unstack(fill_value=0)
print(proporcao_postos)
# Out:
# PRODUTO       ETANOL HIDRATADO  GASOLINA COMUM       GLP       GNV  \
# REGIÃO
# CENTRO OESTE          0.230294        0.231121  0.299611  0.001520
# NORDESTE              0.243871        0.275878  0.183225  0.020457
# NORTE                 0.152683        0.261649  0.301038  0.000201
# SUDESTE               0.268558        0.272246  0.196033  0.019220
# SUL                   0.238576        0.259123  0.253929  0.008886
#
# PRODUTO       ÓLEO DIESEL  ÓLEO DIESEL S10
# REGIÃO
# CENTRO OESTE     0.197647         0.039806
# NORDESTE         0.217078         0.059491
# NORTE            0.230268         0.054160
# SUDESTE          0.200792         0.043151
# SUL              0.191251         0.048234

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolina_sp_2018 = data_exercicios.query('ESTADO == "SAO PAULO" and PRODUTO == "GASOLINA COMUM" and ANO == 2018')
print(gasolina_sp_2018.head())
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 92319                  0.156                 3.499  ...
# 92465                  0.155                 3.549  ...
# 92610                  0.160                 3.499  ...
# 92755                  0.156                 3.579  ...
# 92901                  0.157                 3.579  ...
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92319                       0.104                      2.990
# 92465                       0.102                      2.990
# 92610                       0.102                      2.990
# 92755                       0.107                      2.924
# 92901                       0.102                      2.990
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 92319                     3.9510                          0.029    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92610                     3.9014                          0.028    1  2018
# 92755                     3.9537                          0.030    1  2018
# 92901                     3.9537                          0.028    2  2018
#
#        coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 92319           DEFAULT                     95351                  1, 2, 3
# 92465           DEFAULT                     95502                  1, 2, 3
# 92610           DEFAULT                     95654                  1, 2, 3
# 92755           DEFAULT                     95806                  1, 2, 3
# 92901           DEFAULT                     95958                  1, 2, 3
#
#        PREÇO MÉDIA REVENDA (dólares)
# 92319                         23.928
# 92465                         24.012
# 92610                         24.036
# 92755                         24.114
# 92901                         24.024
#
# [5 rows x 24 columns]

# %%
print(gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe())
# Out:
# count    52.000000
# mean      4.202769
# std       0.180672
# min       3.970000
# 25%       4.008000
# 50%       4.202000
# 75%       4.336250
# max       4.512000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
print(gasolina_sp_2018['PREÇO MÉDIO REVENDA'].mean())
print(gasolina_sp_2018['PREÇO MÉDIO REVENDA'].std())
# Out:
# 4.2027692307692295
# 0.18067201519301895

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
data_exercicios.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 92238   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92384   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 92529   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...            ...         ...      ...        ...               ...
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99472   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 99617   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92238                          1664              R$/l                2.833
# 92319                          1641              R$/l                3.988
# 92384                          1661              R$/l                2.868
# 92465                          1648              R$/l                4.002
# 92529                          1662              R$/l                2.874
# ...                             ...               ...                  ...
# 99410                          1637              R$/l                4.129
# 99472                          1662              R$/l                2.644
# 99553                          1641              R$/l                4.129
# 99617                          1661              R$/l                2.643
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 92238                  0.139                 2.449  ...
# 92319                  0.156                 3.499  ...
# 92384                  0.134                 2.399  ...
# 92465                  0.155                 3.549  ...
# 92529                  0.135                 2.399  ...
# ...                      ...                   ...  ...
# 99410                  0.201                 3.699  ...
# 99472                  0.163                 2.149  ...
# 99553                  0.201                 3.699  ...
# 99617                  0.161                 2.259  ...
# 99698                  0.201                 3.599  ...
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 92238                       0.092                     2.1842
# 92319                       0.104                     2.9900
# 92384                       0.087                     2.2600
# 92465                       0.102                     2.9900
# 92529                       0.095                     1.6900
# ...                           ...                        ...
# 99410                       0.110                     3.3500
# 99472                       0.094                     2.0067
# 99553                       0.107                     3.3500
# 99617                       0.097                     1.9072
# 99698                       0.100                     3.3500
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO  COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  \
# 92238                     2.8833                          0.037    1  2018
# 92319                     3.9510                          0.029    1  2018
# 92384                     2.8471                          0.034    1  2018
# 92465                     3.9014                          0.028    1  2018
# 92529                     2.9722                          0.037    1  2018
# ...                          ...                            ...  ...   ...
# 99410                     3.9892                          0.030   12  2018
# 99472                     2.7443                          0.040   12  2018
# 99553                     3.9892                          0.029   12  2018
# 99617                     2.7957                          0.041   12  2018
# 99698                     3.9585                          0.028   12  2018
#
#        coluna sem nocao  coluna a partir de lista  nova_coluna_valor_unico  \
# 92238           DEFAULT                     95270                  1, 2, 3
# 92319           DEFAULT                     95351                  1, 2, 3
# 92384           DEFAULT                     95421                  1, 2, 3
# 92465           DEFAULT                     95502                  1, 2, 3
# 92529           DEFAULT                     95573                  1, 2, 3
# ...                 ...                       ...                      ...
# 99410           DEFAULT                    102724                  1, 2, 3
# 99472           DEFAULT                    102793                  1, 2, 3
# 99553           DEFAULT                    102874                  1, 2, 3
# 99617           DEFAULT                    102944                  1, 2, 3
# 99698           DEFAULT                    103025                  1, 2, 3
#
#        PREÇO MÉDIA REVENDA (dólares)
# 92238                         16.998
# 92319                         23.928
# 92384                         17.208
# 92465                         24.012
# 92529                         17.244
# ...                              ...
# 99410                         24.774
# 99472                         15.864
# 99553                         24.774
# 99617                         15.858
# 99698                         24.678
#
# [104 rows x 24 columns]

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
