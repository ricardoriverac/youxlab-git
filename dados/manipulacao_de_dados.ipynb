# %% [markdown]
# #Manipulação de Dados

# %% [markdown]
# Dataset: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil
#
# Este dataset contém os registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019.
# Cada amostra (registro/linha) consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil.
# Alguns dos principais atributos (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
# * O arquivo disponibilizado no Kaggle está no formato tsv. Embora o pandas consiga abrí-lo normalmente, convertemos tal arquivo para o formato CSV, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ## Importando o Dataset

# %% [markdown]
# Para carregar um dataset no formato csv,basta utilizar a função read_csv do pandas. Por padrão,ela considera ',' como separador

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/sample_data/GasPricesinBrazil_2004-2019.csv')

# %%
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# ...

# %%
data = pd.read_csv('/content/sample_data/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# A primeira coluna da tabela, chamada 'Unnamed: 0', parece não significar nada. Na verdade, ela parece ser os índices da tabela, que foram salvos como uma coluna.
# Veremos jajá como remover tal coluna.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (null), uma vez que o número de registros do dataframe e os números de valores non-null é de 106823.
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# #### 1.3.2 Data Frame

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (106823, 21)

# %%
print(f'O DataFrame possui {data.shape[0]} linhas/atributos e {data.shape[1]} colunas/atributos/variaveis')
# Out:
# O DataFrame possui 106823 linhas/atributos e 21 colunas/atributos/variaveis

# %% [markdown]
# ## Criando um DataFrame

# %% [markdown]
# Podemos criar um DataFrame a partir de um dicionário, onde cada chave possui uma lista de elementos de igual tamanho.
# As chaves representam as colunas e cada um dos valores de sua lista representa o valor da linha correspondente para aquela coluna.

# %%
alunos_df = pd.DataFrame({
    'nome': ['Luke Skywalker','Yoda','Palpatine'],
    'idade' : [16, 1000, 70],
    'peso': [70,15,60],
    'eh jedi':[True,True,False]
})

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# ## Renomeando as colunas de um DataFrame

# %% [markdown]
# ===> O método DataFrame.columns retorna uma ";lista" com os nomes de todas as colunas do data frame.

# %%
alunos_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(alunos_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(alunos_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# Renomear colunas do data frame, utilize o metodo DataFreme.rename, que retorna uma copia do data frame com as colunas renomeadas:

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df_renomeado =  alunos_df.rename(columns={
    'nome' : 'nome completo',
    'idade': 'ID'
    })

# %%
alunos_df_renomeado
# Out:
#     nome completo    ID  peso  eh jedi
# 0  Luke Skywalker    16    70     True
# 1            Yoda  1000    15     True
# 2       Palpatine    70    60    False

# %%
alunos_df.rename(columns={'nome' : 'nome completo','idade': 'ID'},inplace=True)

# %%
alunos_df
# Out:
#     nome completo    ID  peso  eh jedi
# 0  Luke Skywalker    16    70     True
# 1            Yoda  1000    15     True
# 2       Palpatine    70    60    False

# %%
alunos_df.columns = ['NOME', 'IDADE', 'PESO', 'EH_JEDI']

# %%
alunos_df
# Out:
#              NOME  IDADE  PESO  EH_JEDI
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# # 1.3.3 Series

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Criando uma Series

# %%
pd.Series([5.5,6.0,9.5], index=['prova 1', 'prova 2', 'prova 3'], name='Notas do Luke Skywalker')
# Out:
# prova 1    5.5
# prova 2    6.0
# prova 3    9.5
# Name: Notas do Luke Skywalker, dtype: float64

# %% [markdown]
# ### Atribuindo Dados

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
produto_view = data['PRODUTO']

# %%
produto_copy_bkp = data['PRODUTO'].copy()
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = 'Combustível'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Produto {1}'for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
data['PRODUTO'] = novos_produtos

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO    PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  Produto 1                           127
# 1                     GOIAS  Produto 1                           387
# ...

# %%
print(produto_view)
print('\n')
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = produto_copy_bkp

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data['coluna sem nocao'] = 'DEFAULT'
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data['coluna a partir de lista'] = range(data.shape[0])

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %%
data['PRECO MEDIO DE REVENDA (dolares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# ### 1.3.4 Índices

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %%
pesquisa_de_satisfacao = pd.DataFrame ({
    'bom' : [50,21, 100],
    'ruim' : [141, 2, 30],
    'pessimo' : [30,20, 1]

}, index=['XboxOne', 'Playstation04', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#                bom  ruim  pessimo
# XboxOne         50   141       30
# Playstation04   21     2       20
# Switch         100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation04', 'Switch'], dtype='object')

# %% [markdown]
# # selecionando uma ou mais observações (Indexação)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %% [markdown]
# index-based selection (seleção baseada em índices)

# %% [markdown]
# iloc : seleciona elementos do Datafreme, baseado em seu índice(número)

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                         1
# DATA INICIAL                              2004-05-09
# DATA FINAL                                2004-05-15
# REGIÃO                                  CENTRO OESTE
# ESTADO                                         GOIAS
# PRODUTO                             ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                     387
# UNIDADE DE MEDIDA                               R$/l
# PREÇO MÉDIO REVENDA                            1.162
# DESVIO PADRÃO REVENDA                          0.114
# PREÇO MÍNIMO REVENDA                            0.89
# PREÇO MÁXIMO REVENDA                           1.449
# MARGEM MÉDIA REVENDA                           0.399
# COEF DE VARIAÇÃO REVENDA                       0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                       0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                     0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                     0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                       1.05
# ...

# %% [markdown]
# Selecioando multiplas linhas

# %%
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# ...

# %%
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# ...

# %%
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# ...

# %%
data.iloc[[5,1,15,10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# ...

# %%
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %% [markdown]
# Label-based selection(seleção baseadas em Rótulos)

# %% [markdown]
# loc : seleciiona elementos do Dataframe, baseado em seus rótulos

# %%
pesquisa_de_satisfacao
# Out:
#                bom  ruim  pessimo
# XboxOne         50   141       30
# Playstation04   21     2       20
# Switch         100    30        1

# %%
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       141
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       141
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.loc['Playstation04', 'ruim']
# Out:
# np.int64(2)

# %%
pesquisa_de_satisfacao.loc[['XboxOne','Switch']]
#selecionando as linhas de índices rotulados
# Out:
#          bom  ruim  pessimo
# XboxOne   50   141       30
# Switch   100    30        1

# %%
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#                bom  pessimo
# XboxOne         50       30
# Playstation04   21       20
# Switch         100        1

# %%
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#                bom  pessimo
# XboxOne         50       30
# Playstation04   21       20
# Switch         100        1

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                         1
# DATA INICIAL                              2004-05-09
# DATA FINAL                                2004-05-15
# REGIÃO                                  CENTRO OESTE
# ESTADO                                         GOIAS
# PRODUTO                             ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                     387
# UNIDADE DE MEDIDA                               R$/l
# PREÇO MÉDIO REVENDA                            1.162
# DESVIO PADRÃO REVENDA                          0.114
# PREÇO MÍNIMO REVENDA                            0.89
# PREÇO MÁXIMO REVENDA                           1.449
# MARGEM MÉDIA REVENDA                           0.399
# COEF DE VARIAÇÃO REVENDA                       0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                       0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                     0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                     0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                       1.05
# ...

# %%
data.loc[1]
# Out:
# Unnamed: 0                                         1
# DATA INICIAL                              2004-05-09
# DATA FINAL                                2004-05-15
# REGIÃO                                  CENTRO OESTE
# ESTADO                                         GOIAS
# PRODUTO                             ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                     387
# UNIDADE DE MEDIDA                               R$/l
# PREÇO MÉDIO REVENDA                            1.162
# DESVIO PADRÃO REVENDA                          0.114
# PREÇO MÍNIMO REVENDA                            0.89
# PREÇO MÁXIMO REVENDA                           1.449
# MARGEM MÉDIA REVENDA                           0.399
# COEF DE VARIAÇÃO REVENDA                       0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                       0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                     0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                     0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                       1.05
# ...

# %% [markdown]
# ## selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
data[['PRODUTO','ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# #Removendo um atributo(coluna) do Data frame

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
del data['Unnamed: 0']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# # Salvando um Data frame

# %%
data.to_csv('/content/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %% [markdown]
# #1.8 Seleção Condicional: Filtrando amostras
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas condições, para fins de análise mais específica.
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data.to_csv('/content/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #Selecionando apenas os preços dos Postos de São Paulo
# ==> Alternativa 1: Seleção Condicional (Comparações diretas)
# O código abaixo retorna uma Series ('array') de booleans, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do estado de São Paulo (True).

# %%
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %% [markdown]
# Para filtrarmos os registros de postos do estado de São Paulo

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# #==> Alternativa 2: Utilizando o método query
# query filtra linhas de um DataFrame baseado em uma query (pergunta).

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data.query('ESTADO  == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp = data.query('ESTADO  == "SAO PAULO"')

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 23)

# %%
postos_sp.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                   0.085                 0.590  ...
# ...

# %%
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
postos_sp.reset_index(drop=True, inplace=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
postos_sp = data.query('ESTADO  == "SAO PAULO"').reset_index(drop=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %% [markdown]
# Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] >2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] >2.0)

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma Series de booleans com o mesmo número de linhas/amostras do DataFrame, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo & significa AND na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&).
# Similarmente:
#
# | representa o OR (não é ||)
# ~ representa o NOT (não é !)

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# Alternativamente, poderíamos usar o método query para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
data.query('ESTADO  == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %% [markdown]
# Aprofundando mais ainda
#
# A primeira comparação (data['ESTADO'] == 'RIO DE JANEIRO') checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde apenas a essa "pergunta" feita.
#
# A segunda comparação (data['PREÇO MÉDIO REVENDA'] > 2) checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de TODOS os estados. Como resultado, temos uma Series de booleans que responde apenas a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.
#
# Alguns podem argumentar que tal abordagem é ineficiente, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame.
# O Pandas tenta otimizar isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset muito grande (centenas de milhares de linhas), tal abordagem se tornará lenta.

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro múltiplas vezes:

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
selecao1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao3 = (data['PREÇO MÉDIO REVENDA'] > 2)

selecaofinal = selecao1 & selecao2 & selecao3

# %%
selecaofinal
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data_filtrado = data[selecaofinal]
data_filtrado
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
print(data_filtrado['ESTADO'].unique())
print(data_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %%
selecao1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao1]
postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %%
selecao2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
gasolina_sp_rj = postos_sp_rj[selecao2]
gasolina_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
selecao3 = (gasolina_sp_rj['PREÇO MÉDIO REVENDA'] > 2)
gasolina_sp_rj2 = gasolina_sp_rj[selecao3]
gasolina_sp_rj2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
selecao = (data['ANO'] == 2008) | (data['ANO']== 2010) | (data['ANO'] == 2012)
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %%
lista_de_anos = [2008,2010,2012]

# %%
selecao = data['ANO'].isin(lista_de_anos)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
data.query('ANO in @lista_de_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# #Iterando com DataFrames
# For-each DataFrame.iterrows() (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
for index,row in data.head(10).iterrows():
  print(f'indice {index} ==> {row['ESTADO']}')
# Out:
# indice 0 ==> DISTRITO FEDERAL
# indice 1 ==> GOIAS
# indice 2 ==> MATO GROSSO
# indice 3 ==> MATO GROSSO DO SUL
# indice 4 ==> ALAGOAS
# indice 5 ==> BAHIA
# indice 6 ==> CEARA
# indice 7 ==> MARANHAO
# indice 8 ==> PARAIBA
# indice 9 ==> PERNAMBUCO

# %% [markdown]
# #2. Preparação dos dados

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   DATA INICIAL                      106823 non-null  object
#  1   DATA FINAL                        106823 non-null  object
#  2   REGIÃO                            106823 non-null  object
#  3   ESTADO                            106823 non-null  object
#  4   PRODUTO                           106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS      106823 non-null  int64
#  6   UNIDADE DE MEDIDA                 106823 non-null  object
#  7   PREÇO MÉDIO REVENDA               106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA             106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA              106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA              106823 non-null  float64
# ...

# %% [markdown]
# 2.2 Conversão de tipos de atributos
# O pandas automaticamente reconhece os tipos de dados de cada coluna.
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser float64 e não object.
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos.
#
# Os atributos "DATA INICIAL" e "DATA FINAL" deveriam ser do tipo datetime.
#
# Em outros casos, alguns atributos categóricos são objects, mas poderiam ter o tipo category, que é um tipo especial do pandas.
# Este tipo é necessário para se utilizar algumas funções específicas do pandas.
# Não converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# ### Datas

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   DATA INICIAL                      106823 non-null  datetime64[ns]
#  1   DATA FINAL                        106823 non-null  datetime64[ns]
#  2   REGIÃO                            106823 non-null  object
#  3   ESTADO                            106823 non-null  object
#  4   PRODUTO                           106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS      106823 non-null  int64
#  6   UNIDADE DE MEDIDA                 106823 non-null  object
#  7   PREÇO MÉDIO REVENDA               106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA             106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA              106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA              106823 non-null  float64
# ...

# %% [markdown]
# ### Dado numericos

# %%
for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
 data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   DATA INICIAL                      106823 non-null  datetime64[ns]
#  1   DATA FINAL                        106823 non-null  datetime64[ns]
#  2   REGIÃO                            106823 non-null  object
#  3   ESTADO                            106823 non-null  object
#  4   PRODUTO                           106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS      106823 non-null  int64
#  6   UNIDADE DE MEDIDA                 106823 non-null  object
#  7   PREÇO MÉDIO REVENDA               106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA             106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA              106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA              106823 non-null  float64
# ...

# %% [markdown]
# ##Limpeza de Dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
# ...

# %% [markdown]
# Várias amostras possuem a string '-' em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras.
#
#
#
# Poderíamos preencher os valores NaN com um valor padrão. Para isso, basta usar o método .fillna.

# %%
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO':20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# Por mais que a função fillna seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o 'PREÇO MÉDIO DISTRIBUIÇÃO'.
# A fim de não termos valores sintéticos gerados pelo fillna, que possam atrapalhar nossa análise, iremos remover (drop) todas as amostras que possuem qualquer valor NaN para quaisquer atributos/colunas.
#
# Para isso, basta utilizarmos o método dropna.

# %%
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   DATA INICIAL                      103392 non-null  datetime64[ns]
#  1   DATA FINAL                        103392 non-null  datetime64[ns]
#  2   REGIÃO                            103392 non-null  object
#  3   ESTADO                            103392 non-null  object
#  4   PRODUTO                           103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS      103392 non-null  int64
#  6   UNIDADE DE MEDIDA                 103392 non-null  object
#  7   PREÇO MÉDIO REVENDA               103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA             103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA              103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA              103392 non-null  float64
# ...

# %%
data_pre.to_csv('/content/GasPricesinBrazil_2004-2019_final.csv')

# %% [markdown]
# ### Estatísticas Descritivas

# %%
data_final = pd.read_csv('/content/GasPricesinBrazil_2004-2019_final.csv')

# %%
data_final
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      106818   2019-06-23  2019-06-29      NORDESTE
# 103388      106819   2019-06-23  2019-06-29           SUL
# 103389      106820   2019-06-23  2019-06-29           SUL
# 103390      106821   2019-06-23  2019-06-29       SUDESTE
# 103391      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.
#
# describe: exibe várias estatísticas descritivas para os atributos de um dataframe ou para uma Series.

# %%
data_final.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count  103392.000000                 103392.000000        103392.000000
# mean    52973.958682                    240.511935            10.784472
# std     30968.261500                    408.039174            17.685852
# min         0.000000                      1.000000             0.766000
# 25%     25964.750000                     47.000000             2.073000
# 50%     52661.500000                    108.000000             2.723000
# 75%     79918.250000                    251.000000             3.745000
# max    106822.000000                   4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# ...

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()
stats
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count  103392.000000                 103392.000000        103392.000000
# mean    52973.958682                    240.511935            10.784472
# std     30968.261500                    408.039174            17.685852
# min         0.000000                      1.000000             0.766000
# 25%     25964.750000                     47.000000             2.073000
# 50%     52661.500000                    108.000000             2.723000
# 75%     79918.250000                    251.000000             3.745000
# max    106822.000000                   4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# ...

# %%
stats[['PREÇO MÉDIO REVENDA','DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA']]
# Out:
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA
# count        103392.000000          103392.000000         103392.000000
# mean             10.784472               0.652589              9.334931
# std              17.685852               1.346422             15.024383
# min               0.766000               0.000000              0.590000
# 25%               2.073000               0.073000              1.900000
# 50%               2.723000               0.115000              2.509000
# 75%               3.745000               0.190000              3.490000
# max              99.357000              10.748000             90.000000

# %%
data_final[['PREÇO MÉDIO REVENDA','DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA
# count        103392.000000          103392.000000         103392.000000
# mean             10.784472               0.652589              9.334931
# std              17.685852               1.346422             15.024383
# min               0.766000               0.000000              0.590000
# 25%               2.073000               0.073000              1.900000
# 50%               2.723000               0.115000              2.509000
# 75%               3.745000               0.190000              3.490000
# max              99.357000              10.748000             90.000000

# %%
stats
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count  103392.000000                 103392.000000        103392.000000
# mean    52973.958682                    240.511935            10.784472
# std     30968.261500                    408.039174            17.685852
# min         0.000000                      1.000000             0.766000
# 25%     25964.750000                     47.000000             2.073000
# 50%     52661.500000                    108.000000             2.723000
# 75%     79918.250000                    251.000000             3.745000
# max    106822.000000                   4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# ...

# %%
stats.loc[['min','max','mean']]
# Out:
#          Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min        0.000000                      1.000000             0.766000
# max   106822.000000                   4167.000000            99.357000
# mean   52973.958682                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# ...

# %% [markdown]
# mean, std, min, etc: cada uma das estatísticas do describe podem ser computadas individualmente:

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO DISTRIBUIÇÃO'].std()
print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 11.68

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %%
data_final['ESTADO'].value_counts()
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame()
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# ## 4. Executando funções para cada item de um DataFrame ou Series
# Uma alternativa ao for-loop que vimos anteriormente e que é lento, é usarmos funções próprias do pandas que aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series, retornando novos elementos "transformados".

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
def nossa_soma(linha):
  return linha.sum()

# %%
df['SOMA(A,B,C)'] = df.apply(nossa_soma,axis=1)
df
# Out:
#          A   B    C  SOMA(A,B,C)
# Linha 1  1  10  100          111
# Linha 2  2  20  200          222
# Linha 3  3  30  300          333
# Linha 4  4  40  400          444

# %%
df.loc['LINHA 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A,B,C)
# Linha 1   1   10   100          111
# Linha 2   2   20   200          222
# Linha 3   3   30   300          333
# Linha 4   4   40   400          444
# LINHA 5  20  200  2000         2220

# %%
df['MEDIA(A,B,C)'] = df[['A','B','C']].apply(lambda nossa_soma: nossa_soma.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A,B,C)  MEDIA(A,B,C)
# Linha 1   1   10   100          111          37.0
# Linha 2   2   20   200          222          74.0
# Linha 3   3   30   300          333         111.0
# Linha 4   4   40   400          444         148.0
# LINHA 5  20  200  2000         2220         740.0

# %%
df['C * 2'] = df['C'].apply(lambda x : x *2 )
df
# Out:
#           A    B     C  SOMA(A,B,C)  MEDIA(A,B,C)  C * 2
# Linha 1   1   10   100          111          37.0    200
# Linha 2   2   20   200          222          74.0    400
# Linha 3   3   30   300          333         111.0    600
# Linha 4   4   40   400          444         148.0    800
# LINHA 5  20  200  2000         2220         740.0   4000

# %% [markdown]
# applymap(): usado para aplicar uma função para cada elemento (element-wise) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df.applymap(lambda x: x **2)
# Out:
# /tmp/ipython-input-1081273538.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x **2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %% [markdown]
# map(): usado para aplicar uma função para cada elemento (element-wise) de uma Series.

# %%
nomes = pd.Series(['Joao', 'Maria', 'Alice'])

# %%
nomes.map(lambda x : x.upper())
# Out:
# 0     JOAO
# 1    MARIA
# 2    ALICE
# dtype: object

# %%
nomes.str.upper()
# Out:
# 0     JOAO
# 1    MARIA
# 2    ALICE
# dtype: object

# %% [markdown]
# ## 5. Agrupamento
# groupby: Usado para criar grupo de elementos (e.x., baseado nos valores de um atributo).
# Funções podem então ser aplicadas para os elementos de cada grupo, de modo que os resultados de cada grupo são combinados.

# %%
data_final.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
 grupos = data_final.groupby('REGIÃO')
 grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14,
# ...

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383]),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391]),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379]),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390]),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389])}

# %%
grupos.describe()
# Out:
#              Unnamed: 0                                                       \
#                   count          mean           std   min       25%      50%
# REGIÃO
# CENTRO OESTE    14545.0  52794.848127  31380.202472   0.0  24647.00  53023.0
# NORDESTE        35788.0  53022.749022  30768.203891   4.0  26854.25  51922.5
# NORTE           24000.0  52735.865958  31714.571691  13.0  23526.75  54011.5
# SUDESTE         16744.0  53281.350334  30332.349374  20.0  28253.75  52127.5
# SUL             12315.0  53089.777913  30437.425938  24.0  27716.50  51968.0
#
#                                 NÚMERO DE POSTOS PESQUISADOS              ...  \
#                   75%       max                        count        mean  ...
# REGIÃO                                                                    ...
# CENTRO OESTE  80299.0  106812.0                      14545.0  144.898453  ...
# NORDESTE      79910.5  106822.0                      35788.0  124.721834  ...
# ...

# %%
grupos.min()
# Out:
#               Unnamed: 0 DATA INICIAL  DATA FINAL            ESTADO  \
# REGIÃO
# CENTRO OESTE           0   2004-05-09  2004-05-15  DISTRITO FEDERAL
# NORDESTE               4   2004-05-09  2004-05-15           ALAGOAS
# NORTE                 13   2004-05-09  2004-05-15              ACRE
# SUDESTE               20   2004-05-09  2004-05-15    ESPIRITO SANTO
# SUL                   24   2004-05-09  2004-05-15            PARANA
#
#                        PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO
# CENTRO OESTE  ETANOL HIDRATADO                             1
# NORDESTE      ETANOL HIDRATADO                             1
# NORTE         ETANOL HIDRATADO                             1
# SUDESTE       ETANOL HIDRATADO                             1
# SUL           ETANOL HIDRATADO                             1
#
#              UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE           R$/13Kg                1.097                    0.0
# ...

# %%
grupos.max()
# Out:
#               Unnamed: 0 DATA INICIAL  DATA FINAL              ESTADO  \
# REGIÃO
# CENTRO OESTE      106812   2019-06-23  2019-06-29  MATO GROSSO DO SUL
# NORDESTE          106822   2019-06-23  2019-06-29             SERGIPE
# NORTE             106807   2019-06-23  2019-06-29           TOCANTINS
# SUDESTE           106821   2019-06-23  2019-06-29           SAO PAULO
# SUL               106820   2019-06-23  2019-06-29      SANTA CATARINA
#
#                       PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE  ÓLEO DIESEL S10                           766             R$/m3
# NORDESTE      ÓLEO DIESEL S10                           625             R$/m3
# NORTE         ÓLEO DIESEL S10                           383             R$/m3
# SUDESTE       ÓLEO DIESEL S10                          4167             R$/m3
# SUL           ÓLEO DIESEL S10                          1416             R$/m3
#
# ...

# %%
data_final.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
grupos = data_final.groupby(['REGIÃO','PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [11980, 11981, 11982, 11983, 12007, 12008, 12009, 12010, 12034, 12035, 12036, 12037, 12061, 12062, 12063, 12064, 12088, 12089, 12090, 12091, 12115, 12116, 12117, 12118, 12142, 12143, 12144, 12145, 12169, 12170, 12171, 12172, 12196, 12197, 12198, 12199, 12223, 12224, 12225, 12226, 12250, 12251, 12252, 12253, 12277, 12278, 12279, 12280, 12304, 12305, 12306, 12307, 12331, 12332, 12333, 12334, 12358, 12359, 12360, 12361, 12385, 12386, 1
# ...

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135670
#               GASOLINA COMUM       3.077476
#               GLP                 48.176747
#               GNV                  1.856312
#               ÓLEO DIESEL          2.481286
#               ÓLEO DIESEL S10      3.294752
# NORDESTE      ETANOL HIDRATADO     2.320266
#               GASOLINA COMUM       3.001887
#               GLP                 41.966090
#               GNV                  1.881722
#               ÓLEO DIESEL          2.346950
#               ÓLEO DIESEL S10      3.041966
# NORTE         ETANOL HIDRATADO     2.511624
#               GASOLINA COMUM       3.149501
#               GLP                 47.065572
#               GNV                  2.084399
#               ÓLEO DIESEL          2.571048
#               ÓLEO DIESEL S10      3.316231
# SUDESTE       ETANOL HIDRATADO     2.163621
#               GASOLINA COMUM       3.000565
#               GLP                 42.081544
# ...

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
# ...

# %% [markdown]
# agg: agrega (roda) uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None,None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])
# Out:
# /tmp/ipython-input-1226331895.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum, min])
# /tmp/ipython-input-1226331895.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum, min])
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
# /tmp/ipython-input-3977787304.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# /tmp/ipython-input-3977787304.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# ## 6. Ordenação

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# .sort_values(): ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em ordem descrente.
# Então, reordena os registros "empatados", ou seja, com a mesma nota final, em ordem alfabética (ordem crescente).

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# #7. Exercícios

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios.
# Para isso, utilizaremos o dataset de preços de combustíveis no Brasil.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos remover os dados deste ano da análise.

# %%
data_final
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      106818   2019-06-23  2019-06-29      NORDESTE
# 103388      106819   2019-06-23  2019-06-29           SUL
# 103389      106820   2019-06-23  2019-06-29           SUL
# 103390      106821   2019-06-23  2019-06-29       SUDESTE
# 103391      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# como há apens medições de janeiro para o ano de 2019,resolvemos remover os dados deste ano da analise

# %%
data_final.query('ANO != 2019')
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...           ...          ...         ...           ...                  ...
# 99734      103063   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735      103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736      103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737      103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738      103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
# ...

# %%
df = data_final.query('ANO != 2019')

# %%
df
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...           ...          ...         ...           ...                  ...
# 99734      103063   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735      103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736      103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737      103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738      103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
# ...

# %% [markdown]
# #7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
grupos = df.groupby('PRODUTO')
grupos

# %%
grupos['REGIÃO'].value_counts()
# Out:
# PRODUTO           REGIÃO
# ETANOL HIDRATADO  NORDESTE        6821
#                   NORTE           5021
#                   SUDESTE         3039
#                   CENTRO OESTE    3022
#                   SUL             2278
# GASOLINA COMUM    NORDESTE        6838
#                   NORTE           5289
#                   SUDESTE         3040
#                   CENTRO OESTE    3034
#                   SUL             2279
# GLP               NORDESTE        6185
#                   NORTE           5152
#                   SUDESTE         3037
#                   CENTRO OESTE    2998
#                   SUL             2268
# GNV               NORDESTE        5030
#                   SUDESTE         2772
#                   SUL             1847
#                   CENTRO OESTE     825
#                   NORTE            233
# ÓLEO DIESEL       NORDESTE        6836
#                   NORTE           5290
#                   SUDESTE         3040
# ...

# %% [markdown]
# 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolinasp = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolinasp
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92319       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92465       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92610       95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# 92755       95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO
# 92901       95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO
# 93048       96109   2018-02-11  2018-02-17  SUDESTE  SAO PAULO
# 93192       96259   2018-02-18  2018-02-24  SUDESTE  SAO PAULO
# 93339       96411   2018-02-25  2018-03-03  SUDESTE  SAO PAULO
# 93487       96563   2018-03-04  2018-03-10  SUDESTE  SAO PAULO
# 93634       96715   2018-03-11  2018-03-17  SUDESTE  SAO PAULO
# 93778       96866   2018-03-18  2018-03-24  SUDESTE  SAO PAULO
# 93924       97017   2018-03-25  2018-03-31  SUDESTE  SAO PAULO
# 94070       97168   2018-04-01  2018-04-07  SUDESTE  SAO PAULO
# 94215       97319   2018-04-08  2018-04-14  SUDESTE  SAO PAULO
# ...

# %% [markdown]
# ### ESTATÍSTICAS DESCRITIVAS

# %%
gasolinasp.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count      52.000000                     52.000000            52.000000
# mean    99196.096154                   1610.211538             4.202769
# std      2279.595314                    213.627432             0.180672
# min     95351.000000                    102.000000             3.970000
# 25%     97281.250000                   1639.000000             4.008000
# 50%     99196.500000                   1642.000000             4.202000
# 75%    101116.250000                   1644.000000             4.336250
# max    103025.000000                   1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# ...

# %%
gasolinasp['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    52.000000
# mean      4.202769
# std       0.180672
# min       3.970000
# 25%       4.008000
# 50%       4.202000
# 75%       4.336250
# max       4.512000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df.query('(PRODUTO == "GASOLINA COMUM"or PRODUTO =="ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238       95270   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384       95421   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529       95573   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...           ...          ...         ...      ...        ...
# 99410      102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472      102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553      102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617      102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698      103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# ...

# %%
gasolinasp['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %%
gasolinasp.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                 count      mean       std   min    25%    50%      75%    max
# PRODUTO
# GASOLINA COMUM   52.0  4.202769  0.180672  3.97  4.008  4.202  4.33625  4.512
