# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv('/content/GasPricesinBrazil_2004-2019.csv', sep=';')
display(data.head())
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
data = pd.read_csv('/content/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (106823, 21)

# %%
print(f'o dataframe tem {data.shape[0]} linhas/observações e {data.shape[1]} colunas/atributos/variaveis')
# Out:
# o dataframe tem 106823 linhas/observações e 21 colunas/atributos/variaveis

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
alunos_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15, 60],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
alunos_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(alunos_df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(alunos_df)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
alunos_df.rename(columns={
    'nome':'Nome',
    'idade':'Idade'
})
# Out:
#              Nome  Idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
alunos_df.rename(columns={'nome':'Nome','idade':'Idade'},inplace=True)

# %%
alunos_df
# Out:
#              Nome  Idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
alunos_df.columns = ['Nome Completo', 'Idade', 'Peso', 'É Jedi']

# %%
alunos_df.columns = ['NOME', 'IDADE', 'PESO', 'EH_JEDI']

# %%
alunos_df
# Out:
#              NOME  IDADE  PESO  EH_JEDI
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head  ()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5, 6.0 ,9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5.5, 6.0 ,9.5],index=['prova 1', 'prova 2', 'projeto'], name='Notas do luke skywalker')
# Out:
# prova 1    5.5
# prova 2    6.0
# projeto    9.5
# Name: Notas do luke skywalker, dtype: float64

# %%
pd.Series([5.5, 6.0 ,9.5],index=('prova 1', 'prova 2', 'projeto'))
# Out:
# prova 1    5.5
# prova 2    6.0
# projeto    9.5
# dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_copy_bkp = data['PRODUTO'].copy()
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO']= 'Combustivel'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustivel                           127              R$/l
# 1  Combustivel                           387              R$/l
# 2  Combustivel                           192              R$/l
# 3  Combustivel                           162              R$/l
# 4  Combustivel                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'produto {1}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
data['PRODUTO'] = novos_produtos

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO    PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  produto 1                           127
# 1                     GOIAS  produto 1                           387
# 2               MATO GROSSO  produto 1                           192
# 3        MATO GROSSO DO SUL  produto 1                           162
# 4                   ALAGOAS  produto 1                           103
# ...                     ...        ...                           ...
# 106818  RIO GRANDE DO NORTE  produto 1                             7
# 106819    RIO GRANDE DO SUL  produto 1                            23
# 106820       SANTA CATARINA  produto 1                            24
# 106821            SAO PAULO  produto 1                            52
# 106822              SERGIPE  produto 1                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
print(produto_copy_bkp)
print('\n')
print(produto_copy_bkp)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = produto_copy_bkp

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
data['coluna sem nocao'] = 'DEFAULT'

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  coluna sem nocao
# 0                              0.133   5  2004           DEFAULT
# 1                              0.115   5  2004           DEFAULT
# 2                              0.098   5  2004           DEFAULT
# 3                              0.143   5  2004           DEFAULT
# 4                              0.082   5  2004           DEFAULT
# ...                              ...  ..   ...               ...
# 106818                             0   6  2019           DEFAULT
# 106819                         0.164   6  2019           DEFAULT
# 106820                             0   6  2019           DEFAULT
# 106821                          0.07   6  2019           DEFAULT
# 106822                             0   6  2019           DEFAULT
#
# [106823 rows x 22 columns]

# %%
data['coluna a partir de listas'] = range(data.shape[0])

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        coluna sem nocao  coluna a partir de listas
# 0               DEFAULT                          0
# 1               DEFAULT                          1
# 2               DEFAULT                          2
# 3               DEFAULT                          3
# 4               DEFAULT                          4
# ...                 ...                        ...
# 106818          DEFAULT                     106818
# 106819          DEFAULT                     106819
# 106820          DEFAULT                     106820
# 106821          DEFAULT                     106821
# 106822          DEFAULT                     106822
#
# [106823 rows x 23 columns]

# %%
data['nao funciona'] = [1, 2, 3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4033078709.py in <cell line: 0>()
# ----> 1 data['nao funciona'] = [1, 2, 3]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (3) does not match length of index (106823)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de listas
# 0                          0
# 1                          1
# 2                          2
# 3                          3
# 4                          4
#
# [5 rows x 23 columns]

# %%
data['preço media de revenda(dolares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        coluna a partir de listas  preço media de revenda(dolares)
# 0                              0                            7.728
# 1                              1                            6.972
# 2                              2                            8.334
# 3                              3                            7.572
# 4                              4                            7.086
# ...                          ...                              ...
# 106818                    106818                           21.444
# 106819                    106819                           20.406
# 106820                    106820                           17.472
# 106821                    106821                           18.120
# 106822                    106822                           22.182
#
# [106823 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        coluna a partir de listas  preço media de revenda(dolares)
# 0                              0                            7.728
# 1                              1                            6.972
# 2                              2                            8.334
# 3                              3                            7.572
# 4                              4                            7.086
# ...                          ...                              ...
# 106818                    106818                           21.444
# 106819                    106819                           20.406
# 106820                    106820                           17.472
# 106821                    106821                           18.120
# 106822                    106822                           22.182
#
# [106823 rows x 24 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3257087062.py in <cell line: 0>()
# ----> 1 pesquisa_de_satisfacao.head()
#
# NameError: name 'pesquisa_de_satisfacao' is not defined

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                        1
# DATA INICIAL                             2004-05-09
# DATA FINAL                               2004-05-15
# REGIÃO                                 CENTRO OESTE
# ESTADO                                        GOIAS
# PRODUTO                            ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                    387
# UNIDADE DE MEDIDA                              R$/l
# PREÇO MÉDIO REVENDA                           1.162
# DESVIO PADRÃO REVENDA                         0.114
# PREÇO MÍNIMO REVENDA                           0.89
# PREÇO MÁXIMO REVENDA                          1.449
# MARGEM MÉDIA REVENDA                          0.399
# COEF DE VARIAÇÃO REVENDA                      0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                      0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                    0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                    0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                      1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO                 0.115
# MÊS                                               5
# ANO                                            2004
# coluna sem nocao                            DEFAULT
# coluna a partir de listas                         1
# preço media de revenda(dolares)               6.972
# Name: 1, dtype: object

# %%
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
#
#   coluna sem nocao coluna a partir de listas  preço media de revenda(dolares)
# 0          DEFAULT                         0                            7.728
# 1          DEFAULT                         1                            6.972
# 2          DEFAULT                         2                            8.334
# 3          DEFAULT                         3                            7.572
# 4          DEFAULT                         4                            7.086
# 5          DEFAULT                         5                            8.298
#
# [6 rows x 24 columns]

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                1.573                  0.134  ...                     1.079
# 11                1.276                  0.116  ...                     0.944
# 12                1.301                  0.109  ...                      0.98
# 13                1.805                  0.134  ...                     1.116
# 14                1.785                  0.035  ...                     1.373
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                    0.8857
# 11                       0.078                    0.7119
# 12                       0.052                    0.8267
# 13                       0.171                     0.767
# 14                       0.167                    0.8339
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 10                     1.2499                         0.072   5  2004
# 11                     1.1386                         0.083   5  2004
# 12                     1.1059                         0.053   5  2004
# 13                     1.2992                         0.153   5  2004
# 14                     1.4912                         0.122   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    coluna sem nocao coluna a partir de listas  preço media de revenda(dolares)
# 10          DEFAULT                        10                            9.438
# 11          DEFAULT                        11                            7.656
# 12          DEFAULT                        12                            7.806
# 13          DEFAULT                        13                           10.830
# 14          DEFAULT                        14                           10.710
# 15          DEFAULT                        15                            9.468
#
# [6 rows x 24 columns]

# %%
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 5                        0.128                    0.5686
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 5                        1.35                         0.134   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    coluna sem nocao coluna a partir de listas  preço media de revenda(dolares)
# 1           DEFAULT                         1                            6.972
# 5           DEFAULT                         5                            8.298
# 10          DEFAULT                        10                            9.438
# 15          DEFAULT                        15                            9.468
#
# [4 rows x 24 columns]

# %%
data.iloc[[5, 25, 10, 1]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO             ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE              BAHIA
# 25          25   2004-05-09  2004-05-15           SUL  RIO GRANDE DO SUL
# 10          10   2004-05-09  2004-05-15      NORDESTE              PIAUI
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE              GOIAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 25  ETANOL HIDRATADO                           689              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 25                1.224                  0.143  ...                     0.892
# 10                1.573                  0.134  ...                     1.079
# 1                 1.162                  0.114  ...                     0.763
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                    0.5686
# 25                        0.09                     0.644
# 10                       0.078                    0.8857
# 1                        0.088                    0.5013
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                        1.35                         0.134   5  2004
# 25                     1.2727                         0.101   5  2004
# 10                     1.2499                         0.072   5  2004
# 1                        1.05                         0.115   5  2004
#
#    coluna sem nocao coluna a partir de listas  preço media de revenda(dolares)
# 5           DEFAULT                         5                            8.298
# 25          DEFAULT                        25                            7.344
# 10          DEFAULT                        10                            9.438
# 1           DEFAULT                         1                            6.972
#
# [4 rows x 24 columns]

# %%
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.iloc[0, 1]
# Out:
# np.int64(131)

# %%
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
#NAO FUNCIONA(ILOC LOCALIZA ROTULOS)
pesquisa_de_satisfacao.iloc['XboxOne']

# %%
#AO CONTRARIO Tambem
pesquisa_de_satisfacao.loc[0, 1]

# %%
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# np.int64(2)

# %%
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
pesquisa_de_satisfacao.loc[:,['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
#retorna todas as linhas e apenas as colunas de 'bom' e 'pessimo
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de listas  preço media de revenda(dolares)
# 0          DEFAULT                         0                            7.728
# 1          DEFAULT                         1                            6.972
# 2          DEFAULT                         2                            8.334
# 3          DEFAULT                         3                            7.572
# 4          DEFAULT                         4                            7.086
#
# [5 rows x 24 columns]

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                        1
# DATA INICIAL                             2004-05-09
# DATA FINAL                               2004-05-15
# REGIÃO                                 CENTRO OESTE
# ESTADO                                        GOIAS
# PRODUTO                            ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                    387
# UNIDADE DE MEDIDA                              R$/l
# PREÇO MÉDIO REVENDA                           1.162
# DESVIO PADRÃO REVENDA                         0.114
# PREÇO MÍNIMO REVENDA                           0.89
# PREÇO MÁXIMO REVENDA                          1.449
# MARGEM MÉDIA REVENDA                          0.399
# COEF DE VARIAÇÃO REVENDA                      0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                      0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                    0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                    0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                      1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO                 0.115
# MÊS                                               5
# ANO                                            2004
# coluna sem nocao                            DEFAULT
# coluna a partir de listas                         1
# preço media de revenda(dolares)               6.972
# Name: 1, dtype: object

# %%
data.loc[2]
# Out:
# Unnamed: 0                                        2
# DATA INICIAL                             2004-05-09
# DATA FINAL                               2004-05-15
# REGIÃO                                 CENTRO OESTE
# ESTADO                                  MATO GROSSO
# PRODUTO                            ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                    192
# UNIDADE DE MEDIDA                              R$/l
# PREÇO MÉDIO REVENDA                           1.389
# DESVIO PADRÃO REVENDA                         0.097
# PREÇO MÍNIMO REVENDA                           1.18
# PREÇO MÁXIMO REVENDA                           1.76
# MARGEM MÉDIA REVENDA                          0.419
# COEF DE VARIAÇÃO REVENDA                       0.07
# PREÇO MÉDIO DISTRIBUIÇÃO                       0.97
# DESVIO PADRÃO DISTRIBUIÇÃO                    0.095
# PREÇO MÍNIMO DISTRIBUIÇÃO                    0.5614
# PREÇO MÁXIMO DISTRIBUIÇÃO                     1.161
# COEF DE VARIAÇÃO DISTRIBUIÇÃO                 0.098
# MÊS                                               5
# ANO                                            2004
# coluna sem nocao                            DEFAULT
# coluna a partir de listas                         2
# preço media de revenda(dolares)               8.334
# Name: 2, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de listas  preço media de revenda(dolares)
# 0          DEFAULT                         0                            7.728
# 1          DEFAULT                         1                            6.972
# 2          DEFAULT                         2                            8.334
# 3          DEFAULT                         3                            7.572
# 4          DEFAULT                         4                            7.086
#
# [5 rows x 24 columns]

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:,'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        coluna a partir de listas  preço media de revenda(dolares)
# 0                              0                            7.728
# 1                              1                            6.972
# 2                              2                            8.334
# 3                              3                            7.572
# 4                              4                            7.086
# ...                          ...                              ...
# 106818                    106818                           21.444
# 106819                    106819                           20.406
# 106820                    106820                           17.472
# 106821                    106821                           18.120
# 106822                    106822                           22.182
#
# [106823 rows x 24 columns]

# %%
del data['Unnamed: 0']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.9666
# 1                          0.5013                      1.05
# 2                          0.5614                     1.161
# 3                          0.5991                   1.22242
# 4                          0.7441                    1.0317
# ...                           ...                       ...
# 106818                      2.756                     2.756
# 106819                     1.9842                    2.8661
# 106820                     1.9981                    1.9981
# 106821                     2.0179                    2.5093
# 106822                     2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#         coluna a partir de listas  preço media de revenda(dolares)
# 0                               0                            7.728
# 1                               1                            6.972
# 2                               2                            8.334
# 3                               3                            7.572
# 4                               4                            7.086
# ...                           ...                              ...
# 106818                     106818                           21.444
# 106819                     106819                           20.406
# 106820                     106820                           17.472
# 106821                     106821                           18.120
# 106822                     106822                           22.182
#
# [106823 rows x 23 columns]

# %%
del data['coluna a partir de listas']

# %%
data['preço media de revenda(dolares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0
del data['preço media de revenda(dolares)']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                    0.012
# 1                      0.399                    0.098
# 2                      0.419                    0.070
# 3                      0.432                    0.055
# 4                       0.24                    0.066
# ...                      ...                      ...
# 106818                 0.818                    0.018
# 106819                  0.95                    0.038
# 106820                 0.914                    0.065
# 106821                 0.646                    0.076
# 106822                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  coluna sem nocao
# 0                              0.133   5  2004           DEFAULT
# 1                              0.115   5  2004           DEFAULT
# 2                              0.098   5  2004           DEFAULT
# 3                              0.143   5  2004           DEFAULT
# 4                              0.082   5  2004           DEFAULT
# ...                              ...  ..   ...               ...
# 106818                             0   6  2019           DEFAULT
# 106819                         0.164   6  2019           DEFAULT
# 106820                             0   6  2019           DEFAULT
# 106821                          0.07   6  2019           DEFAULT
# 106822                             0   6  2019           DEFAULT
#
# [106823 rows x 21 columns]

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('/content/sample_data/GasPricesinBrazil_2004-2019_preprossecado.csv', index=False, sep=';')

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos do Pará(São paulo nao apareceu pra mim)**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
data['ESTADO'] == 'PARA'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1529558023.py in <cell line: 0>()
# ----> 1 data['ESTADO'] == 'PARA'
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
#salvando essa series de booleans em uma variavel
selecao = data['ESTADO'] == 'PARA'

# %%
data = pd.read_csv('./sample_data/GasPricesinBrazil_2004-2019_preprossecado.csv', sep=';', engine='python')
display(data.head())
# Out:
#   DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao
# 0  2004-05-09,2004-05-15,CENTRO OESTE,DISTRITO FE...
# 1  2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,ETANO...
# 2  2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 3  2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 4  2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETANOL ...

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 1)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado do Pará:

# %%
data[selecao]
# Out:
#        DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao
# 16      2004-05-09,2004-05-15,NORTE,PARA,ETANOL HIDRAT...
# 43      2004-05-16,2004-05-22,NORTE,PARA,ETANOL HIDRAT...
# 70      2004-05-23,2004-05-29,NORTE,PARA,ETANOL HIDRAT...
# 97      2004-05-30,2004-06-05,NORTE,PARA,ETANOL HIDRAT...
# 124     2004-06-06,2004-06-12,NORTE,PARA,ETANOL HIDRAT...
# ...                                                   ...
# 106686  2019-06-23,2019-06-29,NORTE,PARA,ETANOL HIDRAT...
# 106713  2019-06-23,2019-06-29,NORTE,PARA,ÓLEO DIESEL,6...
# 106740  2019-06-23,2019-06-29,NORTE,PARA,ÓLEO DIESEL S...
# 106767  2019-06-23,2019-06-29,NORTE,PARA,GASOLINA COMU...
# 106794  2019-06-23,2019-06-29,NORTE,PARA,GLP,155,R$/13...
#
# [3497 rows x 1 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao
# 16      2004-05-09,2004-05-15,NORTE,PARA,ETANOL HIDRAT...
# 43      2004-05-16,2004-05-22,NORTE,PARA,ETANOL HIDRAT...
# 70      2004-05-23,2004-05-29,NORTE,PARA,ETANOL HIDRAT...
# 97      2004-05-30,2004-06-05,NORTE,PARA,ETANOL HIDRAT...
# 124     2004-06-06,2004-06-12,NORTE,PARA,ETANOL HIDRAT...
# ...                                                   ...
# 106686  2019-06-23,2019-06-29,NORTE,PARA,ETANOL HIDRAT...
# 106713  2019-06-23,2019-06-29,NORTE,PARA,ÓLEO DIESEL,6...
# 106740  2019-06-23,2019-06-29,NORTE,PARA,ÓLEO DIESEL S...
# 106767  2019-06-23,2019-06-29,NORTE,PARA,GASOLINA COMU...
# 106794  2019-06-23,2019-06-29,NORTE,PARA,GLP,155,R$/13...
#
# [3497 rows x 1 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data
# Out:
#        DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao
# 0       2004-05-09,2004-05-15,CENTRO OESTE,DISTRITO FE...
# 1       2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,ETANO...
# 2       2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 3       2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 4       2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETANOL ...
# ...                                                   ...
# 106818  2019-06-23,2019-06-29,NORDESTE,RIO GRANDE DO N...
# 106819  2019-06-23,2019-06-29,SUL,RIO GRANDE DO SUL,GN...
# 106820  2019-06-23,2019-06-29,SUL,SANTA CATARINA,GNV,2...
# 106821  2019-06-23,2019-06-29,SUDESTE,SAO PAULO,GNV,52...
# 106822  2019-06-23,2019-06-29,NORDESTE,SERGIPE,GNV,4,R...
#
# [106823 rows x 1 columns]

# %%
data.query('ESTADO == "PARA"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.12/collections/__init__.py in __getitem__(self, key)
#    1014                 pass
# -> 1015         return self.__missing__(key)            # support subclasses that define __missing__
#    1016
#
# /usr/lib/python3.12/collections/__init__.py in __missing__(self, key)
#    1006     def __missing__(self, key):
# -> 1007         raise KeyError(key)
#    1008
#
# KeyError: 'ESTADO'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     241                 # e.g., df[df > 0]
# --> 242                 return self.temps[key]
#     243             except KeyError as err:
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /tmp/ipython-input-3813608067.py in <cell line: 0>()
# ----> 1 data.query('ESTADO == "PARA"')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4947         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4948
# -> 4949         return _eval(expr, inplace=inplace, **kwargs)
#    4950
#    4951     def select_dtypes(self, include=None, exclude=None) -> Self:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     334         )
#     335
# --> 336         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     337
#     338         if engine == "numexpr" and (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     807         self.parser = parser
#     808         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809         self.terms = self.parse()
#     810
#     811     @property
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in parse(self)
#     826         Parse an expression.
#     827         """
# --> 828         return self._visitor.visit(self.expr)
#     829
#     830     @property
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     416             raise SyntaxError("only a single expression is allowed")
#     417         expr = node.body[0]
# --> 418         return self.visit(expr, **kwargs)
#     419
#     420     def visit_Expr(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     419
#     420     def visit_Expr(self, node, **kwargs):
# --> 421         return self.visit(node.value, **kwargs)
#     422
#     423     def _rewrite_membership_op(self, node, left, right):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     717             op = self.translate_In(ops[0])
#     718             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719             return self.visit(binop)
#     720
#     721         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     530
#     531     def visit_BinOp(self, node, **kwargs):
# --> 532         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533         left, right = self._maybe_downcast_constants(left, right)
#     534         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     450     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451         if left is None:
# --> 452             left = self.visit(node.left, side="left")
#     453         if right is None:
#     454             right = self.visit(node.right, side="right")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     543
#     544     def visit_Name(self, node, **kwargs) -> Term:
# --> 545         return self.term_type(node.id, self.env, **kwargs)
#     546
#     547     # TODO(py314): deprecated since Python 3.8. Remove after Python 3.14 is min
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      89         tname = str(name)
#      90         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91         self._value = self._resolve_name()
#      92         self.encoding = encoding
#      93
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/ops.py in _resolve_name(self)
#     113             is_local = False
#     114
# --> 115         res = self.env.resolve(local_name, is_local=is_local)
#     116         self.update(res)
#     117
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     242                 return self.temps[key]
#     243             except KeyError as err:
# --> 244                 raise UndefinedVariableError(key, is_local) from err
#     245
#     246     def swapkey(self, old_key: str, new_key: str, new_value=None) -> None:
#
# UndefinedVariableError: name 'ESTADO' is not defined

# %%
data.head()
# Out:
#   DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao
# 0  2004-05-09,2004-05-15,CENTRO OESTE,DISTRITO FE...
# 1  2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,ETANO...
# 2  2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 3  2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 4  2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETANOL ...

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos do Para.

# %%
postos_PR = data.query('ESTADO == "PARA"')
display(postos_PR.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.12/collections/__init__.py in __getitem__(self, key)
#    1014                 pass
# -> 1015         return self.__missing__(key)            # support subclasses that define __missing__
#    1016
#
# /usr/lib/python3.12/collections/__init__.py in __missing__(self, key)
#    1006     def __missing__(self, key):
# -> 1007         raise KeyError(key)
#    1008
#
# KeyError: 'ESTADO'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     241                 # e.g., df[df > 0]
# --> 242                 return self.temps[key]
#     243             except KeyError as err:
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /tmp/ipython-input-2110646900.py in <cell line: 0>()
# ----> 1 postos_PR = data.query('ESTADO == "PARA"')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4947         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4948
# -> 4949         return _eval(expr, inplace=inplace, **kwargs)
#    4950
#    4951     def select_dtypes(self, include=None, exclude=None) -> Self:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     334         )
#     335
# --> 336         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     337
#     338         if engine == "numexpr" and (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     807         self.parser = parser
#     808         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809         self.terms = self.parse()
#     810
#     811     @property
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in parse(self)
#     826         Parse an expression.
#     827         """
# --> 828         return self._visitor.visit(self.expr)
#     829
#     830     @property
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     416             raise SyntaxError("only a single expression is allowed")
#     417         expr = node.body[0]
# --> 418         return self.visit(expr, **kwargs)
#     419
#     420     def visit_Expr(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     419
#     420     def visit_Expr(self, node, **kwargs):
# --> 421         return self.visit(node.value, **kwargs)
#     422
#     423     def _rewrite_membership_op(self, node, left, right):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     717             op = self.translate_In(ops[0])
#     718             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719             return self.visit(binop)
#     720
#     721         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     530
#     531     def visit_BinOp(self, node, **kwargs):
# --> 532         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533         left, right = self._maybe_downcast_constants(left, right)
#     534         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     450     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     451         if left is None:
# --> 452             left = self.visit(node.left, side="left")
#     453         if right is None:
#     454             right = self.visit(node.right, side="right")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     410         method = f"visit_{type(node).__name__}"
#     411         visitor = getattr(self, method)
# --> 412         return visitor(node, **kwargs)
#     413
#     414     def visit_Module(self, node, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     543
#     544     def visit_Name(self, node, **kwargs) -> Term:
# --> 545         return self.term_type(node.id, self.env, **kwargs)
#     546
#     547     # TODO(py314): deprecated since Python 3.8. Remove after Python 3.14 is min
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      89         tname = str(name)
#      90         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91         self._value = self._resolve_name()
#      92         self.encoding = encoding
#      93
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/ops.py in _resolve_name(self)
#     113             is_local = False
#     114
# --> 115         res = self.env.resolve(local_name, is_local=is_local)
#     116         self.update(res)
#     117
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     242                 return self.temps[key]
#     243             except KeyError as err:
# --> 244                 raise UndefinedVariableError(key, is_local) from err
#     245
#     246     def swapkey(self, old_key: str, new_key: str, new_value=None) -> None:
#
# UndefinedVariableError: name 'ESTADO' is not defined

# %%
postos_PR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3250779792.py in <cell line: 0>()
# ----> 1 postos_PR
#
# NameError: name 'postos_PR' is not defined

# %%
type(postos_PR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2366959047.py in <cell line: 0>()
# ----> 1 type(postos_PR)
#
# NameError: name 'postos_PR' is not defined

# %%
postos_PR.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3057322068.py in <cell line: 0>()
# ----> 1 postos_PR.shape
#
# NameError: name 'postos_PR' is not defined

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
postos_PR.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2946724331.py in <cell line: 0>()
# ----> 1 postos_PR.head()
#
# NameError: name 'postos_PR' is not defined

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
postos_PR = data.query('ESTADO == "PARA"').reset_index(drop=True)
display(postos_PR.head())

# %%
postos_PR

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
#data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
(data['ESTADO'] == 'RIO DE JANEIRO')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3450425449.py in <cell line: 0>()
# ----> 1 (data['ESTADO'] == 'RIO DE JANEIRO')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
(data['PREÇO MÉDIO REVENDA'] > 2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PREÇO MÉDIO REVENDA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3392050840.py in <cell line: 0>()
# ----> 1 (data['PREÇO MÉDIO REVENDA'] > 2)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PREÇO MÉDIO REVENDA'

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4128676391.py in <cell line: 0>()
# ----> 1 selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
#       2 selecao
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-83189027.py in <cell line: 0>()
# ----> 1 selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
#       2 postos_rj = data[selecao_1]
#       3 postos_rj
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
selecao_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-520810313.py in <cell line: 0>()
# ----> 1 selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
#       2 selecao_2
#
# NameError: name 'postos_rj' is not defined

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3024850507.py in <cell line: 0>()
# ----> 1 postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
#       2 postos_rj_preco_maior_que_2
#
# NameError: name 'postos_rj' is not defined

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#   DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao
# 0  2004-05-09,2004-05-15,CENTRO OESTE,DISTRITO FE...
# 1  2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,ETANO...
# 2  2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 3  2004-05-09,2004-05-15,CENTRO OESTE,MATO GROSSO...
# 4  2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETANOL ...

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
display(selecao_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3813233461.py in <cell line: 0>()
# ----> 1 selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
#       2 selecao_1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
selecao_COMUM = (
    (data['PRODUTO'] == 'GASOLINA COMUM') &
    (data['ESTADO'].isin(['SAO PAULO', 'RIO DE JANEIRO'])) &
    (data['PREÇO MÉDIO REVENDA'] > 2.0)
)
display(selecao_COMUM)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRODUTO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3901229926.py in <cell line: 0>()
#       1 selecao_COMUM = (
# ----> 2     (data['PRODUTO'] == 'GASOLINA COMUM') &
#       3     (data['ESTADO'].isin(['SAO PAULO', 'RIO DE JANEIRO'])) &
#       4     (data['PREÇO MÉDIO REVENDA'] > 2.0)
#       5 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PRODUTO'

# %%
data[selecao_COMUM]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2218207132.py in <cell line: 0>()
# ----> 1 data[selecao_COMUM]
#
# NameError: name 'selecao_COMUM' is not defined

# %%
selecao = data['ESTADO'] == 'PARA'
display(selecao)

# %%
data_filtrado = data[selecao_COMUM]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1985491702.py in <cell line: 0>()
# ----> 1 data_filtrado = data[selecao_COMUM]
#
# NameError: name 'selecao_COMUM' is not defined

# %%
print(data_filtrado['ESTADO'].unique())
print(data_filtrado['PRODUTO'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4247718524.py in <cell line: 0>()
# ----> 1 print(data_filtrado['ESTADO'].unique())
#       2 print(data_filtrado['PRODUTO'].unique())
#
# NameError: name 'data_filtrado' is not defined

# %%
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PRODUTO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1651578559.py in <cell line: 0>()
# ----> 1 selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PRODUTO'

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao_1]
postos_sp_rj
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2388489282.py in <cell line: 0>()
# ----> 1 selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
#       2 postos_sp_rj = data[selecao_1]
#       3 postos_sp_rj
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]
postos_sp_rj_gasolina
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-956183489.py in <cell line: 0>()
# ----> 1 selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
#       2 postos_sp_rj_gasolina = postos_sp_rj[selecao_2]
#       3 postos_sp_rj_gasolina
#
# NameError: name 'postos_sp_rj' is not defined

# %%
selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)
postos_sp_rj_maior_que_2 = postos_sp_rj_gasolina[selecao_3]
postos_sp_rj_maior_que_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1039095883.py in <cell line: 0>()
# ----> 1 selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)
#       2 postos_sp_rj_maior_que_2 = postos_sp_rj_gasolina[selecao_3]
#       3 postos_sp_rj_maior_que_2
#
# NameError: name 'postos_sp_rj_gasolina' is not defined

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data['ANO'] == 2008) | (data['ANO'] == 2009) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
display(data[selecao].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ANO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2660221749.py in <cell line: 0>()
# ----> 1 selecao = (data['ANO'] == 2008) | (data['ANO'] == 2009) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
#       2 data[selecao]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ANO'

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
lista_de_anos = [2008, 2010, 2012]
selecao = data['ANO'].isin(lista_de_anos)
display(data[selecao].head())
# Out:
#       Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 5098        5098   2008-01-06  2008-01-12  CENTRO OESTE    DISTRITO FEDERAL
# 5099        5099   2008-01-06  2008-01-12  CENTRO OESTE               GOIAS
# 5100        5100   2008-01-06  2008-01-12  CENTRO OESTE         MATO GROSSO
# 5101        5101   2008-01-06  2008-01-12  CENTRO OESTE  MATO GROSSO DO SUL
# 5102        5102   2008-01-06  2008-01-12      NORDESTE             ALAGOAS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098  ETANOL HIDRATADO                            80              R$/l
# 5099  ETANOL HIDRATADO                           255              R$/l
# 5100  ETANOL HIDRATADO                           142              R$/l
# 5101  ETANOL HIDRATADO                           133              R$/l
# 5102  ETANOL HIDRATADO                            97              R$/l
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 5098                1.806                  0.082  ...                 1.950
# 5099                1.616                  0.100  ...                 1.899
# 5100                1.581                  0.095  ...                 1.850
# 5101                1.831                  0.046  ...                 1.910
# 5102                1.699                  0.098  ...                 1.999
#
#       MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5098                  0.29                    0.045                     1.516
# 5099                 0.293                    0.062                     1.323
# 5100                 0.278                    0.060                     1.303
# 5101                 0.382                    0.025                     1.449
# 5102                 0.199                    0.058                       1.5
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5098                      0.061                    1.3892
# 5099                       0.05                    1.2242
# 5100                      0.073                      1.14
# 5101                      0.044                    1.3247
# 5102                      0.062                      1.39
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 5098                    1.6157                          0.04   1  2008
# 5099                    1.6173                         0.038   1  2008
# 5100                      1.45                         0.056   1  2008
# 5101                    1.5514                          0.03   1  2008
# 5102                    1.7689                         0.041   1  2008
#
# [5 rows x 21 columns]

# %%
print(data.columns)
# Out:
# Index(['DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO,coluna sem nocao'], dtype='object')

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
for index, row in data.head(10).iterrows():
  print(f'indice{index} ==> {row["ESTADO"]}')
# Out:
# indice0 ==> DISTRITO FEDERAL
# indice1 ==> GOIAS
# indice2 ==> MATO GROSSO
# indice3 ==> MATO GROSSO DO SUL
# indice4 ==> ALAGOAS
# indice5 ==> BAHIA
# indice6 ==> CEARA
# indice7 ==> MARANHAO
# indice8 ==> PARAIBA
# indice9 ==> PERNAMBUCO

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])
display(data_pre.head())
# Out:
#    Unnamed: 0 DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data_pre.info()

# %% [markdown]
# #### **Dados Numéricos**

# %%
for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
 data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  datetime64[ns]
#  2   DATA FINAL                     106823 non-null  datetime64[ns]
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(4), object(10)
# memory usage: 17.1+ MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
data_pre = data.copy()
data_pre_fill = data_pre.fillna(0)

# %%
data_pre_fill[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %%
data_pre[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %%
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})

# %%
data_pre_fill[mask]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
data_pre.dropna(inplace=True)
display(data_pre.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB
# None

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
import os

if not os.path.exists('./datasets'):
    os.makedirs('./datasets')

data_pre.to_csv('./datasets/GasPriceinBrazil_2004-2019_preprocessado_final.csv')

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv('./datasets/GasPriceinBrazil_2004-2019_preprocessado_final.csv')

# %%
data_final
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 106818        106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819        106819      106819   2019-06-23  2019-06-29           SUL
# 106820        106820      106820   2019-06-23  2019-06-29           SUL
# 106821        106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822        106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 106818             R$/m3                3.574  ...                 3.690
# 106819             R$/m3                3.401  ...                 3.789
# 106820             R$/m3                2.912  ...                 3.499
# 106821             R$/m3                3.020  ...                 3.490
# 106822             R$/m3                3.697  ...                 3.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 22 columns]

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  106823.00000  106823.00000                 106823.000000
# mean    53411.00000   53411.00000                    233.770976
# std     30837.28824   30837.28824                    403.282519
# min         0.00000       0.00000                      1.000000
# 25%     26705.50000   26705.50000                     42.000000
# 50%     53411.00000   53411.00000                    104.000000
# 75%     80116.50000   80116.50000                    243.000000
# max    106822.00000  106822.00000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        106823.000000          106823.000000         106823.000000
# mean             10.870780               0.657227              9.416038
# std              17.752533               1.349169             15.092193
# min               0.766000               0.000000              0.590000
# 25%               2.072000               0.072000              1.900000
# 50%               2.718000               0.114000              2.510000
# 75%               3.752000               0.191000              3.499000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA            MÊS  \
# count         106823.000000             106823.000000  106823.000000
# mean              12.537731                  0.045418       6.484006
# std               20.841497                  0.025066       3.443391
# min                0.999000                  0.000000       1.000000
# 25%                2.310000                  0.029000       4.000000
# 50%                2.999000                  0.041000       6.000000
# 75%                4.150000                  0.058000       9.000000
# max              120.000000                  0.395000      12.000000
#
#                  ANO
# count  106823.000000
# mean     2011.802271
# std         4.391530
# min      2004.000000
# 25%      2008.000000
# 50%      2012.000000
# 75%      2016.000000
# max      2019.000000

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    106823.000000
# mean         10.870780
# std          17.752533
# min           0.766000
# 25%           2.072000
# 50%           2.718000
# 75%           3.752000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
data_final.describe()['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count         8.000000
# mean      13370.036039
# std       37760.714186
# min           0.766000
# 25%           2.556500
# 50%           7.311390
# 75%          38.153650
# max      106823.000000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()['PREÇO MÉDIO REVENDA'].describe()
stats
# Out:
# count         8.000000
# mean      13370.036039
# std       37760.714186
# min           0.766000
# 25%           2.556500
# 50%           7.311390
# 75%          38.153650
# max      106823.000000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats[['PREÇO MÉDIA REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIA DISTRIBUIÇÃO']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-286461379.py in <cell line: 0>()
# ----> 1 stats[['PREÇO MÉDIA REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIA DISTRIBUIÇÃO']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1151             return self._get_rows_with_mask(key)
#    1152
# -> 1153         return self._get_with(key)
#    1154
#    1155     def _get_with(self, key):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_with(self, key)
#    1192
#    1193         # handle the dup indexing case GH#4246
# -> 1194         return self.loc[key]
#    1195
#    1196     def _get_values_tuple(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1418                     raise ValueError("Cannot index with multidimensional key")
#    1419
# -> 1420                 return self._getitem_iterable(key, axis=axis)
#    1421
#    1422             # nested tuple slicing
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1358
#    1359         # A collection of keys
# -> 1360         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361         return self.obj._reindex_with_indexers(
#    1362             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1556         axis_name = self.obj._get_axis_name(axis)
#    1557
# -> 1558         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1559
#    1560         return keyarr, indexer
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['PREÇO MÉDIA REVENDA', 'PREÇO MÁXIMO REVENDA',\n       'PREÇO MÉDIA DISTRIBUIÇÃO'],\n      dtype='object')] are in the [index]"

# %%
print(data_final.columns)

# %%
display(data_final.isnull().sum())

# %%
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
# count         8.000000
# mean      13370.036039
# std       37760.714186
# min           0.766000
# 25%           2.556500
# 50%           7.311390
# 75%          38.153650
# max      106823.000000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
# min          0.766000
# max     106823.000000
# mean     13370.036039
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
# min          0.766000
# max     106823.000000
# mean     13370.036039
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
EXEMPLO VIDEO NAO FUNCIONOU
# Out:
#   File "/tmp/ipython-input-610679421.py", line 1
#     EXEMPLO VIDEO NAO FUNCIONOU
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std_dev = data_final['PREÇO MÍNIMO REVENDA'].std()
print(f'Média: {mean}, Desvio Padrão: {std_dev}')
# Out:
# Média: 9.416037679151493, Desvio Padrão: 15.092193247644039

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted (data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts()
# Out:
# ESTADO
# PARAIBA                4263
# BAHIA                  4263
# CEARA                  4263
# RIO GRANDE DO SUL      4263
# RIO DE JANEIRO         4263
# SAO PAULO              4263
# PERNAMBUCO             4262
# RIO GRANDE DO NORTE    4262
# SANTA CATARINA         4262
# MINAS GERAIS           4261
# ESPIRITO SANTO         4260
# SERGIPE                4259
# PARANA                 4251
# ALAGOAS                4250
# MATO GROSSO DO SUL     4246
# MATO GROSSO            4037
# AMAZONAS               3889
# GOIAS                  3663
# PIAUI                  3548
# MARANHAO               3499
# PARA                   3497
# DISTRITO FEDERAL       3483
# TOCANTINS              3483
# ACRE                   3480
# RONDONIA               3479
# RORAIMA                3471
# AMAPA                  3403
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame()
# Out:
#                      count
# ESTADO
# PARAIBA               4263
# BAHIA                 4263
# CEARA                 4263
# RIO GRANDE DO SUL     4263
# RIO DE JANEIRO        4263
# SAO PAULO             4263
# PERNAMBUCO            4262
# RIO GRANDE DO NORTE   4262
# SANTA CATARINA        4262
# MINAS GERAIS          4261
# ESPIRITO SANTO        4260
# SERGIPE               4259
# PARANA                4251
# ALAGOAS               4250
# MATO GROSSO DO SUL    4246
# MATO GROSSO           4037
# AMAZONAS              3889
# GOIAS                 3663
# PIAUI                 3548
# MARANHAO              3499
# PARA                  3497
# DISTRITO FEDERAL      3483
# TOCANTINS             3483
# ACRE                  3480
# RONDONIA              3479
# RORAIMA               3471
# AMAPA                 3403

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(linha):
  return linha.sum()

# %%
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100            111            37.0
# Linha 2   2   20   200            222            74.0
# Linha 3   3   30   300            333           111.0
# Linha 4   4   40   400            444           148.0
# Linha 5  10  100  1000           1110           370.0

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
df['C * 2'] = df['C'].apply(lambda x: x *2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100            111            37.0    200
# Linha 2   2   20   200            222            74.0    400
# Linha 3   3   30   300            333           111.0    600
# Linha 4   4   40   400            444           148.0    800
# Linha 5  10  100  1000           1110           370.0   2000

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df.applymap(lambda x: x **2)
# Out:
# /tmp/ipython-input-1081273538.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x **2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['Joao', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     Joao
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
nomes.map(lambda x: x.upper())
# Out:
# 0     JOAO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %%
nomes
# Out:
# 0     Joao
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
nomes.str.upper()
# Out:
# 0     JOAO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 106791, 106792, 106812]),
#  'NORDESTE': array([     4,      5,      6, ..., 106816, 106818, 106822]),
#  'NORTE': array([    13,     14,     15, ..., 106802, 106803, 106807]),
#  'SUDESTE': array([    20,     21,     22, ..., 106813, 106817, 106821]),
#  'SUL': array([    24,     25,     26, ..., 106815, 106819, 106820])}

# %%
grupos.get_group('CENTRO OESTE')
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 27                27          27   2004-05-16  2004-05-22  CENTRO OESTE
# ...              ...         ...          ...         ...           ...
# 106787        106787      106787   2019-06-23  2019-06-29  CENTRO OESTE
# 106789        106789      106789   2019-06-23  2019-06-29  CENTRO OESTE
# 106791        106791      106791   2019-06-23  2019-06-29  CENTRO OESTE
# 106792        106792      106792   2019-06-23  2019-06-29  CENTRO OESTE
# 106812        106812      106812   2019-06-23  2019-06-29  CENTRO OESTE
#
#                     ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0         DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                    GOIAS  ETANOL HIDRATADO                           387
# 2              MATO GROSSO  ETANOL HIDRATADO                           192
# 3       MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 27        DISTRITO FEDERAL  ETANOL HIDRATADO                           144
# ...                    ...               ...                           ...
# 106787    DISTRITO FEDERAL               GLP                            42
# 106789               GOIAS               GLP                           209
# 106791         MATO GROSSO               GLP                            95
# 106792  MATO GROSSO DO SUL               GLP                           115
# 106812  MATO GROSSO DO SUL               GNV                             2
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 27                  R$/l                1.271  ...                 1.300
# ...                  ...                  ...  ...                   ...
# 106787           R$/13Kg               73.452  ...                95.000
# 106789           R$/13Kg               71.968  ...                85.000
# 106791           R$/13Kg               96.691  ...               115.000
# 106792           R$/13Kg               72.297  ...                99.000
# 106812             R$/m3                2.934  ...                 2.968
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 27                     0.448                     0.031
# ...                      ...                       ...
# 106787                21.509                     0.066
# 106789                15.044                     0.075
# 106791                19.789                     0.071
# 106792                16.707                     0.111
# 106812                 0.901                     0.017
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 27                        0.823                       0.111
# ...                         ...                         ...
# 106787                   51.943                       7.877
# 106789                   56.924                       4.285
# 106791                   76.902                       8.846
# 106792                    55.59                       5.109
# 106812                    2.033                       0.259
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 27                        0.4094                    1.1931
# ...                          ...                       ...
# 106787                        44                     62.82
# 106789                     45.57                      61.6
# 106791                     61.15                        90
# 106792                        47                        72
# 106812                      1.85                    2.2161
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 27                             0.135   5  2004
# ...                              ...  ..   ...
# 106787                         0.152   6  2019
# 106789                         0.075   6  2019
# 106791                         0.115   6  2019
# 106792                         0.092   6  2019
# 106812                         0.127   6  2019
#
# [15429 rows x 22 columns]

# %%
grupos.describe()
# Out:
#              Unnamed: 0.1                                              \
#                     count          mean           std   min       25%
# REGIÃO
# CENTRO OESTE      15429.0  53417.968955  30938.517860   0.0  26021.00
# NORDESTE          36869.0  53538.276248  30636.581838   4.0  27645.00
# NORTE             24702.0  52805.662214  31594.475085  13.0  23848.25
# SUDESTE           17047.0  53749.005104  30386.889753  20.0  28766.50
# SUL               12776.0  53754.692001  30391.714995  24.0  28743.75
#
#                                           Unnamed: 0                ...   MÊS  \
#                   50%       75%       max      count          mean  ...   75%
# REGIÃO                                                              ...
# CENTRO OESTE  54240.0  80018.00  106812.0    15429.0  53417.968955  ...  9.00
# NORDESTE      53027.0  80098.00  106822.0    36869.0  53538.276248  ...  9.00
# NORTE         54009.5  80299.50  106807.0    24702.0  52805.662214  ...  9.00
# SUDESTE       52829.0  80048.50  106821.0    17047.0  53749.005104  ...  9.00
# SUL           52859.5  80059.75  106820.0    12776.0  53754.692001  ...  9.25
#
#                         ANO                                                 \
#                max    count         mean       std     min     25%     50%
# REGIÃO
# CENTRO OESTE  12.0  15429.0  2011.862532  4.352302  2004.0  2008.0  2012.0
# NORDESTE      12.0  36869.0  2011.777699  4.404509  2004.0  2008.0  2012.0
# NORTE         12.0  24702.0  2011.832524  4.386504  2004.0  2008.0  2012.0
# SUDESTE       12.0  17047.0  2011.775796  4.399684  2004.0  2008.0  2012.0
# SUL           12.0  12776.0  2011.777239  4.399609  2004.0  2008.0  2012.0
#
#
#                  75%     max
# REGIÃO
# CENTRO OESTE  2016.0  2019.0
# NORDESTE      2016.0  2019.0
# NORTE         2016.0  2019.0
# SUDESTE       2016.0  2019.0
# SUL           2016.0  2019.0
#
# [5 rows x 80 columns]

# %%
grupos.mean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1316802999.py in <cell line: 0>()
# ----> 1 grupos.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
grupos.min()
# Out:
#               Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL  \
# REGIÃO
# CENTRO OESTE             0           0   2004-05-09  2004-05-15
# NORDESTE                 4           4   2004-05-09  2004-05-15
# NORTE                   13          13   2004-05-09  2004-05-15
# SUDESTE                 20          20   2004-05-09  2004-05-15
# SUL                     24          24   2004-05-09  2004-05-15
#
#                         ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE               ALAGOAS  ETANOL HIDRATADO
# NORTE                     ACRE  ETANOL HIDRATADO
# SUDESTE         ESPIRITO SANTO  ETANOL HIDRATADO
# SUL                     PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                1.097                    0.0  ...
# NORDESTE                    0.975                    0.0  ...
# NORTE                       1.219                    0.0  ...
# SUDESTE                     0.766                    0.0  ...
# SUL                         0.922                    0.0  ...
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                 1.099                     -
# NORDESTE                     0.999                     -
# NORTE                        1.219                     -
# SUDESTE                      1.099                     -
# SUL                          1.199                     -
#
#              COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                      0.0                         -
# NORDESTE                          0.0                         -
# NORTE                             0.0                         -
# SUDESTE                           0.0                         -
# SUL                               0.0                         -
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                          -                         -
# NORDESTE                              -                         -
# NORTE                                 -                         -
# SUDESTE                               -                         -
# SUL                                   -                         -
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# REGIÃO
# CENTRO OESTE                         -                             -   1  2004
# NORDESTE                             -                             -   1  2004
# NORTE                                -                             -   1  2004
# SUDESTE                              -                             -   1  2004
# SUL                                  -                             -   1  2004
#
# [5 rows x 21 columns]

# %%
data_final.groupby('REGIÃO').min()
# Out:
#               Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL  \
# REGIÃO
# CENTRO OESTE             0           0   2004-05-09  2004-05-15
# NORDESTE                 4           4   2004-05-09  2004-05-15
# NORTE                   13          13   2004-05-09  2004-05-15
# SUDESTE                 20          20   2004-05-09  2004-05-15
# SUL                     24          24   2004-05-09  2004-05-15
#
#                         ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE               ALAGOAS  ETANOL HIDRATADO
# NORTE                     ACRE  ETANOL HIDRATADO
# SUDESTE         ESPIRITO SANTO  ETANOL HIDRATADO
# SUL                     PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                1.097                    0.0  ...
# NORDESTE                    0.975                    0.0  ...
# NORTE                       1.219                    0.0  ...
# SUDESTE                     0.766                    0.0  ...
# SUL                         0.922                    0.0  ...
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                 1.099                     -
# NORDESTE                     0.999                     -
# NORTE                        1.219                     -
# SUDESTE                      1.099                     -
# SUL                          1.199                     -
#
#              COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                      0.0                         -
# NORDESTE                          0.0                         -
# NORTE                             0.0                         -
# SUDESTE                           0.0                         -
# SUL                               0.0                         -
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                          -                         -
# NORDESTE                              -                         -
# NORTE                                 -                         -
# SUDESTE                               -                         -
# SUL                                   -                         -
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# REGIÃO
# CENTRO OESTE                         -                             -   1  2004
# NORDESTE                             -                             -   1  2004
# NORTE                                -                             -   1  2004
# SUDESTE                              -                             -   1  2004
# SUL                                  -                             -   1  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %%
data_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1316802999.py in <cell line: 0>()
# ----> 1 grupos.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                  columns=['A', 'B', 'C'])
df

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final',ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending = [False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending = [False, True])

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
del data_final ['Unnamed: 0.1']

# %%
del data_final ['Unnamed: 0']

# %%
data_final = data_final[data_final['ANO'] != 2019]
display(data_final.head())
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  ...  PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0  ETANOL HIDRATADO  ...                     0.4201                    0.9666
# 1  ETANOL HIDRATADO  ...                     0.5013                      1.05
# 2  ETANOL HIDRATADO  ...                     0.5614                     1.161
# 3  ETANOL HIDRATADO  ...                     0.5991                   1.22242
# 4  ETANOL HIDRATADO  ...                     0.7441                    1.0317
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                          0.133    5  2004
# 1                          0.115    5  2004
# 2                          0.098    5  2004
# 3                          0.143    5  2004
# 4                          0.082    5  2004
#
# [5 rows x 20 columns]

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
# 103068   2018-12-30  2019-01-05      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103064               GNV                            10             R$/m3
# 103065               GNV                            16             R$/m3
# 103066               GNV                            15             R$/m3
# 103067               GNV                            41             R$/m3
# 103068               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 103064                3.465                  0.060                 3.370
# 103065                3.402                  0.103                 3.199
# 103066                2.944                  0.124                 2.790
# 103067                2.353                  0.451                 1.999
# 103068                3.649                  0.000                 3.649
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 103064                 3.590                0.759                     0.017
# 103065                 3.499                1.296                     0.030
# 103066                 3.199                 0.67                     0.042
# 103067                 3.429                0.467                     0.192
# 103068                 3.649                    -                     0.000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 103064                    2.706                          0
# 103065                    2.106                      0.249
# 103066                    2.274                      0.283
# 103067                    1.886                       0.25
# 103068                        -                          -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 103064                    2.7059                    2.7059
# 103065                    1.8775                    2.3724
# 103066                    1.8738                     2.274
# 103067                      1.64                     2.332
# 103068                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 103064                             0   12  2018
# 103065                         0.118   12  2018
# 103066                         0.124   12  2018
# 103067                         0.133   12  2018
# 103068                             -   12  2018
#
# [103069 rows x 20 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %%
data_final.reset_index()
# Out:
#          index DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0            0   2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2            2   2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3            3   2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4            4   2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...        ...          ...         ...           ...                  ...
# 103064  103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 103065  103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 103066  103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 103067  103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
# 103068  103068   2018-12-30  2019-01-05      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103064               GNV                            10             R$/m3
# 103065               GNV                            16             R$/m3
# 103066               GNV                            15             R$/m3
# 103067               GNV                            41             R$/m3
# 103068               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                     1.288                  0.016  ...                 1.350
# 1                     1.162                  0.114  ...                 1.449
# 2                     1.389                  0.097  ...                 1.760
# 3                     1.262                  0.070  ...                 1.509
# 4                     1.181                  0.078  ...                 1.400
# ...                     ...                    ...  ...                   ...
# 103064                3.465                  0.060  ...                 3.590
# 103065                3.402                  0.103  ...                 3.499
# 103066                2.944                  0.124  ...                 3.199
# 103067                2.353                  0.451  ...                 3.429
# 103068                3.649                  0.000  ...                 3.649
#
#         MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                    0.012
# 1                      0.399                    0.098
# 2                      0.419                    0.070
# 3                      0.432                    0.055
# 4                       0.24                    0.066
# ...                      ...                      ...
# 103064                 0.759                    0.017
# 103065                 1.296                    0.030
# 103066                  0.67                    0.042
# 103067                 0.467                    0.192
# 103068                     -                    0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 103064                     2.706                          0
# 103065                     2.106                      0.249
# 103066                     2.274                      0.283
# 103067                     1.886                       0.25
# 103068                         -                          -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 103064                    2.7059                    2.7059
# 103065                    1.8775                    2.3724
# 103066                    1.8738                     2.274
# 103067                      1.64                     2.332
# 103068                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 103064                             0  12  2018
# 103065                         0.118  12  2018
# 103066                         0.124  12  2018
# 103067                         0.133  12  2018
# 103068                             -  12  2018
#
# [103069 rows x 21 columns]

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %%
data_final = data_final.reset_index(drop=True)

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
# 103068   2018-12-30  2019-01-05      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103064               GNV                            10             R$/m3
# 103065               GNV                            16             R$/m3
# 103066               GNV                            15             R$/m3
# 103067               GNV                            41             R$/m3
# 103068               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 103064                3.465                  0.060                 3.370
# 103065                3.402                  0.103                 3.199
# 103066                2.944                  0.124                 2.790
# 103067                2.353                  0.451                 1.999
# 103068                3.649                  0.000                 3.649
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 103064                 3.590                0.759                     0.017
# 103065                 3.499                1.296                     0.030
# 103066                 3.199                 0.67                     0.042
# 103067                 3.429                0.467                     0.192
# 103068                 3.649                    -                     0.000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 103064                    2.706                          0
# 103065                    2.106                      0.249
# 103066                    2.274                      0.283
# 103067                    1.886                       0.25
# 103068                        -                          -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 103064                    2.7059                    2.7059
# 103065                    1.8775                    2.3724
# 103066                    1.8738                     2.274
# 103067                      1.64                     2.332
# 103068                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 103064                             0   12  2018
# 103065                         0.118   12  2018
# 103066                         0.124   12  2018
# 103067                         0.133   12  2018
# 103068                             -   12  2018
#
# [103069 rows x 20 columns]

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
data_final[['PRODUTO', 'REGIÃO']]
# Out:
#                  PRODUTO        REGIÃO
# 0       ETANOL HIDRATADO  CENTRO OESTE
# 1       ETANOL HIDRATADO  CENTRO OESTE
# 2       ETANOL HIDRATADO  CENTRO OESTE
# 3       ETANOL HIDRATADO  CENTRO OESTE
# 4       ETANOL HIDRATADO      NORDESTE
# ...                  ...           ...
# 103064               GNV      NORDESTE
# 103065               GNV           SUL
# 103066               GNV           SUL
# 103067               GNV       SUDESTE
# 103068               GNV      NORDESTE
#
# [103069 rows x 2 columns]

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolina_sp_2018 = data_final[
(data_final['PRODUTO'] == 'GASOLINA COMUM') &(data_final['ESTADO'] == 'SAO PAULO') &(data_final['ANO'] == 2018)]
display(gasolina_sp_2018.head())
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95351                          1641              R$/l                3.988
# 95502                          1648              R$/l                4.002
# 95654                          1648              R$/l                4.006
# 95806                          1644              R$/l                4.019
# 95958                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 95351                  0.156                 3.499                 4.599
# 95502                  0.155                 3.549                 4.499
# 95654                  0.160                 3.499                 4.899
# 95806                  0.156                 3.579                 4.699
# 95958                  0.157                 3.579                 4.597
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 95351                0.411                     0.039                    3.577
# 95502                0.412                     0.039                     3.59
# 95654                 0.41                     0.040                    3.596
# 95806                0.423                     0.039                    3.596
# 95958                0.416                     0.039                    3.588
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 95351                      0.104                      2.99
# 95502                      0.102                      2.99
# 95654                      0.102                      2.99
# 95806                      0.107                     2.924
# 95958                      0.102                      2.99
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 95351                     3.951                         0.029    1  2018
# 95502                    3.9014                         0.028    1  2018
# 95654                    3.9014                         0.028    1  2018
# 95806                    3.9537                          0.03    1  2018
# 95958                    3.9537                         0.028    2  2018

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
data_final ['DATA INICIAL'].describe
# Out:
# <bound method NDFrame.describe of 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 103064    2018-12-30
# 103065    2018-12-30
# 103066    2018-12-30
# 103067    2018-12-30
# 103068    2018-12-30
# Name: DATA INICIAL, Length: 103069, dtype: object>

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
gasolina_sp_2018 = data_final[
    (data_final['PRODUTO'].isin(['GASOLINA COMUM', 'ETANOL'])) &
    (data_final['ESTADO'] == 'SAO PAULO') &
    (data_final['ANO'] == 2018)
]
display(gasolina_sp_2018.head())
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95351                          1641              R$/l                3.988
# 95502                          1648              R$/l                4.002
# 95654                          1648              R$/l                4.006
# 95806                          1644              R$/l                4.019
# 95958                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 95351                  0.156                 3.499                 4.599
# 95502                  0.155                 3.549                 4.499
# 95654                  0.160                 3.499                 4.899
# 95806                  0.156                 3.579                 4.699
# 95958                  0.157                 3.579                 4.597
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 95351                0.411                     0.039                    3.577
# 95502                0.412                     0.039                     3.59
# 95654                 0.41                     0.040                    3.596
# 95806                0.423                     0.039                    3.596
# 95958                0.416                     0.039                    3.588
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 95351                      0.104                      2.99
# 95502                      0.102                      2.99
# 95654                      0.102                      2.99
# 95806                      0.107                     2.924
# 95958                      0.102                      2.99
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 95351                     3.951                         0.029    1  2018
# 95502                    3.9014                         0.028    1  2018
# 95654                    3.9014                         0.028    1  2018
# 95806                    3.9537                          0.03    1  2018
# 95958                    3.9537                         0.028    2  2018

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
