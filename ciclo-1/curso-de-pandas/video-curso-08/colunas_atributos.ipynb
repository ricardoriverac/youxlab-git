# %%
# Aula 3
import pandas as pd

# %%
# carregando dataset corretamente ==> neste caso usa o separador ';'.
data = pd.read_csv('./sample_data/GasPricesinBrazil_2004-2019.csv', sep=";")

# %%
data
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 52472       52472   2010-10-03  2010-10-09         NORTE                PARA
# 52473       52473   2010-10-03  2010-10-09         NORTE            RONDONIA
# 52474       52474   2010-10-03  2010-10-09         NORTE             RORAIMA
# 52475       52475   2010-10-03  2010-10-09         NORTE           TOCANTINS
# 52476       52476   2010-10-03  2010-10-09       SUDESTE      ESPIRITO SANTO
#
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                         127.0              R$/l
# 1  ETANOL HIDRATADO                         387.0              R$/l
# 2  ETANOL HIDRATADO                         192.0              R$/l
# 3  ETANOL HIDRATADO                         162.0              R$/l
# 4  ETANOL HIDRATADO                         103.0              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
# Criando uma coluna a partir de um valor constante/default
# todas as linhas terão o mesmo valor para esta nova coluna
data['coluna sem nocao'] = 'DEFAULT'
data
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 52472       52472   2010-10-03  2010-10-09         NORTE                PARA
# 52473       52473   2010-10-03  2010-10-09         NORTE            RONDONIA
# 52474       52474   2010-10-03  2010-10-09         NORTE             RORAIMA
# 52475       52475   2010-10-03  2010-10-09         NORTE           TOCANTINS
# 52476       52476   2010-10-03  2010-10-09       SUDESTE      ESPIRITO SANTO
#
# ...

# %%
data['coluna a partir da Lista'] = range(data.shape[0])

# %%
data
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 52472       52472   2010-10-03  2010-10-09         NORTE                PARA
# 52473       52473   2010-10-03  2010-10-09         NORTE            RONDONIA
# 52474       52474   2010-10-03  2010-10-09         NORTE             RORAIMA
# 52475       52475   2010-10-03  2010-10-09         NORTE           TOCANTINS
# 52476       52476   2010-10-03  2010-10-09       SUDESTE      ESPIRITO SANTO
#
# ...

# %%
# não funciona porque a quantidade de elementos da lista ( a sertem atribuídos a nova coluna) é diferente
# da quantidade de linhas do dataframe
data['nao funciona'] = [1, 2, 3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3817656257.py in <cell line: 0>()
#       1 # não funciona porque a quantidade de elementos da lista ( a sertem atribuídos a nova coluna) é diferente
#       2 # da quantidade de linhas do dataframe
# ----> 3 data['nao funciona'] = [1, 2, 3]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                         127.0              R$/l
# 1  ETANOL HIDRATADO                         387.0              R$/l
# 2  ETANOL HIDRATADO                         192.0              R$/l
# 3  ETANOL HIDRATADO                         162.0              R$/l
# 4  ETANOL HIDRATADO                         103.0              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %%
data['PREÇO MÉDIO DE REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA']  * 6.0
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 52472       52472   2010-10-03  2010-10-09         NORTE                PARA
# 52473       52473   2010-10-03  2010-10-09         NORTE            RONDONIA
# 52474       52474   2010-10-03  2010-10-09         NORTE             RORAIMA
# 52475       52475   2010-10-03  2010-10-09         NORTE           TOCANTINS
# 52476       52476   2010-10-03  2010-10-09       SUDESTE      ESPIRITO SANTO
#
# ...

# %%
data
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 52472       52472   2010-10-03  2010-10-09         NORTE                PARA
# 52473       52473   2010-10-03  2010-10-09         NORTE            RONDONIA
# 52474       52474   2010-10-03  2010-10-09         NORTE             RORAIMA
# 52475       52475   2010-10-03  2010-10-09         NORTE           TOCANTINS
# 52476       52476   2010-10-03  2010-10-09       SUDESTE      ESPIRITO SANTO
#
# ...
