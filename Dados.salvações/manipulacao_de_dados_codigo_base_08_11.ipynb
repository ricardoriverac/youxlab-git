# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Caminho padrao para a base de dados
path = '/content/drive/MyDrive/trilia-dados/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
# Carregando o dataset corretamente ==> neste caso, usa o separador ';'
pd.read_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv')
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
data = pd.read_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv', sep=';')
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
# exibe as 10 primeiras linhas do dataframe
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (106823, 21)

# %%
print(f'O Dataframe possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atributos/variaveis.')
# Out:
# O Dataframe possui 106823 linhas/observações/registros e 21 colunas/atributos/variaveis.

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
alunos_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15, 60],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
alunos_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(alunos_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.rename(columns={
    'nome': 'Nome Completo',   # renomeia a coluna nome 'nome' para 'Nome Completo'
    'idade': 'Idade'}
# Out:
#   File "/tmp/ipython-input-2363913446.py", line 3
#     'idade': 'Idade'}
#                      ^
# SyntaxError: incomplete input

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
alunos_df.rename(columns={ 'nome': 'Nome Completo', 'idade': 'Idade'}, inplace=True)

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
alunos_df.columns

# %%
alunos_df.columns = ['NOME', 'IDADE', 'PESO','EH_JEDI']

# %%
alunos_df

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()

# %%
# selecionando uma coluna inteira
data['ESTADO']

# %%
# selecionando uma coluna inteira
# esta forma de acesso, só funciona para colunas com nomes sem espaços, acentos, etc (caracteres inválidos)
data.ESTADO

# %%
type(data['ESTADO'])

# %%
# selecionando a observação indexada no índice [1] do dataframe
data.iloc[1]

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5,6.0,9.5  ])

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5.5,6.0,9.5  ], index=['prova 1', 'prova 2', 'projeto'], name ='Notas dos Luke SkyWalker')

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_view = data['PRODUTO']  # a series retornada refente à coluna, NÃO É UMA CÓPIA, mas sim, uma REFERÊNCIA/VIEW à coluna do dataframe
produto_view

# %%
produto_copy_bkp = data['PRODUTO'].copy()  # retorna uma cópia da coluna 'PRODUTO'
produto_copy_bkp

# %%
data['PRODUTO'] = 'Combustível'  # atribuindo o valor constante 'Combustível' para linha do dataframe na coluna 'PRODUTO'

# %%
data.head()

# %%
produto_view

# %%
produto_copy_bkp

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)]
len(novos_produtos)

# %%
# a quantidade de elementos da lista `novos_produtos` é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
data

# %%
print(produto_view)
print('\n')

# %%
# voltando para os produtos originais
data['PRODUTO'] = produto_copy_bkp  # produto_copy_bkp é uma Series

# %%
data

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# criando uma coluna a partir de um valor constante/default
# todas as linhas terão o mesmo valor para esta nova coluna
data['coluna sem nocao'] = 'DEFAULT'
data

# %%
data['coluna a partir de lista'] = range(data.shape[0])
data

# %%
# não funciona pq a quantidade de elementos da lista (a serem atribuídos a nova coluna) é diferente
# da quantidade de linhas do dataframe
data['nao funciona'] = [1, 2, 3]

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()

# %%
data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0
data

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data

# %%
data.index

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %%
data.head()

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
# selecionando a linha 1 ===> observação de índice [1] do dataframe
data.iloc[1]

# %%
data.iloc[:6]

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
# selecionando as linhas de índice de 10 a 15 (incluso)
data.iloc[10:16]

# %%
# selecionando as linhas/observações de índice 1, 5, 10, 15
data.iloc[[1, 5, 10, 15]]

# %%
# selecionando as linhas/observações de índice 5, 1, 10, 15
data.iloc[[5, 1, 10, 15]]

# %%
# retornar o valor da linha de índice 1, coluna 4 ('ESTADO')
data.iloc[1, 4]

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao

# %%
# retorna o valor linha de índice 0 (implícito) e a coluna de índice 1 (implícito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0,1]

# %%
# retorna a linha cujo o rótulo do índice é 'XboxOne'
pesquisa_de_satisfacao.loc['XboxOne']

# %%
# NÃO FUNCIONA  ===> iloc tentando acessar índices com rótulos
pesquisa_de_satisfacao.iloc['XboxOne']

# %%
# NÃO FUNCIONA  ===> iloc tentando acessar índices rotulados com números
pesquisa_de_satisfacao.loc['0']

# %%
pesquisa_de_satisfacao

# %%
# retorna o valor da linha 'Playstation4', coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4','ruim']

# %%
# selecionando as linhas  de índices  resultados 'XboxOne','Switch'
pesquisa_de_satisfacao.loc[['XboxOne','Switch']]

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]

# %%
# retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'pessimo'
pesquisa_de_satisfacao.loc[:,['bom', 'pessimo']]

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()

# %%
# retornando a coluna/atributo 'ESTADO'
data['ESTADO']

# %%
data.ESTADO

# %%
data.loc[:, 'ESTADO']

# %%
# a forma de acesso de colunas por .NOME_DA_COLUNA só funciona se
# NOME_DA_COLUNA não possuir caracteres   ínvalidos (espaços, acentos, cedilha, ...)
### NÃO FUNCIONA
data.DATA INICIAL

# %%
# para colunas cujos rótulos  possuem caracteres ínvalidos,
# apenas para a seleção via string é válida
data['DATA INICIAL']

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %%
# selecionando mútiplas colunas: 'PRODUTO', 'ESTADO', 'REGIÃO'
data[['PRODUTO', 'ESTADO', 'REGIÃO']]

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
data.head()

# %%
# delete/remove in-place (ou seja,no própra  dataframe) a coluna de rótulo 'VUnnamed: 0'
del data ['Unnamed: 0']

# %%
data

# %%
del data['coluna sem nocao']
del data['coluna a apartir de lista']
del data['PREÇO MÉDIO REVENDA (dólares)']

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv')
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %%
# Mostra todos os estados cujos os preço dos combustíveis foram aferidos
# Mais tecnicamente , mostra os valores únicos presentes para atríbuto/coluna 'ESTADO'
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
# faz uma comparação elemento a elemento da series, retornando uma Series de booleans
data['ESTADO'] == 'SÃO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# salvando essa Series de booleans em uma varíavel
seleção = data['ESTADO'] == 'SÃO PAULO'
seleção
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(seleção)
# Out:
# pandas.core.series.Series

# %%
seleção.shape
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 22)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[seleção]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[seleção]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %%
data.query('ESTADO == "SAO PAULO"')
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23                23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50                50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77                77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104              104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131              131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...              ...         ...          ...         ...      ...        ...
# 106724        106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106751        106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106778        106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106805        106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106821        106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 106724       ÓLEO DIESEL                           863              R$/l
# 106751   ÓLEO DIESEL S10                          1277              R$/l
# 106778    GASOLINA COMUM                          1644              R$/l
# 106805               GLP                          1017           R$/13Kg
# 106821               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 23                    0.768  ...                 1.150                 0.198
# 50                    0.766  ...                 1.150                  0.19
# 77                    0.823  ...                 1.199                 0.209
# 104                   0.887  ...                 1.359                 0.216
# 131                   0.894  ...                 1.199                 0.205
# ...                     ...  ...                   ...                   ...
# 106724                3.448  ...                 4.220                 0.401
# 106751                3.574  ...                 4.320                 0.451
# 106778                4.142  ...                 4.999                 0.429
# 106805               66.893  ...                89.900                17.679
# 106821                3.020  ...                 3.490                 0.646
#
#         COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 23                         0.111                     0.57
# 50                         0.108                    0.576
# 77                         0.086                    0.614
# 104                        0.085                    0.671
# 131                        0.079                    0.689
# ...                          ...                      ...
# 106724                     0.045                    3.047
# 106751                     0.047                    3.123
# 106778                     0.044                    3.713
# 106805                     0.091                   49.214
# 106821                     0.076                    2.374
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 23                        1.4123                         0.098   5  2004
# 50                        0.9724                         0.087   5  2004
# 77                         1.412                         0.103   5  2004
# 104                       1.0669                         0.112   5  2004
# 131                       1.0669                         0.104   6  2004
# ...                          ...                           ...  ..   ...
# 106724                    3.3481                         0.032   6  2019
# 106751                     3.491                         0.036   6  2019
# 106778                    4.0892                         0.026   6  2019
# 106805                        72                         0.103   6  2019
# 106821                    2.5093                          0.07   6  2019
#
# [4263 rows x 22 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de São Paulo.

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')
postos_sp
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23                23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50                50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77                77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104              104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131              131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...              ...         ...          ...         ...      ...        ...
# 106724        106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106751        106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106778        106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106805        106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106821        106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 106724       ÓLEO DIESEL                           863              R$/l
# 106751   ÓLEO DIESEL S10                          1277              R$/l
# 106778    GASOLINA COMUM                          1644              R$/l
# 106805               GLP                          1017           R$/13Kg
# 106821               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 23                    0.768  ...                 1.150                 0.198
# 50                    0.766  ...                 1.150                  0.19
# 77                    0.823  ...                 1.199                 0.209
# 104                   0.887  ...                 1.359                 0.216
# 131                   0.894  ...                 1.199                 0.205
# ...                     ...  ...                   ...                   ...
# 106724                3.448  ...                 4.220                 0.401
# 106751                3.574  ...                 4.320                 0.451
# 106778                4.142  ...                 4.999                 0.429
# 106805               66.893  ...                89.900                17.679
# 106821                3.020  ...                 3.490                 0.646
#
#         COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 23                         0.111                     0.57
# 50                         0.108                    0.576
# 77                         0.086                    0.614
# 104                        0.085                    0.671
# 131                        0.079                    0.689
# ...                          ...                      ...
# 106724                     0.045                    3.047
# 106751                     0.047                    3.123
# 106778                     0.044                    3.713
# 106805                     0.091                   49.214
# 106821                     0.076                    2.374
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 23                        1.4123                         0.098   5  2004
# 50                        0.9724                         0.087   5  2004
# 77                         1.412                         0.103   5  2004
# 104                       1.0669                         0.112   5  2004
# 131                       1.0669                         0.104   6  2004
# ...                          ...                           ...  ..   ...
# 106724                    3.3481                         0.032   6  2019
# 106751                     3.491                         0.036   6  2019
# 106778                    4.0892                         0.026   6  2019
# 106805                        72                         0.103   6  2019
# 106821                    2.5093                          0.07   6  2019
#
# [4263 rows x 22 columns]

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 22)

# %%
postos_sp.head()
# Out:
#      Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23             23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50             50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77             77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104           104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131           131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23   ETANOL HIDRATADO                          4047              R$/l
# 50   ETANOL HIDRATADO                          4066              R$/l
# 77   ETANOL HIDRATADO                          4077              R$/l
# 104  ETANOL HIDRATADO                          4073              R$/l
# 131  ETANOL HIDRATADO                          4082              R$/l
#
#      PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 23                 0.768  ...                 1.150                 0.198
# 50                 0.766  ...                 1.150                  0.19
# 77                 0.823  ...                 1.199                 0.209
# 104                0.887  ...                 1.359                 0.216
# 131                0.894  ...                 1.199                 0.205
#
#      COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 23                      0.111                     0.57
# 50                      0.108                    0.576
# 77                      0.086                    0.614
# 104                     0.085                    0.671
# 131                     0.079                    0.689
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                        0.056                    0.4271
# 50                         0.05                   0.43204
# 77                        0.063                   0.34951
# 104                       0.075                    0.3398
# 131                       0.072                   0.47797
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 23                     1.4123                         0.098   5  2004
# 50                     0.9724                         0.087   5  2004
# 77                      1.412                         0.103   5  2004
# 104                    1.0669                         0.112   5  2004
# 131                    1.0669                         0.104   6  2004
#
# [5 rows x 22 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
dataPREÇO MÉDIO REVENDA
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
seleção = (data['ESTADO'] == 'RIO DE JANEIRO ') & (data['PREÇO MÉDIO REVENDA']> 2.0)
seleção
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[seleção]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, DATA INICIAL, DATA FINAL, REGIÃO, ESTADO, PRODUTO, NÚMERO DE POSTOS PESQUISADOS, UNIDADE DE MEDIDA, PREÇO MÉDIO REVENDA, DESVIO PADRÃO REVENDA, PREÇO MÍNIMO REVENDA, PREÇO MÁXIMO REVENDA, MARGEM MÉDIA REVENDA, COEF DE VARIAÇÃO REVENDA, PREÇO MÉDIO DISTRIBUIÇÃO, DESVIO PADRÃO DISTRIBUIÇÃO, PREÇO MÍNIMO DISTRIBUIÇÃO, PREÇO MÁXIMO DISTRIBUIÇÃO, COEF DE VARIAÇÃO DISTRIBUIÇÃO, MÊS, ANO]
# Index: []
#
# [0 rows x 22 columns]

# %%
postos_sp.reset_index()
# Out:
#        index  Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO  \
# 0         23            23          23   2004-05-09  2004-05-15  SUDESTE
# 1         50            50          50   2004-05-16  2004-05-22  SUDESTE
# 2         77            77          77   2004-05-23  2004-05-29  SUDESTE
# 3        104           104         104   2004-05-30  2004-06-05  SUDESTE
# 4        131           131         131   2004-06-06  2004-06-12  SUDESTE
# ...      ...           ...         ...          ...         ...      ...
# 4258  106724        106724      106724   2019-06-23  2019-06-29  SUDESTE
# 4259  106751        106751      106751   2019-06-23  2019-06-29  SUDESTE
# 4260  106778        106778      106778   2019-06-23  2019-06-29  SUDESTE
# 4261  106805        106805      106805   2019-06-23  2019-06-29  SUDESTE
# 4262  106821        106821      106821   2019-06-23  2019-06-29  SUDESTE
#
#          ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0     SAO PAULO  ETANOL HIDRATADO                          4047
# 1     SAO PAULO  ETANOL HIDRATADO                          4066
# 2     SAO PAULO  ETANOL HIDRATADO                          4077
# 3     SAO PAULO  ETANOL HIDRATADO                          4073
# 4     SAO PAULO  ETANOL HIDRATADO                          4082
# ...         ...               ...                           ...
# 4258  SAO PAULO       ÓLEO DIESEL                           863
# 4259  SAO PAULO   ÓLEO DIESEL S10                          1277
# 4260  SAO PAULO    GASOLINA COMUM                          1644
# 4261  SAO PAULO               GLP                          1017
# 4262  SAO PAULO               GNV                            52
#
#      UNIDADE DE MEDIDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                 R$/l  ...                 1.150                 0.198
# 1                 R$/l  ...                 1.150                  0.19
# 2                 R$/l  ...                 1.199                 0.209
# 3                 R$/l  ...                 1.359                 0.216
# 4                 R$/l  ...                 1.199                 0.205
# ...                ...  ...                   ...                   ...
# 4258              R$/l  ...                 4.220                 0.401
# 4259              R$/l  ...                 4.320                 0.451
# 4260              R$/l  ...                 4.999                 0.429
# 4261           R$/13Kg  ...                89.900                17.679
# 4262             R$/m3  ...                 3.490                 0.646
#
#       COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                        0.111                      0.57
# 1                        0.108                     0.576
# 2                        0.086                     0.614
# 3                        0.085                     0.671
# 4                        0.079                     0.689
# ...                        ...                       ...
# 4258                     0.045                     3.047
# 4259                     0.047                     3.123
# 4260                     0.044                     3.713
# 4261                     0.091                    49.214
# 4262                     0.076                     2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                     0.4271
# 1                          0.05                    0.43204
# 2                         0.063                    0.34951
# 3                         0.075                     0.3398
# 4                         0.072                    0.47797
# ...                         ...                        ...
# 4258                      0.097                     2.8599
# 4259                      0.111                      2.885
# 4260                      0.097                       3.52
# 4261                      5.071                      40.19
# 4262                      0.165                     2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
# [4263 rows x 23 columns]

# %%
postos_sp.reset_index(drop=True)
# Out:
#       Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0               23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1               50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2               77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3              104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4              131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...         ...          ...         ...      ...        ...
# 4258        106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259        106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260        106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4261        106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4262        106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4258       ÓLEO DIESEL                           863              R$/l
# 4259   ÓLEO DIESEL S10                          1277              R$/l
# 4260    GASOLINA COMUM                          1644              R$/l
# 4261               GLP                          1017           R$/13Kg
# 4262               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                   0.768  ...                 1.150                 0.198
# 1                   0.766  ...                 1.150                  0.19
# 2                   0.823  ...                 1.199                 0.209
# 3                   0.887  ...                 1.359                 0.216
# 4                   0.894  ...                 1.199                 0.205
# ...                   ...  ...                   ...                   ...
# 4258                3.448  ...                 4.220                 0.401
# 4259                3.574  ...                 4.320                 0.451
# 4260                4.142  ...                 4.999                 0.429
# 4261               66.893  ...                89.900                17.679
# 4262                3.020  ...                 3.490                 0.646
#
#       COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                        0.111                     0.57
# 1                        0.108                    0.576
# 2                        0.086                    0.614
# 3                        0.085                    0.671
# 4                        0.079                    0.689
# ...                        ...                      ...
# 4258                     0.045                    3.047
# 4259                     0.047                    3.123
# 4260                     0.044                    3.713
# 4261                     0.091                   49.214
# 4262                     0.076                    2.374
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.4271
# 1                           0.05                   0.43204
# 2                          0.063                   0.34951
# 3                          0.075                    0.3398
# 4                          0.072                   0.47797
# ...                          ...                       ...
# 4258                       0.097                    2.8599
# 4259                       0.111                     2.885
# 4260                       0.097                      3.52
# 4261                       5.071                     40.19
# 4262                       0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
# [4263 rows x 22 columns]

# %%
# ainda não foi alterado, precisamos usar o atributo/parâmetro inplace=True
postos_sp
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 23                23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 50                50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 77                77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 104              104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 131              131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...              ...         ...          ...         ...      ...        ...
# 106724        106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106751        106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106778        106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106805        106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 106821        106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 23      ETANOL HIDRATADO                          4047              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 77      ETANOL HIDRATADO                          4077              R$/l
# 104     ETANOL HIDRATADO                          4073              R$/l
# 131     ETANOL HIDRATADO                          4082              R$/l
# ...                  ...                           ...               ...
# 106724       ÓLEO DIESEL                           863              R$/l
# 106751   ÓLEO DIESEL S10                          1277              R$/l
# 106778    GASOLINA COMUM                          1644              R$/l
# 106805               GLP                          1017           R$/13Kg
# 106821               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 23                    0.768  ...                 1.150                 0.198
# 50                    0.766  ...                 1.150                  0.19
# 77                    0.823  ...                 1.199                 0.209
# 104                   0.887  ...                 1.359                 0.216
# 131                   0.894  ...                 1.199                 0.205
# ...                     ...  ...                   ...                   ...
# 106724                3.448  ...                 4.220                 0.401
# 106751                3.574  ...                 4.320                 0.451
# 106778                4.142  ...                 4.999                 0.429
# 106805               66.893  ...                89.900                17.679
# 106821                3.020  ...                 3.490                 0.646
#
#         COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 23                         0.111                     0.57
# 50                         0.108                    0.576
# 77                         0.086                    0.614
# 104                        0.085                    0.671
# 131                        0.079                    0.689
# ...                          ...                      ...
# 106724                     0.045                    3.047
# 106751                     0.047                    3.123
# 106778                     0.044                    3.713
# 106805                     0.091                   49.214
# 106821                     0.076                    2.374
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                           0.056                    0.4271
# 50                            0.05                   0.43204
# 77                           0.063                   0.34951
# 104                          0.075                    0.3398
# 131                          0.072                   0.47797
# ...                            ...                       ...
# 106724                       0.097                    2.8599
# 106751                       0.111                     2.885
# 106778                       0.097                      3.52
# 106805                       5.071                     40.19
# 106821                       0.165                    2.0179
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 23                        1.4123                         0.098   5  2004
# 50                        0.9724                         0.087   5  2004
# 77                         1.412                         0.103   5  2004
# 104                       1.0669                         0.112   5  2004
# 131                       1.0669                         0.104   6  2004
# ...                          ...                           ...  ..   ...
# 106724                    3.3481                         0.032   6  2019
# 106751                     3.491                         0.036   6  2019
# 106778                    4.0892                         0.026   6  2019
# 106805                        72                         0.103   6  2019
# 106821                    2.5093                          0.07   6  2019
#
# [4263 rows x 22 columns]

# %%
postos_sp.reset_index(drop=True, inplace=True)
postos_sp
# Out:
#       Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0               23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1               50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2               77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3              104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4              131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...         ...          ...         ...      ...        ...
# 4258        106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259        106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260        106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4261        106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4262        106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4258       ÓLEO DIESEL                           863              R$/l
# 4259   ÓLEO DIESEL S10                          1277              R$/l
# 4260    GASOLINA COMUM                          1644              R$/l
# 4261               GLP                          1017           R$/13Kg
# 4262               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                   0.768  ...                 1.150                 0.198
# 1                   0.766  ...                 1.150                  0.19
# 2                   0.823  ...                 1.199                 0.209
# 3                   0.887  ...                 1.359                 0.216
# 4                   0.894  ...                 1.199                 0.205
# ...                   ...  ...                   ...                   ...
# 4258                3.448  ...                 4.220                 0.401
# 4259                3.574  ...                 4.320                 0.451
# 4260                4.142  ...                 4.999                 0.429
# 4261               66.893  ...                89.900                17.679
# 4262                3.020  ...                 3.490                 0.646
#
#       COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                        0.111                     0.57
# 1                        0.108                    0.576
# 2                        0.086                    0.614
# 3                        0.085                    0.671
# 4                        0.079                    0.689
# ...                        ...                      ...
# 4258                     0.045                    3.047
# 4259                     0.047                    3.123
# 4260                     0.044                    3.713
# 4261                     0.091                   49.214
# 4262                     0.076                    2.374
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.4271
# 1                           0.05                   0.43204
# 2                          0.063                   0.34951
# 3                          0.075                    0.3398
# 4                          0.072                   0.47797
# ...                          ...                       ...
# 4258                       0.097                    2.8599
# 4259                       0.111                     2.885
# 4260                       0.097                      3.52
# 4261                       5.071                     40.19
# 4262                       0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
# [4263 rows x 22 columns]

# %%
# ALTERNATIVA MUITO COMUM
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)
postos_sp
# Out:
#       Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0               23          23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1               50          50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2               77          77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3              104         104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4              131         131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...            ...         ...          ...         ...      ...        ...
# 4258        106724      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259        106751      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260        106778      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4261        106805      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4262        106821      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4258       ÓLEO DIESEL                           863              R$/l
# 4259   ÓLEO DIESEL S10                          1277              R$/l
# 4260    GASOLINA COMUM                          1644              R$/l
# 4261               GLP                          1017           R$/13Kg
# 4262               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                   0.768  ...                 1.150                 0.198
# 1                   0.766  ...                 1.150                  0.19
# 2                   0.823  ...                 1.199                 0.209
# 3                   0.887  ...                 1.359                 0.216
# 4                   0.894  ...                 1.199                 0.205
# ...                   ...  ...                   ...                   ...
# 4258                3.448  ...                 4.220                 0.401
# 4259                3.574  ...                 4.320                 0.451
# 4260                4.142  ...                 4.999                 0.429
# 4261               66.893  ...                89.900                17.679
# 4262                3.020  ...                 3.490                 0.646
#
#       COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                        0.111                     0.57
# 1                        0.108                    0.576
# 2                        0.086                    0.614
# 3                        0.085                    0.671
# 4                        0.079                    0.689
# ...                        ...                      ...
# 4258                     0.045                    3.047
# 4259                     0.047                    3.123
# 4260                     0.044                    3.713
# 4261                     0.091                   49.214
# 4262                     0.076                    2.374
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                          0.056                    0.4271
# 1                           0.05                   0.43204
# 2                          0.063                   0.34951
# 3                          0.075                    0.3398
# 4                          0.072                   0.47797
# ...                          ...                       ...
# 4258                       0.097                    2.8599
# 4259                       0.111                     2.885
# 4260                       0.097                      3.52
# 4261                       5.071                     40.19
# 4262                       0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
# [4263 rows x 22 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO' == "RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
# data.query('ESTADO' == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO  \
# 22                22          22   2004-05-09  2004-05-15  SUDESTE
# 49                49          49   2004-05-16  2004-05-22  SUDESTE
# 76                76          76   2004-05-23  2004-05-29  SUDESTE
# 103              103         103   2004-05-30  2004-06-05  SUDESTE
# 130              130         130   2004-06-06  2004-06-12  SUDESTE
# ...              ...         ...          ...         ...      ...
# 106718        106718      106718   2019-06-23  2019-06-29  SUDESTE
# 106745        106745      106745   2019-06-23  2019-06-29  SUDESTE
# 106772        106772      106772   2019-06-23  2019-06-29  SUDESTE
# 106799        106799      106799   2019-06-23  2019-06-29  SUDESTE
# 106817        106817      106817   2019-06-23  2019-06-29  SUDESTE
#
#                 ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 22      RIO DE JANEIRO  ETANOL HIDRATADO                           952
# 49      RIO DE JANEIRO  ETANOL HIDRATADO                           948
# 76      RIO DE JANEIRO  ETANOL HIDRATADO                           973
# 103     RIO DE JANEIRO  ETANOL HIDRATADO                           955
# 130     RIO DE JANEIRO  ETANOL HIDRATADO                           966
# ...                ...               ...                           ...
# 106718  RIO DE JANEIRO       ÓLEO DIESEL                           212
# 106745  RIO DE JANEIRO   ÓLEO DIESEL S10                           335
# 106772  RIO DE JANEIRO    GASOLINA COMUM                           422
# 106799  RIO DE JANEIRO               GLP                           221
# 106817  RIO DE JANEIRO               GNV                           124
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 22                  R$/l                1.098  ...                 1.890
# 49                  R$/l                1.092  ...                 1.499
# 76                  R$/l                1.103  ...                 1.589
# 103                 R$/l                1.149  ...                 1.599
# 130                 R$/l                1.165  ...                 1.599
# ...                  ...                  ...  ...                   ...
# 106718              R$/l                3.569  ...                 4.059
# 106745              R$/l                3.697  ...                 4.389
# 106772              R$/l                4.928  ...                 5.859
# 106799           R$/13Kg               65.010  ...                79.000
# 106817             R$/m3                3.111  ...                 3.799
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                     0.312                     0.140
# 49                     0.284                     0.144
# 76                     0.281                     0.127
# 103                      0.3                     0.136
# 130                    0.254                     0.132
# ...                      ...                       ...
# 106718                 0.467                     0.047
# 106745                   0.5                     0.051
# 106772                 0.538                     0.033
# 106799                17.475                     0.089
# 106817                 0.707                     0.084
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                        0.786                       0.173
# 49                        0.808                       0.175
# 76                        0.822                       0.166
# 103                       0.849                       0.188
# 130                       0.911                       0.198
# ...                         ...                         ...
# 106718                    3.102                       0.119
# 106745                    3.197                       0.127
# 106772                     4.39                       0.097
# 106799                   47.535                       3.934
# 106817                    2.404                       0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 49                        0.3257                    1.2921
# 76                       0.38909                    1.1859
# 103                       0.3453                    1.3667
# 130                          0.4                    1.3667
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 22                              0.22   5  2004
# 49                             0.217   5  2004
# 76                             0.202   5  2004
# 103                            0.221   5  2004
# 130                            0.217   6  2004
# ...                              ...  ..   ...
# 106718                         0.038   6  2019
# 106745                          0.04   6  2019
# 106772                         0.022   6  2019
# 106799                         0.083   6  2019
# 106817                         0.072   6  2019
#
# [4263 rows x 22 columns]

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO  \
# 2501            2501        2501   2006-02-26  2006-03-04  SUDESTE
# 2528            2528        2528   2006-03-05  2006-03-11  SUDESTE
# 2555            2555        2555   2006-03-12  2006-03-18  SUDESTE
# 2582            2582        2582   2006-03-19  2006-03-25  SUDESTE
# 2609            2609        2609   2006-03-26  2006-04-01  SUDESTE
# ...              ...         ...          ...         ...      ...
# 106718        106718      106718   2019-06-23  2019-06-29  SUDESTE
# 106745        106745      106745   2019-06-23  2019-06-29  SUDESTE
# 106772        106772      106772   2019-06-23  2019-06-29  SUDESTE
# 106799        106799      106799   2019-06-23  2019-06-29  SUDESTE
# 106817        106817      106817   2019-06-23  2019-06-29  SUDESTE
#
#                 ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 2501    RIO DE JANEIRO  ETANOL HIDRATADO                           881
# 2528    RIO DE JANEIRO  ETANOL HIDRATADO                           889
# 2555    RIO DE JANEIRO  ETANOL HIDRATADO                           902
# 2582    RIO DE JANEIRO  ETANOL HIDRATADO                           898
# 2609    RIO DE JANEIRO  ETANOL HIDRATADO                           890
# ...                ...               ...                           ...
# 106718  RIO DE JANEIRO       ÓLEO DIESEL                           212
# 106745  RIO DE JANEIRO   ÓLEO DIESEL S10                           335
# 106772  RIO DE JANEIRO    GASOLINA COMUM                           422
# 106799  RIO DE JANEIRO               GLP                           221
# 106817  RIO DE JANEIRO               GNV                           124
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 2501                R$/l                2.028  ...                 2.550
# 2528                R$/l                2.125  ...                 2.550
# 2555                R$/l                2.163  ...                 2.599
# 2582                R$/l                2.166  ...                 2.568
# 2609                R$/l                2.172  ...                 2.550
# ...                  ...                  ...  ...                   ...
# 106718              R$/l                3.569  ...                 4.059
# 106745              R$/l                3.697  ...                 4.389
# 106772              R$/l                4.928  ...                 5.859
# 106799           R$/13Kg               65.010  ...                79.000
# 106817             R$/m3                3.111  ...                 3.799
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2501                   0.222                     0.073
# 2528                   0.286                     0.070
# 2555                   0.268                     0.064
# 2582                   0.231                     0.067
# 2609                   0.209                     0.066
# ...                      ...                       ...
# 106718                 0.467                     0.047
# 106745                   0.5                     0.051
# 106772                 0.538                     0.033
# 106799                17.475                     0.089
# 106817                 0.707                     0.084
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                      1.806                        0.11
# 2528                      1.839                       0.117
# 2555                      1.895                       0.134
# 2582                      1.935                        0.14
# 2609                      1.963                       0.133
# ...                         ...                         ...
# 106718                    3.102                       0.119
# 106745                    3.197                       0.127
# 106772                     4.39                       0.097
# 106799                   47.535                       3.934
# 106817                    2.404                       0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 2501                           0.061   2  2006
# 2528                           0.064   3  2006
# 2555                           0.071   3  2006
# 2582                           0.072   3  2006
# 2609                           0.068   3  2006
# ...                              ...  ..   ...
# 106718                         0.038   6  2019
# 106745                          0.04   6  2019
# 106772                         0.022   6  2019
# 106799                         0.083   6  2019
# 106817                         0.072   6  2019
#
# [3054 rows x 22 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#   ,Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO
# 0  0,0,2004-05-09,2004-05-15,CENTRO OESTE,DISTRIT...
# 1  1,1,2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,E...
# 2  2,2,2004-05-09,2004-05-15,CENTRO OESTE,MATO GR...
# 3  3,3,2004-05-09,2004-05-15,CENTRO OESTE,MATO GR...
# 4  4,4,2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETA...

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)

selecao_final = selecao_1 & selecao_2 & selecao_3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4015499367.py in <cell line: 0>()
# ----> 1 selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
#       2 selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
#       3 selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2)
#       4
#       5 selecao_final = selecao_1 & selecao_2 & selecao_3
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
selecao_final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4287961883.py in <cell line: 0>()
# ----> 1 selecao_final
#
# NameError: name 'selecao_final' is not defined

# %%
data_filtrado = data[selecao_final]
data_filtrado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-845528028.py in <cell line: 0>()
# ----> 1 data_filtrado = data[selecao_final]
#       2 data_filtrado
#
# NameError: name 'selecao_final' is not defined

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao_1]
postos_sp_rj
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2388489282.py in <cell line: 0>()
# ----> 1 selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
#       2 postos_sp_rj = data[selecao_1]
#       3 postos_sp_rj
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %%
selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]
postos_sp_rj_gasolina
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-956183489.py in <cell line: 0>()
# ----> 1 selecao_2 = (postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM')
#       2 postos_sp_rj_gasolina = postos_sp_rj[selecao_2]
#       3 postos_sp_rj_gasolina
#
# NameError: name 'postos_sp_rj' is not defined

# %%
selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)
postos_sp_rj_maior_que_2 = postos_sp_rj_gasolina[selecao_3]
postos_sp_rj_maior_que_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-924083414.py in <cell line: 0>()
# ----> 1 selecao_3 = (postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2)
#       2 postos_sp_rj_maior_que_2 = postos_sp_rj_gasolina[selecao_3]
#       3 postos_sp_rj_maior_que_2
#
# NameError: name 'postos_sp_rj_gasolina' is not defined

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data['ANO'] == 2008) | (data['ANO'] == 2009) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
display(data[selecao].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ANO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-97434239.py in <cell line: 0>()
# ----> 1 selecao = (data['ANO'] == 2008) | (data['ANO'] == 2009) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
#       2 display(data[selecao].head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ANO'

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos = [2008, 2010, 2012]

# %%
lista_de_anos = [2008, 2010, 2012]
selecao = data['ANO'].isin(lista_de_anos)
display(data[selecao].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ANO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-442274604.py in <cell line: 0>()
#       1 lista_de_anos = [2008, 2010, 2012]
# ----> 2 selecao = data['ANO'].isin(lista_de_anos)
#       3 display(data[selecao].head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ANO'

# %%
print(data.columns)
# Out:
# Index([',Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO'], dtype='object')

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
for index, row in data.head(10).iterrows():
  print(f'indice{index} ==> {row["ESTADO"]}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ESTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2597304287.py in <cell line: 0>()
#       1 for index, row in data.head(10).iterrows():
# ----> 2   print(f'indice{index} ==> {row["ESTADO"]}')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ESTADO'

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data
# Out:
#        ,Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO
# 0       0,0,2004-05-09,2004-05-15,CENTRO OESTE,DISTRIT...
# 1       1,1,2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,E...
# 2       2,2,2004-05-09,2004-05-15,CENTRO OESTE,MATO GR...
# 3       3,3,2004-05-09,2004-05-15,CENTRO OESTE,MATO GR...
# 4       4,4,2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETA...
# ...                                                   ...
# 106818  106818,106818,2019-06-23,2019-06-29,NORDESTE,R...
# 106819  106819,106819,2019-06-23,2019-06-29,SUL,RIO GR...
# 106820  106820,106820,2019-06-23,2019-06-29,SUL,SANTA ...
# 106821  106821,106821,2019-06-23,2019-06-29,SUDESTE,SA...
# 106822  106822,106822,2019-06-23,2019-06-29,NORDESTE,S...
#
# [106823 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                    --------------   -----
#  0   ,Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO  106823 non-null  object
# dtypes: object(1)
# memory usage: 834.7+ KB

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
 data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])
data_pre.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATA INICIAL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2763738909.py in <cell line: 0>()
# ----> 1 data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
#       2 data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])
#       3 data_pre.info()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'DATA INICIAL'

# %% [markdown]
# #### **Dados Numéricos**

# %%
for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
 data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MARGEM MÉDIA REVENDA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-617978465.py in <cell line: 0>()
#       1 for atributo in ['MARGEM MÉDIA REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO', 'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
# ----> 2  data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'MARGEM MÉDIA REVENDA'

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                    --------------   -----
#  0   ,Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO  106823 non-null  object
# dtypes: object(1)
# memory usage: 834.7+ KB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()
data_pre[mask]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PREÇO MÉDIO DISTRIBUIÇÃO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3789362481.py in <cell line: 0>()
# ----> 1 mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()
#       2 data_pre[mask]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'PREÇO MÉDIO DISTRIBUIÇÃO'

# %%
data_pre[mask]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2742747452.py in <cell line: 0>()
# ----> 1 data_pre[mask]
#
# NameError: name 'mask' is not defined

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
# Retorna uma cópia do data fram `data_pre` com todos os valores NaN de todas as colunas agora preenchidos com 0.
# Para alterar o próprio data frame, use o argumento `inplace=True`.

data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        ,Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO
# 0       0,0,2004-05-09,2004-05-15,CENTRO OESTE,DISTRIT...
# 1       1,1,2004-05-09,2004-05-15,CENTRO OESTE,GOIAS,E...
# 2       2,2,2004-05-09,2004-05-15,CENTRO OESTE,MATO GR...
# 3       3,3,2004-05-09,2004-05-15,CENTRO OESTE,MATO GR...
# 4       4,4,2004-05-09,2004-05-15,NORDESTE,ALAGOAS,ETA...
# ...                                                   ...
# 106818  106818,106818,2019-06-23,2019-06-29,NORDESTE,R...
# 106819  106819,106819,2019-06-23,2019-06-29,SUL,RIO GR...
# 106820  106820,106820,2019-06-23,2019-06-29,SUL,SANTA ...
# 106821  106821,106821,2019-06-23,2019-06-29,SUDESTE,SA...
# 106822  106822,106822,2019-06-23,2019-06-29,NORDESTE,S...
#
# [106823 rows x 1 columns]

# %%
data_pre_fill[mask]  # valores que antes eram NaN, agora são 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-580498602.py in <cell line: 0>()
# ----> 1 data_pre_fill[mask]  # valores que antes eram NaN, agora são 0
#
# NameError: name 'mask' is not defined

# %%
# retorna uma cópia do data frame `data_pre` com todos os valores NaN das colunas:
# 'PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO' e 'PREÇO MÁXIMO DISTRIBUIÇÃO', respectivamente, com os valores: 10, 20, 30, 'vazio'.
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'
})

data_pre_fill[mask]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1881108101.py in <cell line: 0>()
#       8 })
#       9
# ---> 10 data_pre_fill[mask]
#      11
#
# NameError: name 'mask' is not defined

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
# remove, no próprio dataframe, todas as linhas/registros com valores NaN (vazios) em quaisquer colunas/atributos.
data_pre.dropna(inplace=True)
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                    Non-Null Count   Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                    --------------   -----
#  0   ,Unnamed: 0,DATA INICIAL,DATA FINAL,REGIÃO,ESTADO,PRODUTO,NÚMERO DE POSTOS PESQUISADOS,UNIDADE DE MEDIDA,PREÇO MÉDIO REVENDA,DESVIO PADRÃO REVENDA,PREÇO MÍNIMO REVENDA,PREÇO MÁXIMO REVENDA,MARGEM MÉDIA REVENDA,COEF DE VARIAÇÃO REVENDA,PREÇO MÉDIO DISTRIBUIÇÃO,DESVIO PADRÃO DISTRIBUIÇÃO,PREÇO MÍNIMO DISTRIBUIÇÃO,PREÇO MÁXIMO DISTRIBUIÇÃO,COEF DE VARIAÇÃO DISTRIBUIÇÃO,MÊS,ANO  106823 non-null  object
# dtypes: object(1)
# memory usage: 834.7+ KB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv', index=False\)
# Out:
#   File "/tmp/ipython-input-560306730.py", line 1
#     data_pre.to_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv', index=False\)
#                                                                                                               ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv('/content/drive/MyDrive/Trilha de Dados/GasPricesinBrazil_2004-2019 (1).csv')
data_final
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 106818        106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819        106819      106819   2019-06-23  2019-06-29           SUL
# 106820        106820      106820   2019-06-23  2019-06-29           SUL
# 106821        106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822        106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 106818             R$/m3                3.574  ...                 3.690
# 106819             R$/m3                3.401  ...                 3.789
# 106820             R$/m3                2.912  ...                 3.499
# 106821             R$/m3                3.020  ...                 3.490
# 106822             R$/m3                3.697  ...                 3.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 22 columns]

# %%
data_final.describe()
# Out:
#        Unnamed: 0.1    Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  106823.00000  106823.00000                 106823.000000
# mean    53411.00000   53411.00000                    233.770976
# std     30837.28824   30837.28824                    403.282519
# min         0.00000       0.00000                      1.000000
# 25%     26705.50000   26705.50000                     42.000000
# 50%     53411.00000   53411.00000                    104.000000
# 75%     80116.50000   80116.50000                    243.000000
# max    106822.00000  106822.00000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        106823.000000          106823.000000         106823.000000
# mean             10.870780               0.657227              9.416038
# std              17.752533               1.349169             15.092193
# min               0.766000               0.000000              0.590000
# 25%               2.072000               0.072000              1.900000
# 50%               2.718000               0.114000              2.510000
# 75%               3.752000               0.191000              3.499000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA            MÊS  \
# count         106823.000000             106823.000000  106823.000000
# mean              12.537731                  0.045418       6.484006
# std               20.841497                  0.025066       3.443391
# min                0.999000                  0.000000       1.000000
# 25%                2.310000                  0.029000       4.000000
# 50%                2.999000                  0.041000       6.000000
# 75%                4.150000                  0.058000       9.000000
# max              120.000000                  0.395000      12.000000
#
#                  ANO
# count  106823.000000
# mean     2011.802271
# std         4.391530
# min      2004.000000
# 25%      2008.000000
# 50%      2012.000000
# 75%      2016.000000
# max      2019.000000

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    106823.000000
# mean         10.870780
# std          17.752533
# min           0.766000
# 25%           2.072000
# 50%           2.718000
# 75%           3.752000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    106823.000000
# mean         10.870780
# std          17.752533
# min           0.766000
# 25%           2.072000
# 50%           2.718000
# 75%           3.752000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()
stats
# Out:
#        Unnamed: 0.1    Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  106823.00000  106823.00000                 106823.000000
# mean    53411.00000   53411.00000                    233.770976
# std     30837.28824   30837.28824                    403.282519
# min         0.00000       0.00000                      1.000000
# 25%     26705.50000   26705.50000                     42.000000
# 50%     53411.00000   53411.00000                    104.000000
# 75%     80116.50000   80116.50000                    243.000000
# max    106822.00000  106822.00000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        106823.000000          106823.000000         106823.000000
# mean             10.870780               0.657227              9.416038
# std              17.752533               1.349169             15.092193
# min               0.766000               0.000000              0.590000
# 25%               2.072000               0.072000              1.900000
# 50%               2.718000               0.114000              2.510000
# 75%               3.752000               0.191000              3.499000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA            MÊS  \
# count         106823.000000             106823.000000  106823.000000
# mean              12.537731                  0.045418       6.484006
# std               20.841497                  0.025066       3.443391
# min                0.999000                  0.000000       1.000000
# 25%                2.310000                  0.029000       4.000000
# 50%                2.999000                  0.041000       6.000000
# 75%                4.150000                  0.058000       9.000000
# max              120.000000                  0.395000      12.000000
#
#                  ANO
# count  106823.000000
# mean     2011.802271
# std         4.391530
# min      2004.000000
# 25%      2008.000000
# 50%      2012.000000
# 75%      2016.000000
# max      2019.000000

# %%
stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-683104944.py in <cell line: 0>()
# ----> 1 stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['PREÇO MÉDIO DISTRIBUIÇÃO'] not in index"

# %%
# ALTERNATIVA MAIS EFICIENTE
# apenas computa as estatísticas descritivas para 3 atributos
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA
# count        106823.000000         106823.000000
# mean             10.870780             12.537731
# std              17.752533             20.841497
# min               0.766000              0.999000
# 25%               2.072000              2.310000
# 50%               2.718000              2.999000
# 75%               3.752000              4.150000
# max              99.357000            120.000000

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#        Unnamed: 0.1    Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count  106823.00000  106823.00000                 106823.000000
# mean    53411.00000   53411.00000                    233.770976
# std     30837.28824   30837.28824                    403.282519
# min         0.00000       0.00000                      1.000000
# 25%     26705.50000   26705.50000                     42.000000
# 50%     53411.00000   53411.00000                    104.000000
# 75%     80116.50000   80116.50000                    243.000000
# max    106822.00000  106822.00000                   4167.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count        106823.000000          106823.000000         106823.000000
# mean             10.870780               0.657227              9.416038
# std              17.752533               1.349169             15.092193
# min               0.766000               0.000000              0.590000
# 25%               2.072000               0.072000              1.900000
# 50%               2.718000               0.114000              2.510000
# 75%               3.752000               0.191000              3.499000
# max              99.357000              10.748000             90.000000
#
#        PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA            MÊS  \
# count         106823.000000             106823.000000  106823.000000
# mean              12.537731                  0.045418       6.484006
# std               20.841497                  0.025066       3.443391
# min                0.999000                  0.000000       1.000000
# 25%                2.310000                  0.029000       4.000000
# 50%                2.999000                  0.041000       6.000000
# 75%                4.150000                  0.058000       9.000000
# max              120.000000                  0.395000      12.000000
#
#                  ANO
# count  106823.000000
# mean     2011.802271
# std         4.391530
# min      2004.000000
# 25%      2008.000000
# 50%      2012.000000
# 75%      2016.000000
# max      2019.000000

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       Unnamed: 0.1  Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# min            0.0         0.0                      1.000000
# max       106822.0    106822.0                   4167.000000
# mean       53411.0     53411.0                    233.770976
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# min               0.76600               0.000000              0.590000
# max              99.35700              10.748000             90.000000
# mean             10.87078               0.657227              9.416038
#
#       PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA        MÊS          ANO
# min               0.999000                  0.000000   1.000000  2004.000000
# max             120.000000                  0.395000  12.000000  2019.000000
# mean             12.537731                  0.045418   6.484006  2011.802271

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3345973522.py in <cell line: 0>()
# ----> 1 stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1373         # ugly hack for GH #836
#    1374         if self._multi_take_opportunity(tup):
# -> 1375             return self._multi_take(tup)
#    1376
#    1377         return self._getitem_tuple_same_dim(tup)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _multi_take(self, tup)
#    1325         # GH 836
#    1326         d = {
# -> 1327             axis: self._get_listlike_indexer(key, axis)
#    1328             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1329         }
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1556         axis_name = self.obj._get_axis_name(axis)
#    1557
# -> 1558         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1559
#    1560         return keyarr, indexer
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['PREÇO MÉDIO DISTRIBUIÇÃO'] not in index"

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.42 +- 15.09

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts()  # retorna em ordem decrescente, a quantidade de registros/linhas para cada estado
# Out:
# ESTADO
# PARAIBA                4263
# BAHIA                  4263
# CEARA                  4263
# RIO GRANDE DO SUL      4263
# RIO DE JANEIRO         4263
# SAO PAULO              4263
# PERNAMBUCO             4262
# RIO GRANDE DO NORTE    4262
# SANTA CATARINA         4262
# MINAS GERAIS           4261
# ESPIRITO SANTO         4260
# SERGIPE                4259
# PARANA                 4251
# ALAGOAS                4250
# MATO GROSSO DO SUL     4246
# MATO GROSSO            4037
# AMAZONAS               3889
# GOIAS                  3663
# PIAUI                  3548
# MARANHAO               3499
# PARA                   3497
# DISTRITO FEDERAL       3483
# TOCANTINS              3483
# ACRE                   3480
# RONDONIA               3479
# RORAIMA                3471
# AMAPA                  3403
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts()  # retorna em ordem decrescente, a quantidade de registros/linhas para cada estado
# Out:
# ESTADO
# PARAIBA                4263
# BAHIA                  4263
# CEARA                  4263
# RIO GRANDE DO SUL      4263
# RIO DE JANEIRO         4263
# SAO PAULO              4263
# PERNAMBUCO             4262
# RIO GRANDE DO NORTE    4262
# SANTA CATARINA         4262
# MINAS GERAIS           4261
# ESPIRITO SANTO         4260
# SERGIPE                4259
# PARANA                 4251
# ALAGOAS                4250
# MATO GROSSO DO SUL     4246
# MATO GROSSO            4037
# AMAZONAS               3889
# GOIAS                  3663
# PIAUI                  3548
# MARANHAO               3499
# PARA                   3497
# DISTRITO FEDERAL       3483
# TOCANTINS              3483
# ACRE                   3480
# RONDONIA               3479
# RORAIMA                3471
# AMAPA                  3403
# Name: count, dtype: int64

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
def nossa_soma(series):
    return series.sum()  # retorna a soma de todos os valores de uma series

# %%
# aplica a função soma para cada linha do dataframe
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1344063707.py in <cell line: 0>()
#       1 # aplica a função soma para cada linha do dataframe
# ----> 2 df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
#       3 df
#
# NameError: name 'df' is not defined

# %%
# aplica a função soma para cada coluna do dataframe
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1661944616.py in <cell line: 0>()
#       1 # aplica a função soma para cada coluna do dataframe
# ----> 2 df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
#       3 df
#       4
#
# NameError: name 'df' is not defined

# %%
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1531815242.py in <cell line: 0>()
# ----> 1 df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
#       2 df
#
# NameError: name 'df' is not defined

# %%
# plica a lambda function abaixo para cada elemento da coluna
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3014938055.py in <cell line: 0>()
#       1 # plica a lambda function abaixo para cada elemento da coluna
# ----> 2 df['C * 2'] = df['C'].apply(lambda x: x * 2)
#       3 df
#
# NameError: name 'df' is not defined

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3294854075.py in <cell line: 0>()
# ----> 1 df['A * 2'] = df['A'] * 2
#       2 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %%
# agrupa as linhas da tablea de acordo com suas respectivas regiões
grupos = data_final.groupby('REGIÃO')
grupos

# %%
# retorna os grupos obtidos pelo groupby
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
# retorna os índices das linhas/observações de cada grupo
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 106791, 106792, 106812]),
#  'NORDESTE': array([     4,      5,      6, ..., 106816, 106818, 106822]),
#  'NORTE': array([    13,     14,     15, ..., 106802, 106803, 106807]),
#  'SUDESTE': array([    20,     21,     22, ..., 106813, 106817, 106821]),
#  'SUL': array([    24,     25,     26, ..., 106815, 106819, 106820])}

# %%
# retorna um dataframe apenas com as observações do grupo 'CENTRO OESTE'
grupos.get_group('CENTRO OESTE')
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 27                27          27   2004-05-16  2004-05-22  CENTRO OESTE
# ...              ...         ...          ...         ...           ...
# 106787        106787      106787   2019-06-23  2019-06-29  CENTRO OESTE
# 106789        106789      106789   2019-06-23  2019-06-29  CENTRO OESTE
# 106791        106791      106791   2019-06-23  2019-06-29  CENTRO OESTE
# 106792        106792      106792   2019-06-23  2019-06-29  CENTRO OESTE
# 106812        106812      106812   2019-06-23  2019-06-29  CENTRO OESTE
#
#                     ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0         DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                    GOIAS  ETANOL HIDRATADO                           387
# 2              MATO GROSSO  ETANOL HIDRATADO                           192
# 3       MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 27        DISTRITO FEDERAL  ETANOL HIDRATADO                           144
# ...                    ...               ...                           ...
# 106787    DISTRITO FEDERAL               GLP                            42
# 106789               GOIAS               GLP                           209
# 106791         MATO GROSSO               GLP                            95
# 106792  MATO GROSSO DO SUL               GLP                           115
# 106812  MATO GROSSO DO SUL               GNV                             2
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 27                  R$/l                1.271  ...                 1.300
# ...                  ...                  ...  ...                   ...
# 106787           R$/13Kg               73.452  ...                95.000
# 106789           R$/13Kg               71.968  ...                85.000
# 106791           R$/13Kg               96.691  ...               115.000
# 106792           R$/13Kg               72.297  ...                99.000
# 106812             R$/m3                2.934  ...                 2.968
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 27                     0.448                     0.031
# ...                      ...                       ...
# 106787                21.509                     0.066
# 106789                15.044                     0.075
# 106791                19.789                     0.071
# 106792                16.707                     0.111
# 106812                 0.901                     0.017
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 27                        0.823                       0.111
# ...                         ...                         ...
# 106787                   51.943                       7.877
# 106789                   56.924                       4.285
# 106791                   76.902                       8.846
# 106792                    55.59                       5.109
# 106812                    2.033                       0.259
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 27                        0.4094                    1.1931
# ...                          ...                       ...
# 106787                        44                     62.82
# 106789                     45.57                      61.6
# 106791                     61.15                        90
# 106792                        47                        72
# 106812                      1.85                    2.2161
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 27                             0.135   5  2004
# ...                              ...  ..   ...
# 106787                         0.152   6  2019
# 106789                         0.075   6  2019
# 106791                         0.115   6  2019
# 106792                         0.092   6  2019
# 106812                         0.127   6  2019
#
# [15429 rows x 22 columns]

# %%
# descreva para nós algumas estatística descritivas para as observações de cada grupo
grupos.describe()
# Out:
#              Unnamed: 0.1                                              \
#                     count          mean           std   min       25%
# REGIÃO
# CENTRO OESTE      15429.0  53417.968955  30938.517860   0.0  26021.00
# NORDESTE          36869.0  53538.276248  30636.581838   4.0  27645.00
# NORTE             24702.0  52805.662214  31594.475085  13.0  23848.25
# SUDESTE           17047.0  53749.005104  30386.889753  20.0  28766.50
# SUL               12776.0  53754.692001  30391.714995  24.0  28743.75
#
#                                           Unnamed: 0                ...   MÊS  \
#                   50%       75%       max      count          mean  ...   75%
# REGIÃO                                                              ...
# CENTRO OESTE  54240.0  80018.00  106812.0    15429.0  53417.968955  ...  9.00
# NORDESTE      53027.0  80098.00  106822.0    36869.0  53538.276248  ...  9.00
# NORTE         54009.5  80299.50  106807.0    24702.0  52805.662214  ...  9.00
# SUDESTE       52829.0  80048.50  106821.0    17047.0  53749.005104  ...  9.00
# SUL           52859.5  80059.75  106820.0    12776.0  53754.692001  ...  9.25
#
#                         ANO                                                 \
#                max    count         mean       std     min     25%     50%
# REGIÃO
# CENTRO OESTE  12.0  15429.0  2011.862532  4.352302  2004.0  2008.0  2012.0
# NORDESTE      12.0  36869.0  2011.777699  4.404509  2004.0  2008.0  2012.0
# NORTE         12.0  24702.0  2011.832524  4.386504  2004.0  2008.0  2012.0
# SUDESTE       12.0  17047.0  2011.775796  4.399684  2004.0  2008.0  2012.0
# SUL           12.0  12776.0  2011.777239  4.399609  2004.0  2008.0  2012.0
#
#
#                  75%     max
# REGIÃO
# CENTRO OESTE  2016.0  2019.0
# NORDESTE      2016.0  2019.0
# NORTE         2016.0  2019.0
# SUDESTE       2016.0  2019.0
# SUL           2016.0  2019.0
#
# [5 rows x 80 columns]

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3176563243.py in <cell line: 0>()
# ----> 1 grupos.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
grupos.min()
# Out:
#               Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL  \
# REGIÃO
# CENTRO OESTE             0           0   2004-05-09  2004-05-15
# NORDESTE                 4           4   2004-05-09  2004-05-15
# NORTE                   13          13   2004-05-09  2004-05-15
# SUDESTE                 20          20   2004-05-09  2004-05-15
# SUL                     24          24   2004-05-09  2004-05-15
#
#                         ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE               ALAGOAS  ETANOL HIDRATADO
# NORTE                     ACRE  ETANOL HIDRATADO
# SUDESTE         ESPIRITO SANTO  ETANOL HIDRATADO
# SUL                     PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                1.097                    0.0  ...
# NORDESTE                    0.975                    0.0  ...
# NORTE                       1.219                    0.0  ...
# SUDESTE                     0.766                    0.0  ...
# SUL                         0.922                    0.0  ...
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                 1.099                     -
# NORDESTE                     0.999                     -
# NORTE                        1.219                     -
# SUDESTE                      1.099                     -
# SUL                          1.199                     -
#
#              COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                      0.0                         -
# NORDESTE                          0.0                         -
# NORTE                             0.0                         -
# SUDESTE                           0.0                         -
# SUL                               0.0                         -
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                          -                         -
# NORDESTE                              -                         -
# NORTE                                 -                         -
# SUDESTE                               -                         -
# SUL                                   -                         -
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# REGIÃO
# CENTRO OESTE                         -                             -   1  2004
# NORDESTE                             -                             -   1  2004
# NORTE                                -                             -   1  2004
# SUDESTE                              -                             -   1  2004
# SUL                                  -                             -   1  2004
#
# [5 rows x 21 columns]

# %%
data_final.groupby('REGIÃO').min()
# Out:
#               Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL  \
# REGIÃO
# CENTRO OESTE             0           0   2004-05-09  2004-05-15
# NORDESTE                 4           4   2004-05-09  2004-05-15
# NORTE                   13          13   2004-05-09  2004-05-15
# SUDESTE                 20          20   2004-05-09  2004-05-15
# SUL                     24          24   2004-05-09  2004-05-15
#
#                         ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE               ALAGOAS  ETANOL HIDRATADO
# NORTE                     ACRE  ETANOL HIDRATADO
# SUDESTE         ESPIRITO SANTO  ETANOL HIDRATADO
# SUL                     PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                1.097                    0.0  ...
# NORDESTE                    0.975                    0.0  ...
# NORTE                       1.219                    0.0  ...
# SUDESTE                     0.766                    0.0  ...
# SUL                         0.922                    0.0  ...
#
#               PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                 1.099                     -
# NORDESTE                     0.999                     -
# NORTE                        1.219                     -
# SUDESTE                      1.099                     -
# SUL                          1.199                     -
#
#              COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                      0.0                         -
# NORDESTE                          0.0                         -
# NORTE                             0.0                         -
# SUDESTE                           0.0                         -
# SUL                               0.0                         -
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                          -                         -
# NORDESTE                              -                         -
# NORTE                                 -                         -
# SUDESTE                               -                         -
# SUL                                   -                         -
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# REGIÃO
# CENTRO OESTE                         -                             -   1  2004
# NORDESTE                             -                             -   1  2004
# NORTE                                -                             -   1  2004
# SUDESTE                              -                             -   1  2004
# SUL                                  -                             -   1  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0             0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1             1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2             2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3             3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4             4           4   2004-05-09  2004-05-15      NORDESTE
#
#                ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0    DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1               GOIAS  ETANOL HIDRATADO                           387
# 2         MATO GROSSO  ETANOL HIDRATADO                           192
# 3  MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4             ALAGOAS  ETANOL HIDRATADO                           103
#
#   UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0              R$/l                1.288  ...                 1.350
# 1              R$/l                1.162  ...                 1.449
# 2              R$/l                1.389  ...                 1.760
# 3              R$/l                1.262  ...                 1.509
# 4              R$/l                1.181  ...                 1.400
#
#    MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                     0.012                    0.825
# 1                 0.399                     0.098                    0.763
# 2                 0.419                     0.070                     0.97
# 3                 0.432                     0.055                     0.83
# 4                  0.24                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 22 columns]

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                  columns=['A', 'B', 'C'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3186067447.py in <cell line: 0>()
#       2                    [4, 5, 6],
#       3                    [7, 8, 9],
# ----> 4                    [np.nan, np.nan, np.nan]],
#       5                   columns=['A', 'B', 'C'])
#       6 df
#
# NameError: name 'np' is not defined

# %%
df.agg([sum, min])  # ignora o NaN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1900601191.py in <cell line: 0>()
# ----> 1 df.agg([sum, min])  # ignora o NaN
#
# NameError: name 'df' is not defined

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
# Computa o menor e maior valor do 'PREÇO MÉDIO REVENDA' para cada região (grupo)
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
# /tmp/ipython-input-2444597663.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# /tmp/ipython-input-2444597663.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.219  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_final
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 106818        106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819        106819      106819   2019-06-23  2019-06-29           SUL
# 106820        106820      106820   2019-06-23  2019-06-29           SUL
# 106821        106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822        106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 106818             R$/m3                3.574  ...                 3.690
# 106819             R$/m3                3.401  ...                 3.789
# 106820             R$/m3                2.912  ...                 3.499
# 106821             R$/m3                3.020  ...                 3.490
# 106822             R$/m3                3.697  ...                 3.699
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 22 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %%
data_final.query('ANO != 2019')
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 103064        103064      103064   2018-12-30  2019-01-05      NORDESTE
# 103065        103065      103065   2018-12-30  2019-01-05           SUL
# 103066        103066      103066   2018-12-30  2019-01-05           SUL
# 103067        103067      103067   2018-12-30  2019-01-05       SUDESTE
# 103068        103068      103068   2018-12-30  2019-01-05      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103064  RIO GRANDE DO NORTE               GNV                            10
# 103065    RIO GRANDE DO SUL               GNV                            16
# 103066       SANTA CATARINA               GNV                            15
# 103067            SAO PAULO               GNV                            41
# 103068              SERGIPE               GNV                             2
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 103064             R$/m3                3.465  ...                 3.590
# 103065             R$/m3                3.402  ...                 3.499
# 103066             R$/m3                2.944  ...                 3.199
# 103067             R$/m3                2.353  ...                 3.429
# 103068             R$/m3                3.649  ...                 3.649
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 103064                 0.759                     0.017
# 103065                 1.296                     0.030
# 103066                  0.67                     0.042
# 103067                 0.467                     0.192
# 103068                     -                     0.000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 103064                    2.706                           0
# 103065                    2.106                       0.249
# 103066                    2.274                       0.283
# 103067                    1.886                        0.25
# 103068                        -                           -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 103064                    2.7059                    2.7059
# 103065                    1.8775                    2.3724
# 103066                    1.8738                     2.274
# 103067                      1.64                     2.332
# 103068                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 103064                             0  12  2018
# 103065                         0.118  12  2018
# 103066                         0.124  12  2018
# 103067                         0.133  12  2018
# 103068                             -  12  2018
#
# [103069 rows x 22 columns]

# %%
df = data_final.query('ANO != 2019')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                  0           0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                  1           1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                  2           2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                  3           3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                  4           4   2004-05-09  2004-05-15      NORDESTE
# ...              ...         ...          ...         ...           ...
# 103064        103064      103064   2018-12-30  2019-01-05      NORDESTE
# 103065        103065      103065   2018-12-30  2019-01-05           SUL
# 103066        103066      103066   2018-12-30  2019-01-05           SUL
# 103067        103067      103067   2018-12-30  2019-01-05       SUDESTE
# 103068        103068      103068   2018-12-30  2019-01-05      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 103064  RIO GRANDE DO NORTE               GNV                            10
# 103065    RIO GRANDE DO SUL               GNV                            16
# 103066       SANTA CATARINA               GNV                            15
# 103067            SAO PAULO               GNV                            41
# 103068              SERGIPE               GNV                             2
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                   R$/l                1.288  ...                 1.350
# 1                   R$/l                1.162  ...                 1.449
# 2                   R$/l                1.389  ...                 1.760
# 3                   R$/l                1.262  ...                 1.509
# 4                   R$/l                1.181  ...                 1.400
# ...                  ...                  ...  ...                   ...
# 103064             R$/m3                3.465  ...                 3.590
# 103065             R$/m3                3.402  ...                 3.499
# 103066             R$/m3                2.944  ...                 3.199
# 103067             R$/m3                2.353  ...                 3.429
# 103068             R$/m3                3.649  ...                 3.649
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 103064                 0.759                     0.017
# 103065                 1.296                     0.030
# 103066                  0.67                     0.042
# 103067                 0.467                     0.192
# 103068                     -                     0.000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 103064                    2.706                           0
# 103065                    2.106                       0.249
# 103066                    2.274                       0.283
# 103067                    1.886                        0.25
# 103068                        -                           -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 103064                    2.7059                    2.7059
# 103065                    1.8775                    2.3724
# 103066                    1.8738                     2.274
# 103067                      1.64                     2.332
# 103068                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 103064                             0  12  2018
# 103065                         0.118  12  2018
# 103066                         0.124  12  2018
# 103067                         0.133  12  2018
# 103068                             -  12  2018
#
# [103069 rows x 22 columns]

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %%
grupos = df.groupby('PRODUTO')
grupos

# %%
grupos['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6839
#                  NORTE          5244
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2279
# GASOLINA COMUM   NORDESTE       6840
#                  NORTE          5319
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2280
# GLP              NORDESTE       6836
#                  NORTE          5319
#                  SUDESTE        3039
#                  CENTRO OESTE   3037
#                  SUL            2280
# GNV              NORDESTE       5398
#                  SUDESTE        3036
#                  SUL            2269
#                  CENTRO OESTE   1493
#                  NORTE           444
# ÓLEO DIESEL      NORDESTE       6840
#                  NORTE          5319
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2280
# ÓLEO DIESEL S10  NORDESTE       2814
#                  NORTE          2184
#                  SUDESTE        1252
#                  CENTRO OESTE   1249
#                  SUL             939

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolina_sp_2018 = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_sp_2018.head()
# Out:
#        Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 95351         95351       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 95502         95502       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 95654         95654       95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# 95806         95806       95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO
# 95958         95958       95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 95351  GASOLINA COMUM                          1641              R$/l
# 95502  GASOLINA COMUM                          1648              R$/l
# 95654  GASOLINA COMUM                          1648              R$/l
# 95806  GASOLINA COMUM                          1644              R$/l
# 95958  GASOLINA COMUM                          1646              R$/l
#
#        PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 95351                3.988  ...                 4.599                 0.411
# 95502                4.002  ...                 4.499                 0.412
# 95654                4.006  ...                 4.899                  0.41
# 95806                4.019  ...                 4.699                 0.423
# 95958                4.004  ...                 4.597                 0.416
#
#        COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 95351                     0.039                    3.577
# 95502                     0.039                     3.59
# 95654                     0.040                    3.596
# 95806                     0.039                    3.596
# 95958                     0.039                    3.588
#
#        DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 95351                       0.104                      2.99
# 95502                       0.102                      2.99
# 95654                       0.102                      2.99
# 95806                       0.107                     2.924
# 95958                       0.102                      2.99
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 95351                     3.951                         0.029   1  2018
# 95502                    3.9014                         0.028   1  2018
# 95654                    3.9014                         0.028   1  2018
# 95806                    3.9537                          0.03   1  2018
# 95958                    3.9537                         0.028   2  2018
#
# [5 rows x 22 columns]

# %%
gasolina_sp_2018.shape
# Out:
# (52, 22)

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
gasolina_sp_2018.describe()
# Out:
#         Unnamed: 0.1     Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# count      52.000000      52.000000                     52.000000
# mean    99196.096154   99196.096154                   1610.211538
# std      2279.595314    2279.595314                    213.627432
# min     95351.000000   95351.000000                    102.000000
# 25%     97281.250000   97281.250000                   1639.000000
# 50%     99196.500000   99196.500000                   1642.000000
# 75%    101116.250000  101116.250000                   1644.000000
# max    103025.000000  103025.000000                   1649.000000
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# count            52.000000              52.000000             52.000000
# mean              4.202769               0.175500              3.671500
# std               0.180672               0.017955              0.163808
# min               3.970000               0.150000              3.369000
# 25%               4.008000               0.159750              3.499000
# 50%               4.202000               0.173000              3.679000
# 75%               4.336250               0.189000              3.784000
# max               4.512000               0.216000              3.969000
#
#        PREÇO MÁXIMO REVENDA  COEF DE VARIAÇÃO REVENDA        MÊS     ANO
# count             52.000000                 52.000000  52.000000    52.0
# mean               4.975750                  0.041750   6.615385  2018.0
# std                0.211198                  0.003965   3.470627     0.0
# min                4.499000                  0.034000   1.000000  2018.0
# 25%                4.899000                  0.039000   4.000000  2018.0
# 50%                4.999000                  0.040000   7.000000  2018.0
# 75%                5.099000                  0.044000   9.250000  2018.0
# max                5.299000                  0.051000  12.000000  2018.0

# %%
gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#         Unnamed: 0.1  Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 95270          95270       95270   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 95351          95351       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 95421          95421       95421   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 95502          95502       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 95573          95573       95573   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...              ...         ...          ...         ...      ...        ...
# 102724        102724      102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 102793        102793      102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 102874        102874      102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 102944        102944      102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 103025        103025      103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 95270   ETANOL HIDRATADO                          1664              R$/l
# 95351     GASOLINA COMUM                          1641              R$/l
# 95421   ETANOL HIDRATADO                          1661              R$/l
# 95502     GASOLINA COMUM                          1648              R$/l
# 95573   ETANOL HIDRATADO                          1662              R$/l
# ...                  ...                           ...               ...
# 102724    GASOLINA COMUM                          1637              R$/l
# 102793  ETANOL HIDRATADO                          1662              R$/l
# 102874    GASOLINA COMUM                          1641              R$/l
# 102944  ETANOL HIDRATADO                          1661              R$/l
# 103025    GASOLINA COMUM                          1643              R$/l
#
#         PREÇO MÉDIO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 95270                 2.833  ...                 3.399                 0.338
# 95351                 3.988  ...                 4.599                 0.411
# 95421                 2.868  ...                 3.399                 0.331
# 95502                 4.002  ...                 4.499                 0.412
# 95573                 2.874  ...                 3.399                 0.324
# ...                     ...  ...                   ...                   ...
# 102724                4.129  ...                 5.099                  0.49
# 102793                2.644  ...                 3.699                 0.305
# 102874                4.129  ...                 4.999                 0.484
# 102944                2.643  ...                 3.699                 0.303
# 103025                4.113  ...                 4.999                 0.503
#
#         COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 95270                      0.049                    2.495
# 95351                      0.039                    3.577
# 95421                      0.047                    2.537
# 95502                      0.039                     3.59
# 95573                      0.047                     2.55
# ...                          ...                      ...
# 102724                     0.049                    3.639
# 102793                     0.062                    2.339
# 102874                     0.049                    3.645
# 102944                     0.061                     2.34
# 103025                     0.049                     3.61
#
#         DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 95270                        0.092                    2.1842
# 95351                        0.104                      2.99
# 95421                        0.087                      2.26
# 95502                        0.102                      2.99
# 95573                        0.095                      1.69
# ...                            ...                       ...
# 102724                        0.11                      3.35
# 102793                       0.094                    2.0067
# 102874                       0.107                      3.35
# 102944                       0.097                    1.9072
# 103025                         0.1                      3.35
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 95270                     2.8833                         0.037   1  2018
# 95351                      3.951                         0.029   1  2018
# 95421                     2.8471                         0.034   1  2018
# 95502                     3.9014                         0.028   1  2018
# 95573                     2.9722                         0.037   1  2018
# ...                          ...                           ...  ..   ...
# 102724                    3.9892                          0.03  12  2018
# 102793                    2.7443                          0.04  12  2018
# 102874                    3.9892                         0.029  12  2018
# 102944                    2.7957                         0.041  12  2018
# 103025                    3.9585                         0.028  12  2018
#
# [104 rows x 22 columns]

# %%
# considerando os preços do etanol e da gasolina juntos, teremos essas estatística descritivas
gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2922556481.py in <cell line: 0>()
#       1 # considerando os preços do etanol e da gasolina juntos, teremos essas estatística descritivas
# ----> 2 gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
#
# NameError: name 'gasolina_etanol_sp_2018' is not defined

# %%
gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-969083219.py in <cell line: 0>()
# ----> 1 gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
#
# NameError: name 'gasolina_etanol_sp_2018' is not defined

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
