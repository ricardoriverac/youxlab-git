# %% [markdown]
# ## 03. Gráficos Estatícos-Parte 1

# %%
# !pip install -U plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Histogramas

# %%
px.histogram(df,x='total_bill',color='time',nbins=50,
             histnorm= 'probability density')

# %% [markdown]
# ## Distribuição

# %%
import plotly.figure_factory as fr
import numpy as np

# %%
x = np.random.randn(1000)

# %%
ff.create_distplot([x], group_labels=['Normal'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ff.create_distplot([x], group_labels=['Normal'])
#
# NameError: name 'ff' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
ff.create_ff.create_distplot(['total_bill'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ff.create_ff.create_distplot(['total_bill'])
#
# NameError: name 'ff' is not defined

# %%
x1 = np.random.randn(1000)
x2 = np.random.randn(1000) + 5

# %%
ff.create_distplot([x1, x2], group_labels=["Normal 1", "Normal 2"])

# %%
df.head()

# %%
ff.create_distplot([ df["total_bill"], df["tip"] ], 
                group_labels=["Total bill", "tips"])
