# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %%
# Conecta com o google drive para extrair a base de dados
from google.colab import drive
drive.mount('/content/drive')

# Caminho padrao para a base de dados
path = '/content/drive/MyDrive/trilia-dados/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv(path + "GasPricesinBrazil_2004-2019.csv")

# %%
from typing_extensions import dataclass_transform
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
data = pd.read_csv(path + "GasPricesinBrazil_2004-2019.csv",
                   sep = ";")

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
data.shape
# Out:
# (106823, 21)

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
print(f'o dataframe possui {data.shape[0]} linhas/atributos/registros e {data.shape[1]} colunas/atributos/variaveis  ')
# Out:
# o dataframe possui 106823 linhas/atributos/registros e 21 colunas/atributos/variaveis

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
alunos_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15, 60],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
alunos_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(alunos_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(alunos_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.rename(columns={
    "nome":" Nome Completo",
    "idade": "Idade Atual"
})
# Out:
#     Nome Completo  Idade Atual  peso  eh jedi
# 0  Luke Skywalker           16    70     True
# 1            Yoda         1000    15     True
# 2       Palpatine           70    60    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data["ESTADO"]
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(data["ESTADO"])
# Out:
# pandas.core.series.Series

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5,9.9,1.0])
# Out:
# 0    5.5
# 1    9.9
# 2    1.0
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5.5,9.9,1.0],index=['prova1','prova2','prova3'],name= 'Notas dos darth vader')
# Out:
# prova1    5.5
# prova2    9.9
# prova3    1.0
# Name: Notas dos darth vader, dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_view= data.head()
produto_view
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data.PRODUTO
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy=data.PRODUTO.copy()
produto_copy
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = 'COMBUSTIVEL' #todos itens da coluna produto vao virar combustivel
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  COMBUSTIVEL                           127              R$/l
# 1  COMBUSTIVEL                           387              R$/l
# 2  COMBUSTIVEL                           192              R$/l
# 3  COMBUSTIVEL                           162              R$/l
# 4  COMBUSTIVEL                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_copy
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nwros, ncols = data.shape
nwros, ncols
# Out:
# (106823, 21)

# %%
novos_produtos =[f'produto {i}'for i in range(nwros)]
len(novos_produtos)
# Out:
# 106823

# %%
data['PRODUTO'] = novos_produtos
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       produto 0                           127
# 1                     GOIAS       produto 1                           387
# 2               MATO GROSSO       produto 2                           192
# 3        MATO GROSSO DO SUL       produto 3                           162
# 4                   ALAGOAS       produto 4                           103
# ...                     ...             ...                           ...
# 106818  RIO GRANDE DO NORTE  produto 106818                             7
# 106819    RIO GRANDE DO SUL  produto 106819                            23
# 106820       SANTA CATARINA  produto 106820                            24
# 106821            SAO PAULO  produto 106821                            52
# 106822              SERGIPE  produto 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
data['PRODUTO'] = produto_copy
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
data['coluna sem noçao'] = "default"
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  coluna sem noçao
# 0                              0.133   5  2004           default
# 1                              0.115   5  2004           default
# 2                              0.098   5  2004           default
# 3                              0.143   5  2004           default
# 4                              0.082   5  2004           default
# ...                              ...  ..   ...               ...
# 106818                             0   6  2019           default
# 106819                         0.164   6  2019           default
# 106820                             0   6  2019           default
# 106821                          0.07   6  2019           default
# 106822                             0   6  2019           default
#
# [106823 rows x 22 columns]

# %%
data['coluna a partir de lista'] = range(data.shape[0])
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        coluna sem noçao  coluna a partir de lista
# 0               default                         0
# 1               default                         1
# 2               default                         2
# 3               default                         3
# 4               default                         4
# ...                 ...                       ...
# 106818          default                    106818
# 106819          default                    106819
# 106820          default                    106820
# 106821          default                    106821
# 106822          default                    106822
#
# [106823 rows x 23 columns]

# %%
data['nao funcinoa']= [1,2,3]
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3716011355.py in <cell line: 0>()
# ----> 1 data['nao funcinoa']= [1,2,3]
#       2 data
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (3) does not match length of index (106823)

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()

# %%
data["PREÇO DE MEDIA (dolares)"] = data["PREÇO MÉDIO REVENDA"] * 6.0
data

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data

# %%
data.index

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()

# %%
pesquisa_de_satisfacao.index

# %%
data.head()

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra/linha:**

# %%
data.iloc[1]

# %%
data.iloc[0:6]

# %% [markdown]
# **Selecionando múltiplias amostras/linhas:**

# %%
data.iloc[[5,9,10,15]]

# %%
data.iloc[[5,2,11,7]]

# %%
data.iloc[1,5]

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao

# %%
pesquisa_de_satisfacao.iloc[0]

# %%
pesquisa_de_satisfacao.loc["Switch"]

# %%
pesquisa_de_satisfacao

# %%
pesquisa_de_satisfacao.loc['Playstation4','ruim']

# %%
pesquisa_de_satisfacao.loc[['XboxOne','Playstation4']]

# %%
pesquisa_de_satisfacao[['bom','pessimo']]

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()

# %%
data.ESTADO

# %%
data.loc[:,'ESTADO']

# %%
data[['ESTADO','PRODUTO','REGIÃO']]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
data.head()

# %%
del data["Unnamed: 0"]

# %%
data

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv( '/content/drive/MyDrive/trilia-dados/GasPricesinBrazil_2004-2019-copia.csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('/content/drive/MyDrive/trilia-dados/GasPricesinBrazil_2004-2019-copia.csv')

# %%
data.head()

# %%
data["ESTADO"].unique()

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
data["ESTADO"]== "SAO PAULO"

# %%
selecao = data["ESTADO"]== "SAO PAULO"

# %%
selecao

# %%
type(selecao)

# %%
selecao.shape

# %%
data.shape

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()

# %%
data.query('ESTADO =="SAO PAULO"')

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de São Paulo.

# %%
posto_sp = data.query('ESTADO =="SAO PAULO"')

# %%
posto_sp

# %%
type(posto_sp)

# %%
posto_sp.shape

# %%
posto_sp.head()

# %%
posto_sp.reset_index()

# %%
posto_sp.reset_index(drop=True)

# %%
posto_sp.reset_index(drop=True,inplace=True)

# %%
posto_sp

# %%
posto_sp = data.query('ESTADO=="SAO PAULO"').reset_index(drop=True)

# %%
posto_sp

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()

# %%
data['ESTADO'] == 'RIO JANIERO'

# %%
data["PREÇO MÉDIO REVENDA"] > 2

# %%
SELECAO = (data['ESTADO'] == 'RIO JANEIRO') & data["PREÇO MÉDIO REVENDA"] > 2
SELECAO

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[SELECAO]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
data.query('ESTADO=="RIO DE JANEIRO" or ESTADO == "SAO PAULO"')

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
seleçao1 =(data['ESTADO'] == 'RIO DE JANEIRO')
posto_rj = data[seleçao1]
posto_rj

# %%
seleçao2 = (posto_rj['PREÇO MÉDIO REVENDA'] > 2)
seleçao2

# %%
preço_maior_que_2 =posto_rj[seleçao2]
preço_maior_que_2

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
gasolina_comum = (data['ESTADO'] == "SAO PAULO")
gasolina_comum2 =(data['PRODUTO'] == 'GASOLINA COMUM')
gasolina_comum3 = (data['PREÇO MÉDIO REVENDA']> 2)
gasolina_comum_final = (gasolina_comum & gasolina_comum2 & gasolina_comum3)
gasolina_comum_final

# %%
data[gasolina_comum_final]

# %% [markdown]
# <br/>
#
# Alternativamente:

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %% [markdown]
# **ALTERNATIVA 1**

# %%
anos = (data['ANO'] == 2008) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
data[anos]

# %% [markdown]
# **ALTERNATIVA 2**

# %%
lista_de_anos =(2008,2010,2012)
data['ANO'].isin(lista_de_anos)

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
for index ,row in data.head(10).iterrows():
  print(f"indice {index} ==> {row['ESTADO']}")

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL']= pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL']= pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()

# %% [markdown]
# #### **Dados Numéricos**

# %%
for atributo in ['MARGEM MÉDIA REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO', 'DESVIO PADRÃO DISTRIBUIÇÃO','PREÇO MÍNIMO DISTRIBUIÇÃO','PREÇO MÁXIMO DISTRIBUIÇÃO']:
 data_pre[atributo]= pd.to_numeric(data_pre[atributo],errors = 'coerce')

# %%
data_pre.info()

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]

# %%
data[mask]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
data_pre_fill = data_pre.fillna(0)
data_pre_fill

# %%
data_pre_fill[mask]

# %%
data_pre[mask]

# %%
data_pre_fill = data_pre.fillna(value={ 'PREÇO MÉDIO DISTRIBUIÇÃO':10,
                                          'DESVIO PADRÃO DISTRIBUIÇÃO':20,
                                           'PREÇO MIŃIMO DISTRIBUIÇÃO': 30,
                                           'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio'})

# %%
data_pre_fill[mask]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
data_pre.dropna(inplace=True)

# %%
data_pre.info()

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('/content/drive/MyDrive/trilia-dados/GasPricesinBrazil_2004-2019-prepocessando_final.csv')

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv('/content/drive/MyDrive/trilia-dados/GasPricesinBrazil_2004-2019-copia.csv')

# %%
data_final.describe()

# %%
coluna_removida = data_final.pop('coluna sem noçao')
coluna_removida = data_final.pop ('coluna a partir de lista')
coluna_removida = data_final.pop ('PREÇO DE MEDIA (dolares)')

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
stats = data_final.describe()
stats

# %%
stats[['PREÇO MÉDIO REVENDA','PREÇO MEÉDIO DISTRIBUIÇÃO']]

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats

# %%
stats.loc[['min','max','mean'],'PREÇO MÉDIO REVENDA']

# %%
stats.loc[['min','max','mean'],['PREÇO MÉDIO REVENDA','PREÇO MÉDIO DISTRIBUIÇÃO']]

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].mean()

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']

# %%
data_final['ESTADO'].unique()

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts()

# %%
data_final['ESTADO'].value_counts().to_frame()

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(linha):
  return linha.sum()

# %%
df['SOMA(A,B,C)'] = df.apply(nossa_soma,axis=1)
df

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
df.apply(nossa_soma,axis=0)
df

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
df['MEDIA(A,B,C)']= df[['A','B','C']].apply(lambda series:series.mean(),axis=1)
df

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
df['C*2'] = df['C'].apply(lambda x: x * 2)
df

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4],
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df

# %%
df.applymap(lambda x: x **2)

# %%
df

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['Joao', 'Maria', 'Alice' , 'Pedro'])
nomes

# %%
nomes.map(lambda x: x.upper())

# %%
nomes.str.upper()

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem noçao  \
# 0                         0.133   5  2004          default
# 1                         0.115   5  2004          default
# 2                         0.098   5  2004          default
# 3                         0.143   5  2004          default
# 4                         0.082   5  2004          default
#
#    coluna a partir de lista  PREÇO DE MEDIA (dolares)
# 0                         0                     7.728
# 1                         1                     6.972
# 2                         2                     8.334
# 3                         3                     7.572
# 4                         4                     7.086
#
# [5 rows x 23 columns]

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 106791, 106792, 106812]),
#  'NORDESTE': array([     4,      5,      6, ..., 106816, 106818, 106822]),
#  'NORTE': array([    13,     14,     15, ..., 106802, 106803, 106807]),
#  'SUDESTE': array([    20,     21,     22, ..., 106813, 106817, 106821]),
#  'SUL': array([    24,     25,     26, ..., 106815, 106819, 106820])}

# %%
grupos.get_group
# Out:
# <bound method BaseGroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7cb52da36ae0>>

# %%
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      15429.0  137.263983  107.396548  1.0   76.0
# NORDESTE                          36869.0  123.194364  112.856327  1.0   40.0
# NORTE                             24702.0   66.249899   53.119277  1.0   29.0
# SUDESTE                           17047.0  713.297002  786.310843  1.0  158.0
# SUL                               12776.0  353.486146  238.387934  1.0  153.0
#
#                                    PREÇO MÉDIO REVENDA             ...  \
#                 50%    75%     max               count       mean  ...
# REGIÃO                                                             ...
# CENTRO OESTE  119.0  178.0   766.0             15429.0  11.843486  ...
# NORDESTE       93.0  167.0   625.0             36869.0  10.097994  ...
# NORTE          52.0   94.0   383.0             24702.0  12.670958  ...
# SUDESTE       403.0  993.0  4167.0             17047.0   9.700178  ...
# SUL           362.0  560.0  1416.0             12776.0  10.007542  ...
#
#              coluna a partir de lista           PREÇO DE MEDIA (dolares)  \
#                                   75%       max                    count
# REGIÃO
# CENTRO OESTE                 80018.00  106812.0                  15429.0
# NORDESTE                     80098.00  106822.0                  36869.0
# NORTE                        80299.50  106807.0                  24702.0
# SUDESTE                      80048.50  106821.0                  17047.0
# SUL                          80059.75  106820.0                  12776.0
#
#
#                    mean         std    min     25%     50%      75%      max
# REGIÃO
# CENTRO OESTE  71.060919  117.624654  6.582  12.606  16.518  22.6560  596.142
# NORDESTE      60.587964   98.749681  5.850  11.928  15.858  21.8460  477.780
# NORTE         76.025748  118.116441  7.314  14.202  17.958  25.3800  523.620
# SUDESTE       58.201066   97.031261  4.596  11.274  15.276  21.2850  475.152
# SUL           60.045250  100.287489  5.532  11.862  15.459  21.0675  432.528
#
# [5 rows x 80 columns]

# %%
grupos.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1316802999.py in <cell line: 0>()
# ----> 1 grupos.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
grupos.min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.219                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                  0.87                 1.099  ...
# NORDESTE                      0.79                 0.999  ...
# NORTE                         1.05                 1.219  ...
# SUDESTE                       0.59                 1.099  ...
# SUL                           0.73                 1.199  ...
#
#              PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                        -                           -
# NORDESTE                            -                           -
# NORTE                               -                           -
# SUDESTE                             -                           -
# SUL                                 -                           -
#
#              PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                         -                         -
# NORDESTE                             -                         -
# NORTE                                -                         -
# SUDESTE                              -                         -
# SUL                                  -                         -
#
#              COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  coluna sem noçao  \
# REGIÃO
# CENTRO OESTE                             -   1  2004           default
# NORDESTE                                 -   1  2004           default
# NORTE                                    -   1  2004           default
# SUDESTE                                  -   1  2004           default
# SUL                                      -   1  2004           default
#
#               coluna a partir de lista PREÇO DE MEDIA (dolares)
# REGIÃO
# CENTRO OESTE                         0                    6.582
# NORDESTE                             4                    5.850
# NORTE                               13                    7.314
# SUDESTE                             20                    4.596
# SUL                                 24                    5.532
#
# [5 rows x 22 columns]

# %%
data_final.groupby('REGIÃO').min
# Out:
# <bound method GroupBy.min of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7cb52daa4740>>

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem noçao  \
# 0                         0.133   5  2004          default
# 1                         0.115   5  2004          default
# 2                         0.098   5  2004          default
# 3                         0.143   5  2004          default
# 4                         0.082   5  2004          default
#
#    coluna a partir de lista  PREÇO DE MEDIA (dolares)
# 0                         0                     7.728
# 1                         1                     6.972
# 2                         2                     8.334
# 3                         3                     7.572
# 4                         4                     7.086
#
# [5 rows x 23 columns]

# %% [markdown]
# Qual e o  preço médio  de cada  Produto (COMBUSTIVIES) pra cada **regiao**

# %%
GRUPOS = data_final.groupby(['REGIÃO','PRODUTO'])
GRUPOS

# %%
GRUPOS.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [12064, 12065, 12066, 12067, 12091, 12092, 12093, 12094, 12118, 12119, 12120, 12121, 12145, 12146, 12147, 12148, 12172, 12173, 12174, 12175, 12199, 12200, 12201, 12202, 12226, 12227, 12228, 12229, 12253, 12254, 12255, 12256, 12280, 12281, 12282, 12283, 12307, 12308, 12309, 12310, 12334, 12335, 12336, 12337, 12361, 12362, 12363, 12364, 12388, 12389, 12390, 12391, 12415, 12416, 12417, 12418, 12442, 12443, 12444, 12445, 12469, 12470, 12471, 12472, 12496, 12497, 12498, 12499, 12523, 12524, 12525, 12526, 12550, 12551, 12552, 12553, 12577, 12578, 12579, 12580, 12604, 12605, 12606, 12607, 12631, 12632, 12633, 12634, 12658, 12659, 12660, 12661, 12685, 12686, 12687, 12688, 12712, 12713, 12714, 12715, ...], ('CENTRO OESTE', 'GLP'): [24132, 24133, 24134, 24135, 24159, 24160, 24161, 24162, 24186, 24187, 24188, 24189, 24213, 24214, 24215, 24216, 24240, 24241, 24242, 24243, 24267, 24268, 24269, 24270, 24294, 24295, 24296, 24297, 24321, 24322, 24323, 24324, 24348, 24349, 24350, 24351, 24375, 24376, 24377, 24378, 24402, 24403, 24404, 24405, 24429, 24430, 24431, 24432, 24456, 24457, 24458, 24459, 24483, 24484, 24485, 24486, 24510, 24511, 24512, 24513, 24537, 24538, 24539, 24540, 24564, 24565, 24566, 24567, 24591, 24592, 24593, 24594, 24618, 24619, 24620, 24621, 24645, 24646, 24647, 24648, 24672, 24673, 24674, 24675, 24699, 24700, 24701, 24702, 24726, 24727, 24728, 24729, 24753, 24754, 24755, 24756, 24780, 24781, 24782, 24783, ...], ('CENTRO OESTE', 'GNV'): [36196, 36211, 36226, 36241, 36256, 36271, 36286, 36301, 36316, 36331, 36346, 36361, 36377, 36393, 36409, 36425, 36441, 36457, 36473, 36489, 36505, 36521, 36537, 36553, 36569, 36585, 36601, 36617, 36633, 36649, 36665, 36681, 36697, 36713, 36729, 36745, 36761, 36777, 36793, 36809, 36825, 36841, 36857, 36873, 36889, 36905, 36921, 36937, 36953, 36969, 36985, 37001, 37017, 37033, 37049, 37065, 37081, 37097, 37113, 37129, 37145, 37161, 37177, 37193, 37209, 37225, 37242, 37257, 37258, 37274, 37290, 37307, 37322, 37338, 37353, 37368, 37383, 37399, 37415, 37430, 37446, 37462, 37478, 37494, 37510, 37526, 37542, 37558, 37574, 37590, 37606, 37621, 37637, 37653, 37669, 37686, 37702, 37718, 37734, 37750, ...], ('CENTRO OESTE', 'ÓLEO DIESEL'): [43547, 43548, 43549, 43550, 43574, 43575, 43576, 43577, 43601, 43602, 43603, 43604, 43628, 43629, 43630, 43631, 43655, 43656, 43657, 43658, 43682, 43683, 43684, 43685, 43709, 43710, 43711, 43712, 43736, 43737, 43738, 43739, 43763, 43764, 43765, 43766, 43790, 43791, 43792, 43793, 43817, 43818, 43819, 43820, 43844, 43845, 43846, 43847, 43871, 43872, 43873, 43874, 43898, 43899, 43900, 43901, 43925, 43926, 43927, 43928, 43952, 43953, 43954, 43955, 43979, 43980, 43981, 43982, 44006, 44007, 44008, 44009, 44033, 44034, 44035, 44036, 44060, 44061, 44062, 44063, 44087, 44088, 44089, 44090, 44114, 44115, 44116, 44117, 44141, 44142, 44143, 44144, 44168, 44169, 44170, 44171, 44195, 44196, 44197, 44198, ...], ('CENTRO OESTE', 'ÓLEO DIESEL S10'): [55672, 55674, 55819, 55821, 55822, 55967, 55969, 55971, 55972, 56119, 56121, 56123, 56124, 56272, 56274, 56276, 56277, 56425, 56427, 56429, 56430, 56577, 56579, 56581, 56582, 56729, 56731, 56733, 56734, 56882, 56884, 56886, 56887, 57035, 57037, 57039, 57040, 57187, 57189, 57191, 57192, 57339, 57341, 57343, 57344, 57490, 57492, 57494, 57495, 57642, 57644, 57646, 57647, 57795, 57797, 57799, 57800, 57947, 57949, 57951, 57952, 58099, 58101, 58103, 58104, 58251, 58253, 58255, 58256, 58402, ...

# %%
GRUPOS.mean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2453                 "mean",
# -> 2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455                 numeric_only=numeric_only,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#
# TypeError: Could not convert string '2004-05-092004-05-092004-05-092004-05-092004-05-162004-05-162004-05-162004-05-162004-05-232004-05-232004-05-232004-05-232004-05-302004-05-302004-05-302004-05-302004-06-062004-06-062004-06-062004-06-062004-06-132004-06-132004-06-132004-06-132004-06-202004-06-202004-06-202004-06-202004-06-272004-06-272004-06-272004-06-272004-07-042004-07-042004-07-042004-07-042004-07-112004-07-112004-07-112004-07-112004-07-182004-07-182004-07-182004-07-182004-07-252004-07-252004-07-252004-07-252004-08-012004-08-012004-08-012004-08-012004-08-082004-08-082004-08-082004-08-082004-08-152004-08-152004-08-152004-08-152004-08-222004-08-222004-08-222004-08-222004-08-292004-08-292004-08-292004-08-292004-09-052004-09-052004-09-052004-09-052004-09-122004-09-122004-09-122004-09-122004-09-192004-09-192004-09-192004-09-192004-09-262004-09-262004-09-262004-09-262004-10-032004-10-032004-10-032004-10-032004-10-102004-10-102004-10-102004-10-102004-10-172004-10-172004-10-172004-10-172004-10-242004-10-242004-10-242004-10-242004-10-312004-10-312004-10-312004-10-312004-11-072004-11-072004-11-072004-11-072004-11-142004-11-142004-11-142004-11-142004-11-212004-11-212004-11-212004-11-212004-11-282004-11-282004-11-282004-11-282004-12-052004-12-052004-12-052004-12-052004-12-122004-12-122004-12-122004-12-122004-12-192004-12-192004-12-192004-12-192004-12-262004-12-262004-12-262004-12-262005-01-022005-01-022005-01-022005-01-022005-01-092005-01-092005-01-092005-01-092005-01-1...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-727526141.py in <cell line: 0>()
# ----> 1 GRUPOS.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1467                 #  while others do not.
#    1468                 for sb in blk._split():
# -> 1469                     applied = sb.apply(func)
#    1470                     result_blocks = extend_blocks(applied, result_blocks)
#    1471             else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     391         one
#     392         """
# --> 393         result = func(self.values, **kwargs)
#     394
#     395         result = maybe_coerce_values(result)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1993
#    1994             assert alt is not None
# -> 1995             result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996             return result
#    1997
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1944             msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945             # preserve the kind of exception that raised
# -> 1946             raise type(err)(msg) from err
#    1947
#    1948         if ser.dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
GRUPOS['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3140.0   2.135950   0.561154   1.162   1.71600
#              GASOLINA COMUM    3140.0   3.078123   0.616315   1.936   2.66800
#              GLP               3137.0  48.181149  15.189152  28.791  37.34000
#              GNV               1523.0   2.004153   0.457802   1.097   1.59900
#              ÓLEO DIESEL       3140.0   2.481534   0.627607   1.435   2.03300
#              ÓLEO DIESEL S10   1349.0   3.241185   0.433797   2.212   2.82000
# NORDESTE     ETANOL HIDRATADO  7064.0   2.322075   0.605121   1.181   1.82500
#              GASOLINA COMUM    7065.0   3.002337   0.641163   1.949   2.58400
#              GLP               7061.0  42.221312  11.654978  28.367  33.59800
#              GNV               5575.0   1.925318   0.555183   0.975   1.60300
#              ÓLEO DIESEL       7065.0   2.347550   0.606381   1.313   1.90000
#              ÓLEO DIESEL S10   3039.0   3.041957   0.442555   2.130   2.60000
# NORTE        ETANOL HIDRATADO  5404.0   2.530796   0.655421   1.226   2.04600
#              GASOLINA COMUM    5494.0   3.149212   0.640964   1.995   2.70525
#              GLP               5494.0  47.174539  14.477296  28.086  36.50925
#              GNV                457.0   2.000190   0.602366   1.219   1.39900
#              ÓLEO DIESEL       5494.0   2.569905   0.650350   1.450   2.08800
#              ÓLEO DIESEL S10   2359.0   3.310619   0.533966   2.172   2.87800
# SUDESTE      ETANOL HIDRATADO  3140.0   2.164832   0.652355   0.766   1.69275
#              GASOLINA COMUM    3140.0   3.000565   0.698573   1.888   2.50200
#              GLP               3139.0  42.077813  11.522013  28.026  33.63850
#              GNV               3136.0   1.779684   0.507284   0.996   1.47300
#              ÓLEO DIESEL       3140.0   2.339699   0.588641   1.356   1.87600
#              ÓLEO DIESEL S10   1352.0   3.054425   0.419618   2.180   2.64700
# SUL          ETANOL HIDRATADO  2354.0   2.268864   0.703567   0.922   1.72100
#              GASOLINA COMUM    2355.0   2.973136   0.624032   1.961   2.54300
#              GLP               2355.0  43.535465  11.628193  29.440  34.82450
#              GNV               2343.0   1.907944   0.500694   1.168   1.51200
#              ÓLEO DIESEL       2355.0   2.332862   0.528454   1.374   1.95100
#              ÓLEO DIESEL S10   1014.0   2.981745   0.366952   2.140   2.66300
#
#                                    50%       75%     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   2.0010   2.47900   3.999
#              GASOLINA COMUM     2.8560   3.46025   4.963
#              GLP               42.8570  55.90500  99.357
#              GNV                1.9550   2.35250   3.890
#              ÓLEO DIESEL        2.2455   3.01900   4.162
#              ÓLEO DIESEL S10    3.2640   3.58400   4.200
# NORDESTE     ETANOL HIDRATADO   2.1880   2.67550   3.927
#              GASOLINA COMUM     2.7420   3.42500   4.951
#              GLP               37.5750  48.18300  79.630
#              GNV                1.8210   2.16850   3.811
#              ÓLEO DIESEL        2.0820   2.87300   4.114
#              ÓLEO DIESEL S10    3.0870   3.33800   4.069
# NORTE        ETANOL HIDRATADO   2.3430   2.93525   4.459
#              GASOLINA COMUM     2.9320   3.57975   5.362
#              GLP               42.4535  54.63575  87.270
#              GNV                1.8500   2.30000   4.020
#              ÓLEO DIESEL        2.3340   3.08000   4.774
#              ÓLEO DIESEL S10    3.3070   3.65300   4.878
# SUDESTE      ETANOL HIDRATADO   2.0435   2.57200   4.115
#              GASOLINA COMUM     2.7930   3.45150   5.119
#              GLP               38.2660  49.25100  79.192
#              GNV                1.6940   2.00300   3.594
#              ÓLEO DIESEL        2.0825   2.82500   3.994
#              ÓLEO DIESEL S10    3.0900   3.38600   4.080
# SUL          ETANOL HIDRATADO   2.1140   2.60325   4.287
#              GASOLINA COMUM     2.7320   3.34350   4.953
#              GLP               40.0470  51.41250  72.088
#              GNV                1.8000   2.19250   3.499
#              ÓLEO DIESEL        2.0900   2.78550   3.800
#              ÓLEO DIESEL S10    2.9910   3.25400   3.815

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None,None,None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum,min])
# Out:
# /tmp/ipython-input-1413054331.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum,min])
# /tmp/ipython-input-1413054331.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum,min])
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby("REGIÃO")
grupos

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([min,max])
# Out:
# /tmp/ipython-input-2084642471.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min,max])
# /tmp/ipython-input-2084642471.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min,max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.219  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by=['nota_final','nome'],ascending=[False, True],inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_final.query('ANO != 2019')
default = data_final

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
grupos = default.groupby("PRODUTO")
default

# %%
d
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.9666
# 1                          0.5013                      1.05
# 2                          0.5614                     1.161
# 3                          0.5991                   1.22242
# 4                          0.7441                    1.0317
# ...                           ...                       ...
# 106818                      2.756                     2.756
# 106819                     1.9842                    2.8661
# 106820                     1.9981                    1.9981
# 106821                     2.0179                    2.5093
# 106822                     2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem noçao  \
# 0                              0.133   5  2004          default
# 1                              0.115   5  2004          default
# 2                              0.098   5  2004          default
# 3                              0.143   5  2004          default
# 4                              0.082   5  2004          default
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          default
# 106819                         0.164   6  2019          default
# 106820                             0   6  2019          default
# 106821                          0.07   6  2019          default
# 106822                             0   6  2019          default
#
#         coluna a partir de lista  PREÇO DE MEDIA (dolares)
# 0                              0                     7.728
# 1                              1                     6.972
# 2                              2                     8.334
# 3                              3                     7.572
# 4                              4                     7.086
# ...                          ...                       ...
# 106818                    106818                    21.444
# 106819                    106819                    20.406
# 106820                    106820                    17.472
# 106821                    106821                    18.120
# 106822                    106822                    22.182
#
# [106823 rows x 23 columns]

# %%
grupos['REGIÃO'].value_counts()
# Out:
# PRODUTO           REGIÃO
# ETANOL HIDRATADO  NORDESTE        7064
#                   NORTE           5404
#                   CENTRO OESTE    3140
#                   SUDESTE         3140
#                   SUL             2354
# GASOLINA COMUM    NORDESTE        7065
#                   NORTE           5494
#                   CENTRO OESTE    3140
#                   SUDESTE         3140
#                   SUL             2355
# GLP               NORDESTE        7061
#                   NORTE           5494
#                   SUDESTE         3139
#                   CENTRO OESTE    3137
#                   SUL             2355
# GNV               NORDESTE        5575
#                   SUDESTE         3136
#                   SUL             2343
#                   CENTRO OESTE    1523
#                   NORTE            457
# ÓLEO DIESEL       NORDESTE        7065
#                   NORTE           5494
#                   CENTRO OESTE    3140
#                   SUDESTE         3140
#                   SUL             2355
# ÓLEO DIESEL S10   NORDESTE        3039
#                   NORTE           2359
#                   SUDESTE         1352
#                   CENTRO OESTE    1349
#                   SUL             1014
# Name: count, dtype: int64

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
gasolina_sp_2018 =default.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO== 2018' )
gasolina_sp_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95351                          1641              R$/l                3.988
# 95502                          1648              R$/l                4.002
# 95654                          1648              R$/l                4.006
# 95806                          1644              R$/l                4.019
# 95958                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 95351                  0.156                 3.499  ...
# 95502                  0.155                 3.549  ...
# 95654                  0.160                 3.499  ...
# 95806                  0.156                 3.579  ...
# 95958                  0.157                 3.579  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 95351                     3.577                      0.104
# 95502                      3.59                      0.102
# 95654                     3.596                      0.102
# 95806                     3.596                      0.107
# 95958                     3.588                      0.102
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 95351                       2.99                     3.951
# 95502                       2.99                    3.9014
# 95654                       2.99                    3.9014
# 95806                      2.924                    3.9537
# 95958                       2.99                    3.9537
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem noçao  \
# 95351                         0.029   1  2018          default
# 95502                         0.028   1  2018          default
# 95654                         0.028   1  2018          default
# 95806                          0.03   1  2018          default
# 95958                         0.028   2  2018          default
#
#        coluna a partir de lista  PREÇO DE MEDIA (dolares)
# 95351                     95351                    23.928
# 95502                     95502                    24.012
# 95654                     95654                    24.036
# 95806                     95806                    24.114
# 95958                     95958                    24.024
#
# [5 rows x 23 columns]

# %%
gasolina_sp_2018.shape
# Out:
# (52, 23)

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
gasolina_sp_2018.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# 50%                 0.173000              3.679000              4.999000
# 75%                 0.189000              3.784000              5.099000
# max                 0.216000              3.969000              5.299000
#
#        COEF DE VARIAÇÃO REVENDA        MÊS     ANO  coluna a partir de lista  \
# count                 52.000000  52.000000    52.0                 52.000000
# mean                   0.041750   6.615385  2018.0              99196.096154
# std                    0.003965   3.470627     0.0               2279.595314
# min                    0.034000   1.000000  2018.0              95351.000000
# 25%                    0.039000   4.000000  2018.0              97281.250000
# 50%                    0.040000   7.000000  2018.0              99196.500000
# 75%                    0.044000   9.250000  2018.0             101116.250000
# max                    0.051000  12.000000  2018.0             103025.000000
#
#        PREÇO DE MEDIA (dolares)
# count                 52.000000
# mean                  25.216615
# std                    1.084032
# min                   23.820000
# 25%                   24.048000
# 50%                   25.212000
# 75%                   26.017500
# max                   27.072000

# %%
gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    52.000000
# mean      4.202769
# std       0.180672
# min       3.970000
# 25%       4.008000
# 50%       4.202000
# 75%       4.336250
# max       4.512000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
 etanol_sp=default.query('(PRODUTO == "ETANOL HIDRATADO" or PRODUTO== "GASOLINA COMUM") and ESTADO == "SAO PAULO" and ANO== 2018' )

# %%
etanol_sp['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
etanol_sp.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
